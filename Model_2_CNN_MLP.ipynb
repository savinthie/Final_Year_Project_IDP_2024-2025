# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_IDP_2024-2025/blob/main/Model_2_CNN_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
df = df.fillna(0)
# Out:
# Mounted at /content/drive

# %%
# Data Preprocessing

df.columns = [col.lower().replace(' ', '').replace('.', '') for col in df.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
df1 = df[cols_to_keep].copy()

df1['median_family_income'] = df1['median_family_income'].replace(',', '', regex=True).astype(float)
df1['median_family_income'] = df1['median_family_income'].map(lambda x: x/12)

# %%
# Feature Engineering
df1['n_parents'] = df1['family'].str.slice(0, 1).astype(int)
df1['n_children'] = df1['family'].str.slice(2, 3).astype(int)
df1['n_members'] = df1['n_parents'] + df1['n_children']
df1['financial_stability'] = df1['median_family_income'] / df1['total']
df1["per_member_cost"] = df1["total"] / df1["n_members"]
df1["child_expense_cost"] = df1["per_member_cost"]*df1["n_children"]
df1["parent_expense_cost"] = df1["per_member_cost"]*df1["n_parents"]
df1["other_expense_cost"] = df1["total"] - (df1["child_expense_cost"]+df1["parent_expense_cost"])

df1["zero_childcare_cost"] = df1['n_children'].map(lambda x: 0 if x < 1 else 1)

# %%
# Splitting the data
X = df1[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost','zero_childcare_cost']].values
y_expenses = df1[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = MinMaxScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)


# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
def replace_zeros_with_ones(a, b):
    # Iterate through both lists simultaneously
    for i in range(len(a)):
        # If both value is 0, replace both with 1
        if a[i] == 0 and b[i] == 0:
            a[i] = 1
            b[i] = 1
    return a, b

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def calculateSmape(y_true, y_pred):
    """
    Calculate Symmetric Mean Absolute Percentage Error (SMAPE).

    Parameters:
    y_true (array-like): Actual values.
    y_pred (array-like): Predicted values.

    Returns:
    float: SMAPE value.
    """
    y_true, y_pred = replace_zeros_with_ones(y_true, y_pred)
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_value = np.mean(numerator / denominator) * 100
    return smape_value

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    smape_score = calculateSmape(x, y)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse} ,smape: {smape_score}'

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import xgboost as xgb

num_children_col = 3  # 4th position, 0-indexed
childcare_exp_col = target_col_list.index('childcare')  # Replace 'childcare_exp' with the actual target name

# %%
from tensorflow.keras.layers import Input, Conv1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# L2 regularization strength (you can tune this value)
l2_strength = 0.01

# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
global X_train_global, X_test_global, X_val_global
global y_train_global, y_test_global, y_val_global

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    global X_train_global, X_test_global, X_val_global
    global y_train_global, y_test_global, y_val_global
    fold = 1
    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100) # 50/50 split of remaining 20%

        X_train_global, X_test_global, X_val_global = X_train, X_test, X_val
        y_train_global, y_test_global, y_val_global = y_train, y_test, y_val

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        model.summary()

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Training
        model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks= [early_stopping])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test)) #Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test) #Inverse transform for test set

        # Enforce the rule after predictions for childcare expense
        # The issue is likely caused by X_train having an extra dimension due to[..., np.newaxis].
        # We need to select the original features for the condition
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col, 0] == 0, 0, y_train_pred_original[:, childcare_exp_col]) #Using X_train[:, num_children_col, 0] instead of X_train[:, num_children_col]

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col, 0] == 0, 0, y_val_pred_original[:, childcare_exp_col]) #Using X_val[:, num_children_col, 0] instead of X_val[:, num_children_col]

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col]) #Using X_test[:, num_children_col, 0] instead of X_test[:, num_children_col]

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return model

model_combine = cross_val_with_evaluation(X_scaled, y_exp_scaled,kf)
# Out:
# Fold 1/5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 11, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 11, 8)          │             32 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 88)             │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         11,392 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_healthcare (Dense) │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_othernecessities   │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_childcare (Dense)  │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_taxes (Dense)      │ (None, 1)              │             65 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,135 (78.65 KB)
#  Trainable params: 20,135 (78.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0478 - target_childcare_loss: 0.0051 - target_food_loss: 0.0030 - target_healthcare_loss: 0.0122 - target_housing_loss: 0.0037 - target_othernecessities_loss: 0.0049 - target_taxes_loss: 0.0029 - target_transportation_loss: 0.0160 - val_loss: 0.0136 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.2947e-04 - val_target_healthcare_loss: 0.0048 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.8543e-04 - val_target_taxes_loss: 4.5139e-04 - val_target_transportation_loss: 0.0035
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0135 - target_childcare_loss: 0.0021 - target_food_loss: 6.1739e-04 - target_healthcare_loss: 0.0049 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.9619e-04 - target_taxes_loss: 4.5744e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0132 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.4218e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.1743e-04 - val_target_taxes_loss: 4.6580e-04 - val_target_transportation_loss: 0.0035
# Epoch 3/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0135 - target_childcare_loss: 0.0021 - target_food_loss: 6.0795e-04 - target_healthcare_loss: 0.0049 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.6970e-04 - target_taxes_loss: 4.3313e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.7684e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.3240e-04 - val_target_taxes_loss: 4.1811e-04 - val_target_transportation_loss: 0.0034
# Epoch 4/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0131 - target_childcare_loss: 0.0020 - target_food_loss: 6.6312e-04 - target_healthcare_loss: 0.0048 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.4993e-04 - target_taxes_loss: 4.1327e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.6877e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9891e-04 - val_target_taxes_loss: 3.7988e-04 - val_target_transportation_loss: 0.0035
# Epoch 5/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0128 - target_childcare_loss: 0.0020 - target_food_loss: 5.4828e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.1516e-04 - target_taxes_loss: 3.8689e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0124 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.6292e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.9389e-04 - val_target_taxes_loss: 3.8830e-04 - val_target_transportation_loss: 0.0034
# Epoch 6/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0127 - target_childcare_loss: 0.0020 - target_food_loss: 5.5923e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9593e-04 - target_taxes_loss: 3.8389e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0129 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 4.7679e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.3379e-04 - val_target_taxes_loss: 4.9580e-04 - val_target_transportation_loss: 0.0034
# Epoch 7/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0128 - target_childcare_loss: 0.0020 - target_food_loss: 5.7831e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.0868e-04 - target_taxes_loss: 3.8303e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0123 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.1416e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6838e-04 - val_target_taxes_loss: 3.7484e-04 - val_target_transportation_loss: 0.0034
# Epoch 8/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0128 - target_childcare_loss: 0.0020 - target_food_loss: 5.6710e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.0047e-04 - target_taxes_loss: 3.8645e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8450e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9215e-04 - val_target_taxes_loss: 3.7459e-04 - val_target_transportation_loss: 0.0036
# Epoch 9/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.6678e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.6214e-04 - target_taxes_loss: 3.9210e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0124 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.5655e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5083e-04 - val_target_taxes_loss: 4.0552e-04 - val_target_transportation_loss: 0.0034
# Epoch 10/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.2338e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3516e-04 - target_taxes_loss: 3.6725e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0125 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 4.5653e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.7270e-04 - val_target_taxes_loss: 4.0219e-04 - val_target_transportation_loss: 0.0034
# Epoch 11/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.8603e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4337e-04 - target_taxes_loss: 3.7681e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.0343e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.9785e-04 - val_target_taxes_loss: 3.8122e-04 - val_target_transportation_loss: 0.0034
# Epoch 12/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0124 - target_childcare_loss: 0.0020 - target_food_loss: 5.4601e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.7210e-04 - target_taxes_loss: 3.6107e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8371e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.1970e-04 - val_target_taxes_loss: 3.6446e-04 - val_target_transportation_loss: 0.0033
# Epoch 13/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.5380e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5398e-04 - target_taxes_loss: 3.7163e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0123 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.0165e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.4963e-04 - val_target_taxes_loss: 3.6654e-04 - val_target_transportation_loss: 0.0033
# Epoch 14/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.3611e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4623e-04 - target_taxes_loss: 3.7358e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4593e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5142e-04 - val_target_taxes_loss: 3.6137e-04 - val_target_transportation_loss: 0.0033
# Epoch 15/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.6052e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5423e-04 - target_taxes_loss: 3.7399e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0120 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6504e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6225e-04 - val_target_taxes_loss: 4.0084e-04 - val_target_transportation_loss: 0.0033
# Epoch 16/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.3668e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3739e-04 - target_taxes_loss: 3.6721e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5723e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4870e-04 - val_target_taxes_loss: 3.6604e-04 - val_target_transportation_loss: 0.0034
# Epoch 17/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.3385e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2127e-04 - target_taxes_loss: 3.5346e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4991e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3637e-04 - val_target_taxes_loss: 4.7540e-04 - val_target_transportation_loss: 0.0033
# Epoch 18/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.3178e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0992e-04 - target_taxes_loss: 3.5000e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0120 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4557e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4579e-04 - val_target_taxes_loss: 3.6759e-04 - val_target_transportation_loss: 0.0035
# Epoch 19/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0120 - target_childcare_loss: 0.0019 - target_food_loss: 5.5266e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4803e-04 - target_taxes_loss: 3.6334e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5855e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2991e-04 - val_target_taxes_loss: 3.5824e-04 - val_target_transportation_loss: 0.0033
# Epoch 20/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.5441e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2375e-04 - target_taxes_loss: 3.5262e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0116 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4808e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3120e-04 - val_target_taxes_loss: 3.6632e-04 - val_target_transportation_loss: 0.0033
# Epoch 21/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0018 - target_food_loss: 5.6072e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3385e-04 - target_taxes_loss: 3.6596e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0116 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6894e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3352e-04 - val_target_taxes_loss: 3.5367e-04 - val_target_transportation_loss: 0.0033
# Epoch 22/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0018 - target_food_loss: 5.2188e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1333e-04 - target_taxes_loss: 3.7116e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0115 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.8459e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3814e-04 - val_target_taxes_loss: 3.6811e-04 - val_target_transportation_loss: 0.0033
# Epoch 23/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0114 - target_childcare_loss: 0.0017 - target_food_loss: 5.1316e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0028e-04 - target_taxes_loss: 3.5161e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0114 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5458e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1732e-04 - val_target_taxes_loss: 3.4632e-04 - val_target_transportation_loss: 0.0033
# Epoch 24/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.3883e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4517e-04 - target_taxes_loss: 3.5915e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0114 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6363e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3304e-04 - val_target_taxes_loss: 3.4688e-04 - val_target_transportation_loss: 0.0034
# Epoch 25/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.5915e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1948e-04 - target_taxes_loss: 3.5151e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5407e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4312e-04 - val_target_taxes_loss: 3.4727e-04 - val_target_transportation_loss: 0.0033
# Epoch 26/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.3485e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0230e-04 - target_taxes_loss: 3.5756e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4332e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0752e-04 - val_target_taxes_loss: 3.5570e-04 - val_target_transportation_loss: 0.0032
# Epoch 27/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0112 - target_childcare_loss: 0.0017 - target_food_loss: 5.1561e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0905e-04 - target_taxes_loss: 3.5157e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0110 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.3234e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1470e-04 - val_target_taxes_loss: 3.4262e-04 - val_target_transportation_loss: 0.0033
# Epoch 28/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 4.9172e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0184e-04 - target_taxes_loss: 3.4441e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.6605e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0895e-04 - val_target_taxes_loss: 3.3646e-04 - val_target_transportation_loss: 0.0032
# Epoch 29/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.3550e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0776e-04 - target_taxes_loss: 3.4619e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3586e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0687e-04 - val_target_taxes_loss: 3.4877e-04 - val_target_transportation_loss: 0.0032
# Epoch 30/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.3859e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0954e-04 - target_taxes_loss: 3.3721e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3395e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1484e-04 - val_target_taxes_loss: 3.6599e-04 - val_target_transportation_loss: 0.0033
# Epoch 31/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.2454e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8787e-04 - target_taxes_loss: 3.3179e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5380e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1064e-04 - val_target_taxes_loss: 3.6938e-04 - val_target_transportation_loss: 0.0032
# Epoch 32/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.0866e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0038e-04 - target_taxes_loss: 3.4357e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3648e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1795e-04 - val_target_taxes_loss: 4.0963e-04 - val_target_transportation_loss: 0.0032
# Epoch 33/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.4423e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9868e-04 - target_taxes_loss: 3.4159e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4758e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.1328e-04 - val_target_taxes_loss: 3.4638e-04 - val_target_transportation_loss: 0.0032
# Epoch 34/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.3303e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9234e-04 - target_taxes_loss: 3.3325e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4120e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2510e-04 - val_target_taxes_loss: 3.4277e-04 - val_target_transportation_loss: 0.0032
# Epoch 35/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.3326e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0841e-04 - target_taxes_loss: 3.4371e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4370e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2857e-04 - val_target_taxes_loss: 3.5289e-04 - val_target_transportation_loss: 0.0032
# Epoch 36/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1798e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8251e-04 - target_taxes_loss: 3.3120e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3241e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0119e-04 - val_target_taxes_loss: 3.4114e-04 - val_target_transportation_loss: 0.0032
# Epoch 37/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.0427e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6859e-04 - target_taxes_loss: 3.2734e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4406e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0320e-04 - val_target_taxes_loss: 3.4228e-04 - val_target_transportation_loss: 0.0031
# Epoch 38/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.2798e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8267e-04 - target_taxes_loss: 3.3170e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0606e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7055e-04 - val_target_taxes_loss: 3.5394e-04 - val_target_transportation_loss: 0.0031
# Epoch 39/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.3753e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0727e-04 - target_taxes_loss: 3.3245e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4302e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9611e-04 - val_target_taxes_loss: 3.3906e-04 - val_target_transportation_loss: 0.0031
# Epoch 40/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.3684e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.9048e-04 - target_othernecessities_loss: 6.6030e-04 - target_taxes_loss: 3.1480e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4587e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9159e-04 - val_target_taxes_loss: 3.3443e-04 - val_target_transportation_loss: 0.0031
# Epoch 41/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.2556e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7491e-04 - target_taxes_loss: 3.2350e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.8923e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0357e-04 - val_target_taxes_loss: 3.7100e-04 - val_target_transportation_loss: 0.0031
# Epoch 42/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.1960e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9039e-04 - target_taxes_loss: 3.1908e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4105e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7414e-04 - val_target_taxes_loss: 3.2647e-04 - val_target_transportation_loss: 0.0032
# Epoch 43/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 4.9583e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8136e-04 - target_taxes_loss: 3.2581e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7365e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9039e-04 - val_target_taxes_loss: 3.5365e-04 - val_target_transportation_loss: 0.0032
# Epoch 44/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 4.8899e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7903e-04 - target_taxes_loss: 3.3484e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3868e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1500e-04 - val_target_taxes_loss: 3.2972e-04 - val_target_transportation_loss: 0.0031
# Epoch 45/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.2619e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8556e-04 - target_taxes_loss: 3.2609e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3905e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.1957e-04 - val_target_taxes_loss: 3.7882e-04 - val_target_transportation_loss: 0.0031
# Epoch 46/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.1166e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8964e-04 - target_taxes_loss: 3.2419e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4056e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0235e-04 - val_target_taxes_loss: 3.4526e-04 - val_target_transportation_loss: 0.0033
# Epoch 47/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.0756e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6546e-04 - target_taxes_loss: 3.1917e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0107 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5147e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8429e-04 - val_target_taxes_loss: 3.8331e-04 - val_target_transportation_loss: 0.0032
# Epoch 48/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.1233e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.9349e-04 - target_othernecessities_loss: 6.6509e-04 - target_taxes_loss: 3.1594e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3558e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7660e-04 - val_target_taxes_loss: 3.2318e-04 - val_target_transportation_loss: 0.0031
# Epoch 49/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.1879e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7457e-04 - target_taxes_loss: 3.2464e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3397e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0499e-04 - val_target_taxes_loss: 3.5599e-04 - val_target_transportation_loss: 0.0031
# Epoch 50/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 4.9725e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7307e-04 - target_taxes_loss: 3.2274e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4095e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8008e-04 - val_target_taxes_loss: 3.1569e-04 - val_target_transportation_loss: 0.0031
# Epoch 51/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.1933e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.6683e-04 - target_othernecessities_loss: 6.4630e-04 - target_taxes_loss: 3.1153e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3256e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6922e-04 - val_target_taxes_loss: 3.2147e-04 - val_target_transportation_loss: 0.0031
# Epoch 52/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.0053e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7636e-04 - target_taxes_loss: 3.1603e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4239e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8595e-04 - val_target_taxes_loss: 3.3598e-04 - val_target_transportation_loss: 0.0030
# Epoch 53/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 5.1041e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.7808e-04 - target_othernecessities_loss: 6.5047e-04 - target_taxes_loss: 3.2131e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7243e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.8719e-04 - val_target_othernecessities_loss: 6.6869e-04 - val_target_taxes_loss: 3.5876e-04 - val_target_transportation_loss: 0.0032
# Epoch 54/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.8750e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.7813e-04 - target_othernecessities_loss: 6.4564e-04 - target_taxes_loss: 3.1570e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3472e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.9618e-04 - val_target_othernecessities_loss: 6.6817e-04 - val_target_taxes_loss: 3.5113e-04 - val_target_transportation_loss: 0.0031
# Epoch 55/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 5.1650e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.9419e-04 - target_othernecessities_loss: 6.5636e-04 - target_taxes_loss: 3.1133e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0104 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5899e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8187e-04 - val_target_taxes_loss: 3.3498e-04 - val_target_transportation_loss: 0.0032
# Epoch 56/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.2407e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6956e-04 - target_taxes_loss: 3.2796e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3318e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6187e-04 - val_target_taxes_loss: 3.3745e-04 - val_target_transportation_loss: 0.0030
# Epoch 57/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 5.0637e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.7817e-04 - target_othernecessities_loss: 6.4344e-04 - target_taxes_loss: 3.1337e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3309e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8706e-04 - val_target_taxes_loss: 3.1391e-04 - val_target_transportation_loss: 0.0030
# Epoch 58/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 5.1709e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.8149e-04 - target_othernecessities_loss: 6.4588e-04 - target_taxes_loss: 3.1813e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3149e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.9288e-04 - val_target_othernecessities_loss: 6.6557e-04 - val_target_taxes_loss: 3.2136e-04 - val_target_transportation_loss: 0.0030
# Epoch 59/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 5.0675e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.5847e-04 - target_taxes_loss: 3.1715e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2890e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8443e-04 - val_target_othernecessities_loss: 6.5581e-04 - val_target_taxes_loss: 3.2772e-04 - val_target_transportation_loss: 0.0031
# Epoch 60/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.7904e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.6407e-04 - target_othernecessities_loss: 6.3017e-04 - target_taxes_loss: 3.0642e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3707e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.7742e-04 - val_target_othernecessities_loss: 6.5427e-04 - val_target_taxes_loss: 3.1748e-04 - val_target_transportation_loss: 0.0030
# Epoch 61/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9992e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.5432e-04 - target_taxes_loss: 3.2179e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3408e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.7591e-04 - val_target_othernecessities_loss: 6.5348e-04 - val_target_taxes_loss: 3.2645e-04 - val_target_transportation_loss: 0.0030
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.9654e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7494e-04 - target_othernecessities_loss: 6.4758e-04 - target_taxes_loss: 3.1159e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0101 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.5095e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 9.9781e-04 - val_target_othernecessities_loss: 6.5207e-04 - val_target_taxes_loss: 3.1466e-04 - val_target_transportation_loss: 0.0030
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 5.1426e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8506e-04 - target_othernecessities_loss: 6.3529e-04 - target_taxes_loss: 3.1486e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.6997e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.9763e-04 - val_target_othernecessities_loss: 6.8581e-04 - val_target_taxes_loss: 3.4142e-04 - val_target_transportation_loss: 0.0030
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.1832e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7872e-04 - target_othernecessities_loss: 6.5621e-04 - target_taxes_loss: 3.0781e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2131e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.8715e-04 - val_target_othernecessities_loss: 6.4935e-04 - val_target_taxes_loss: 3.1744e-04 - val_target_transportation_loss: 0.0031
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0591e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.8803e-04 - target_othernecessities_loss: 6.4445e-04 - target_taxes_loss: 3.0219e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3851e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.6670e-04 - val_target_othernecessities_loss: 6.3685e-04 - val_target_taxes_loss: 3.1878e-04 - val_target_transportation_loss: 0.0030
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 5.2947e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.6961e-04 - target_othernecessities_loss: 6.1998e-04 - target_taxes_loss: 3.1103e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4256e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.6844e-04 - val_target_othernecessities_loss: 6.2600e-04 - val_target_taxes_loss: 3.2337e-04 - val_target_transportation_loss: 0.0030
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 5.0549e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.6497e-04 - target_othernecessities_loss: 6.3291e-04 - target_taxes_loss: 3.0977e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3161e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.3656e-04 - val_target_othernecessities_loss: 6.0395e-04 - val_target_taxes_loss: 3.1108e-04 - val_target_transportation_loss: 0.0030
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.9145e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5690e-04 - target_othernecessities_loss: 6.2944e-04 - target_taxes_loss: 3.1265e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3968e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.4333e-04 - val_target_othernecessities_loss: 6.1335e-04 - val_target_taxes_loss: 3.0966e-04 - val_target_transportation_loss: 0.0030
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.7996e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4156e-04 - target_othernecessities_loss: 6.1282e-04 - target_taxes_loss: 3.0733e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4741e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.5553e-04 - val_target_othernecessities_loss: 6.2058e-04 - val_target_taxes_loss: 3.1761e-04 - val_target_transportation_loss: 0.0030
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.9285e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5396e-04 - target_othernecessities_loss: 6.0683e-04 - target_taxes_loss: 3.0854e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.1899e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.4451e-04 - val_target_othernecessities_loss: 6.0924e-04 - val_target_taxes_loss: 3.3137e-04 - val_target_transportation_loss: 0.0030
# Epoch 71/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 5.1371e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3402e-04 - target_othernecessities_loss: 6.0881e-04 - target_taxes_loss: 2.9829e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2320e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3157e-04 - val_target_othernecessities_loss: 6.0193e-04 - val_target_taxes_loss: 3.1869e-04 - val_target_transportation_loss: 0.0029
# Epoch 72/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0582e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7363e-04 - target_othernecessities_loss: 6.2060e-04 - target_taxes_loss: 3.0907e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2805e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3507e-04 - val_target_othernecessities_loss: 6.0394e-04 - val_target_taxes_loss: 3.1030e-04 - val_target_transportation_loss: 0.0030
# Epoch 73/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 5.2206e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4776e-04 - target_othernecessities_loss: 6.1775e-04 - target_taxes_loss: 2.9635e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2179e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3350e-04 - val_target_othernecessities_loss: 6.0744e-04 - val_target_taxes_loss: 3.2897e-04 - val_target_transportation_loss: 0.0031
# Epoch 74/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 5.0031e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4890e-04 - target_othernecessities_loss: 6.1269e-04 - target_taxes_loss: 3.0693e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3254e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3126e-04 - val_target_othernecessities_loss: 6.2790e-04 - val_target_taxes_loss: 3.0884e-04 - val_target_transportation_loss: 0.0030
# Epoch 75/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7568e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3672e-04 - target_othernecessities_loss: 6.1234e-04 - target_taxes_loss: 3.0866e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2602e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.7337e-04 - val_target_othernecessities_loss: 6.5729e-04 - val_target_taxes_loss: 3.0635e-04 - val_target_transportation_loss: 0.0029
# Epoch 76/200
# ...
# Epoch 77/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7213e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.3181e-04 - target_othernecessities_loss: 5.9714e-04 - target_taxes_loss: 2.8828e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6428e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.7718e-04 - val_target_othernecessities_loss: 5.6154e-04 - val_target_taxes_loss: 2.8552e-04 - val_target_transportation_loss: 0.0028
# Epoch 78/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.9823e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.2901e-04 - target_othernecessities_loss: 5.9646e-04 - target_taxes_loss: 2.8674e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6896e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.0966e-04 - val_target_othernecessities_loss: 5.8855e-04 - val_target_taxes_loss: 2.9832e-04 - val_target_transportation_loss: 0.0028
# Epoch 79/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6651e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9354e-04 - target_othernecessities_loss: 5.8352e-04 - target_taxes_loss: 2.8324e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6805e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.8164e-04 - val_target_othernecessities_loss: 5.6151e-04 - val_target_taxes_loss: 2.8715e-04 - val_target_transportation_loss: 0.0028
# Epoch 80/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.8505e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.5984e-04 - target_othernecessities_loss: 5.6372e-04 - target_taxes_loss: 2.9141e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6875e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9256e-04 - val_target_othernecessities_loss: 5.5570e-04 - val_target_taxes_loss: 2.9608e-04 - val_target_transportation_loss: 0.0028
# Epoch 81/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.6901e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1457e-04 - target_othernecessities_loss: 5.7890e-04 - target_taxes_loss: 2.9280e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7099e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.1482e-04 - val_target_othernecessities_loss: 5.7509e-04 - val_target_taxes_loss: 2.8246e-04 - val_target_transportation_loss: 0.0027
# Epoch 82/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6441e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.5441e-04 - target_othernecessities_loss: 6.0261e-04 - target_taxes_loss: 2.9687e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6096e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 8.7115e-04 - val_target_othernecessities_loss: 5.6051e-04 - val_target_taxes_loss: 3.0060e-04 - val_target_transportation_loss: 0.0028
# Epoch 83/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7727e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8500e-04 - target_othernecessities_loss: 5.6579e-04 - target_taxes_loss: 2.9007e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6196e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.1516e-04 - val_target_othernecessities_loss: 5.9424e-04 - val_target_taxes_loss: 3.0059e-04 - val_target_transportation_loss: 0.0027
# Epoch 84/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6323e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9830e-04 - target_othernecessities_loss: 5.6975e-04 - target_taxes_loss: 2.8906e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7254e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6357e-04 - val_target_othernecessities_loss: 5.5741e-04 - val_target_taxes_loss: 2.8594e-04 - val_target_transportation_loss: 0.0028
# Epoch 85/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.8104e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1654e-04 - target_othernecessities_loss: 5.8074e-04 - target_taxes_loss: 2.8705e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6039e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.5654e-04 - val_target_othernecessities_loss: 5.9864e-04 - val_target_taxes_loss: 3.0779e-04 - val_target_transportation_loss: 0.0028
# Epoch 86/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.6697e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.8839e-04 - target_othernecessities_loss: 5.7095e-04 - target_taxes_loss: 2.9394e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7180e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6718e-04 - val_target_othernecessities_loss: 5.5028e-04 - val_target_taxes_loss: 2.8811e-04 - val_target_transportation_loss: 0.0027
# Epoch 87/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.8354e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9125e-04 - target_othernecessities_loss: 5.7066e-04 - target_taxes_loss: 2.8643e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.0419e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9009e-04 - val_target_othernecessities_loss: 5.5447e-04 - val_target_taxes_loss: 3.0358e-04 - val_target_transportation_loss: 0.0027
# Epoch 88/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 5.0877e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.2507e-04 - target_othernecessities_loss: 5.9302e-04 - target_taxes_loss: 2.8684e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6778e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.5258e-04 - val_target_othernecessities_loss: 5.5014e-04 - val_target_taxes_loss: 2.9375e-04 - val_target_transportation_loss: 0.0027
# Epoch 89/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6313e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 9.2804e-04 - target_othernecessities_loss: 5.9399e-04 - target_taxes_loss: 2.7919e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.2657e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.8724e-04 - val_target_othernecessities_loss: 5.4684e-04 - val_target_taxes_loss: 2.7952e-04 - val_target_transportation_loss: 0.0027
# Epoch 90/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.8483e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9922e-04 - target_othernecessities_loss: 5.7547e-04 - target_taxes_loss: 2.8820e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.0918e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7151e-04 - val_target_othernecessities_loss: 5.5765e-04 - val_target_taxes_loss: 2.9808e-04 - val_target_transportation_loss: 0.0028
# Epoch 91/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.5489e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.7757e-04 - target_othernecessities_loss: 5.6461e-04 - target_taxes_loss: 2.8251e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.5990e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.8162e-04 - val_target_othernecessities_loss: 5.5563e-04 - val_target_taxes_loss: 3.0362e-04 - val_target_transportation_loss: 0.0027
# Epoch 92/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.6263e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.5727e-04 - target_othernecessities_loss: 5.5023e-04 - target_taxes_loss: 2.8503e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6664e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.0776e-04 - val_target_othernecessities_loss: 5.8020e-04 - val_target_taxes_loss: 2.9446e-04 - val_target_transportation_loss: 0.0027
# Epoch 93/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0091 - target_childcare_loss: 0.0012 - target_food_loss: 4.7359e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.8966e-04 - target_othernecessities_loss: 5.6799e-04 - target_taxes_loss: 2.7858e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.5569e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.5488e-04 - val_target_othernecessities_loss: 5.4457e-04 - val_target_taxes_loss: 2.8564e-04 - val_target_transportation_loss: 0.0027
# Epoch 94/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.5504e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.9983e-04 - target_othernecessities_loss: 5.7100e-04 - target_taxes_loss: 2.8454e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6518e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.0481e-04 - val_target_othernecessities_loss: 5.7766e-04 - val_target_taxes_loss: 2.8737e-04 - val_target_transportation_loss: 0.0027
# Epoch 95/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0091 - target_childcare_loss: 0.0012 - target_food_loss: 4.8551e-04 - target_healthcare_loss: 0.0027 - target_housing_loss: 9.0615e-04 - target_othernecessities_loss: 5.7641e-04 - target_taxes_loss: 2.8309e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0091 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.7133e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.5140e-04 - val_target_othernecessities_loss: 5.4031e-04 - val_target_taxes_loss: 2.8225e-04 - val_target_transportation_loss: 0.0027
# Epoch 96/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0090 - target_childcare_loss: 0.0013 - target_food_loss: 4.7666e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.7133e-04 - target_othernecessities_loss: 5.5826e-04 - target_taxes_loss: 2.9039e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.9798e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.0367e-04 - val_target_othernecessities_loss: 5.5796e-04 - val_target_taxes_loss: 2.8406e-04 - val_target_transportation_loss: 0.0027
# Epoch 97/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0091 - target_childcare_loss: 0.0012 - target_food_loss: 4.5490e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.9139e-04 - target_othernecessities_loss: 5.7061e-04 - target_taxes_loss: 2.7562e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.5424e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.1054e-04 - val_target_othernecessities_loss: 5.7590e-04 - val_target_taxes_loss: 2.8513e-04 - val_target_transportation_loss: 0.0027
# Epoch 98/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0090 - target_childcare_loss: 0.0012 - target_food_loss: 4.4562e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.8878e-04 - target_othernecessities_loss: 5.7654e-04 - target_taxes_loss: 2.8237e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.7324e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.6171e-04 - val_target_othernecessities_loss: 5.5639e-04 - val_target_taxes_loss: 3.5432e-04 - val_target_transportation_loss: 0.0027
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model Results for Housing:
# Train Data: MAE: 81.5202, R-Squared: 0.9082, RMSE: 117.2921, MSE: 13757.4482 ,smape: 7.628331594269581
# Validation Data: MAE: 82.367, R-Squared: 0.8974, RMSE: 116.4621, MSE: 13563.4281 ,smape: 7.67188318442847
# Test Data: MAE: 83.1941, R-Squared: 0.9034, RMSE: 120.9808, MSE: 14636.3595 ,smape: 7.753545767862981
#
# Model Results for Food:
# Train Data: MAE: 41.9968, R-Squared: 0.9666, RMSE: 62.3936, MSE: 3892.9659 ,smape: 4.811971074216446
# Validation Data: MAE: 44.842, R-Squared: 0.958, RMSE: 69.959, MSE: 4894.2571 ,smape: 5.070958497594662
# Test Data: MAE: 42.6687, R-Squared: 0.9658, RMSE: 62.9837, MSE: 3966.9501 ,smape: 4.930738992480959
#
# Model Results for Transportation:
# Train Data: MAE: 94.4169, R-Squared: 0.715, RMSE: 127.0542, MSE: 16142.7813 ,smape: 6.150594062427486
# Validation Data: MAE: 93.6892, R-Squared: 0.714, RMSE: 124.9427, MSE: 15610.6844 ,smape: 6.110227134488467
# Test Data: MAE: 93.9136, R-Squared: 0.7219, RMSE: 126.3721, MSE: 15969.9176 ,smape: 6.145817111683995
#
# Model Results for Healthcare:
# Train Data: MAE: 114.9018, R-Squared: 0.8914, RMSE: 162.0548, MSE: 26261.7521 ,smape: 9.38720227049292
# Validation Data: MAE: 117.6425, R-Squared: 0.8909, RMSE: 164.9212, MSE: 27198.9881 ,smape: 9.506921287220708
# Test Data: MAE: 115.7654, R-Squared: 0.8851, RMSE: 163.5534, MSE: 26749.7094 ,smape: 9.538706600809066
#
# Model Results for Othernecessities:
# Train Data: MAE: 32.6604, R-Squared: 0.9595, RMSE: 46.1732, MSE: 2131.9617 ,smape: 4.818519579486896
# Validation Data: MAE: 33.146, R-Squared: 0.9561, RMSE: 46.2381, MSE: 2137.9579 ,smape: 4.859134157221054
# Test Data: MAE: 32.9487, R-Squared: 0.957, RMSE: 47.6033, MSE: 2266.0698 ,smape: 4.85245799494949
#
# Model Results for Childcare:
# Train Data: MAE: 91.7172, R-Squared: 0.9492, RMSE: 141.8645, MSE: 20125.5336 ,smape: 8.288385971413003
# Validation Data: MAE: 91.8087, R-Squared: 0.9454, RMSE: 140.9036, MSE: 19853.811 ,smape: 8.364903866513352
# Test Data: MAE: 89.5544, R-Squared: 0.948, RMSE: 142.1438, MSE: 20204.87 ,smape: 8.139586714194115
#
# Model Results for Taxes:
# Train Data: MAE: 51.5797, R-Squared: 0.9688, RMSE: 72.5691, MSE: 5266.2782 ,smape: 5.746067336242133
# Validation Data: MAE: 53.1099, R-Squared: 0.9625, RMSE: 74.844, MSE: 5601.6242 ,smape: 5.866780001770733
# Test Data: MAE: 50.8448, R-Squared: 0.9697, RMSE: 71.7582, MSE: 5149.2454 ,smape: 5.657104224847261

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score

def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    fold = 1
    cnn_results, xgb_results = [], []

    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")

        # Split data
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)

        # CNN: Train and Predict
        print("Training CNN...")
        cnn_model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        cnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        cnn_model.fit(X_train[..., np.newaxis], [y_train[:, i] for i in range(y_train.shape[1])],
                      validation_data=(X_val[..., np.newaxis], [y_val[:, i] for i in range(y_val.shape[1])]),
                      epochs=num_epochs, batch_size=64, verbose=1, callbacks=[early_stopping])

        y_train_pred_cnn = np.column_stack(cnn_model.predict(X_train[..., np.newaxis]))
        y_val_pred_cnn = np.column_stack(cnn_model.predict(X_val[..., np.newaxis]))
        y_test_pred_cnn = np.column_stack(cnn_model.predict(X_test[..., np.newaxis]))

        # XGBoost: Train and Predict
        print("Training XGBoost...")
        xgb_models = []
        y_train_pred_xgb, y_val_pred_xgb, y_test_pred_xgb = [], [], []

        for i in range(y_train.shape[1]):
            dtrain = xgb.DMatrix(X_train, label=y_train[:, i])
            dval = xgb.DMatrix(X_val, label=y_val[:, i])
            dtest = xgb.DMatrix(X_test)

            params = {
                'objective': 'reg:squarederror',
                'eval_metric': 'rmse',
                'learning_rate': 0.1,
                'max_depth': 6,
                'seed': 100
            }

            xgb_model = xgb.train(params, dtrain, num_boost_round=200, evals=[(dval, 'validation')],
                                  early_stopping_rounds=10, verbose_eval=False)
            xgb_models.append(xgb_model)

            y_train_pred_xgb.append(xgb_model.predict(dtrain))
            y_val_pred_xgb.append(xgb_model.predict(dval))
            y_test_pred_xgb.append(xgb_model.predict(dtest))

        y_train_pred_xgb = np.column_stack(y_train_pred_xgb)
        y_val_pred_xgb = np.column_stack(y_val_pred_xgb)
        y_test_pred_xgb = np.column_stack(y_test_pred_xgb)

        # Combine Predictions (Weighted Average)
        alpha = 0.5
        y_train_pred_combined = alpha * y_train_pred_cnn + (1 - alpha) * y_train_pred_xgb
        y_val_pred_combined = alpha * y_val_pred_cnn + (1 - alpha) * y_val_pred_xgb
        y_test_pred_combined = alpha * y_test_pred_cnn + (1 - alpha) * y_test_pred_xgb

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred_combined)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred_combined)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred_combined)
        y_test_original = scaler_y.inverse_transform(y_test)

        # Metrics
        for i, target in enumerate(target_col_list):
            print(f'Results for {target.capitalize()}:')
            print(f'  Train R^2: {r2_score(y_train_original[:, i], y_train_pred_original[:, i]):.4f}')
            print(f'  Validation R^2: {r2_score(y_val_original[:, i], y_val_pred_original[:, i]):.4f}')
            print(f'  Test R^2: {r2_score(y_test_original[:, i], y_test_pred_original[:, i]):.4f}')
            print()

        fold += 1

    return cnn_model, xgb_models

cnn_model, xgb_models = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
# Out:
# Fold 1/5
# Training CNN...
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0561 - target_childcare_loss: 0.0088 - target_food_loss: 0.0026 - target_healthcare_loss: 0.0179 - target_housing_loss: 0.0048 - target_othernecessities_loss: 0.0072 - target_taxes_loss: 0.0097 - target_transportation_loss: 0.0051 - val_loss: 0.0135 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.4862e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.8168e-04 - val_target_taxes_loss: 5.0824e-04 - val_target_transportation_loss: 0.0035
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0138 - target_childcare_loss: 0.0021 - target_food_loss: 5.8824e-04 - target_healthcare_loss: 0.0050 - target_housing_loss: 0.0013 - target_othernecessities_loss: 9.1580e-04 - target_taxes_loss: 5.1654e-04 - target_transportation_loss: 0.0034 - val_loss: 0.0131 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.7354e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0014 - val_target_othernecessities_loss: 8.3740e-04 - val_target_taxes_loss: 4.4584e-04 - val_target_transportation_loss: 0.0035
# Epoch 3/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0129 - target_childcare_loss: 0.0020 - target_food_loss: 5.7261e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.4797e-04 - target_taxes_loss: 4.4703e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0127 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8646e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.1411e-04 - val_target_taxes_loss: 4.1464e-04 - val_target_transportation_loss: 0.0036
# Epoch 4/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0127 - target_childcare_loss: 0.0019 - target_food_loss: 5.5300e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.2111e-04 - target_taxes_loss: 4.1309e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0128 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.7829e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9030e-04 - val_target_taxes_loss: 4.1785e-04 - val_target_transportation_loss: 0.0038
# Epoch 5/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0130 - target_childcare_loss: 0.0019 - target_food_loss: 5.7290e-04 - target_healthcare_loss: 0.0047 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.3088e-04 - target_taxes_loss: 4.2810e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.5112e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.1661e-04 - val_target_taxes_loss: 4.2292e-04 - val_target_transportation_loss: 0.0035
# Epoch 6/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0125 - target_childcare_loss: 0.0020 - target_food_loss: 5.4870e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.7985e-04 - target_taxes_loss: 4.1174e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0127 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.0534e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.8014e-04 - val_target_taxes_loss: 4.1777e-04 - val_target_transportation_loss: 0.0037
# Epoch 7/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0127 - target_childcare_loss: 0.0020 - target_food_loss: 5.7146e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9780e-04 - target_taxes_loss: 3.9807e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.5986e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5277e-04 - val_target_taxes_loss: 3.8799e-04 - val_target_transportation_loss: 0.0035
# Epoch 8/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0124 - target_childcare_loss: 0.0020 - target_food_loss: 5.2189e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6968e-04 - target_taxes_loss: 3.9978e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0124 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.6717e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.6761e-04 - val_target_taxes_loss: 3.9043e-04 - val_target_transportation_loss: 0.0035
# Epoch 9/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.4639e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6121e-04 - target_taxes_loss: 3.8145e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0123 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5653e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6633e-04 - val_target_taxes_loss: 5.3377e-04 - val_target_transportation_loss: 0.0034
# Epoch 10/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.4261e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6714e-04 - target_taxes_loss: 4.0599e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0121 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.6359e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5201e-04 - val_target_taxes_loss: 3.7720e-04 - val_target_transportation_loss: 0.0034
# Epoch 11/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.4046e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4760e-04 - target_taxes_loss: 3.8093e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.6272e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5196e-04 - val_target_taxes_loss: 3.7645e-04 - val_target_transportation_loss: 0.0034
# Epoch 12/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.4197e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.5097e-04 - target_taxes_loss: 3.7817e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5999e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7784e-04 - val_target_taxes_loss: 4.6117e-04 - val_target_transportation_loss: 0.0033
# Epoch 13/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.4079e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6453e-04 - target_taxes_loss: 3.8910e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0131 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 4.7434e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5716e-04 - val_target_taxes_loss: 3.7333e-04 - val_target_transportation_loss: 0.0036
# Epoch 14/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.2357e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3822e-04 - target_taxes_loss: 3.6949e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6115e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3309e-04 - val_target_taxes_loss: 3.8548e-04 - val_target_transportation_loss: 0.0033
# Epoch 15/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0119 - target_childcare_loss: 0.0018 - target_food_loss: 5.4491e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2248e-04 - target_taxes_loss: 3.7660e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4842e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3090e-04 - val_target_taxes_loss: 3.6553e-04 - val_target_transportation_loss: 0.0034
# Epoch 16/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.9651e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3531e-04 - target_taxes_loss: 3.6057e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5658e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2861e-04 - val_target_taxes_loss: 3.6091e-04 - val_target_transportation_loss: 0.0034
# Epoch 17/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0120 - target_childcare_loss: 0.0019 - target_food_loss: 5.3770e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1721e-04 - target_taxes_loss: 3.7376e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5255e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.1632e-04 - val_target_taxes_loss: 3.5765e-04 - val_target_transportation_loss: 0.0033
# Epoch 18/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0018 - target_food_loss: 5.4927e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1425e-04 - target_taxes_loss: 3.6314e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.2979e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4472e-04 - val_target_taxes_loss: 3.6306e-04 - val_target_transportation_loss: 0.0034
# Epoch 19/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.1916e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3206e-04 - target_taxes_loss: 3.6571e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5699e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4814e-04 - val_target_taxes_loss: 3.6383e-04 - val_target_transportation_loss: 0.0034
# Epoch 20/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0119 - target_childcare_loss: 0.0019 - target_food_loss: 5.4970e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0515e-04 - target_taxes_loss: 3.5397e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0117 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5565e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4737e-04 - val_target_taxes_loss: 3.7004e-04 - val_target_transportation_loss: 0.0033
# Epoch 21/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0115 - target_childcare_loss: 0.0018 - target_food_loss: 5.3496e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1061e-04 - target_taxes_loss: 3.6095e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0125 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5257e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5004e-04 - val_target_taxes_loss: 4.8330e-04 - val_target_transportation_loss: 0.0035
# Epoch 22/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0018 - target_food_loss: 5.3963e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0044e-04 - target_taxes_loss: 3.5910e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0116 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4495e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3086e-04 - val_target_taxes_loss: 3.8410e-04 - val_target_transportation_loss: 0.0033
# Epoch 23/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0113 - target_childcare_loss: 0.0017 - target_food_loss: 5.2591e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9648e-04 - target_taxes_loss: 3.4429e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0113 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.7824e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2227e-04 - val_target_taxes_loss: 3.5435e-04 - val_target_transportation_loss: 0.0033
# Epoch 24/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0115 - target_childcare_loss: 0.0018 - target_food_loss: 5.1791e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9770e-04 - target_taxes_loss: 3.5031e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0113 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6231e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1259e-04 - val_target_taxes_loss: 4.1320e-04 - val_target_transportation_loss: 0.0033
# Epoch 25/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.4025e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0078e-04 - target_taxes_loss: 3.4895e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0115 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5321e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5411e-04 - val_target_taxes_loss: 3.4330e-04 - val_target_transportation_loss: 0.0035
# Epoch 26/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0114 - target_childcare_loss: 0.0017 - target_food_loss: 5.6055e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2018e-04 - target_taxes_loss: 3.5549e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0114 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.4775e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1928e-04 - val_target_taxes_loss: 3.7637e-04 - val_target_transportation_loss: 0.0033
# Epoch 27/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0113 - target_childcare_loss: 0.0017 - target_food_loss: 5.5020e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0978e-04 - target_taxes_loss: 3.5432e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5685e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7610e-04 - val_target_taxes_loss: 3.6404e-04 - val_target_transportation_loss: 0.0033
# Epoch 28/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0114 - target_childcare_loss: 0.0016 - target_food_loss: 5.2887e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1791e-04 - target_taxes_loss: 3.5119e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6355e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0751e-04 - val_target_taxes_loss: 3.4735e-04 - val_target_transportation_loss: 0.0033
# Epoch 29/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.3055e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8127e-04 - target_taxes_loss: 3.4053e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4320e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1249e-04 - val_target_taxes_loss: 3.6702e-04 - val_target_transportation_loss: 0.0033
# Epoch 30/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.1805e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9376e-04 - target_taxes_loss: 3.4167e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.9730e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1775e-04 - val_target_taxes_loss: 3.4874e-04 - val_target_transportation_loss: 0.0033
# Epoch 31/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.5268e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9992e-04 - target_taxes_loss: 3.4821e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0112 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5642e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1561e-04 - val_target_taxes_loss: 4.1657e-04 - val_target_transportation_loss: 0.0032
# Epoch 32/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.2589e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0831e-04 - target_taxes_loss: 3.4847e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5015e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2056e-04 - val_target_taxes_loss: 3.4070e-04 - val_target_transportation_loss: 0.0032
# Epoch 33/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.2248e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7348e-04 - target_taxes_loss: 3.4443e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0112 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.3221e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.4298e-04 - val_target_taxes_loss: 3.4834e-04 - val_target_transportation_loss: 0.0033
# Epoch 34/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.2736e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2153e-04 - target_taxes_loss: 3.4431e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.7569e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9996e-04 - val_target_taxes_loss: 3.3873e-04 - val_target_transportation_loss: 0.0032
# Epoch 35/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.1506e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0302e-04 - target_taxes_loss: 3.2897e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4465e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0907e-04 - val_target_taxes_loss: 3.4823e-04 - val_target_transportation_loss: 0.0032
# Epoch 36/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0015 - target_food_loss: 5.2557e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9882e-04 - target_taxes_loss: 3.4033e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0110 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4866e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3077e-04 - val_target_taxes_loss: 3.4090e-04 - val_target_transportation_loss: 0.0032
# Epoch 37/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.0956e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9058e-04 - target_taxes_loss: 3.3244e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6161e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2180e-04 - val_target_taxes_loss: 3.4218e-04 - val_target_transportation_loss: 0.0032
# Epoch 38/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1978e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0223e-04 - target_taxes_loss: 3.4418e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4974e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2316e-04 - val_target_taxes_loss: 3.4641e-04 - val_target_transportation_loss: 0.0032
# Epoch 39/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.0776e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8617e-04 - target_taxes_loss: 3.2918e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4906e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1170e-04 - val_target_taxes_loss: 3.4859e-04 - val_target_transportation_loss: 0.0032
# Epoch 40/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1150e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9787e-04 - target_taxes_loss: 3.3737e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.8279e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2205e-04 - val_target_taxes_loss: 3.3138e-04 - val_target_transportation_loss: 0.0031
# Epoch 41/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.0771e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7893e-04 - target_taxes_loss: 3.2767e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4462e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0172e-04 - val_target_taxes_loss: 3.3052e-04 - val_target_transportation_loss: 0.0031
# Epoch 42/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.0757e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8077e-04 - target_taxes_loss: 3.3213e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0439e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.3107e-04 - val_target_taxes_loss: 3.2954e-04 - val_target_transportation_loss: 0.0032
# Epoch 43/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 4.9270e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1532e-04 - target_taxes_loss: 3.4091e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4172e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1896e-04 - val_target_taxes_loss: 3.4262e-04 - val_target_transportation_loss: 0.0032
# Epoch 44/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0105 - target_childcare_loss: 0.0014 - target_food_loss: 5.3091e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 9.9927e-04 - target_othernecessities_loss: 6.7795e-04 - target_taxes_loss: 3.2122e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6417e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0888e-04 - val_target_taxes_loss: 3.4414e-04 - val_target_transportation_loss: 0.0031
# Epoch 45/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.3710e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9318e-04 - target_taxes_loss: 3.3034e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3871e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0503e-04 - val_target_taxes_loss: 3.3444e-04 - val_target_transportation_loss: 0.0031
# Epoch 46/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.0239e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0470e-04 - target_taxes_loss: 3.3534e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3244e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9910e-04 - val_target_taxes_loss: 3.3265e-04 - val_target_transportation_loss: 0.0031
# Epoch 47/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.2059e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7704e-04 - target_taxes_loss: 3.2643e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0110 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4197e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0099e-04 - val_target_taxes_loss: 3.2739e-04 - val_target_transportation_loss: 0.0034
# Epoch 48/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.2507e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9747e-04 - target_taxes_loss: 3.3204e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.6882e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0656e-04 - val_target_taxes_loss: 3.3141e-04 - val_target_transportation_loss: 0.0031
# Epoch 49/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.3697e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8934e-04 - target_taxes_loss: 3.3158e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3865e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3006e-04 - val_target_taxes_loss: 3.4693e-04 - val_target_transportation_loss: 0.0032
# Epoch 50/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0014 - target_food_loss: 5.0045e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9656e-04 - target_taxes_loss: 3.2101e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4082e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0430e-04 - val_target_taxes_loss: 3.4071e-04 - val_target_transportation_loss: 0.0031
# Epoch 51/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0014 - target_food_loss: 4.8868e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7379e-04 - target_taxes_loss: 3.3573e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3172e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9247e-04 - val_target_taxes_loss: 3.2735e-04 - val_target_transportation_loss: 0.0031
# Epoch 52/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.2092e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8458e-04 - target_taxes_loss: 3.2559e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0110 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3002e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2785e-04 - val_target_taxes_loss: 3.2994e-04 - val_target_transportation_loss: 0.0034
# Epoch 53/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 4.9949e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8180e-04 - target_taxes_loss: 3.1234e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4190e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0504e-04 - val_target_taxes_loss: 3.5426e-04 - val_target_transportation_loss: 0.0032
# Epoch 54/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 4.9552e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7077e-04 - target_taxes_loss: 3.2744e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.1731e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2505e-04 - val_target_taxes_loss: 3.4505e-04 - val_target_transportation_loss: 0.0032
# Epoch 55/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 4.9360e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6187e-04 - target_taxes_loss: 3.2943e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7908e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0943e-04 - val_target_taxes_loss: 3.4129e-04 - val_target_transportation_loss: 0.0031
# Epoch 56/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0014 - target_food_loss: 5.2489e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9065e-04 - target_taxes_loss: 3.3327e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4051e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.1682e-04 - val_target_taxes_loss: 3.4706e-04 - val_target_transportation_loss: 0.0031
# Epoch 57/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.0450e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.8861e-04 - target_othernecessities_loss: 6.7219e-04 - target_taxes_loss: 3.2380e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4142e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0481e-04 - val_target_taxes_loss: 3.2116e-04 - val_target_transportation_loss: 0.0031
# Epoch 58/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 5.0416e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.7825e-04 - target_othernecessities_loss: 6.5586e-04 - target_taxes_loss: 3.1894e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3275e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0960e-04 - val_target_taxes_loss: 3.2011e-04 - val_target_transportation_loss: 0.0030
# Epoch 59/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.3602e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6795e-04 - target_taxes_loss: 3.2289e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0104 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7584e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.1699e-04 - val_target_taxes_loss: 3.5335e-04 - val_target_transportation_loss: 0.0030
# Epoch 60/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.1184e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8459e-04 - target_taxes_loss: 3.2971e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0104 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3357e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8936e-04 - val_target_taxes_loss: 3.2355e-04 - val_target_transportation_loss: 0.0030
# Epoch 61/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.2789e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8715e-04 - target_taxes_loss: 3.1769e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5881e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8980e-04 - val_target_taxes_loss: 3.2473e-04 - val_target_transportation_loss: 0.0031
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.2328e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7145e-04 - target_taxes_loss: 3.1372e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2553e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8754e-04 - val_target_taxes_loss: 3.1811e-04 - val_target_transportation_loss: 0.0031
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 4.8867e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8312e-04 - target_taxes_loss: 3.1989e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0104 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7202e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8538e-04 - val_target_taxes_loss: 3.1837e-04 - val_target_transportation_loss: 0.0032
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.1645e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6228e-04 - target_taxes_loss: 3.2146e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4058e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7781e-04 - val_target_taxes_loss: 3.3531e-04 - val_target_transportation_loss: 0.0030
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 4.9188e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.8601e-04 - target_othernecessities_loss: 6.6258e-04 - target_taxes_loss: 3.1617e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4898e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.9660e-04 - val_target_othernecessities_loss: 6.8160e-04 - val_target_taxes_loss: 3.2215e-04 - val_target_transportation_loss: 0.0030
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 5.2514e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7496e-04 - target_taxes_loss: 3.2577e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3789e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9521e-04 - val_target_taxes_loss: 3.1925e-04 - val_target_transportation_loss: 0.0031
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.7445e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.9648e-04 - target_othernecessities_loss: 6.6534e-04 - target_taxes_loss: 3.0858e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2989e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9033e-04 - val_target_taxes_loss: 3.3219e-04 - val_target_transportation_loss: 0.0030
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.2715e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8428e-04 - target_taxes_loss: 3.2343e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3647e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7877e-04 - val_target_taxes_loss: 3.3105e-04 - val_target_transportation_loss: 0.0030
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.0053e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7448e-04 - target_taxes_loss: 3.1596e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7086e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0495e-04 - val_target_taxes_loss: 3.2130e-04 - val_target_transportation_loss: 0.0031
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 4.9965e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6715e-04 - target_taxes_loss: 3.1958e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3347e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8026e-04 - val_target_taxes_loss: 3.3314e-04 - val_target_transportation_loss: 0.0030
# Epoch 71/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9029e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.6954e-04 - target_othernecessities_loss: 6.4676e-04 - target_taxes_loss: 3.2079e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3577e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2087e-04 - val_target_taxes_loss: 3.1983e-04 - val_target_transportation_loss: 0.0030
# Epoch 72/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 5.1219e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6140e-04 - target_taxes_loss: 3.1308e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4238e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8328e-04 - val_target_taxes_loss: 3.2425e-04 - val_target_transportation_loss: 0.0030
# Epoch 73/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9900e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.7094e-04 - target_othernecessities_loss: 6.5110e-04 - target_taxes_loss: 3.1410e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3319e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.9604e-04 - val_target_othernecessities_loss: 6.7142e-04 - val_target_taxes_loss: 3.3579e-04 - val_target_transportation_loss: 0.0030
# Epoch 74/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.7565e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8031e-04 - target_othernecessities_loss: 6.5000e-04 - target_taxes_loss: 3.0912e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3482e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8113e-04 - val_target_othernecessities_loss: 6.5166e-04 - val_target_taxes_loss: 3.1906e-04 - val_target_transportation_loss: 0.0029
# Epoch 75/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9775e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7553e-04 - target_taxes_loss: 3.1789e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3260e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.9469e-04 - val_target_othernecessities_loss: 6.7683e-04 - val_target_taxes_loss: 3.4978e-04 - val_target_transportation_loss: 0.0030
# Epoch 76/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 5.0018e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7938e-04 - target_othernecessities_loss: 6.5414e-04 - target_taxes_loss: 3.1061e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3443e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7399e-04 - val_target_taxes_loss: 3.1415e-04 - val_target_transportation_loss: 0.0030
# Epoch 77/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9881e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8570e-04 - target_othernecessities_loss: 6.5340e-04 - target_taxes_loss: 3.0873e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4799e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.5607e-04 - val_target_othernecessities_loss: 6.3984e-04 - val_target_taxes_loss: 3.1143e-04 - val_target_transportation_loss: 0.0030
# Epoch 78/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.8760e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.9730e-04 - target_othernecessities_loss: 6.6292e-04 - target_taxes_loss: 3.2215e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3005e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.5096e-04 - val_target_othernecessities_loss: 6.3313e-04 - val_target_taxes_loss: 3.2227e-04 - val_target_transportation_loss: 0.0030
# Epoch 79/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 5.0639e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5359e-04 - target_othernecessities_loss: 6.2919e-04 - target_taxes_loss: 3.1240e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.6763e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.9547e-04 - val_target_othernecessities_loss: 6.8344e-04 - val_target_taxes_loss: 3.2824e-04 - val_target_transportation_loss: 0.0030
# Epoch 80/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.8126e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7957e-04 - target_othernecessities_loss: 6.5231e-04 - target_taxes_loss: 3.1700e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2452e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.7785e-04 - val_target_othernecessities_loss: 6.4923e-04 - val_target_taxes_loss: 3.1052e-04 - val_target_transportation_loss: 0.0030
# Epoch 81/200
# ...
# Epoch 54/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7135e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3424e-04 - target_othernecessities_loss: 6.1088e-04 - target_taxes_loss: 2.8677e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 6.1834e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 8.9290e-04 - val_target_othernecessities_loss: 5.9665e-04 - val_target_taxes_loss: 3.0221e-04 - val_target_transportation_loss: 0.0027
# Epoch 55/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.6871e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.5000e-04 - target_othernecessities_loss: 6.0863e-04 - target_taxes_loss: 2.9172e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7036e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7428e-04 - val_target_othernecessities_loss: 5.6744e-04 - val_target_taxes_loss: 2.9585e-04 - val_target_transportation_loss: 0.0027
# Epoch 56/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0096 - target_childcare_loss: 0.0013 - target_food_loss: 4.7957e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0635e-04 - target_othernecessities_loss: 5.9236e-04 - target_taxes_loss: 2.8654e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6294e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.0862e-04 - val_target_othernecessities_loss: 5.7036e-04 - val_target_taxes_loss: 2.9590e-04 - val_target_transportation_loss: 0.0027
# Epoch 57/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.6667e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.4041e-04 - target_othernecessities_loss: 6.0643e-04 - target_taxes_loss: 2.9160e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.7224e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.0638e-04 - val_target_othernecessities_loss: 5.6428e-04 - val_target_taxes_loss: 2.9026e-04 - val_target_transportation_loss: 0.0027
# Epoch 58/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.7204e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.4388e-04 - target_othernecessities_loss: 6.0764e-04 - target_taxes_loss: 2.8252e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7037e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.2814e-04 - val_target_othernecessities_loss: 5.7504e-04 - val_target_taxes_loss: 3.0114e-04 - val_target_transportation_loss: 0.0027
# Epoch 59/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.5884e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0837e-04 - target_othernecessities_loss: 5.9447e-04 - target_taxes_loss: 2.8280e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 6.2655e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.2980e-04 - val_target_othernecessities_loss: 5.7184e-04 - val_target_taxes_loss: 3.2345e-04 - val_target_transportation_loss: 0.0027
# Epoch 60/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.9307e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1118e-04 - target_othernecessities_loss: 5.9192e-04 - target_taxes_loss: 2.8763e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5836e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8906e-04 - val_target_othernecessities_loss: 5.5888e-04 - val_target_taxes_loss: 2.9197e-04 - val_target_transportation_loss: 0.0027
# Epoch 61/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.9484e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3975e-04 - target_othernecessities_loss: 6.0239e-04 - target_taxes_loss: 2.9191e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.9353e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.6799e-04 - val_target_othernecessities_loss: 5.6073e-04 - val_target_taxes_loss: 2.8345e-04 - val_target_transportation_loss: 0.0027
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.8475e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1090e-04 - target_othernecessities_loss: 5.8713e-04 - target_taxes_loss: 2.8291e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7632e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 9.4190e-04 - val_target_othernecessities_loss: 6.0241e-04 - val_target_taxes_loss: 2.9530e-04 - val_target_transportation_loss: 0.0027
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7099e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3235e-04 - target_othernecessities_loss: 5.9127e-04 - target_taxes_loss: 2.8486e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5604e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.0835e-04 - val_target_othernecessities_loss: 5.7195e-04 - val_target_taxes_loss: 2.8519e-04 - val_target_transportation_loss: 0.0028
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.5777e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3171e-04 - target_othernecessities_loss: 5.9545e-04 - target_taxes_loss: 2.9359e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 6.0286e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.2908e-04 - val_target_othernecessities_loss: 5.7122e-04 - val_target_taxes_loss: 2.9308e-04 - val_target_transportation_loss: 0.0027
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.5690e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3046e-04 - target_othernecessities_loss: 6.0325e-04 - target_taxes_loss: 2.8606e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7335e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7905e-04 - val_target_othernecessities_loss: 5.5426e-04 - val_target_taxes_loss: 2.8029e-04 - val_target_transportation_loss: 0.0027
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6903e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.3769e-04 - target_othernecessities_loss: 5.9802e-04 - target_taxes_loss: 2.7154e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.8004e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.7095e-04 - val_target_othernecessities_loss: 5.5781e-04 - val_target_taxes_loss: 3.0421e-04 - val_target_transportation_loss: 0.0027
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.5193e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8829e-04 - target_othernecessities_loss: 5.6759e-04 - target_taxes_loss: 2.7755e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5974e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9859e-04 - val_target_othernecessities_loss: 5.5504e-04 - val_target_taxes_loss: 3.8349e-04 - val_target_transportation_loss: 0.0027
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.8247e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1296e-04 - target_othernecessities_loss: 5.8535e-04 - target_taxes_loss: 2.8638e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5616e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.7675e-04 - val_target_othernecessities_loss: 5.4198e-04 - val_target_taxes_loss: 2.8014e-04 - val_target_transportation_loss: 0.0027
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.8686e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0235e-04 - target_othernecessities_loss: 5.7615e-04 - target_taxes_loss: 2.7090e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7008e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9071e-04 - val_target_othernecessities_loss: 5.6423e-04 - val_target_taxes_loss: 2.8575e-04 - val_target_transportation_loss: 0.0027
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.9509e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.4167e-04 - target_othernecessities_loss: 6.0695e-04 - target_taxes_loss: 2.8184e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.8836e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7373e-04 - val_target_othernecessities_loss: 5.6898e-04 - val_target_taxes_loss: 2.9344e-04 - val_target_transportation_loss: 0.0027
# Epoch 71/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7787e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0696e-04 - target_othernecessities_loss: 5.8383e-04 - target_taxes_loss: 2.8570e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5725e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7437e-04 - val_target_othernecessities_loss: 5.5190e-04 - val_target_taxes_loss: 3.0874e-04 - val_target_transportation_loss: 0.0028
# Epoch 72/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.7008e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0979e-04 - target_othernecessities_loss: 5.7931e-04 - target_taxes_loss: 2.7874e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.7021e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.2512e-04 - val_target_othernecessities_loss: 5.8971e-04 - val_target_taxes_loss: 2.9728e-04 - val_target_transportation_loss: 0.0027
# Epoch 73/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.9316e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0414e-04 - target_othernecessities_loss: 5.7232e-04 - target_taxes_loss: 2.6948e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6437e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8389e-04 - val_target_othernecessities_loss: 5.7980e-04 - val_target_taxes_loss: 2.9036e-04 - val_target_transportation_loss: 0.0028
# Epoch 74/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.4821e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1708e-04 - target_othernecessities_loss: 5.8392e-04 - target_taxes_loss: 2.8076e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.9895e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.9992e-04 - val_target_othernecessities_loss: 6.0052e-04 - val_target_taxes_loss: 2.8206e-04 - val_target_transportation_loss: 0.0028
# Epoch 75/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6448e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0663e-04 - target_othernecessities_loss: 5.7613e-04 - target_taxes_loss: 2.7215e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7339e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9015e-04 - val_target_othernecessities_loss: 5.6293e-04 - val_target_taxes_loss: 2.8321e-04 - val_target_transportation_loss: 0.0027
# Epoch 76/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.4841e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8536e-04 - target_othernecessities_loss: 5.5788e-04 - target_taxes_loss: 2.7980e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.0500e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9294e-04 - val_target_othernecessities_loss: 5.7069e-04 - val_target_taxes_loss: 2.8506e-04 - val_target_transportation_loss: 0.0027
# Epoch 77/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.4434e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9390e-04 - target_othernecessities_loss: 5.6222e-04 - target_taxes_loss: 2.7066e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7225e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8913e-04 - val_target_othernecessities_loss: 5.5283e-04 - val_target_taxes_loss: 2.9183e-04 - val_target_transportation_loss: 0.0027
# Epoch 78/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.4806e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0641e-04 - target_othernecessities_loss: 5.8329e-04 - target_taxes_loss: 2.7677e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6354e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6089e-04 - val_target_othernecessities_loss: 5.4361e-04 - val_target_taxes_loss: 2.8730e-04 - val_target_transportation_loss: 0.0027
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training XGBoost...
# Results for Housing:
#   Train R^2: 0.9427
#   Validation R^2: 0.9262
#   Test R^2: 0.9315
#
# Results for Food:
#   Train R^2: 0.9796
#   Validation R^2: 0.9692
#   Test R^2: 0.9749
#
# Results for Transportation:
#   Train R^2: 0.8187
#   Validation R^2: 0.7945
#   Test R^2: 0.7991
#
# Results for Healthcare:
#   Train R^2: 0.9422
#   Validation R^2: 0.9370
#   Test R^2: 0.9354
#
# Results for Othernecessities:
#   Train R^2: 0.9756
#   Validation R^2: 0.9708
#   Test R^2: 0.9713
#
# Results for Childcare:
#   Train R^2: 0.9685
#   Validation R^2: 0.9616
#   Test R^2: 0.9629
#
# Results for Taxes:
#   Train R^2: 0.9896
#   Validation R^2: 0.9868
#   Test R^2: 0.9898

# %%
import pandas as pd
import numpy as np
import joblib

# Load the scalers
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')

def get_prediction(model_combine, input_data, scaler_X, scaler_y, num_children_col, childcare_exp_col):
    """
    Generates predictions for expenses using the combined model.

    Args:
        model_combine: The trained Keras model.
        input_data: Pandas DataFrame of new input data.
        scaler_X: Fitted MinMaxScaler for features.
        scaler_y: Fitted MinMaxScaler for target variables.
        num_children_col: Integer column index for number of children.
        childcare_exp_col: Integer column index for the 'childcare' target.

    Returns:
         Numpy Array: Predicted expense values.
    """

    # Step 1: Create new features
    input_data_with_features = createFeatures(input_data.copy())

    # Step 2: Select relevant features
    X = input_data_with_features[['total', 'median_family_income', 'num_counties_in_st', 'n_children',
                                  'n_parents', 'n_members', 'per_member_cost', 'child_expense_cost',
                                  'parent_expense_cost', 'other_expense_cost','zero_childcare_cost']].values

    # Step 3: Scale the input data using the fitted scaler_X
    input_data_scaled = scaler_X.transform(X)

    # Step 4: Reshape for the CNN layer (add the extra dimension)
    input_data_scaled = input_data_scaled[..., np.newaxis]  # This line is crucial to match the training data shape

    # Step 5: Make predictions using the trained model
    # We need to unpack the predictions from the model output
    # Then, we can stack those into a single output array.
    input_data_pred = model_combine.predict(input_data_scaled)
    input_data_pred = np.column_stack(input_data_pred)

    # Step 6: Inverse transform the predictions to return them to the original scale
    input_data_pred_original = scaler_y.inverse_transform(input_data_pred)

    # Step 7: Enforce the rule that if there are no children, childcare cost is 0
    input_data_pred_original[:, childcare_exp_col] = np.where(
        input_data_with_features['n_children'].values == 0, 0, input_data_pred_original[:, childcare_exp_col]
    )

    return input_data_pred_original

def createFeatures(input_data):
    """
    Creates additional features needed for the model prediction.

    Args:
        input_data: The input pandas DataFrame with the original data.

    Returns:
        input_data: The input data with additional features.
    """
    # Step 1: Create additional features
    input_data["per_member_cost"] = input_data["total"] / input_data["n_members"]
    input_data["child_expense_cost"] = input_data["per_member_cost"] * input_data["n_children"]
    input_data["parent_expense_cost"] = input_data["per_member_cost"] * input_data["n_parents"]
    input_data["other_expense_cost"] = input_data["total"] - (input_data["child_expense_cost"] + input_data["parent_expense_cost"])

    # Step 2: Create binary column for whether there are children (0 if no children, 1 if there are children)
    input_data["zero_childcare_cost"] = input_data['n_children'].map(lambda x: 0 if x < 1 else 1)

    return input_data

# Example of input data to test predictions
input_data = pd.DataFrame(
    [[4541, 8790.0, 67, 0, 2, 2]],
    columns=['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']
)

# Assuming `model_combine` is your trained model
input_data_pred_original = get_prediction(model_combine, input_data, scaler_X, scaler_y, num_children_col=3, childcare_exp_col=5)

# Print predictions
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']
for i, prediction in enumerate(input_data_pred_original[0]):
    print(f"{target_col_list[i]}: {prediction:.2f}")
