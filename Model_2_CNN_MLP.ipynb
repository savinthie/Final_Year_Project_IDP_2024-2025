# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_IDP_2024-2025/blob/main/Model_2_CNN_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
df = df.fillna(0)
# Out:
# Mounted at /content/drive

# %%
# Data Preprocessing

df.columns = [col.lower().replace(' ', '').replace('.', '') for col in df.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
df1 = df[cols_to_keep].copy()

df1['median_family_income'] = df1['median_family_income'].replace(',', '', regex=True).astype(float)
df1['median_family_income'] = df1['median_family_income'].map(lambda x: x/12)

# %%
# Feature Engineering
df1['n_parents'] = df1['family'].str.slice(0, 1).astype(int)
df1['n_children'] = df1['family'].str.slice(2, 3).astype(int)
df1['n_members'] = df1['n_parents'] + df1['n_children']
df1['financial_stability'] = df1['median_family_income'] / df1['total']
df1["per_member_cost"] = df1["total"] / df1["n_members"]
df1["child_expense_cost"] = df1["per_member_cost"]*df1["n_children"]
df1["parent_expense_cost"] = df1["per_member_cost"]*df1["n_parents"]
df1["other_expense_cost"] = df1["total"] - (df1["child_expense_cost"]+df1["parent_expense_cost"])

df1["zero_childcare_cost"] = df1['n_children'].map(lambda x: 0 if x < 1 else 1)

# %%
# Splitting the data
X = df1[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost','zero_childcare_cost']].values
y_expenses = df1[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = MinMaxScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)


# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
def replace_zeros_with_ones(a, b):
    # Iterate through both lists simultaneously
    for i in range(len(a)):
        # If both value is 0, replace both with 1
        if a[i] == 0 and b[i] == 0:
            a[i] = 1
            b[i] = 1
    return a, b

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def calculateSmape(y_true, y_pred):
    """
    Calculate Symmetric Mean Absolute Percentage Error (SMAPE).

    Parameters:
    y_true (array-like): Actual values.
    y_pred (array-like): Predicted values.

    Returns:
    float: SMAPE value.
    """
    y_true, y_pred = replace_zeros_with_ones(y_true, y_pred)
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_value = np.mean(numerator / denominator) * 100
    return smape_value

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    smape_score = calculateSmape(x, y)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse} ,smape: {smape_score}'

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import xgboost as xgb

num_children_col = 3  # 4th position, 0-indexed
childcare_exp_col = target_col_list.index('childcare')  # Replace 'childcare_exp' with the actual target name

# %%
from tensorflow.keras.layers import Input, Conv1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# L2 regularization strength (you can tune this value)
l2_strength = 0.01

# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    fold = 1
    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100) # 50/50 split of remaining 20%

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        model.summary()

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Training
        model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks= [early_stopping])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test)) #Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test) #Inverse transform for test set

        # Enforce the rule after predictions for childcare expense
        # The issue is likely caused by X_train having an extra dimension due to[..., np.newaxis].
        # We need to select the original features for the condition
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col, 0] == 0, 0, y_train_pred_original[:, childcare_exp_col]) #Using X_train[:, num_children_col, 0] instead of X_train[:, num_children_col]

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col, 0] == 0, 0, y_val_pred_original[:, childcare_exp_col]) #Using X_val[:, num_children_col, 0] instead of X_val[:, num_children_col]

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col]) #Using X_test[:, num_children_col, 0] instead of X_test[:, num_children_col]

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return model

model_combine = cross_val_with_evaluation(X_scaled, y_exp_scaled,kf)
# Out:
# Fold 1/2
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 11, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 11, 8)          │             32 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 88)             │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         11,392 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_healthcare (Dense) │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_othernecessities   │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_childcare (Dense)  │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_taxes (Dense)      │ (None, 1)              │             65 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,135 (78.65 KB)
#  Trainable params: 20,135 (78.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0585 - target_childcare_loss: 0.0085 - target_food_loss: 0.0030 - target_healthcare_loss: 0.0155 - target_housing_loss: 0.0048 - target_othernecessities_loss: 0.0159 - target_taxes_loss: 0.0038 - target_transportation_loss: 0.0069 - val_loss: 0.0146 - val_target_childcare_loss: 0.0022 - val_target_food_loss: 6.7011e-04 - val_target_healthcare_loss: 0.0053 - val_target_housing_loss: 0.0014 - val_target_othernecessities_loss: 9.7052e-04 - val_target_taxes_loss: 5.6787e-04 - val_target_transportation_loss: 0.0035
# Epoch 2/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0135 - target_childcare_loss: 0.0021 - target_food_loss: 6.3433e-04 - target_healthcare_loss: 0.0048 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.8248e-04 - target_taxes_loss: 5.8039e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0140 - val_target_childcare_loss: 0.0023 - val_target_food_loss: 5.7456e-04 - val_target_healthcare_loss: 0.0049 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.6452e-04 - val_target_taxes_loss: 6.1231e-04 - val_target_transportation_loss: 0.0034
# Epoch 3/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0131 - target_childcare_loss: 0.0020 - target_food_loss: 5.7797e-04 - target_healthcare_loss: 0.0047 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.4252e-04 - target_taxes_loss: 5.2612e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0135 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.9359e-04 - val_target_healthcare_loss: 0.0048 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 9.3937e-04 - val_target_taxes_loss: 4.4876e-04 - val_target_transportation_loss: 0.0033
# Epoch 4/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0129 - target_childcare_loss: 0.0020 - target_food_loss: 5.5712e-04 - target_healthcare_loss: 0.0047 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.3935e-04 - target_taxes_loss: 4.7107e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0137 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.7813e-04 - val_target_healthcare_loss: 0.0049 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.0731e-04 - val_target_taxes_loss: 4.5852e-04 - val_target_transportation_loss: 0.0036
# Epoch 5/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0126 - target_childcare_loss: 0.0020 - target_food_loss: 5.5952e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.1706e-04 - target_taxes_loss: 4.3932e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0131 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.9673e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 7.9143e-04 - val_target_taxes_loss: 3.8943e-04 - val_target_transportation_loss: 0.0033
# Epoch 6/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0125 - target_childcare_loss: 0.0020 - target_food_loss: 5.6253e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.8801e-04 - target_taxes_loss: 4.3404e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0133 - val_target_childcare_loss: 0.0022 - val_target_food_loss: 6.5717e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.0276e-04 - val_target_taxes_loss: 3.9261e-04 - val_target_transportation_loss: 0.0035
# Epoch 7/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0127 - target_childcare_loss: 0.0020 - target_food_loss: 6.0302e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.0141e-04 - target_taxes_loss: 4.1688e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0130 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.6459e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.8692e-04 - val_target_taxes_loss: 3.6272e-04 - val_target_transportation_loss: 0.0035
# Epoch 8/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.2536e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 8.0716e-04 - target_taxes_loss: 4.1680e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0130 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.8197e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 7.8697e-04 - val_target_taxes_loss: 3.6860e-04 - val_target_transportation_loss: 0.0034
# Epoch 9/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.4037e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.7743e-04 - target_taxes_loss: 4.0932e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0134 - val_target_childcare_loss: 0.0022 - val_target_food_loss: 5.5608e-04 - val_target_healthcare_loss: 0.0047 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 9.2777e-04 - val_target_taxes_loss: 4.0007e-04 - val_target_transportation_loss: 0.0034
# Epoch 10/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0125 - target_childcare_loss: 0.0019 - target_food_loss: 5.8685e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.2497e-04 - target_taxes_loss: 4.0704e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0127 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.4853e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7213e-04 - val_target_taxes_loss: 4.1885e-04 - val_target_transportation_loss: 0.0033
# Epoch 11/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0125 - target_childcare_loss: 0.0020 - target_food_loss: 5.5225e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9883e-04 - target_taxes_loss: 4.0941e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0131 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.5526e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5714e-04 - val_target_taxes_loss: 4.6615e-04 - val_target_transportation_loss: 0.0036
# Epoch 12/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.2241e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.8787e-04 - target_taxes_loss: 4.1376e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0130 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.7769e-04 - val_target_healthcare_loss: 0.0047 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9183e-04 - val_target_taxes_loss: 4.3654e-04 - val_target_transportation_loss: 0.0033
# Epoch 13/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0120 - target_childcare_loss: 0.0019 - target_food_loss: 5.4765e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.8952e-04 - target_taxes_loss: 3.9361e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0127 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.5149e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.8622e-04 - val_target_taxes_loss: 4.0008e-04 - val_target_transportation_loss: 0.0033
# Epoch 14/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.3552e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.6945e-04 - target_taxes_loss: 4.1201e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.5691e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6025e-04 - val_target_taxes_loss: 4.5907e-04 - val_target_transportation_loss: 0.0033
# Epoch 15/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.3705e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4478e-04 - target_taxes_loss: 4.0172e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.5755e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5927e-04 - val_target_taxes_loss: 4.2641e-04 - val_target_transportation_loss: 0.0033
# Epoch 16/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.3939e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2928e-04 - target_taxes_loss: 3.8063e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0125 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.5673e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.0256e-04 - val_target_taxes_loss: 3.6176e-04 - val_target_transportation_loss: 0.0033
# Epoch 17/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.5229e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1905e-04 - target_taxes_loss: 3.5813e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.4379e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.4909e-04 - val_target_taxes_loss: 4.2839e-04 - val_target_transportation_loss: 0.0034
# Epoch 18/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.5542e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2989e-04 - target_taxes_loss: 3.9454e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0129 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.5311e-04 - val_target_healthcare_loss: 0.0047 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.7508e-04 - val_target_taxes_loss: 4.3199e-04 - val_target_transportation_loss: 0.0033
# Epoch 19/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.4239e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3662e-04 - target_taxes_loss: 3.8400e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0127 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.5320e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.1419e-04 - val_target_taxes_loss: 3.9187e-04 - val_target_transportation_loss: 0.0033
# Epoch 20/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.2482e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3640e-04 - target_taxes_loss: 3.8433e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0123 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.4781e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4164e-04 - val_target_taxes_loss: 3.6034e-04 - val_target_transportation_loss: 0.0033
# Epoch 21/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.3712e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2699e-04 - target_taxes_loss: 3.6868e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0123 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.5170e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3648e-04 - val_target_taxes_loss: 3.7199e-04 - val_target_transportation_loss: 0.0033
# Epoch 22/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0119 - target_childcare_loss: 0.0018 - target_food_loss: 5.4502e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.8355e-04 - target_taxes_loss: 3.7892e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0123 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.4528e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4943e-04 - val_target_taxes_loss: 3.6964e-04 - val_target_transportation_loss: 0.0034
# Epoch 23/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.3863e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4847e-04 - target_taxes_loss: 3.8315e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0127 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.5114e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.1195e-04 - val_target_taxes_loss: 3.8926e-04 - val_target_transportation_loss: 0.0035
# Epoch 24/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.5417e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3405e-04 - target_taxes_loss: 3.7556e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0123 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 6.2638e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5186e-04 - val_target_taxes_loss: 3.3743e-04 - val_target_transportation_loss: 0.0033
# Epoch 25/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0017 - target_food_loss: 5.1438e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1238e-04 - target_taxes_loss: 3.4829e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0125 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.9305e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.7819e-04 - val_target_taxes_loss: 3.8304e-04 - val_target_transportation_loss: 0.0034
# Epoch 26/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0114 - target_childcare_loss: 0.0018 - target_food_loss: 5.1482e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9985e-04 - target_taxes_loss: 3.6534e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.4193e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.7090e-04 - val_target_taxes_loss: 3.5502e-04 - val_target_transportation_loss: 0.0033
# Epoch 27/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.3584e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3042e-04 - target_taxes_loss: 3.5981e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0123 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.7022e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3898e-04 - val_target_taxes_loss: 3.5208e-04 - val_target_transportation_loss: 0.0034
# Epoch 28/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0018 - target_food_loss: 5.3249e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0451e-04 - target_taxes_loss: 3.5234e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0123 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.5283e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2522e-04 - val_target_taxes_loss: 3.6799e-04 - val_target_transportation_loss: 0.0034
# Epoch 29/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.2722e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1478e-04 - target_taxes_loss: 3.5636e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0123 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.7072e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5340e-04 - val_target_taxes_loss: 3.4792e-04 - val_target_transportation_loss: 0.0034
# Epoch 30/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.4308e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2687e-04 - target_taxes_loss: 3.7993e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0122 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.5149e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.6103e-04 - val_target_taxes_loss: 3.8011e-04 - val_target_transportation_loss: 0.0033
# Epoch 31/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0111 - target_childcare_loss: 0.0017 - target_food_loss: 5.0211e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9167e-04 - target_taxes_loss: 3.6250e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0120 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.4331e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.3742e-04 - val_target_taxes_loss: 3.5572e-04 - val_target_transportation_loss: 0.0033
# Epoch 32/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0112 - target_childcare_loss: 0.0017 - target_food_loss: 5.2335e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0061e-04 - target_taxes_loss: 3.6761e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0121 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.8617e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.2651e-04 - val_target_taxes_loss: 4.2891e-04 - val_target_transportation_loss: 0.0033
# Epoch 33/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0114 - target_childcare_loss: 0.0016 - target_food_loss: 5.3077e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.1455e-04 - target_taxes_loss: 3.6324e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.4350e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3588e-04 - val_target_taxes_loss: 3.3345e-04 - val_target_transportation_loss: 0.0033
# Epoch 34/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0113 - target_childcare_loss: 0.0017 - target_food_loss: 5.3903e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1026e-04 - target_taxes_loss: 3.4146e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0119 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.5336e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1750e-04 - val_target_taxes_loss: 3.4668e-04 - val_target_transportation_loss: 0.0034
# Epoch 35/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0114 - target_childcare_loss: 0.0016 - target_food_loss: 5.5067e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1708e-04 - target_taxes_loss: 3.5330e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.8038e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4370e-04 - val_target_taxes_loss: 3.5794e-04 - val_target_transportation_loss: 0.0033
# Epoch 36/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0114 - target_childcare_loss: 0.0017 - target_food_loss: 5.3869e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.1573e-04 - target_taxes_loss: 3.5073e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.4544e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2125e-04 - val_target_taxes_loss: 3.7526e-04 - val_target_transportation_loss: 0.0033
# Epoch 37/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.3513e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0730e-04 - target_taxes_loss: 3.5807e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.5823e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4349e-04 - val_target_taxes_loss: 3.3216e-04 - val_target_transportation_loss: 0.0032
# Epoch 38/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.1315e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1206e-04 - target_taxes_loss: 3.4971e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0118 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.9802e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4083e-04 - val_target_taxes_loss: 3.5085e-04 - val_target_transportation_loss: 0.0033
# Epoch 39/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.4176e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8785e-04 - target_taxes_loss: 3.2925e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.5190e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0668e-04 - val_target_taxes_loss: 3.4404e-04 - val_target_transportation_loss: 0.0033
# Epoch 40/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.2298e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2350e-04 - target_taxes_loss: 3.6420e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0123 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.4625e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 7.7268e-04 - val_target_taxes_loss: 3.5468e-04 - val_target_transportation_loss: 0.0038
# Epoch 41/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.1841e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8313e-04 - target_taxes_loss: 3.4372e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0120 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 6.3245e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.5741e-04 - val_target_taxes_loss: 3.5779e-04 - val_target_transportation_loss: 0.0033
# Epoch 42/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.3692e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9183e-04 - target_taxes_loss: 3.4477e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0115 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.4129e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0330e-04 - val_target_taxes_loss: 3.4401e-04 - val_target_transportation_loss: 0.0033
# Epoch 43/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.0053e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9589e-04 - target_taxes_loss: 3.3947e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.3923e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.4416e-04 - val_target_taxes_loss: 3.2489e-04 - val_target_transportation_loss: 0.0033
# Epoch 44/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1554e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7245e-04 - target_taxes_loss: 3.3068e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0118 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3815e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 7.5079e-04 - val_target_taxes_loss: 3.3207e-04 - val_target_transportation_loss: 0.0033
# Epoch 45/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.2609e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1009e-04 - target_taxes_loss: 3.3707e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0119 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.4175e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4731e-04 - val_target_taxes_loss: 3.1989e-04 - val_target_transportation_loss: 0.0035
# Epoch 46/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.3998e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2061e-04 - target_taxes_loss: 3.4867e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0114 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3301e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1839e-04 - val_target_taxes_loss: 3.3684e-04 - val_target_transportation_loss: 0.0032
# Epoch 47/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 4.9932e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 9.8453e-04 - target_othernecessities_loss: 6.6405e-04 - target_taxes_loss: 3.4294e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3252e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9934e-04 - val_target_taxes_loss: 3.1924e-04 - val_target_transportation_loss: 0.0032
# Epoch 48/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.3797e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7860e-04 - target_taxes_loss: 3.3507e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3440e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1599e-04 - val_target_taxes_loss: 3.3727e-04 - val_target_transportation_loss: 0.0033
# Epoch 49/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 4.8958e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7575e-04 - target_taxes_loss: 3.3688e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3762e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.8831e-04 - val_target_taxes_loss: 3.3948e-04 - val_target_transportation_loss: 0.0032
# Epoch 50/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1056e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 9.7345e-04 - target_othernecessities_loss: 6.6033e-04 - target_taxes_loss: 3.2661e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.4004e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9691e-04 - val_target_taxes_loss: 3.4650e-04 - val_target_transportation_loss: 0.0032
# Epoch 51/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.0939e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7678e-04 - target_taxes_loss: 3.4006e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.5342e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9678e-04 - val_target_taxes_loss: 3.2967e-04 - val_target_transportation_loss: 0.0032
# Epoch 52/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.2225e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 9.9526e-04 - target_othernecessities_loss: 6.5933e-04 - target_taxes_loss: 3.2479e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0112 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.3382e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9281e-04 - val_target_taxes_loss: 3.2593e-04 - val_target_transportation_loss: 0.0032
# Epoch 53/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 4.9974e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6783e-04 - target_taxes_loss: 3.3427e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.5909e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1052e-04 - val_target_taxes_loss: 3.2305e-04 - val_target_transportation_loss: 0.0032
# Epoch 54/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.0740e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7766e-04 - target_taxes_loss: 3.2950e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0113 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.3215e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3822e-04 - val_target_taxes_loss: 3.3360e-04 - val_target_transportation_loss: 0.0032
# Epoch 55/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.1547e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7853e-04 - target_taxes_loss: 3.2529e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.2407e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9481e-04 - val_target_taxes_loss: 3.6878e-04 - val_target_transportation_loss: 0.0032
# Epoch 56/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.8819e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9104e-04 - target_othernecessities_loss: 6.5297e-04 - target_taxes_loss: 3.2703e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0110 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3035e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9032e-04 - val_target_taxes_loss: 3.2101e-04 - val_target_transportation_loss: 0.0032
# Epoch 57/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 4.9414e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7018e-04 - target_taxes_loss: 3.2037e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3295e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9811e-04 - val_target_taxes_loss: 3.1400e-04 - val_target_transportation_loss: 0.0032
# Epoch 58/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 4.9572e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7284e-04 - target_taxes_loss: 3.3655e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0110 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3061e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1406e-04 - val_target_taxes_loss: 3.3417e-04 - val_target_transportation_loss: 0.0032
# Epoch 59/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.0885e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7083e-04 - target_taxes_loss: 3.2331e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.3077e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9137e-04 - val_target_taxes_loss: 3.4785e-04 - val_target_transportation_loss: 0.0032
# Epoch 60/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 5.2313e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8317e-04 - target_taxes_loss: 3.3260e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0110 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.2443e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.8377e-04 - val_target_taxes_loss: 3.2574e-04 - val_target_transportation_loss: 0.0032
# Epoch 61/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.1812e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8524e-04 - target_taxes_loss: 3.2650e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.3131e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0025e-04 - val_target_taxes_loss: 3.1940e-04 - val_target_transportation_loss: 0.0031
# Epoch 62/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 4.7780e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6419e-04 - target_taxes_loss: 3.3843e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0109 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.2979e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9337e-04 - val_target_taxes_loss: 3.2027e-04 - val_target_transportation_loss: 0.0031
# Epoch 63/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0102 - target_childcare_loss: 0.0015 - target_food_loss: 4.9775e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.8719e-04 - target_othernecessities_loss: 6.5620e-04 - target_taxes_loss: 3.1960e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.7063e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9250e-04 - val_target_taxes_loss: 3.4027e-04 - val_target_transportation_loss: 0.0031
# Epoch 64/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.8923e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.8341e-04 - target_othernecessities_loss: 6.4374e-04 - target_taxes_loss: 3.2578e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3139e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0328e-04 - val_target_taxes_loss: 3.1946e-04 - val_target_transportation_loss: 0.0032
# Epoch 65/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 4.9453e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.6958e-04 - target_othernecessities_loss: 6.5075e-04 - target_taxes_loss: 3.2326e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.3062e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9112e-04 - val_target_taxes_loss: 3.2849e-04 - val_target_transportation_loss: 0.0031
# Epoch 66/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 4.9686e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9070e-04 - target_taxes_loss: 3.1366e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.7538e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.6340e-04 - val_target_taxes_loss: 3.5283e-04 - val_target_transportation_loss: 0.0032
# Epoch 67/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.2259e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8777e-04 - target_othernecessities_loss: 6.5510e-04 - target_taxes_loss: 3.2941e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0108 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.4506e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9702e-04 - val_target_taxes_loss: 3.1582e-04 - val_target_transportation_loss: 0.0031
# Epoch 68/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.8885e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9373e-04 - target_othernecessities_loss: 6.7156e-04 - target_taxes_loss: 3.3619e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0107 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.2684e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.7216e-04 - val_target_taxes_loss: 3.4398e-04 - val_target_transportation_loss: 0.0032
# Epoch 69/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.9176e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7031e-04 - target_othernecessities_loss: 6.4015e-04 - target_taxes_loss: 3.2537e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0108 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.4766e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.8527e-04 - val_target_taxes_loss: 3.2469e-04 - val_target_transportation_loss: 0.0032
# Epoch 70/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.8458e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.8935e-04 - target_othernecessities_loss: 6.5320e-04 - target_taxes_loss: 3.2001e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0108 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.4118e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6997e-04 - val_target_taxes_loss: 3.2918e-04 - val_target_transportation_loss: 0.0031
# Epoch 71/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 5.2101e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8334e-04 - target_othernecessities_loss: 6.3862e-04 - target_taxes_loss: 3.2018e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.2033e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.6406e-04 - val_target_taxes_loss: 3.2315e-04 - val_target_transportation_loss: 0.0031
# Epoch 72/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.8008e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7701e-04 - target_othernecessities_loss: 6.3373e-04 - target_taxes_loss: 3.1400e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0107 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.4507e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.4915e-04 - val_target_taxes_loss: 3.0062e-04 - val_target_transportation_loss: 0.0030
# Epoch 73/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.8415e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5595e-04 - target_othernecessities_loss: 6.2800e-04 - target_taxes_loss: 3.0764e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0105 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.3777e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.5052e-04 - val_target_taxes_loss: 2.9947e-04 - val_target_transportation_loss: 0.0031
# Epoch 74/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8915e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4948e-04 - target_othernecessities_loss: 6.2215e-04 - target_taxes_loss: 3.1964e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.2262e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7505e-04 - val_target_taxes_loss: 3.5098e-04 - val_target_transportation_loss: 0.0031
# Epoch 75/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 5.0701e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7549e-04 - target_othernecessities_loss: 6.3585e-04 - target_taxes_loss: 3.0439e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.1366e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.8981e-04 - val_target_taxes_loss: 3.4361e-04 - val_target_transportation_loss: 0.0031
# Epoch 76/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 5.0272e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4788e-04 - target_othernecessities_loss: 6.2247e-04 - target_taxes_loss: 3.1360e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0958e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.4930e-04 - val_target_taxes_loss: 3.1258e-04 - val_target_transportation_loss: 0.0031
# ...
# Epoch 39/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.5598e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9939e-04 - target_taxes_loss: 3.3562e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.9550e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1620e-04 - val_target_taxes_loss: 3.4534e-04 - val_target_transportation_loss: 0.0030
# Epoch 40/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0113 - target_childcare_loss: 0.0016 - target_food_loss: 5.2973e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1408e-04 - target_taxes_loss: 3.3999e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0107 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.2811e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7927e-04 - val_target_taxes_loss: 3.3751e-04 - val_target_transportation_loss: 0.0029
# Epoch 41/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.4497e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9844e-04 - target_taxes_loss: 3.3045e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.9276e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9599e-04 - val_target_taxes_loss: 3.3678e-04 - val_target_transportation_loss: 0.0029
# Epoch 42/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.2000e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7998e-04 - target_taxes_loss: 3.2907e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0109 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.8757e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.7914e-04 - val_target_taxes_loss: 3.2803e-04 - val_target_transportation_loss: 0.0030
# Epoch 43/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 4.9926e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6572e-04 - target_taxes_loss: 3.3327e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0253e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9336e-04 - val_target_taxes_loss: 3.2894e-04 - val_target_transportation_loss: 0.0029
# Epoch 44/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.6639e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2127e-04 - target_taxes_loss: 3.4721e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0585e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0394e-04 - val_target_taxes_loss: 3.5640e-04 - val_target_transportation_loss: 0.0029
# Epoch 45/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.0155e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 9.9366e-04 - target_othernecessities_loss: 6.6389e-04 - target_taxes_loss: 3.2113e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0108 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.9834e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4052e-04 - val_target_taxes_loss: 3.3351e-04 - val_target_transportation_loss: 0.0029
# Epoch 46/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.1625e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9052e-04 - target_taxes_loss: 3.3173e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.8938e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7487e-04 - val_target_taxes_loss: 3.2546e-04 - val_target_transportation_loss: 0.0029
# Epoch 47/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.3845e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9929e-04 - target_taxes_loss: 3.3764e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0106 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.8648e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9168e-04 - val_target_taxes_loss: 3.2821e-04 - val_target_transportation_loss: 0.0029
# Epoch 48/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.6300e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8022e-04 - target_taxes_loss: 3.4198e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.1125e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7336e-04 - val_target_taxes_loss: 3.2285e-04 - val_target_transportation_loss: 0.0029
# Epoch 49/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0110 - target_childcare_loss: 0.0015 - target_food_loss: 5.1247e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1409e-04 - target_taxes_loss: 3.4739e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0111 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 4.9550e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9942e-04 - val_target_taxes_loss: 3.2119e-04 - val_target_transportation_loss: 0.0029
# Epoch 50/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.2465e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2772e-04 - target_taxes_loss: 3.4241e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0000e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8129e-04 - val_target_taxes_loss: 3.2055e-04 - val_target_transportation_loss: 0.0028
# Epoch 51/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 4.9774e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8474e-04 - target_taxes_loss: 3.2754e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.9247e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8257e-04 - val_target_taxes_loss: 3.1876e-04 - val_target_transportation_loss: 0.0029
# Epoch 52/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.2694e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9290e-04 - target_taxes_loss: 3.3066e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0340e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0124e-04 - val_target_taxes_loss: 3.2648e-04 - val_target_transportation_loss: 0.0029
# Epoch 53/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.0304e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9333e-04 - target_taxes_loss: 3.3658e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.8247e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8443e-04 - val_target_taxes_loss: 3.3387e-04 - val_target_transportation_loss: 0.0029
# Epoch 54/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.2090e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7057e-04 - target_taxes_loss: 3.3735e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.9592e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.8052e-04 - val_target_taxes_loss: 3.3362e-04 - val_target_transportation_loss: 0.0029
# Epoch 55/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0014 - target_food_loss: 5.3343e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.8345e-04 - target_taxes_loss: 3.1597e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.8333e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.5759e-04 - val_target_taxes_loss: 3.1439e-04 - val_target_transportation_loss: 0.0029
# Epoch 56/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1845e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8160e-04 - target_taxes_loss: 3.3062e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0894e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7610e-04 - val_target_taxes_loss: 3.3200e-04 - val_target_transportation_loss: 0.0029
# Epoch 57/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0109 - target_childcare_loss: 0.0015 - target_food_loss: 5.4720e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9666e-04 - target_taxes_loss: 3.3511e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.8894e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1793e-04 - val_target_taxes_loss: 3.3706e-04 - val_target_transportation_loss: 0.0029
# Epoch 58/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 4.9999e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9396e-04 - target_taxes_loss: 3.1864e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.1311e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5906e-04 - val_target_taxes_loss: 3.1948e-04 - val_target_transportation_loss: 0.0030
# Epoch 59/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 4.7356e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9221e-04 - target_othernecessities_loss: 6.5500e-04 - target_taxes_loss: 3.2163e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 5.0680e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.8336e-04 - val_target_taxes_loss: 3.3861e-04 - val_target_transportation_loss: 0.0029
# Epoch 60/200
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.2346e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6910e-04 - target_taxes_loss: 3.1599e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.2089e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.6796e-04 - val_target_taxes_loss: 3.3127e-04 - val_target_transportation_loss: 0.0030
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Model Results for Housing:
# Train Data: MAE: 86.9652, R-Squared: 0.8922, RMSE: 128.9412, MSE: 16625.8347 ,smape: 8.033504127367182
# Validation Data: MAE: 87.4096, R-Squared: 0.8818, RMSE: 128.9298, MSE: 16622.9041 ,smape: 8.045751766518752
# Test Data: MAE: 87.4526, R-Squared: 0.8849, RMSE: 128.7935, MSE: 16587.7702 ,smape: 8.123593124995294
#
# Model Results for Food:
# Train Data: MAE: 43.9592, R-Squared: 0.9622, RMSE: 66.4411, MSE: 4414.4153 ,smape: 5.024937839467946
# Validation Data: MAE: 44.1902, R-Squared: 0.9626, RMSE: 65.3011, MSE: 4264.2345 ,smape: 5.054925348654768
# Test Data: MAE: 45.9635, R-Squared: 0.9599, RMSE: 68.8834, MSE: 4744.9165 ,smape: 5.246398764518563
#
# Model Results for Transportation:
# Train Data: MAE: 97.8178, R-Squared: 0.694, RMSE: 132.3282, MSE: 17510.7424 ,smape: 6.381684229588029
# Validation Data: MAE: 96.0694, R-Squared: 0.7008, RMSE: 127.5584, MSE: 16271.1507 ,smape: 6.237287503792062
# Test Data: MAE: 98.0464, R-Squared: 0.6977, RMSE: 131.5737, MSE: 17311.6396 ,smape: 6.406368685540592
#
# Model Results for Healthcare:
# Train Data: MAE: 126.4048, R-Squared: 0.8609, RMSE: 183.8199, MSE: 33789.7721 ,smape: 10.130765003503003
# Validation Data: MAE: 128.132, R-Squared: 0.8567, RMSE: 183.9189, MSE: 33826.1478 ,smape: 10.25742511865758
# Test Data: MAE: 127.2589, R-Squared: 0.8599, RMSE: 185.2459, MSE: 34316.0404 ,smape: 10.264532202428901
#
# Model Results for Othernecessities:
# Train Data: MAE: 35.2769, R-Squared: 0.9504, RMSE: 51.5218, MSE: 2654.4909 ,smape: 5.135633556326616
# Validation Data: MAE: 35.2924, R-Squared: 0.9476, RMSE: 51.3139, MSE: 2633.1212 ,smape: 5.136359027342528
# Test Data: MAE: 35.6614, R-Squared: 0.9478, RMSE: 51.9309, MSE: 2696.8144 ,smape: 5.221686400239989
#
# Model Results for Childcare:
# Train Data: MAE: 101.7574, R-Squared: 0.9411, RMSE: 153.466, MSE: 23551.8096 ,smape: 9.242694373169407
# Validation Data: MAE: 103.564, R-Squared: 0.9372, RMSE: 155.4004, MSE: 24149.2955 ,smape: 9.417969847764832
# Test Data: MAE: 102.5235, R-Squared: 0.9353, RMSE: 157.6715, MSE: 24860.2884 ,smape: 9.141966183680516
#
# Model Results for Taxes:
# Train Data: MAE: 52.4144, R-Squared: 0.9654, RMSE: 77.1631, MSE: 5954.1426 ,smape: 5.8325720233971206
# Validation Data: MAE: 52.6972, R-Squared: 0.9627, RMSE: 77.5101, MSE: 6007.8192 ,smape: 5.880388388479011
# Test Data: MAE: 52.899, R-Squared: 0.9627, RMSE: 77.9842, MSE: 6081.5301 ,smape: 5.905352918248105

# %%
import pandas as pd
import numpy as np
import joblib

# Load the scalers
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')

def get_prediction(model, input_data):
    # Step 1: Preprocess input data (same as training)
    input_data["per_member_cost"] = input_data["total"] / input_data["n_members"]
    input_data["child_expense_cost"] = input_data["per_member_cost"] * input_data["n_children"]
    input_data["parent_expense_cost"] = input_data["per_member_cost"] * input_data["n_parents"]
    input_data["other_expense_cost"] = input_data["total"] - (
        input_data["child_expense_cost"] + input_data["parent_expense_cost"]
    )

    # Convert input data to numpy array
    input_data_val = input_data[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents',
                                 'n_members', 'per_member_cost', 'child_expense_cost', 'parent_expense_cost', 'other_expense_cost']].values

    # Step 2: Scale the input data using the pre-fitted scaler_X
    input_data_val_scaled = scaler_X.transform(input_data_val)

    # Ensure model expects input in the right shape (if using CNN or RNN, it might need reshaping)
    input_data_val_scaled = input_data_val_scaled[..., np.newaxis]  # If needed

    # Step 3: Make predictions using the trained model
    raw_predictions = model.predict(input_data_val_scaled)

    # Step 3.5: Reshape raw_predictions before inverse scaling
    raw_predictions = np.squeeze(raw_predictions, axis=-1)  # Remove the extra dimension
    raw_predictions = np.column_stack(raw_predictions) # Reshape to 2D

    # Step 4: Inverse transform the predictions to return them to the original scale
    input_data_pred_original = scaler_y.inverse_transform(raw_predictions)

    return input_data_pred_original

# Example of input data to test predictions
input_data = pd.DataFrame(
    [[3803, 87000, 67, 0, 1, 1]],
    columns=['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']
)

input_data_pred_original = get_prediction(model, input_data)

# Print predictions
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']
for i, prediction in enumerate(input_data_pred_original[0]):
    print(f"{target_col_list[i]}: {prediction:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-151cd36987c3> in <cell line: 46>()
#      44 )
#      45
# ---> 46 input_data_pred_original = get_prediction(model, input_data)
#      47
#      48 # Print predictions
#
# NameError: name 'model' is not defined
