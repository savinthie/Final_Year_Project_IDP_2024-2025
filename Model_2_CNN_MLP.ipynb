# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_IDP_2024-2025/blob/main/Model_2_CNN_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
df = df.fillna(0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Data Preprocessing

df.columns = [col.lower().replace(' ', '').replace('.', '') for col in df.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
df1 = df[cols_to_keep].copy()

df1['median_family_income'] = df1['median_family_income'].replace(',', '', regex=True).astype(float)
df1['median_family_income'] = df1['median_family_income'].map(lambda x: x/12)

# %%
# Feature Engineering
df1['n_parents'] = df1['family'].str.slice(0, 1).astype(int)
df1['n_children'] = df1['family'].str.slice(2, 3).astype(int)
df1['n_members'] = df1['n_parents'] + df1['n_children']
df1['financial_stability'] = df1['median_family_income'] / df1['total']
df1["per_member_cost"] = df1["total"] / df1["n_members"]
df1["child_expense_cost"] = df1["per_member_cost"]*df1["n_children"]
df1["parent_expense_cost"] = df1["per_member_cost"]*df1["n_parents"]
df1["other_expense_cost"] = df1["total"] - (df1["child_expense_cost"]+df1["parent_expense_cost"])

df1["zero_childcare_cost"] = df1['n_children'].map(lambda x: 0 if x < 1 else 1)

# %%
# Splitting the data
X = df1[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost','zero_childcare_cost']].values
y_expenses = df1[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = MinMaxScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)


# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
def replace_zeros_with_ones(a, b):
    # Iterate through both lists simultaneously
    for i in range(len(a)):
        # If both value is 0, replace both with 1
        if a[i] == 0 and b[i] == 0:
            a[i] = 1
            b[i] = 1
    return a, b

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def calculateSmape(y_true, y_pred):
    """
    Calculate Symmetric Mean Absolute Percentage Error (SMAPE).

    Parameters:
    y_true (array-like): Actual values.
    y_pred (array-like): Predicted values.

    Returns:
    float: SMAPE value.
    """
    y_true, y_pred = replace_zeros_with_ones(y_true, y_pred)
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_value = np.mean(numerator / denominator) * 100
    return smape_value

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    smape_score = calculateSmape(x, y)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse} ,smape: {smape_score}'

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import xgboost as xgb

num_children_col = 3  # 4th position, 0-indexed
childcare_exp_col = target_col_list.index('childcare')  # Replace 'childcare_exp' with the actual target name

# %%
from tensorflow.keras.layers import Input, Conv1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# L2 regularization strength (you can tune this value)
l2_strength = 0.01

# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
global X_train_global, X_test_global, X_val_global
global y_train_global, y_test_global, y_val_global

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    global X_train_global, X_test_global, X_val_global
    global y_train_global, y_test_global, y_val_global
    fold = 1
    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100) # 50/50 split of remaining 20%

        X_train_global, X_test_global, X_val_global = X_train, X_test, X_val
        y_train_global, y_test_global, y_val_global = y_train, y_test, y_val

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        model.summary()

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Training
        model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks= [early_stopping])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test)) #Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test) #Inverse transform for test set

        # Enforce the rule after predictions for childcare expense
        # The issue is likely caused by X_train having an extra dimension due to[..., np.newaxis].
        # We need to select the original features for the condition
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col, 0] == 0, 0, y_train_pred_original[:, childcare_exp_col]) #Using X_train[:, num_children_col, 0] instead of X_train[:, num_children_col]

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col, 0] == 0, 0, y_val_pred_original[:, childcare_exp_col]) #Using X_val[:, num_children_col, 0] instead of X_val[:, num_children_col]

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col]) #Using X_test[:, num_children_col, 0] instead of X_test[:, num_children_col]

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return model

model_combine = cross_val_with_evaluation(X_scaled, y_exp_scaled,kf)
# Out:
# Fold 1/5
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 11, 1)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_5 (Conv1D)         │ (None, 11, 8)          │             32 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_5 (Flatten)       │ (None, 88)             │              0 │ conv1d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 128)            │         11,392 │ flatten_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 64)             │          8,256 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_11[0][0]         │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_healthcare (Dense) │ (None, 1)              │             65 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_othernecessities   │ (None, 1)              │             65 │ dense_11[0][0]         │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_childcare (Dense)  │ (None, 1)              │             65 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_taxes (Dense)      │ (None, 1)              │             65 │ dense_11[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,135 (78.65 KB)
#  Trainable params: 20,135 (78.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.0629 - target_childcare_loss: 0.0096 - target_food_loss: 0.0058 - target_healthcare_loss: 0.0123 - target_housing_loss: 0.0138 - target_othernecessities_loss: 0.0081 - target_taxes_loss: 0.0049 - target_transportation_loss: 0.0085 - val_loss: 0.0137 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.4704e-04 - val_target_healthcare_loss: 0.0048 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 9.0892e-04 - val_target_taxes_loss: 5.2901e-04 - val_target_transportation_loss: 0.0036
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0138 - target_childcare_loss: 0.0020 - target_food_loss: 6.1131e-04 - target_healthcare_loss: 0.0050 - target_housing_loss: 0.0013 - target_othernecessities_loss: 9.0391e-04 - target_taxes_loss: 5.1930e-04 - target_transportation_loss: 0.0034 - val_loss: 0.0131 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.2951e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.4362e-04 - val_target_taxes_loss: 4.5205e-04 - val_target_transportation_loss: 0.0035
# Epoch 3/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0133 - target_childcare_loss: 0.0020 - target_food_loss: 5.6035e-04 - target_healthcare_loss: 0.0049 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.4833e-04 - target_taxes_loss: 4.3277e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0129 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.7840e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.1971e-04 - val_target_taxes_loss: 4.6584e-04 - val_target_transportation_loss: 0.0036
# Epoch 4/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0132 - target_childcare_loss: 0.0020 - target_food_loss: 6.0257e-04 - target_healthcare_loss: 0.0048 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.1468e-04 - target_taxes_loss: 4.2215e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0128 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8177e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.0367e-04 - val_target_taxes_loss: 4.1885e-04 - val_target_transportation_loss: 0.0035
# Epoch 5/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0128 - target_childcare_loss: 0.0019 - target_food_loss: 5.8913e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.2315e-04 - target_taxes_loss: 3.9087e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.6504e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9061e-04 - val_target_taxes_loss: 4.1376e-04 - val_target_transportation_loss: 0.0034
# Epoch 6/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0125 - target_childcare_loss: 0.0019 - target_food_loss: 5.4799e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9055e-04 - target_taxes_loss: 3.8837e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0129 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 4.7224e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.8505e-04 - val_target_taxes_loss: 3.7851e-04 - val_target_transportation_loss: 0.0038
# Epoch 7/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.4223e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.8533e-04 - target_taxes_loss: 3.8774e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0123 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6392e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7391e-04 - val_target_taxes_loss: 3.8057e-04 - val_target_transportation_loss: 0.0034
# Epoch 8/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.5160e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6444e-04 - target_taxes_loss: 3.7526e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.4983e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5664e-04 - val_target_taxes_loss: 3.7009e-04 - val_target_transportation_loss: 0.0033
# Epoch 9/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.5140e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5082e-04 - target_taxes_loss: 3.7233e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6277e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.8035e-04 - val_target_taxes_loss: 3.9279e-04 - val_target_transportation_loss: 0.0035
# Epoch 10/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.5440e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6760e-04 - target_taxes_loss: 3.6446e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0127 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.7980e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.7471e-04 - val_target_taxes_loss: 4.5328e-04 - val_target_transportation_loss: 0.0035
# Epoch 11/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.5156e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.7857e-04 - target_taxes_loss: 3.8157e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.8704e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.4394e-04 - val_target_taxes_loss: 4.0311e-04 - val_target_transportation_loss: 0.0033
# Epoch 12/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0122 - target_childcare_loss: 0.0018 - target_food_loss: 5.4608e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.7486e-04 - target_taxes_loss: 3.7357e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.1833e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.6693e-04 - val_target_taxes_loss: 3.6371e-04 - val_target_transportation_loss: 0.0035
# Epoch 13/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.3691e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4837e-04 - target_taxes_loss: 3.7071e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0125 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6837e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9814e-04 - val_target_taxes_loss: 4.0521e-04 - val_target_transportation_loss: 0.0034
# Epoch 14/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0018 - target_food_loss: 5.4870e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.6938e-04 - target_taxes_loss: 3.8525e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.7137e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4733e-04 - val_target_taxes_loss: 3.9205e-04 - val_target_transportation_loss: 0.0034
# Epoch 15/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0119 - target_childcare_loss: 0.0018 - target_food_loss: 5.4287e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2770e-04 - target_taxes_loss: 3.5288e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6700e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6388e-04 - val_target_taxes_loss: 3.6582e-04 - val_target_transportation_loss: 0.0033
# Epoch 16/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0018 - target_food_loss: 5.5670e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5632e-04 - target_taxes_loss: 3.7840e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0126 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 4.6869e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.0892e-04 - val_target_taxes_loss: 3.9608e-04 - val_target_transportation_loss: 0.0034
# Epoch 17/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.6615e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3083e-04 - target_taxes_loss: 3.5753e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5656e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5421e-04 - val_target_taxes_loss: 3.8278e-04 - val_target_transportation_loss: 0.0033
# Epoch 18/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.7863e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5077e-04 - target_taxes_loss: 3.6210e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6021e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4453e-04 - val_target_taxes_loss: 3.9654e-04 - val_target_transportation_loss: 0.0033
# Epoch 19/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.6461e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3463e-04 - target_taxes_loss: 3.6096e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6144e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5140e-04 - val_target_taxes_loss: 3.7665e-04 - val_target_transportation_loss: 0.0033
# Epoch 20/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.3666e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3674e-04 - target_taxes_loss: 3.4788e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.4703e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.2696e-04 - val_target_taxes_loss: 3.5560e-04 - val_target_transportation_loss: 0.0033
# Epoch 21/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.3582e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2282e-04 - target_taxes_loss: 3.4712e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0114 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5734e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3769e-04 - val_target_taxes_loss: 3.8402e-04 - val_target_transportation_loss: 0.0033
# Epoch 22/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.5016e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1734e-04 - target_taxes_loss: 3.3754e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5071e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4997e-04 - val_target_taxes_loss: 3.9643e-04 - val_target_transportation_loss: 0.0033
# Epoch 23/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0112 - target_childcare_loss: 0.0017 - target_food_loss: 5.0790e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8485e-04 - target_taxes_loss: 3.4191e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.6641e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4176e-04 - val_target_taxes_loss: 3.5773e-04 - val_target_transportation_loss: 0.0032
# Epoch 24/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0113 - target_childcare_loss: 0.0017 - target_food_loss: 5.1786e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0249e-04 - target_taxes_loss: 3.4009e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.7164e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2408e-04 - val_target_taxes_loss: 3.5200e-04 - val_target_transportation_loss: 0.0032
# Epoch 25/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.3454e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0542e-04 - target_taxes_loss: 3.3238e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0113 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.9180e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2615e-04 - val_target_taxes_loss: 3.4862e-04 - val_target_transportation_loss: 0.0032
# Epoch 26/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0113 - target_childcare_loss: 0.0016 - target_food_loss: 5.7541e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0201e-04 - target_taxes_loss: 3.4299e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.7140e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2740e-04 - val_target_taxes_loss: 3.3830e-04 - val_target_transportation_loss: 0.0032
# Epoch 27/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.3289e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0044e-04 - target_taxes_loss: 3.3690e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.8531e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0411e-04 - val_target_taxes_loss: 3.3375e-04 - val_target_transportation_loss: 0.0033
# Epoch 28/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.3902e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0161e-04 - target_taxes_loss: 3.3419e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0108 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5162e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2286e-04 - val_target_taxes_loss: 3.2981e-04 - val_target_transportation_loss: 0.0032
# Epoch 29/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.2951e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1212e-04 - target_taxes_loss: 3.4821e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6813e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3730e-04 - val_target_taxes_loss: 3.4246e-04 - val_target_transportation_loss: 0.0032
# Epoch 30/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.4877e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.8625e-04 - target_taxes_loss: 3.3710e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4143e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.2462e-04 - val_target_taxes_loss: 3.4028e-04 - val_target_transportation_loss: 0.0032
# Epoch 31/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0016 - target_food_loss: 5.2589e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9014e-04 - target_taxes_loss: 3.2931e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6374e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2952e-04 - val_target_taxes_loss: 3.4434e-04 - val_target_transportation_loss: 0.0033
# Epoch 32/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.2140e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8086e-04 - target_taxes_loss: 3.2184e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0111 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5219e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4344e-04 - val_target_taxes_loss: 3.2747e-04 - val_target_transportation_loss: 0.0033
# Epoch 33/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.5246e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9876e-04 - target_taxes_loss: 3.3745e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0108 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4040e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9211e-04 - val_target_taxes_loss: 3.2492e-04 - val_target_transportation_loss: 0.0032
# Epoch 34/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.4228e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7863e-04 - target_taxes_loss: 3.2289e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.7597e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8125e-04 - val_target_taxes_loss: 3.3382e-04 - val_target_transportation_loss: 0.0032
# Epoch 35/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0016 - target_food_loss: 5.2783e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7302e-04 - target_taxes_loss: 3.3819e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4873e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0255e-04 - val_target_taxes_loss: 3.2488e-04 - val_target_transportation_loss: 0.0032
# Epoch 36/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.1667e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.5997e-04 - target_taxes_loss: 3.2241e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3686e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.7406e-04 - val_target_othernecessities_loss: 6.5317e-04 - val_target_taxes_loss: 3.9534e-04 - val_target_transportation_loss: 0.0032
# Epoch 37/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.3313e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.9883e-04 - target_othernecessities_loss: 6.4929e-04 - target_taxes_loss: 3.2413e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5326e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.8784e-04 - val_target_othernecessities_loss: 6.7116e-04 - val_target_taxes_loss: 3.2129e-04 - val_target_transportation_loss: 0.0032
# Epoch 38/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.5453e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7551e-04 - target_taxes_loss: 3.1737e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0104 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.6505e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7289e-04 - val_target_taxes_loss: 3.1878e-04 - val_target_transportation_loss: 0.0032
# Epoch 39/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.0346e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.7487e-04 - target_othernecessities_loss: 6.4262e-04 - target_taxes_loss: 3.2077e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5527e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.8233e-04 - val_target_othernecessities_loss: 6.6144e-04 - val_target_taxes_loss: 3.2800e-04 - val_target_transportation_loss: 0.0032
# Epoch 40/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.0303e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9434e-04 - target_othernecessities_loss: 6.5453e-04 - target_taxes_loss: 3.1282e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4156e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0574e-04 - val_target_taxes_loss: 3.7705e-04 - val_target_transportation_loss: 0.0031
# Epoch 41/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.1476e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.7846e-04 - target_othernecessities_loss: 6.4961e-04 - target_taxes_loss: 3.1654e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.3158e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6958e-04 - val_target_taxes_loss: 3.2919e-04 - val_target_transportation_loss: 0.0031
# Epoch 42/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.1462e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9259e-04 - target_othernecessities_loss: 6.5015e-04 - target_taxes_loss: 3.1389e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3404e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0065e-04 - val_target_taxes_loss: 3.1611e-04 - val_target_transportation_loss: 0.0032
# Epoch 43/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.1597e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.8469e-04 - target_othernecessities_loss: 6.4599e-04 - target_taxes_loss: 3.2221e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4982e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8151e-04 - val_target_othernecessities_loss: 6.5399e-04 - val_target_taxes_loss: 3.1539e-04 - val_target_transportation_loss: 0.0031
# Epoch 44/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 5.0202e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8559e-04 - target_othernecessities_loss: 6.3851e-04 - target_taxes_loss: 3.0993e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.8116e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7841e-04 - val_target_taxes_loss: 3.4607e-04 - val_target_transportation_loss: 0.0031
# Epoch 45/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 4.9587e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.5351e-04 - target_taxes_loss: 3.1840e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7478e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.6422e-04 - val_target_othernecessities_loss: 6.5789e-04 - val_target_taxes_loss: 3.0736e-04 - val_target_transportation_loss: 0.0031
# Epoch 46/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0102 - target_childcare_loss: 0.0015 - target_food_loss: 5.2799e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8216e-04 - target_othernecessities_loss: 6.3623e-04 - target_taxes_loss: 3.0433e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5109e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.4482e-04 - val_target_othernecessities_loss: 6.4017e-04 - val_target_taxes_loss: 3.2039e-04 - val_target_transportation_loss: 0.0032
# Epoch 47/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.8479e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.6740e-04 - target_othernecessities_loss: 6.3198e-04 - target_taxes_loss: 2.9919e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0106 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.3842e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7526e-04 - val_target_taxes_loss: 3.6201e-04 - val_target_transportation_loss: 0.0030
# Epoch 48/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.0706e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6323e-04 - target_taxes_loss: 3.0945e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3698e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8093e-04 - val_target_othernecessities_loss: 6.6704e-04 - val_target_taxes_loss: 3.1378e-04 - val_target_transportation_loss: 0.0032
# Epoch 49/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0106e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.6632e-04 - target_othernecessities_loss: 6.3602e-04 - target_taxes_loss: 3.0237e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0100 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.5315e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.4616e-04 - val_target_othernecessities_loss: 6.3824e-04 - val_target_taxes_loss: 3.3813e-04 - val_target_transportation_loss: 0.0030
# Epoch 50/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 5.0168e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.9282e-04 - target_othernecessities_loss: 6.4489e-04 - target_taxes_loss: 3.0276e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.5190e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.6621e-04 - val_target_othernecessities_loss: 6.4773e-04 - val_target_taxes_loss: 3.2026e-04 - val_target_transportation_loss: 0.0031
# Epoch 51/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.9637e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.6310e-04 - target_othernecessities_loss: 6.2447e-04 - target_taxes_loss: 2.9970e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3193e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 9.5253e-04 - val_target_othernecessities_loss: 6.2131e-04 - val_target_taxes_loss: 2.9976e-04 - val_target_transportation_loss: 0.0031
# Epoch 52/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.8687e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5278e-04 - target_othernecessities_loss: 6.2033e-04 - target_taxes_loss: 3.0589e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4164e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.5800e-04 - val_target_othernecessities_loss: 6.4881e-04 - val_target_taxes_loss: 3.1653e-04 - val_target_transportation_loss: 0.0031
# Epoch 53/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0268e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.9200e-04 - target_othernecessities_loss: 6.3053e-04 - target_taxes_loss: 2.9291e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.4291e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.4362e-04 - val_target_othernecessities_loss: 6.1313e-04 - val_target_taxes_loss: 3.2131e-04 - val_target_transportation_loss: 0.0031
# Epoch 54/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.8429e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.6320e-04 - target_othernecessities_loss: 6.2561e-04 - target_taxes_loss: 2.9498e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2890e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.2800e-04 - val_target_othernecessities_loss: 6.1607e-04 - val_target_taxes_loss: 3.0416e-04 - val_target_transportation_loss: 0.0030
# Epoch 55/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.7308e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5039e-04 - target_othernecessities_loss: 6.1904e-04 - target_taxes_loss: 3.0328e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.7628e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.3361e-04 - val_target_othernecessities_loss: 6.1411e-04 - val_target_taxes_loss: 3.4304e-04 - val_target_transportation_loss: 0.0031
# Epoch 56/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0263e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7452e-04 - target_othernecessities_loss: 6.3011e-04 - target_taxes_loss: 3.0497e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5091e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.5676e-04 - val_target_othernecessities_loss: 6.3923e-04 - val_target_taxes_loss: 3.0572e-04 - val_target_transportation_loss: 0.0031
# Epoch 57/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 5.0645e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4906e-04 - target_othernecessities_loss: 6.1179e-04 - target_taxes_loss: 2.8737e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0101 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5006e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.6488e-04 - val_target_othernecessities_loss: 6.3592e-04 - val_target_taxes_loss: 2.9981e-04 - val_target_transportation_loss: 0.0031
# Epoch 58/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.9673e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7491e-04 - target_othernecessities_loss: 6.2649e-04 - target_taxes_loss: 2.9676e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2665e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.2394e-04 - val_target_othernecessities_loss: 6.1849e-04 - val_target_taxes_loss: 3.0178e-04 - val_target_transportation_loss: 0.0030
# Epoch 59/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0096 - target_childcare_loss: 0.0013 - target_food_loss: 4.8232e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.2547e-04 - target_othernecessities_loss: 5.9570e-04 - target_taxes_loss: 2.9808e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.5319e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.5391e-04 - val_target_othernecessities_loss: 6.3048e-04 - val_target_taxes_loss: 2.9599e-04 - val_target_transportation_loss: 0.0031
# Epoch 60/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8063e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3125e-04 - target_othernecessities_loss: 6.0765e-04 - target_taxes_loss: 2.9146e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2256e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.2545e-04 - val_target_othernecessities_loss: 6.1110e-04 - val_target_taxes_loss: 3.2944e-04 - val_target_transportation_loss: 0.0030
# Epoch 61/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.9702e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.3215e-04 - target_othernecessities_loss: 6.0048e-04 - target_taxes_loss: 2.9308e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5013e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.4538e-04 - val_target_othernecessities_loss: 6.5295e-04 - val_target_taxes_loss: 3.1366e-04 - val_target_transportation_loss: 0.0030
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 5.0798e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4922e-04 - target_othernecessities_loss: 6.1376e-04 - target_taxes_loss: 2.9246e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2667e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3360e-04 - val_target_othernecessities_loss: 6.1036e-04 - val_target_taxes_loss: 3.0298e-04 - val_target_transportation_loss: 0.0030
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.9166e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1867e-04 - target_othernecessities_loss: 5.9716e-04 - target_taxes_loss: 2.8299e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2623e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3220e-04 - val_target_othernecessities_loss: 6.1863e-04 - val_target_taxes_loss: 2.9562e-04 - val_target_transportation_loss: 0.0030
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7965e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.6010e-04 - target_othernecessities_loss: 6.1353e-04 - target_taxes_loss: 2.9388e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2214e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.5429e-04 - val_target_othernecessities_loss: 6.3940e-04 - val_target_taxes_loss: 3.0173e-04 - val_target_transportation_loss: 0.0030
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7951e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4597e-04 - target_othernecessities_loss: 6.1165e-04 - target_taxes_loss: 2.9413e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2865e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.5903e-04 - val_target_othernecessities_loss: 6.1326e-04 - val_target_taxes_loss: 2.9055e-04 - val_target_transportation_loss: 0.0030
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.6913e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.2042e-04 - target_othernecessities_loss: 5.9563e-04 - target_taxes_loss: 2.7747e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.5772e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.1713e-04 - val_target_othernecessities_loss: 5.9241e-04 - val_target_taxes_loss: 2.9511e-04 - val_target_transportation_loss: 0.0030
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0096 - target_childcare_loss: 0.0013 - target_food_loss: 4.8312e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.5960e-04 - target_othernecessities_loss: 6.0070e-04 - target_taxes_loss: 2.9519e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.4280e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.1214e-04 - val_target_othernecessities_loss: 6.0856e-04 - val_target_taxes_loss: 3.4762e-04 - val_target_transportation_loss: 0.0031
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 5.0234e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7102e-04 - target_othernecessities_loss: 6.1119e-04 - target_taxes_loss: 2.9376e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3530e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.2673e-04 - val_target_othernecessities_loss: 6.0125e-04 - val_target_taxes_loss: 2.9456e-04 - val_target_transportation_loss: 0.0030
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.7115e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.5602e-04 - target_othernecessities_loss: 6.0723e-04 - target_taxes_loss: 2.8480e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2096e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.6220e-04 - val_target_othernecessities_loss: 6.0800e-04 - val_target_taxes_loss: 2.9308e-04 - val_target_transportation_loss: 0.0030
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6434e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3037e-04 - target_othernecessities_loss: 5.9448e-04 - target_taxes_loss: 2.8602e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2620e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3496e-04 - val_target_othernecessities_loss: 6.0780e-04 - val_target_taxes_loss: 2.8441e-04 - val_target_transportation_loss: 0.0030
# Epoch 71/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6438e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.2169e-04 - target_othernecessities_loss: 5.9115e-04 - target_taxes_loss: 2.8052e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2405e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.2309e-04 - val_target_othernecessities_loss: 5.9087e-04 - val_target_taxes_loss: 2.9034e-04 - val_target_transportation_loss: 0.0030
# Epoch 72/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6663e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1275e-04 - target_othernecessities_loss: 5.8521e-04 - target_taxes_loss: 2.8343e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1299e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.1037e-04 - val_target_othernecessities_loss: 5.8828e-04 - val_target_taxes_loss: 3.0502e-04 - val_target_transportation_loss: 0.0030
# Epoch 73/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6772e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1931e-04 - target_othernecessities_loss: 5.8345e-04 - target_taxes_loss: 2.7509e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.4954e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.1395e-04 - val_target_othernecessities_loss: 5.8446e-04 - val_target_taxes_loss: 2.8267e-04 - val_target_transportation_loss: 0.0029
# Epoch 74/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.8321e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3282e-04 - target_othernecessities_loss: 5.9808e-04 - target_taxes_loss: 2.8132e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3214e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 9.2246e-04 - val_target_othernecessities_loss: 6.0253e-04 - val_target_taxes_loss: 2.9612e-04 - val_target_transportation_loss: 0.0030
# Epoch 75/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 5.1834e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3968e-04 - target_othernecessities_loss: 5.9530e-04 - target_taxes_loss: 2.8836e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.7264e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.1919e-04 - val_target_othernecessities_loss: 6.0691e-04 - val_target_taxes_loss: 3.0237e-04 - val_target_transportation_loss: 0.0030
# Epoch 76/200
# ...
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.9061e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3406e-04 - target_othernecessities_loss: 6.1629e-04 - target_taxes_loss: 3.0221e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7137e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 9.0204e-04 - val_target_othernecessities_loss: 5.8219e-04 - val_target_taxes_loss: 2.8607e-04 - val_target_transportation_loss: 0.0027
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 5.1625e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.3499e-04 - target_othernecessities_loss: 6.1768e-04 - target_taxes_loss: 2.9612e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.7313e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.1683e-04 - val_target_othernecessities_loss: 5.8978e-04 - val_target_taxes_loss: 3.1154e-04 - val_target_transportation_loss: 0.0029
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.8270e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.2804e-04 - target_othernecessities_loss: 6.0647e-04 - target_taxes_loss: 3.0200e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.8448e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.2449e-04 - val_target_othernecessities_loss: 5.7017e-04 - val_target_taxes_loss: 3.4033e-04 - val_target_transportation_loss: 0.0028
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 5.0480e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.2575e-04 - target_othernecessities_loss: 6.0228e-04 - target_taxes_loss: 2.9595e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.8614e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 8.9740e-04 - val_target_othernecessities_loss: 5.9085e-04 - val_target_taxes_loss: 3.0863e-04 - val_target_transportation_loss: 0.0027
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9193e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.5618e-04 - target_othernecessities_loss: 6.3354e-04 - target_taxes_loss: 3.0629e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7300e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7955e-04 - val_target_othernecessities_loss: 5.7292e-04 - val_target_taxes_loss: 3.0857e-04 - val_target_transportation_loss: 0.0028
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.7630e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1957e-04 - target_othernecessities_loss: 6.0174e-04 - target_taxes_loss: 2.9012e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.1710e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.8237e-04 - val_target_othernecessities_loss: 5.5565e-04 - val_target_taxes_loss: 2.9435e-04 - val_target_transportation_loss: 0.0027
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.6770e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.0130e-04 - target_othernecessities_loss: 5.8835e-04 - target_taxes_loss: 2.9591e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7277e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.0744e-04 - val_target_othernecessities_loss: 5.8374e-04 - val_target_taxes_loss: 3.1473e-04 - val_target_transportation_loss: 0.0027
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.7667e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3187e-04 - target_othernecessities_loss: 5.9691e-04 - target_taxes_loss: 2.8281e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6887e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7276e-04 - val_target_othernecessities_loss: 5.6645e-04 - val_target_taxes_loss: 2.9610e-04 - val_target_transportation_loss: 0.0027
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.8237e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.2580e-04 - target_othernecessities_loss: 5.8755e-04 - target_taxes_loss: 2.8828e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7743e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7129e-04 - val_target_othernecessities_loss: 5.6123e-04 - val_target_taxes_loss: 2.8758e-04 - val_target_transportation_loss: 0.0027
# Epoch 71/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7908e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 8.9092e-04 - target_othernecessities_loss: 5.8667e-04 - target_taxes_loss: 2.8275e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7909e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9328e-04 - val_target_othernecessities_loss: 5.8615e-04 - val_target_taxes_loss: 3.1444e-04 - val_target_transportation_loss: 0.0027
# Epoch 72/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.6087e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0598e-04 - target_othernecessities_loss: 5.7914e-04 - target_taxes_loss: 2.8055e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6531e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.9462e-04 - val_target_othernecessities_loss: 5.7544e-04 - val_target_taxes_loss: 2.9514e-04 - val_target_transportation_loss: 0.0027
# Epoch 73/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 5.0619e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.0912e-04 - target_othernecessities_loss: 5.9436e-04 - target_taxes_loss: 3.0329e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.8599e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8946e-04 - val_target_othernecessities_loss: 5.7036e-04 - val_target_taxes_loss: 2.9709e-04 - val_target_transportation_loss: 0.0028
# Epoch 74/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.9255e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.0934e-04 - target_othernecessities_loss: 5.9004e-04 - target_taxes_loss: 2.9456e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6917e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.9617e-04 - val_target_othernecessities_loss: 5.7606e-04 - val_target_taxes_loss: 2.8662e-04 - val_target_transportation_loss: 0.0028
# Epoch 75/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.5072e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1383e-04 - target_othernecessities_loss: 5.8653e-04 - target_taxes_loss: 2.8807e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5778e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7238e-04 - val_target_othernecessities_loss: 5.5908e-04 - val_target_taxes_loss: 3.2150e-04 - val_target_transportation_loss: 0.0028
# Epoch 76/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.7132e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0535e-04 - target_othernecessities_loss: 5.9216e-04 - target_taxes_loss: 2.9942e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7284e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.8278e-04 - val_target_othernecessities_loss: 5.6579e-04 - val_target_taxes_loss: 3.0339e-04 - val_target_transportation_loss: 0.0027
# Epoch 77/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.9521e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3136e-04 - target_othernecessities_loss: 6.0479e-04 - target_taxes_loss: 2.9438e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.8602e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.8608e-04 - val_target_othernecessities_loss: 5.6880e-04 - val_target_taxes_loss: 2.9981e-04 - val_target_transportation_loss: 0.0027
# Epoch 78/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 5.2003e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1715e-04 - target_othernecessities_loss: 5.8983e-04 - target_taxes_loss: 2.8820e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7398e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.8077e-04 - val_target_othernecessities_loss: 5.7411e-04 - val_target_taxes_loss: 2.9358e-04 - val_target_transportation_loss: 0.0027
# Epoch 79/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7730e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3704e-04 - target_othernecessities_loss: 6.0632e-04 - target_taxes_loss: 2.8287e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.8657e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.0712e-04 - val_target_othernecessities_loss: 5.7048e-04 - val_target_taxes_loss: 3.2694e-04 - val_target_transportation_loss: 0.0027
# Epoch 80/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7833e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1661e-04 - target_othernecessities_loss: 6.0429e-04 - target_taxes_loss: 2.9140e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.8698e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.0210e-04 - val_target_othernecessities_loss: 5.5554e-04 - val_target_taxes_loss: 2.8863e-04 - val_target_transportation_loss: 0.0029
# Epoch 81/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6981e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0017e-04 - target_othernecessities_loss: 5.8462e-04 - target_taxes_loss: 2.7736e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7761e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.4310e-04 - val_target_othernecessities_loss: 5.6965e-04 - val_target_taxes_loss: 2.8533e-04 - val_target_transportation_loss: 0.0027
# Epoch 82/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.8756e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.2538e-04 - target_othernecessities_loss: 5.9166e-04 - target_taxes_loss: 2.8244e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.9287e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 8.6778e-04 - val_target_othernecessities_loss: 5.7067e-04 - val_target_taxes_loss: 2.9273e-04 - val_target_transportation_loss: 0.0027
# Epoch 83/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.9570e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1285e-04 - target_othernecessities_loss: 5.8759e-04 - target_taxes_loss: 2.9538e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.3013e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.9457e-04 - val_target_othernecessities_loss: 6.2544e-04 - val_target_taxes_loss: 2.7933e-04 - val_target_transportation_loss: 0.0027
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model Results for Housing:
# Train Data: MAE: 82.1242, R-Squared: 0.9038, RMSE: 120.0892, MSE: 14421.41 ,smape: 7.658394163916933
# Validation Data: MAE: 83.0142, R-Squared: 0.8929, RMSE: 119.0114, MSE: 14163.7064 ,smape: 7.746275467367414
# Test Data: MAE: 83.8033, R-Squared: 0.9025, RMSE: 121.5108, MSE: 14764.8705 ,smape: 7.810473737728106
#
# Model Results for Food:
# Train Data: MAE: 44.825, R-Squared: 0.9643, RMSE: 64.5149, MSE: 4162.1682 ,smape: 5.113643905748614
# Validation Data: MAE: 47.4888, R-Squared: 0.9567, RMSE: 71.0143, MSE: 5043.0329 ,smape: 5.369554710878666
# Test Data: MAE: 44.9286, R-Squared: 0.9645, RMSE: 64.0909, MSE: 4107.6435 ,smape: 5.161619048259473
#
# Model Results for Transportation:
# Train Data: MAE: 95.4062, R-Squared: 0.7107, RMSE: 128.0235, MSE: 16390.0283 ,smape: 6.202926013185163
# Validation Data: MAE: 94.6683, R-Squared: 0.7111, RMSE: 125.5896, MSE: 15772.7585 ,smape: 6.151645789180337
# Test Data: MAE: 95.2611, R-Squared: 0.7151, RMSE: 127.9111, MSE: 16361.2489 ,smape: 6.206041495339926
#
# Model Results for Healthcare:
# Train Data: MAE: 118.857, R-Squared: 0.8822, RMSE: 168.7967, MSE: 28492.3232 ,smape: 9.72162713824164
# Validation Data: MAE: 120.5497, R-Squared: 0.8855, RMSE: 168.91, MSE: 28530.5744 ,smape: 9.798827218039548
# Test Data: MAE: 119.1741, R-Squared: 0.8778, RMSE: 168.6882, MSE: 28455.7139 ,smape: 9.841311284978495
#
# Model Results for Othernecessities:
# Train Data: MAE: 33.8277, R-Squared: 0.9567, RMSE: 47.7393, MSE: 2279.0428 ,smape: 4.972643349819075
# Validation Data: MAE: 34.2656, R-Squared: 0.9544, RMSE: 47.167, MSE: 2224.73 ,smape: 5.013403811127539
# Test Data: MAE: 33.6319, R-Squared: 0.9561, RMSE: 48.1124, MSE: 2314.8031 ,smape: 4.959296478325622
#
# Model Results for Childcare:
# Train Data: MAE: 95.678, R-Squared: 0.9452, RMSE: 147.3049, MSE: 21698.7221 ,smape: 8.618032963696036
# Validation Data: MAE: 95.2805, R-Squared: 0.9422, RMSE: 144.9418, MSE: 21008.1363 ,smape: 8.646617247461652
# Test Data: MAE: 95.0689, R-Squared: 0.9421, RMSE: 150.0214, MSE: 22506.4342 ,smape: 8.58680921741755
#
# Model Results for Taxes:
# Train Data: MAE: 49.1438, R-Squared: 0.9681, RMSE: 73.3777, MSE: 5384.2829 ,smape: 5.2608974085485025
# Validation Data: MAE: 50.0538, R-Squared: 0.9622, RMSE: 75.1874, MSE: 5653.1404 ,smape: 5.335970328000142
# Test Data: MAE: 48.298, R-Squared: 0.9698, RMSE: 71.7249, MSE: 5144.4676 ,smape: 5.19406645767526

# %%
# Out:
#       feature1  feature2  feature3  feature4  feature1  feature2  feature3  \
# 0     0.075586  0.307823  0.470356      0.00       1.0       0.2  0.132114
# 1     0.363579  0.418043  0.387352      1.00       1.0       1.0  0.039623
# 2     0.097141  0.305326  1.000000      0.00       1.0       0.2  0.165041
# 3     0.152030  0.337261  0.320158      0.25       1.0       0.4  0.090396
# 4     0.331847  0.241743  0.300395      0.75       1.0       0.8  0.073475
# ...        ...       ...       ...       ...       ...       ...       ...
# 3138  0.290280  0.296488  0.213439      0.50       1.0       0.6  0.116743
# 3139  0.338879  0.269664  0.260870      1.00       0.0       0.8  0.077772
# 3140  0.215952  0.346029  0.391304      0.50       0.0       0.4  0.155492
# 3141  0.304631  0.382407  0.150198      0.50       1.0       0.6  0.127704
# 3142  0.189251  0.466541  0.051383      0.00       1.0       0.2  0.305744
#
#       feature4  feature1  feature2  feature3
# 0     0.000000  0.352226       0.5       0.0
# 1     0.387550  0.214116       0.5       1.0
# 2     0.000000  0.401393       0.5       0.0
# 3     0.115366  0.289931       0.5       1.0
# 4     0.327624  0.264665       0.5       1.0
# ...        ...       ...       ...       ...
# 3138  0.249911  0.329273       0.5       1.0
# 3139  0.443088  0.043846       0.5       1.0
# 3140  0.278117  0.101872       0.5       1.0
# 3141  0.257890  0.345640       0.5       1.0
# 3142  0.000000  0.611492       0.5       0.0
#
# [3143 rows x 11 columns]

# %%
import pandas as pd
import numpy as np
import joblib

# Load the scalers
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')

def get_prediction(model_combine, input_data, scaler_X, scaler_y, num_children_col, childcare_exp_col):
    """
    Generates predictions for expenses using the combined model.

    Args:
        model_combine: The trained Keras model.
        input_data: Pandas DataFrame of new input data.
        scaler_X: Fitted MinMaxScaler for features.
        scaler_y: Fitted MinMaxScaler for target variables.
        num_children_col: Integer column index for number of children.
        childcare_exp_col: Integer column index for the 'childcare' target.

    Returns:
         Numpy Array: Predicted expense values.
    """

    # Step 1: Create new features
    input_data_with_features = createFeatures(input_data.copy())

    # Step 2: Select relevant features
    X = input_data_with_features[['total', 'median_family_income', 'num_counties_in_st', 'n_children',
                                  'n_parents', 'n_members', 'per_member_cost', 'child_expense_cost',
                                  'parent_expense_cost', 'other_expense_cost','zero_childcare_cost']].values

    # Step 3: Scale the input data using the fitted scaler_X
    input_data_scaled = scaler_X.transform(X)

    # Step 4: Reshape for the CNN layer (add the extra dimension)
    input_data_scaled = input_data_scaled[..., np.newaxis]  # This line is crucial to match the training data shape

    # Step 5: Make predictions using the trained model
    # We need to unpack the predictions from the model output
    # Then, we can stack those into a single output array.
    input_data_pred = model_combine.predict(input_data_scaled)
    input_data_pred = np.column_stack(input_data_pred)

    # Step 6: Inverse transform the predictions to return them to the original scale
    input_data_pred_original = scaler_y.inverse_transform(input_data_pred)

    # Step 7: Enforce the rule that if there are no children, childcare cost is 0
    input_data_pred_original[:, childcare_exp_col] = np.where(
        input_data_with_features['n_children'].values == 0, 0, input_data_pred_original[:, childcare_exp_col]
    )

    return input_data_pred_original

def createFeatures(input_data):
    """
    Creates additional features needed for the model prediction.

    Args:
        input_data: The input pandas DataFrame with the original data.

    Returns:
        input_data: The input data with additional features.
    """
    # Step 1: Create additional features
    input_data["per_member_cost"] = input_data["total"] / input_data["n_members"]
    input_data["child_expense_cost"] = input_data["per_member_cost"] * input_data["n_children"]
    input_data["parent_expense_cost"] = input_data["per_member_cost"] * input_data["n_parents"]
    input_data["other_expense_cost"] = input_data["total"] - (input_data["child_expense_cost"] + input_data["parent_expense_cost"])

    # Step 2: Create binary column for whether there are children (0 if no children, 1 if there are children)
    input_data["zero_childcare_cost"] = input_data['n_children'].map(lambda x: 0 if x < 1 else 1)

    return input_data

# Example of input data to test predictions
input_data = pd.DataFrame(
    [[4541, 8790.0, 67, 0, 2, 2]],
    columns=['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']
)

# Assuming `model_combine` is your trained model
input_data_pred_original = get_prediction(model_combine, input_data, scaler_X, scaler_y, num_children_col=3, childcare_exp_col=5)

# Print predictions
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']
for i, prediction in enumerate(input_data_pred_original[0]):
    print(f"{target_col_list[i]}: {prediction:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# housing: 681.63
# food: 610.70
# transportation: 1352.26
# healthcare: 900.27
# othernecessities: 464.47
# childcare: 0.00
# taxes: 579.26
