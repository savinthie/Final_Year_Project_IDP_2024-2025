# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_IDP_2024-2025/blob/main/Model_2_CNN_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
df = df.fillna(0)
# Out:
# Mounted at /content/drive

# %%
# Data Preprocessing

df.columns = [col.lower().replace(' ', '').replace('.', '') for col in df.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
df1 = df[cols_to_keep].copy()

df1['median_family_income'] = df1['median_family_income'].replace(',', '', regex=True).astype(float)
#getting the median family income on monthly basis
df1['median_family_income'] = df1['median_family_income'].map(lambda x: x/12)

# %%
# Feature Engineering
df1['n_parents'] = df1['family'].str.slice(0, 1).astype(int)
df1['n_children'] = df1['family'].str.slice(2, 3).astype(int)
df1['n_members'] = df1['n_parents'] + df1['n_children']
df1['financial_stability'] = df1['median_family_income'] / df1['total']
df1["per_member_cost"] = df1["total"] / df1["n_members"]
df1["child_expense_cost"] = df1["per_member_cost"]*df1["n_children"]
df1["parent_expense_cost"] = df1["per_member_cost"]*df1["n_parents"]
df1["other_expense_cost"] = df1["total"] - (df1["child_expense_cost"]+df1["parent_expense_cost"])
# fixing the 0 child issue
df1["zero_childcare_cost"] = df1['n_children'].map(lambda x: 0 if x < 1 else 1)

# %%
# Splitting the data
X = df1[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost','zero_childcare_cost']].values
y_expenses = df1[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = MinMaxScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = MinMaxScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)


# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
# this method is used to avoid the issue in the mape and smape value for the childcare expenses since the childcare expenses consist of 0 value where the smape and mape are sensitive of.
def replace_zeros_with_ones(a, b):
    # Iterate through both lists simultaneously
    for i in range(len(a)):
        # If both value is 0, replace both with 1
        if a[i] == 0 and b[i] == 0:
            a[i] = 1
            b[i] = 1
    return a, b

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def calculateSmape(y_true, y_pred):
    y_true, y_pred = replace_zeros_with_ones(y_true, y_pred)
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_value = np.mean(numerator / denominator) * 100
    return smape_value

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    smape_score = calculateSmape(x, y)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse} ,smape: {smape_score}'

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import xgboost as xgb

num_children_col = 3  # 4th position, 0-indexed
childcare_exp_col = target_col_list.index('childcare')  # Replace 'childcare_exp' with the actual target name

# %%
from tensorflow.keras.layers import Input, Conv1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# L2 regularization strength (you can tune this value)
l2_strength = 0.01

# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
global X_train_global, X_test_global, X_val_global
global y_train_global, y_test_global, y_val_global

# %%
# Cross-Validation with Evaluation
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    global X_train_global, X_test_global, X_val_global
    global y_train_global, y_test_global, y_val_global
    fold = 1
    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100) # 50/50 split of remaining 20%

        X_train_global, X_test_global, X_val_global = X_train, X_test, X_val
        y_train_global, y_test_global, y_val_global = y_train, y_test, y_val

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        model.summary()

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Training
        model.fit(X_train, [y_train[:, i] for i in range(y_train.shape[1])],
                  validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
                  epochs=num_epochs, batch_size=64, verbose=1, callbacks= [early_stopping])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test)) #Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test) #Inverse transform for test set

        # Enforce the rule after predictions for childcare expense
        # The issue is likely caused by X_train having an extra dimension due to[..., np.newaxis].
        # We need to select the original features for the condition
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col, 0] == 0, 0, y_train_pred_original[:, childcare_exp_col]) #Using X_train[:, num_children_col, 0] instead of X_train[:, num_children_col]

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col, 0] == 0, 0, y_val_pred_original[:, childcare_exp_col]) #Using X_val[:, num_children_col, 0] instead of X_val[:, num_children_col]

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col, 0] == 0, 0, y_test_pred_original[:, childcare_exp_col]) #Using X_test[:, num_children_col, 0] instead of X_test[:, num_children_col]

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return model

model_combine = cross_val_with_evaluation(X_scaled, y_exp_scaled,kf)
# Out:
# Fold 1/5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 11, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 11, 8)          │             32 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 88)             │              0 │ conv1d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │         11,392 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │          8,256 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_housing (Dense)    │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_food (Dense)       │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_transportation     │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_healthcare (Dense) │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_othernecessities   │ (None, 1)              │             65 │ dense_1[0][0]          │
# │ (Dense)                   │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_childcare (Dense)  │ (None, 1)              │             65 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ target_taxes (Dense)      │ (None, 1)              │             65 │ dense_1[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,135 (78.65 KB)
#  Trainable params: 20,135 (78.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0383 - target_childcare_loss: 0.0054 - target_food_loss: 0.0044 - target_healthcare_loss: 0.0144 - target_housing_loss: 0.0036 - target_othernecessities_loss: 0.0035 - target_taxes_loss: 0.0030 - target_transportation_loss: 0.0041 - val_loss: 0.0134 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.0154e-04 - val_target_healthcare_loss: 0.0046 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 9.1709e-04 - val_target_taxes_loss: 4.7194e-04 - val_target_transportation_loss: 0.0035
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0136 - target_childcare_loss: 0.0020 - target_food_loss: 5.9169e-04 - target_healthcare_loss: 0.0049 - target_housing_loss: 0.0014 - target_othernecessities_loss: 8.8275e-04 - target_taxes_loss: 4.7613e-04 - target_transportation_loss: 0.0034 - val_loss: 0.0129 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 5.1992e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.7208e-04 - val_target_taxes_loss: 4.8925e-04 - val_target_transportation_loss: 0.0034
# Epoch 3/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0132 - target_childcare_loss: 0.0020 - target_food_loss: 6.1467e-04 - target_healthcare_loss: 0.0047 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.6245e-04 - target_taxes_loss: 4.5598e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0127 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8870e-04 - val_target_healthcare_loss: 0.0044 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9136e-04 - val_target_taxes_loss: 4.1722e-04 - val_target_transportation_loss: 0.0035
# Epoch 4/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0128 - target_childcare_loss: 0.0019 - target_food_loss: 5.7494e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9050e-04 - target_taxes_loss: 4.1720e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0125 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6034e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.8106e-04 - val_target_taxes_loss: 3.9519e-04 - val_target_transportation_loss: 0.0035
# Epoch 5/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0127 - target_childcare_loss: 0.0019 - target_food_loss: 5.6402e-04 - target_healthcare_loss: 0.0047 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9838e-04 - target_taxes_loss: 4.0650e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0126 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 4.6806e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.0473e-04 - val_target_taxes_loss: 3.9075e-04 - val_target_transportation_loss: 0.0034
# Epoch 6/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0126 - target_childcare_loss: 0.0019 - target_food_loss: 5.6862e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9159e-04 - target_taxes_loss: 3.9731e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0124 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5576e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.7428e-04 - val_target_taxes_loss: 4.2491e-04 - val_target_transportation_loss: 0.0034
# Epoch 7/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0126 - target_childcare_loss: 0.0019 - target_food_loss: 5.5099e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.9181e-04 - target_taxes_loss: 3.9467e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0127 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.0001e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 9.6861e-04 - val_target_taxes_loss: 3.9571e-04 - val_target_transportation_loss: 0.0036
# Epoch 8/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0126 - target_childcare_loss: 0.0019 - target_food_loss: 5.6003e-04 - target_healthcare_loss: 0.0046 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.0833e-04 - target_taxes_loss: 4.2859e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0123 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.3279e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.1117e-04 - val_target_taxes_loss: 4.1255e-04 - val_target_transportation_loss: 0.0034
# Epoch 9/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.5015e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6008e-04 - target_taxes_loss: 3.8759e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6631e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5665e-04 - val_target_taxes_loss: 3.8153e-04 - val_target_transportation_loss: 0.0033
# Epoch 10/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.5672e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.6225e-04 - target_taxes_loss: 3.7622e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0120 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6960e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5999e-04 - val_target_taxes_loss: 3.9483e-04 - val_target_transportation_loss: 0.0033
# Epoch 11/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.4266e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3478e-04 - target_taxes_loss: 3.8484e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0120 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5898e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5316e-04 - val_target_taxes_loss: 3.7182e-04 - val_target_transportation_loss: 0.0034
# Epoch 12/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0121 - target_childcare_loss: 0.0018 - target_food_loss: 5.2263e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4264e-04 - target_taxes_loss: 3.7266e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5780e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7204e-04 - val_target_taxes_loss: 4.2304e-04 - val_target_transportation_loss: 0.0033
# Epoch 13/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.4249e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3789e-04 - target_taxes_loss: 3.6309e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.1508e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.9316e-04 - val_target_taxes_loss: 3.6862e-04 - val_target_transportation_loss: 0.0035
# Epoch 14/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.5541e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3825e-04 - target_taxes_loss: 3.6738e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.8640e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.5558e-04 - val_target_taxes_loss: 3.5491e-04 - val_target_transportation_loss: 0.0033
# Epoch 15/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0017 - target_food_loss: 5.1909e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1974e-04 - target_taxes_loss: 3.7328e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0125 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 5.2267e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5422e-04 - val_target_taxes_loss: 3.6702e-04 - val_target_transportation_loss: 0.0033
# Epoch 16/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.5699e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2777e-04 - target_taxes_loss: 3.7322e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0115 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5370e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2708e-04 - val_target_taxes_loss: 3.7225e-04 - val_target_transportation_loss: 0.0032
# Epoch 17/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.3820e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0861e-04 - target_taxes_loss: 3.6114e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5185e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7332e-04 - val_target_taxes_loss: 3.6990e-04 - val_target_transportation_loss: 0.0034
# Epoch 18/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.4370e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0381e-04 - target_taxes_loss: 3.4729e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.7263e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2107e-04 - val_target_taxes_loss: 3.5065e-04 - val_target_transportation_loss: 0.0033
# Epoch 19/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0017 - target_food_loss: 5.1014e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9178e-04 - target_taxes_loss: 3.4391e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4606e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7762e-04 - val_target_taxes_loss: 3.4788e-04 - val_target_transportation_loss: 0.0032
# Epoch 20/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0112 - target_childcare_loss: 0.0017 - target_food_loss: 5.2819e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8302e-04 - target_taxes_loss: 3.3688e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.6093e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2385e-04 - val_target_taxes_loss: 3.4926e-04 - val_target_transportation_loss: 0.0032
# Epoch 21/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0017 - target_food_loss: 5.1399e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9195e-04 - target_taxes_loss: 3.4054e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5671e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2875e-04 - val_target_taxes_loss: 3.3853e-04 - val_target_transportation_loss: 0.0032
# Epoch 22/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.2727e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1864e-04 - target_taxes_loss: 3.3828e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5202e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1170e-04 - val_target_taxes_loss: 3.3523e-04 - val_target_transportation_loss: 0.0032
# Epoch 23/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.3356e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8998e-04 - target_taxes_loss: 3.3765e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4454e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0059e-04 - val_target_taxes_loss: 3.4464e-04 - val_target_transportation_loss: 0.0032
# Epoch 24/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.0681e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7775e-04 - target_taxes_loss: 3.3469e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0110 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4281e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2394e-04 - val_target_taxes_loss: 3.4102e-04 - val_target_transportation_loss: 0.0033
# Epoch 25/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.7421e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9927e-04 - target_taxes_loss: 3.3365e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3938e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9813e-04 - val_target_taxes_loss: 3.3032e-04 - val_target_transportation_loss: 0.0031
# Epoch 26/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.1322e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8153e-04 - target_taxes_loss: 3.2274e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4847e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0325e-04 - val_target_taxes_loss: 3.2421e-04 - val_target_transportation_loss: 0.0031
# Epoch 27/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0108 - target_childcare_loss: 0.0016 - target_food_loss: 5.4038e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9701e-04 - target_taxes_loss: 3.2313e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3875e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9516e-04 - val_target_taxes_loss: 3.3126e-04 - val_target_transportation_loss: 0.0031
# Epoch 28/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.1318e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.5231e-04 - target_taxes_loss: 3.2029e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4349e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8081e-04 - val_target_taxes_loss: 3.2987e-04 - val_target_transportation_loss: 0.0031
# Epoch 29/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.4815e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9755e-04 - target_taxes_loss: 3.1624e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6244e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9811e-04 - val_target_taxes_loss: 3.3172e-04 - val_target_transportation_loss: 0.0032
# Epoch 30/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.3539e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1280e-04 - target_taxes_loss: 3.2639e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4202e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9742e-04 - val_target_taxes_loss: 3.4472e-04 - val_target_transportation_loss: 0.0031
# Epoch 31/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.3392e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9043e-04 - target_taxes_loss: 3.0815e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3660e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8349e-04 - val_target_taxes_loss: 3.4208e-04 - val_target_transportation_loss: 0.0031
# Epoch 32/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.4283e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9120e-04 - target_taxes_loss: 3.2221e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3204e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7970e-04 - val_target_taxes_loss: 3.1848e-04 - val_target_transportation_loss: 0.0031
# Epoch 33/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.2574e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 9.9574e-04 - target_othernecessities_loss: 6.6853e-04 - target_taxes_loss: 3.0554e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.7433e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7605e-04 - val_target_taxes_loss: 2.9898e-04 - val_target_transportation_loss: 0.0031
# Epoch 34/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 4.9306e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8441e-04 - target_taxes_loss: 3.1808e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0104 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.2508e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8944e-04 - val_target_taxes_loss: 3.0242e-04 - val_target_transportation_loss: 0.0031
# Epoch 35/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.1212e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6847e-04 - target_taxes_loss: 3.0202e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4442e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9009e-04 - val_target_taxes_loss: 3.2621e-04 - val_target_transportation_loss: 0.0031
# Epoch 36/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0103 - target_childcare_loss: 0.0014 - target_food_loss: 5.1128e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9698e-04 - target_othernecessities_loss: 6.5856e-04 - target_taxes_loss: 3.0846e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5763e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8333e-04 - val_target_taxes_loss: 2.9895e-04 - val_target_transportation_loss: 0.0031
# Epoch 37/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0104 - target_childcare_loss: 0.0014 - target_food_loss: 5.1337e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6773e-04 - target_taxes_loss: 3.0040e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3179e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6637e-04 - val_target_taxes_loss: 2.9898e-04 - val_target_transportation_loss: 0.0031
# Epoch 38/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.0806e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7938e-04 - target_taxes_loss: 2.9694e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.9035e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8076e-04 - val_target_othernecessities_loss: 6.8937e-04 - val_target_taxes_loss: 3.1477e-04 - val_target_transportation_loss: 0.0030
# Epoch 39/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0102 - target_childcare_loss: 0.0015 - target_food_loss: 5.0255e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8362e-04 - target_taxes_loss: 2.9646e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0102 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4560e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7779e-04 - val_target_taxes_loss: 3.2308e-04 - val_target_transportation_loss: 0.0030
# Epoch 40/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.1198e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6064e-04 - target_taxes_loss: 3.0750e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4431e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8737e-04 - val_target_othernecessities_loss: 6.5707e-04 - val_target_taxes_loss: 2.8884e-04 - val_target_transportation_loss: 0.0030
# Epoch 41/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.0169e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7030e-04 - target_taxes_loss: 3.0021e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0099 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3291e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8630e-04 - val_target_othernecessities_loss: 6.4037e-04 - val_target_taxes_loss: 2.9855e-04 - val_target_transportation_loss: 0.0030
# Epoch 42/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0223e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.5537e-04 - target_taxes_loss: 2.9698e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3860e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8972e-04 - val_target_othernecessities_loss: 6.3993e-04 - val_target_taxes_loss: 3.1719e-04 - val_target_transportation_loss: 0.0030
# Epoch 43/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0102 - target_childcare_loss: 0.0014 - target_food_loss: 5.1132e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9284e-04 - target_othernecessities_loss: 6.3778e-04 - target_taxes_loss: 3.0213e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5888e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.9790e-04 - val_target_othernecessities_loss: 6.3686e-04 - val_target_taxes_loss: 3.0008e-04 - val_target_transportation_loss: 0.0031
# Epoch 44/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.9044e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.4690e-04 - target_othernecessities_loss: 6.1627e-04 - target_taxes_loss: 2.8362e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.3819e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8767e-04 - val_target_taxes_loss: 2.9248e-04 - val_target_transportation_loss: 0.0031
# Epoch 45/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.0952e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7848e-04 - target_othernecessities_loss: 6.2770e-04 - target_taxes_loss: 2.8177e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0098 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2485e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.6634e-04 - val_target_othernecessities_loss: 6.3617e-04 - val_target_taxes_loss: 2.9205e-04 - val_target_transportation_loss: 0.0030
# Epoch 46/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.8277e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7874e-04 - target_othernecessities_loss: 6.3242e-04 - target_taxes_loss: 2.9085e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3604e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.9193e-04 - val_target_othernecessities_loss: 6.3789e-04 - val_target_taxes_loss: 2.9050e-04 - val_target_transportation_loss: 0.0030
# Epoch 47/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.7457e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.6992e-04 - target_othernecessities_loss: 6.1816e-04 - target_taxes_loss: 2.8414e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3197e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.3603e-04 - val_target_taxes_loss: 2.9037e-04 - val_target_transportation_loss: 0.0031
# Epoch 48/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.9278e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4864e-04 - target_othernecessities_loss: 6.1328e-04 - target_taxes_loss: 2.8859e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3095e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.5355e-04 - val_target_othernecessities_loss: 6.3549e-04 - val_target_taxes_loss: 3.0885e-04 - val_target_transportation_loss: 0.0030
# Epoch 49/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8982e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.5628e-04 - target_othernecessities_loss: 6.1886e-04 - target_taxes_loss: 2.8957e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.1956e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3404e-04 - val_target_othernecessities_loss: 6.1144e-04 - val_target_taxes_loss: 2.8156e-04 - val_target_transportation_loss: 0.0030
# Epoch 50/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.8879e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.6559e-04 - target_othernecessities_loss: 6.1995e-04 - target_taxes_loss: 2.8134e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2664e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0364e-04 - val_target_othernecessities_loss: 5.9222e-04 - val_target_taxes_loss: 2.7888e-04 - val_target_transportation_loss: 0.0029
# Epoch 51/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7482e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3098e-04 - target_othernecessities_loss: 5.8648e-04 - target_taxes_loss: 2.8331e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5264e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.3342e-04 - val_target_othernecessities_loss: 6.1750e-04 - val_target_taxes_loss: 2.8779e-04 - val_target_transportation_loss: 0.0030
# Epoch 52/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.8563e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.4803e-04 - target_othernecessities_loss: 6.0420e-04 - target_taxes_loss: 2.9250e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2002e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.1583e-04 - val_target_othernecessities_loss: 5.8206e-04 - val_target_taxes_loss: 2.8941e-04 - val_target_transportation_loss: 0.0030
# Epoch 53/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.7727e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.6716e-04 - target_othernecessities_loss: 6.0754e-04 - target_taxes_loss: 2.8946e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2169e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0974e-04 - val_target_othernecessities_loss: 6.0416e-04 - val_target_taxes_loss: 2.8630e-04 - val_target_transportation_loss: 0.0030
# Epoch 54/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6759e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.4110e-04 - target_othernecessities_loss: 5.8778e-04 - target_taxes_loss: 2.8127e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2862e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.4289e-04 - val_target_othernecessities_loss: 6.0104e-04 - val_target_taxes_loss: 3.4460e-04 - val_target_transportation_loss: 0.0029
# Epoch 55/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.6791e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4881e-04 - target_othernecessities_loss: 5.9606e-04 - target_taxes_loss: 2.7849e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5329e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.4350e-04 - val_target_othernecessities_loss: 5.9272e-04 - val_target_taxes_loss: 2.8963e-04 - val_target_transportation_loss: 0.0030
# Epoch 56/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8220e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.1754e-04 - target_othernecessities_loss: 5.8127e-04 - target_taxes_loss: 2.7602e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3644e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.4234e-04 - val_target_othernecessities_loss: 6.2049e-04 - val_target_taxes_loss: 2.7667e-04 - val_target_transportation_loss: 0.0029
# Epoch 57/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7181e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1131e-04 - target_othernecessities_loss: 5.7242e-04 - target_taxes_loss: 2.8002e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1794e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.5587e-04 - val_target_othernecessities_loss: 6.1483e-04 - val_target_taxes_loss: 3.0415e-04 - val_target_transportation_loss: 0.0029
# Epoch 58/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.9295e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.6334e-04 - target_othernecessities_loss: 6.0738e-04 - target_taxes_loss: 2.8283e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2310e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0032e-04 - val_target_othernecessities_loss: 5.7415e-04 - val_target_taxes_loss: 3.0457e-04 - val_target_transportation_loss: 0.0029
# Epoch 59/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.8885e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.2699e-04 - target_othernecessities_loss: 5.8993e-04 - target_taxes_loss: 2.8049e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2691e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.1474e-04 - val_target_othernecessities_loss: 5.8855e-04 - val_target_taxes_loss: 2.7901e-04 - val_target_transportation_loss: 0.0030
# Epoch 60/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7684e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0290e-04 - target_othernecessities_loss: 5.7834e-04 - target_taxes_loss: 2.7673e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1657e-04 - val_target_healthcare_loss: 0.0026 - val_target_housing_loss: 9.0085e-04 - val_target_othernecessities_loss: 5.7249e-04 - val_target_taxes_loss: 2.7360e-04 - val_target_transportation_loss: 0.0029
# Epoch 61/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7365e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0901e-04 - target_othernecessities_loss: 5.7529e-04 - target_taxes_loss: 2.7950e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.0673e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.2118e-04 - val_target_othernecessities_loss: 5.8795e-04 - val_target_taxes_loss: 3.0748e-04 - val_target_transportation_loss: 0.0029
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.5649e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1350e-04 - target_othernecessities_loss: 5.7706e-04 - target_taxes_loss: 2.7831e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2056e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 9.1921e-04 - val_target_othernecessities_loss: 6.1836e-04 - val_target_taxes_loss: 2.9271e-04 - val_target_transportation_loss: 0.0030
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.7239e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0857e-04 - target_othernecessities_loss: 5.7980e-04 - target_taxes_loss: 2.6559e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1573e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 9.0724e-04 - val_target_othernecessities_loss: 5.7996e-04 - val_target_taxes_loss: 2.7459e-04 - val_target_transportation_loss: 0.0029
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.6488e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.2533e-04 - target_othernecessities_loss: 5.9386e-04 - target_taxes_loss: 2.7122e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2525e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 9.1410e-04 - val_target_othernecessities_loss: 5.9597e-04 - val_target_taxes_loss: 2.8412e-04 - val_target_transportation_loss: 0.0029
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.5404e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.2568e-04 - target_othernecessities_loss: 5.8128e-04 - target_taxes_loss: 2.7500e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.7374e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.8822e-04 - val_target_othernecessities_loss: 6.3499e-04 - val_target_taxes_loss: 2.8087e-04 - val_target_transportation_loss: 0.0029
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7932e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3346e-04 - target_othernecessities_loss: 5.7788e-04 - target_taxes_loss: 2.8119e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0091 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1078e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 8.8855e-04 - val_target_othernecessities_loss: 5.7208e-04 - val_target_taxes_loss: 2.7019e-04 - val_target_transportation_loss: 0.0029
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6373e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9458e-04 - target_othernecessities_loss: 5.6125e-04 - target_taxes_loss: 2.7719e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0091 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.0941e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 8.7711e-04 - val_target_othernecessities_loss: 5.7773e-04 - val_target_taxes_loss: 2.7315e-04 - val_target_transportation_loss: 0.0030
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.6663e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.2273e-04 - target_othernecessities_loss: 5.8316e-04 - target_taxes_loss: 2.5831e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1760e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0638e-04 - val_target_othernecessities_loss: 6.0280e-04 - val_target_taxes_loss: 2.8991e-04 - val_target_transportation_loss: 0.0029
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.5406e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0525e-04 - target_othernecessities_loss: 5.7117e-04 - target_taxes_loss: 2.7517e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1953e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0700e-04 - val_target_othernecessities_loss: 5.8343e-04 - val_target_taxes_loss: 2.6695e-04 - val_target_transportation_loss: 0.0029
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.6394e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8740e-04 - target_othernecessities_loss: 5.6343e-04 - target_taxes_loss: 2.7390e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.1923e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 9.0752e-04 - val_target_othernecessities_loss: 5.7648e-04 - val_target_taxes_loss: 2.6913e-04 - val_target_transportation_loss: 0.0029
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model Results for Housing:
# Train Data: MAE: 83.1883, R-Squared: 0.9029, RMSE: 120.3529, MSE: 14484.8323 ,smape: 7.73089580537325
# Validation Data: MAE: 82.6418, R-Squared: 0.8984, RMSE: 120.258, MSE: 14461.9844 ,smape: 7.705246278677885
# Test Data: MAE: 84.829, R-Squared: 0.8995, RMSE: 121.8413, MSE: 14845.3068 ,smape: 7.870882372371082
#
# Model Results for Food:
# Train Data: MAE: 42.4379, R-Squared: 0.9664, RMSE: 62.5604, MSE: 3913.8093 ,smape: 4.881075753092267
# Validation Data: MAE: 41.5239, R-Squared: 0.9688, RMSE: 59.6669, MSE: 3560.1443 ,smape: 4.797654511386106
# Test Data: MAE: 43.4629, R-Squared: 0.9602, RMSE: 68.3683, MSE: 4674.2182 ,smape: 4.91880313073416
#
# Model Results for Transportation:
# Train Data: MAE: 94.4372, R-Squared: 0.7138, RMSE: 126.877, MSE: 16097.7782 ,smape: 6.147864615165027
# Validation Data: MAE: 95.9543, R-Squared: 0.7117, RMSE: 128.346, MSE: 16472.6845 ,smape: 6.287108681801349
# Test Data: MAE: 98.4302, R-Squared: 0.6995, RMSE: 131.9828, MSE: 17419.4492 ,smape: 6.364742847292469
#
# Model Results for Healthcare:
# Train Data: MAE: 115.1444, R-Squared: 0.8855, RMSE: 166.1897, MSE: 27619.0219 ,smape: 9.317834209579976
# Validation Data: MAE: 112.465, R-Squared: 0.892, RMSE: 160.9131, MSE: 25893.0261 ,smape: 9.216459329423703
# Test Data: MAE: 116.4374, R-Squared: 0.8884, RMSE: 166.1345, MSE: 27600.6832 ,smape: 9.339466459720152
#
# Model Results for Othernecessities:
# Train Data: MAE: 33.1567, R-Squared: 0.9585, RMSE: 46.6876, MSE: 2179.7317 ,smape: 4.881947703574654
# Validation Data: MAE: 32.83, R-Squared: 0.957, RMSE: 46.8435, MSE: 2194.3165 ,smape: 4.8355412658549906
# Test Data: MAE: 33.7832, R-Squared: 0.9562, RMSE: 47.4579, MSE: 2252.2499 ,smape: 4.915826352716426
#
# Model Results for Childcare:
# Train Data: MAE: 95.1544, R-Squared: 0.9451, RMSE: 146.6791, MSE: 21514.7463 ,smape: 8.497057845334595
# Validation Data: MAE: 93.5619, R-Squared: 0.9471, RMSE: 144.9317, MSE: 21005.1943 ,smape: 8.373649470766601
# Test Data: MAE: 97.1097, R-Squared: 0.942, RMSE: 150.053, MSE: 22515.902 ,smape: 8.725327633360966
#
# Model Results for Taxes:
# Train Data: MAE: 46.1684, R-Squared: 0.9707, RMSE: 70.0774, MSE: 4910.8431 ,smape: 5.029196406775475
# Validation Data: MAE: 47.1156, R-Squared: 0.9686, RMSE: 71.8437, MSE: 5161.5178 ,smape: 5.0669004676139195
# Test Data: MAE: 45.1643, R-Squared: 0.9709, RMSE: 69.2747, MSE: 4798.9853 ,smape: 4.898778573383186
#
# Fold 2/5
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 11, 1)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 11, 8)          │             32 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# Epoch 79/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.6874e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1608e-04 - target_othernecessities_loss: 5.8413e-04 - target_taxes_loss: 2.9492e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.6996e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6750e-04 - val_target_othernecessities_loss: 5.6063e-04 - val_target_taxes_loss: 3.3261e-04 - val_target_transportation_loss: 0.0028
# Epoch 80/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0014 - target_food_loss: 4.6462e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 8.8690e-04 - target_othernecessities_loss: 5.6286e-04 - target_taxes_loss: 2.9511e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.7511e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.9793e-04 - val_target_othernecessities_loss: 5.7375e-04 - val_target_taxes_loss: 3.0475e-04 - val_target_transportation_loss: 0.0028
# Epoch 81/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7622e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0948e-04 - target_othernecessities_loss: 5.8329e-04 - target_taxes_loss: 3.0327e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6068e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3324e-04 - val_target_othernecessities_loss: 5.7954e-04 - val_target_taxes_loss: 2.9796e-04 - val_target_transportation_loss: 0.0028
# Epoch 82/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 5.0346e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.6066e-04 - target_othernecessities_loss: 6.1416e-04 - target_taxes_loss: 2.9461e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5820e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.5060e-04 - val_target_othernecessities_loss: 6.0565e-04 - val_target_taxes_loss: 3.5789e-04 - val_target_transportation_loss: 0.0028
# Epoch 83/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.6960e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.4456e-04 - target_othernecessities_loss: 5.9796e-04 - target_taxes_loss: 3.0196e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5905e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.9303e-04 - val_target_othernecessities_loss: 5.5847e-04 - val_target_taxes_loss: 2.9911e-04 - val_target_transportation_loss: 0.0028
# Epoch 84/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 5.0224e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3692e-04 - target_othernecessities_loss: 5.8895e-04 - target_taxes_loss: 3.0606e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5830e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.8146e-04 - val_target_othernecessities_loss: 5.5034e-04 - val_target_taxes_loss: 3.1352e-04 - val_target_transportation_loss: 0.0029
# Epoch 85/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.4567e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0155e-04 - target_othernecessities_loss: 5.7749e-04 - target_taxes_loss: 2.9591e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6353e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 8.8319e-04 - val_target_othernecessities_loss: 5.6476e-04 - val_target_taxes_loss: 3.0129e-04 - val_target_transportation_loss: 0.0028
# Epoch 86/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0014 - target_food_loss: 4.8101e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0160e-04 - target_othernecessities_loss: 5.8412e-04 - target_taxes_loss: 2.9304e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 6.0433e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.7035e-04 - val_target_othernecessities_loss: 5.5840e-04 - val_target_taxes_loss: 3.4361e-04 - val_target_transportation_loss: 0.0027
# Epoch 87/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.7896e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0489e-04 - target_othernecessities_loss: 5.8644e-04 - target_taxes_loss: 3.0205e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.7601e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.0615e-04 - val_target_othernecessities_loss: 5.6252e-04 - val_target_taxes_loss: 3.0388e-04 - val_target_transportation_loss: 0.0028
# Epoch 88/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.9176e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1604e-04 - target_othernecessities_loss: 5.8296e-04 - target_taxes_loss: 2.9996e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5209e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.2363e-04 - val_target_othernecessities_loss: 5.6813e-04 - val_target_taxes_loss: 3.0574e-04 - val_target_transportation_loss: 0.0027
# Epoch 89/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.7242e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1191e-04 - target_othernecessities_loss: 5.8692e-04 - target_taxes_loss: 2.9956e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.5939e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.6364e-04 - val_target_othernecessities_loss: 5.4272e-04 - val_target_taxes_loss: 3.1261e-04 - val_target_transportation_loss: 0.0027
# Epoch 90/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.7522e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0253e-04 - target_othernecessities_loss: 5.7735e-04 - target_taxes_loss: 2.9197e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6126e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.8222e-04 - val_target_othernecessities_loss: 5.4831e-04 - val_target_taxes_loss: 3.0024e-04 - val_target_transportation_loss: 0.0027
# Epoch 91/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.8527e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0220e-04 - target_othernecessities_loss: 5.6720e-04 - target_taxes_loss: 2.8977e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 6.0870e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8938e-04 - val_target_othernecessities_loss: 5.7303e-04 - val_target_taxes_loss: 3.6165e-04 - val_target_transportation_loss: 0.0027
# Epoch 92/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.7050e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 8.9639e-04 - target_othernecessities_loss: 5.8258e-04 - target_taxes_loss: 3.0359e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 5.6161e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.7409e-04 - val_target_othernecessities_loss: 5.4943e-04 - val_target_taxes_loss: 3.0031e-04 - val_target_transportation_loss: 0.0027
# Epoch 93/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.9406e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.2128e-04 - target_othernecessities_loss: 5.8290e-04 - target_taxes_loss: 3.0073e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6024e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.1800e-04 - val_target_othernecessities_loss: 5.7797e-04 - val_target_taxes_loss: 3.0076e-04 - val_target_transportation_loss: 0.0028
# Epoch 94/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.5887e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0322e-04 - target_othernecessities_loss: 5.7249e-04 - target_taxes_loss: 2.9505e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.9774e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 8.9462e-04 - val_target_othernecessities_loss: 5.9575e-04 - val_target_taxes_loss: 3.2006e-04 - val_target_transportation_loss: 0.0027
# Epoch 95/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.6850e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.2038e-04 - target_othernecessities_loss: 5.9590e-04 - target_taxes_loss: 2.9146e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6708e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.9709e-04 - val_target_othernecessities_loss: 5.6860e-04 - val_target_taxes_loss: 2.9085e-04 - val_target_transportation_loss: 0.0027
# Epoch 96/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0014 - target_food_loss: 4.7684e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.8457e-04 - target_othernecessities_loss: 5.7196e-04 - target_taxes_loss: 2.9043e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6530e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8525e-04 - val_target_othernecessities_loss: 5.6491e-04 - val_target_taxes_loss: 2.9794e-04 - val_target_transportation_loss: 0.0027
# Epoch 97/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.5200e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1954e-04 - target_othernecessities_loss: 5.9514e-04 - target_taxes_loss: 2.9963e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5053e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.5774e-04 - val_target_othernecessities_loss: 5.3543e-04 - val_target_taxes_loss: 2.9366e-04 - val_target_transportation_loss: 0.0027
# Epoch 98/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.6638e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0681e-04 - target_othernecessities_loss: 5.7419e-04 - target_taxes_loss: 2.9185e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.6497e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 9.1365e-04 - val_target_othernecessities_loss: 5.8538e-04 - val_target_taxes_loss: 2.9947e-04 - val_target_transportation_loss: 0.0028
# Epoch 99/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0014 - target_food_loss: 4.8816e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1006e-04 - target_othernecessities_loss: 5.7943e-04 - target_taxes_loss: 2.8742e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5739e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6284e-04 - val_target_othernecessities_loss: 5.4626e-04 - val_target_taxes_loss: 3.2268e-04 - val_target_transportation_loss: 0.0027
# Epoch 100/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0014 - target_food_loss: 4.6519e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8885e-04 - target_othernecessities_loss: 5.7065e-04 - target_taxes_loss: 2.9139e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.4291e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8233e-04 - val_target_othernecessities_loss: 5.4469e-04 - val_target_taxes_loss: 3.5376e-04 - val_target_transportation_loss: 0.0027
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Model Results for Housing:
# Train Data: MAE: 82.0997, R-Squared: 0.9058, RMSE: 118.8188, MSE: 14117.9117 ,smape: 7.6545959559261885
# Validation Data: MAE: 83.3457, R-Squared: 0.8933, RMSE: 118.7731, MSE: 14107.0528 ,smape: 7.728687632232291
# Test Data: MAE: 83.3731, R-Squared: 0.9026, RMSE: 121.471, MSE: 14755.2127 ,smape: 7.756921401979855
#
# Model Results for Food:
# Train Data: MAE: 42.2572, R-Squared: 0.9665, RMSE: 62.4691, MSE: 3902.3899 ,smape: 4.832974945539059
# Validation Data: MAE: 45.4076, R-Squared: 0.9585, RMSE: 69.5019, MSE: 4830.5096 ,smape: 5.136483220476927
# Test Data: MAE: 43.048, R-Squared: 0.9657, RMSE: 63.0393, MSE: 3973.9554 ,smape: 4.972217974511897
#
# Model Results for Transportation:
# Train Data: MAE: 94.7541, R-Squared: 0.7173, RMSE: 126.5402, MSE: 16012.4209 ,smape: 6.169842815185935
# Validation Data: MAE: 94.1623, R-Squared: 0.7157, RMSE: 124.587, MSE: 15521.924 ,smape: 6.138830502467649
# Test Data: MAE: 95.4571, R-Squared: 0.7152, RMSE: 127.8832, MSE: 16354.1189 ,smape: 6.233864822635337
#
# Model Results for Healthcare:
# Train Data: MAE: 113.6212, R-Squared: 0.8883, RMSE: 164.379, MSE: 27020.4661 ,smape: 9.217964790931376
# Validation Data: MAE: 116.8436, R-Squared: 0.8892, RMSE: 166.1344, MSE: 27600.6254 ,smape: 9.383804435154948
# Test Data: MAE: 113.2973, R-Squared: 0.8833, RMSE: 164.846, MSE: 27174.1986 ,smape: 9.2625596804452
#
# Model Results for Othernecessities:
# Train Data: MAE: 32.5089, R-Squared: 0.9593, RMSE: 46.2411, MSE: 2138.2422 ,smape: 4.783304651165031
# Validation Data: MAE: 33.0426, R-Squared: 0.9561, RMSE: 46.2367, MSE: 2137.8346 ,smape: 4.842278851307349
# Test Data: MAE: 32.6709, R-Squared: 0.9576, RMSE: 47.3142, MSE: 2238.6321 ,smape: 4.825485013650537
#
# Model Results for Childcare:
# Train Data: MAE: 96.6028, R-Squared: 0.9445, RMSE: 148.2104, MSE: 21966.3214 ,smape: 8.796160529206002
# Validation Data: MAE: 95.1461, R-Squared: 0.9421, RMSE: 145.1473, MSE: 21067.7529 ,smape: 8.684014143625994
# Test Data: MAE: 94.8878, R-Squared: 0.9434, RMSE: 148.2286, MSE: 21971.7123 ,smape: 8.63708700072488
#
# Model Results for Taxes:
# Train Data: MAE: 49.5043, R-Squared: 0.9686, RMSE: 72.8427, MSE: 5306.0629 ,smape: 5.444055037190446
# Validation Data: MAE: 50.8821, R-Squared: 0.9618, RMSE: 75.5461, MSE: 5707.2184 ,smape: 5.54143242089106
# Test Data: MAE: 48.7205, R-Squared: 0.9699, RMSE: 71.6138, MSE: 5128.5375 ,smape: 5.357614149220962

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score

def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=200):
    fold = 1
    cnn_results, xgb_results = [], []

    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")

        # Split data
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)

        # CNN: Train and Predict
        print("Training CNN...")
        cnn_model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        cnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        cnn_model.fit(X_train[..., np.newaxis], [y_train[:, i] for i in range(y_train.shape[1])],
                      validation_data=(X_val[..., np.newaxis], [y_val[:, i] for i in range(y_val.shape[1])]),
                      epochs=num_epochs, batch_size=64, verbose=1, callbacks=[early_stopping])

        y_train_pred_cnn = np.column_stack(cnn_model.predict(X_train[..., np.newaxis]))
        y_val_pred_cnn = np.column_stack(cnn_model.predict(X_val[..., np.newaxis]))
        y_test_pred_cnn = np.column_stack(cnn_model.predict(X_test[..., np.newaxis]))

        # XGBoost: Train and Predict
        print("Training XGBoost...")
        xgb_models = []
        y_train_pred_xgb, y_val_pred_xgb, y_test_pred_xgb = [], [], []

        for i in range(y_train.shape[1]):
            dtrain = xgb.DMatrix(X_train, label=y_train[:, i])
            dval = xgb.DMatrix(X_val, label=y_val[:, i])
            dtest = xgb.DMatrix(X_test)

            params = {
                'objective': 'reg:squarederror',
                'eval_metric': 'rmse',
                'learning_rate': 0.1,
                'max_depth': 6,
                'seed': 100
            }

            xgb_model = xgb.train(params, dtrain, num_boost_round=200, evals=[(dval, 'validation')],
                                  early_stopping_rounds=10, verbose_eval=False)
            xgb_models.append(xgb_model)

            y_train_pred_xgb.append(xgb_model.predict(dtrain))
            y_val_pred_xgb.append(xgb_model.predict(dval))
            y_test_pred_xgb.append(xgb_model.predict(dtest))

        y_train_pred_xgb = np.column_stack(y_train_pred_xgb)
        y_val_pred_xgb = np.column_stack(y_val_pred_xgb)
        y_test_pred_xgb = np.column_stack(y_test_pred_xgb)

        # Combine Predictions (Weighted Average)
        alpha = 0.5
        y_train_pred_combined = alpha * y_train_pred_cnn + (1 - alpha) * y_train_pred_xgb
        y_val_pred_combined = alpha * y_val_pred_cnn + (1 - alpha) * y_val_pred_xgb
        y_test_pred_combined = alpha * y_test_pred_cnn + (1 - alpha) * y_test_pred_xgb

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred_combined)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred_combined)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred_combined)
        y_test_original = scaler_y.inverse_transform(y_test)

        # Metrics
        for i, target in enumerate(target_col_list):
            print(f'Results for {target.capitalize()}:')
            print(f'  Train R^2: {r2_score(y_train_original[:, i], y_train_pred_original[:, i]):.4f}')
            print(f'  Validation R^2: {r2_score(y_val_original[:, i], y_val_pred_original[:, i]):.4f}')
            print(f'  Test R^2: {r2_score(y_test_original[:, i], y_test_pred_original[:, i]):.4f}')
            print()

        fold += 1

    return cnn_model, xgb_models

cnn_model, xgb_models = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
# Out:
# Fold 1/5
# Training CNN...
# Epoch 1/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0776 - target_childcare_loss: 0.0134 - target_food_loss: 0.0048 - target_healthcare_loss: 0.0134 - target_housing_loss: 0.0095 - target_othernecessities_loss: 0.0069 - target_taxes_loss: 0.0089 - target_transportation_loss: 0.0207 - val_loss: 0.0133 - val_target_childcare_loss: 0.0021 - val_target_food_loss: 5.3239e-04 - val_target_healthcare_loss: 0.0045 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.5791e-04 - val_target_taxes_loss: 4.8541e-04 - val_target_transportation_loss: 0.0035
# Epoch 2/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0135 - target_childcare_loss: 0.0020 - target_food_loss: 6.1540e-04 - target_healthcare_loss: 0.0049 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.7017e-04 - target_taxes_loss: 4.9101e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8946e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.1259e-04 - val_target_taxes_loss: 4.3972e-04 - val_target_transportation_loss: 0.0034
# Epoch 3/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0131 - target_childcare_loss: 0.0020 - target_food_loss: 5.7219e-04 - target_healthcare_loss: 0.0047 - target_housing_loss: 0.0013 - target_othernecessities_loss: 8.3835e-04 - target_taxes_loss: 4.3273e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0124 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8425e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.9037e-04 - val_target_taxes_loss: 4.1552e-04 - val_target_transportation_loss: 0.0034
# Epoch 4/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0128 - target_childcare_loss: 0.0020 - target_food_loss: 5.8173e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 8.0730e-04 - target_taxes_loss: 4.1081e-04 - target_transportation_loss: 0.0033 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.7299e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0013 - val_target_othernecessities_loss: 8.1231e-04 - val_target_taxes_loss: 4.0735e-04 - val_target_transportation_loss: 0.0034
# Epoch 5/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.5651e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6919e-04 - target_taxes_loss: 3.8736e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0126 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.7949e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.7684e-04 - val_target_taxes_loss: 4.6037e-04 - val_target_transportation_loss: 0.0036
# Epoch 6/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.4442e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.6448e-04 - target_taxes_loss: 4.0715e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0124 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 4.6677e-04 - val_target_healthcare_loss: 0.0042 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.0576e-04 - val_target_taxes_loss: 3.6636e-04 - val_target_transportation_loss: 0.0034
# Epoch 7/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0124 - target_childcare_loss: 0.0019 - target_food_loss: 5.3089e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.6149e-04 - target_taxes_loss: 3.9517e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.5795e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.6477e-04 - val_target_taxes_loss: 3.6570e-04 - val_target_transportation_loss: 0.0034
# Epoch 8/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0121 - target_childcare_loss: 0.0018 - target_food_loss: 5.4412e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4528e-04 - target_taxes_loss: 3.7245e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0126 - val_target_childcare_loss: 0.0019 - val_target_food_loss: 4.8810e-04 - val_target_healthcare_loss: 0.0043 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.8598e-04 - val_target_taxes_loss: 4.2518e-04 - val_target_transportation_loss: 0.0035
# Epoch 9/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0125 - target_childcare_loss: 0.0019 - target_food_loss: 5.6461e-04 - target_healthcare_loss: 0.0045 - target_housing_loss: 0.0012 - target_othernecessities_loss: 7.7601e-04 - target_taxes_loss: 3.8296e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6787e-04 - val_target_healthcare_loss: 0.0041 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.8948e-04 - val_target_taxes_loss: 4.0003e-04 - val_target_transportation_loss: 0.0034
# Epoch 10/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0122 - target_childcare_loss: 0.0019 - target_food_loss: 5.6164e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5410e-04 - target_taxes_loss: 3.7396e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0122 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 5.1891e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.2858e-04 - val_target_taxes_loss: 3.6193e-04 - val_target_transportation_loss: 0.0034
# Epoch 11/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0123 - target_childcare_loss: 0.0019 - target_food_loss: 5.6212e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5724e-04 - target_taxes_loss: 3.6949e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0119 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.6648e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6219e-04 - val_target_taxes_loss: 3.6646e-04 - val_target_transportation_loss: 0.0033
# Epoch 12/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0121 - target_childcare_loss: 0.0019 - target_food_loss: 5.3526e-04 - target_healthcare_loss: 0.0044 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.4703e-04 - target_taxes_loss: 3.6871e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6108e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4716e-04 - val_target_taxes_loss: 3.5961e-04 - val_target_transportation_loss: 0.0033
# Epoch 13/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0121 - target_childcare_loss: 0.0018 - target_food_loss: 5.5953e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5036e-04 - target_taxes_loss: 3.6452e-04 - target_transportation_loss: 0.0032 - val_loss: 0.0121 - val_target_childcare_loss: 0.0018 - val_target_food_loss: 4.9053e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6632e-04 - val_target_taxes_loss: 3.6582e-04 - val_target_transportation_loss: 0.0035
# Epoch 14/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0119 - target_childcare_loss: 0.0018 - target_food_loss: 5.3987e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2996e-04 - target_taxes_loss: 3.6033e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0118 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6954e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.6312e-04 - val_target_taxes_loss: 3.7643e-04 - val_target_transportation_loss: 0.0033
# Epoch 15/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0118 - target_childcare_loss: 0.0018 - target_food_loss: 5.2399e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5777e-04 - target_taxes_loss: 3.6678e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0020 - val_target_food_loss: 4.6366e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.0771e-04 - val_target_taxes_loss: 3.5931e-04 - val_target_transportation_loss: 0.0034
# Epoch 16/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0120 - target_childcare_loss: 0.0018 - target_food_loss: 5.6896e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.5626e-04 - target_taxes_loss: 3.5779e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5497e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5783e-04 - val_target_taxes_loss: 3.7163e-04 - val_target_transportation_loss: 0.0033
# Epoch 17/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.1000e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2929e-04 - target_taxes_loss: 3.5255e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5989e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4786e-04 - val_target_taxes_loss: 3.7172e-04 - val_target_transportation_loss: 0.0033
# Epoch 18/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.3327e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3003e-04 - target_taxes_loss: 3.5894e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6103e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.4291e-04 - val_target_taxes_loss: 3.6139e-04 - val_target_transportation_loss: 0.0033
# Epoch 19/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0118 - target_childcare_loss: 0.0017 - target_food_loss: 5.1375e-04 - target_healthcare_loss: 0.0043 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.3101e-04 - target_taxes_loss: 3.5262e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0121 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 5.8663e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 8.8884e-04 - val_target_taxes_loss: 3.4871e-04 - val_target_transportation_loss: 0.0033
# Epoch 20/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0117 - target_childcare_loss: 0.0018 - target_food_loss: 5.1877e-04 - target_healthcare_loss: 0.0042 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2802e-04 - target_taxes_loss: 3.5657e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5580e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0012 - val_target_othernecessities_loss: 7.5116e-04 - val_target_taxes_loss: 3.8254e-04 - val_target_transportation_loss: 0.0033
# Epoch 21/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0116 - target_childcare_loss: 0.0017 - target_food_loss: 5.1563e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1335e-04 - target_taxes_loss: 3.5520e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0116 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 5.1845e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 8.1094e-04 - val_target_taxes_loss: 3.5335e-04 - val_target_transportation_loss: 0.0033
# Epoch 22/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0116 - target_childcare_loss: 0.0018 - target_food_loss: 5.3556e-04 - target_healthcare_loss: 0.0041 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1555e-04 - target_taxes_loss: 3.4726e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0117 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5341e-04 - val_target_healthcare_loss: 0.0039 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2435e-04 - val_target_taxes_loss: 3.4319e-04 - val_target_transportation_loss: 0.0033
# Epoch 23/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0114 - target_childcare_loss: 0.0017 - target_food_loss: 5.1419e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0701e-04 - target_taxes_loss: 3.4647e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0116 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.6544e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3637e-04 - val_target_taxes_loss: 3.5270e-04 - val_target_transportation_loss: 0.0033
# Epoch 24/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0113 - target_childcare_loss: 0.0017 - target_food_loss: 5.3258e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0010 - target_othernecessities_loss: 7.0359e-04 - target_taxes_loss: 3.4308e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0114 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4979e-04 - val_target_healthcare_loss: 0.0038 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1664e-04 - val_target_taxes_loss: 3.5431e-04 - val_target_transportation_loss: 0.0033
# Epoch 25/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.5989e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2058e-04 - target_taxes_loss: 3.5430e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0113 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4780e-04 - val_target_healthcare_loss: 0.0037 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2843e-04 - val_target_taxes_loss: 3.4815e-04 - val_target_transportation_loss: 0.0034
# Epoch 26/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0115 - target_childcare_loss: 0.0017 - target_food_loss: 5.3880e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.2450e-04 - target_taxes_loss: 3.4555e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.8068e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.3309e-04 - val_target_taxes_loss: 3.3607e-04 - val_target_transportation_loss: 0.0033
# Epoch 27/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0113 - target_childcare_loss: 0.0017 - target_food_loss: 5.4865e-04 - target_healthcare_loss: 0.0040 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0902e-04 - target_taxes_loss: 3.3159e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0111 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4464e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1630e-04 - val_target_taxes_loss: 3.5227e-04 - val_target_transportation_loss: 0.0033
# Epoch 28/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0112 - target_childcare_loss: 0.0016 - target_food_loss: 5.4515e-04 - target_healthcare_loss: 0.0039 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0463e-04 - target_taxes_loss: 3.3246e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0112 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.6758e-04 - val_target_healthcare_loss: 0.0036 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2418e-04 - val_target_taxes_loss: 3.4236e-04 - val_target_transportation_loss: 0.0033
# Epoch 29/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0111 - target_childcare_loss: 0.0017 - target_food_loss: 5.2733e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.0980e-04 - target_taxes_loss: 3.4215e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5127e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1597e-04 - val_target_taxes_loss: 3.3613e-04 - val_target_transportation_loss: 0.0032
# Epoch 30/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.4152e-04 - target_healthcare_loss: 0.0038 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8272e-04 - target_taxes_loss: 3.2818e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0109 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6298e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2527e-04 - val_target_taxes_loss: 3.2999e-04 - val_target_transportation_loss: 0.0032
# Epoch 31/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0110 - target_childcare_loss: 0.0016 - target_food_loss: 5.3470e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 7.1347e-04 - target_taxes_loss: 3.3511e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5772e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1190e-04 - val_target_taxes_loss: 3.3084e-04 - val_target_transportation_loss: 0.0032
# Epoch 32/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0111 - target_childcare_loss: 0.0016 - target_food_loss: 5.4488e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.9752e-04 - target_taxes_loss: 3.2562e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.6089e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2689e-04 - val_target_taxes_loss: 3.2875e-04 - val_target_transportation_loss: 0.0032
# Epoch 33/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0107 - target_childcare_loss: 0.0016 - target_food_loss: 5.1135e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9421e-04 - target_taxes_loss: 3.2670e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0108 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.9829e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 7.0588e-04 - val_target_taxes_loss: 3.4348e-04 - val_target_transportation_loss: 0.0032
# Epoch 34/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0109 - target_childcare_loss: 0.0016 - target_food_loss: 5.1838e-04 - target_healthcare_loss: 0.0037 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9190e-04 - target_taxes_loss: 3.4538e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4453e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9542e-04 - val_target_taxes_loss: 3.4968e-04 - val_target_transportation_loss: 0.0031
# Epoch 35/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0108 - target_childcare_loss: 0.0016 - target_food_loss: 5.3883e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8029e-04 - target_taxes_loss: 3.2658e-04 - target_transportation_loss: 0.0031 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5165e-04 - val_target_healthcare_loss: 0.0035 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9399e-04 - val_target_taxes_loss: 3.6778e-04 - val_target_transportation_loss: 0.0031
# Epoch 36/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.0385e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6615e-04 - target_taxes_loss: 3.2846e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0114 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.5501e-04 - val_target_healthcare_loss: 0.0040 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2259e-04 - val_target_taxes_loss: 3.4074e-04 - val_target_transportation_loss: 0.0032
# Epoch 37/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0108 - target_childcare_loss: 0.0015 - target_food_loss: 5.3916e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9096e-04 - target_taxes_loss: 3.1902e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5215e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.1142e-04 - val_target_taxes_loss: 3.5778e-04 - val_target_transportation_loss: 0.0031
# Epoch 38/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 4.9422e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9436e-04 - target_taxes_loss: 3.1709e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0107 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.4974e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.2280e-04 - val_target_taxes_loss: 3.2230e-04 - val_target_transportation_loss: 0.0031
# Epoch 39/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 4.9253e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7527e-04 - target_taxes_loss: 3.1760e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0107 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.8135e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0305e-04 - val_target_taxes_loss: 3.2838e-04 - val_target_transportation_loss: 0.0032
# Epoch 40/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0107 - target_childcare_loss: 0.0015 - target_food_loss: 5.2658e-04 - target_healthcare_loss: 0.0036 - target_housing_loss: 0.0011 - target_othernecessities_loss: 6.8412e-04 - target_taxes_loss: 3.2892e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5620e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9770e-04 - val_target_taxes_loss: 3.2266e-04 - val_target_transportation_loss: 0.0032
# Epoch 41/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 4.9615e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8305e-04 - target_taxes_loss: 3.1820e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5590e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 6.9729e-04 - val_target_taxes_loss: 3.2175e-04 - val_target_transportation_loss: 0.0031
# Epoch 42/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 5.0422e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.8144e-04 - target_taxes_loss: 3.2070e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0105 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4538e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0714e-04 - val_target_taxes_loss: 3.4039e-04 - val_target_transportation_loss: 0.0031
# Epoch 43/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0106 - target_childcare_loss: 0.0015 - target_food_loss: 5.3219e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7981e-04 - target_taxes_loss: 3.2063e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5633e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6934e-04 - val_target_taxes_loss: 3.3707e-04 - val_target_transportation_loss: 0.0033
# Epoch 44/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 4.9589e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9699e-04 - target_othernecessities_loss: 6.5824e-04 - target_taxes_loss: 3.1833e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0107 - val_target_childcare_loss: 0.0017 - val_target_food_loss: 4.5163e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8468e-04 - val_target_taxes_loss: 3.2755e-04 - val_target_transportation_loss: 0.0031
# Epoch 45/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0104 - target_childcare_loss: 0.0015 - target_food_loss: 4.8935e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.9017e-04 - target_taxes_loss: 3.2241e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0106 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.9996e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8830e-04 - val_target_taxes_loss: 3.3051e-04 - val_target_transportation_loss: 0.0032
# Epoch 46/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.4929e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.7540e-04 - target_taxes_loss: 3.1870e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0106 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4799e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9470e-04 - val_target_taxes_loss: 3.5379e-04 - val_target_transportation_loss: 0.0032
# Epoch 47/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0105 - target_childcare_loss: 0.0015 - target_food_loss: 5.1826e-04 - target_healthcare_loss: 0.0035 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6932e-04 - target_taxes_loss: 3.3949e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0105 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.3908e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0543e-04 - val_target_taxes_loss: 3.1761e-04 - val_target_transportation_loss: 0.0031
# Epoch 48/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.1443e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6287e-04 - target_taxes_loss: 3.1055e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0102 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4568e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.8393e-04 - val_target_taxes_loss: 3.1882e-04 - val_target_transportation_loss: 0.0031
# Epoch 49/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0103 - target_childcare_loss: 0.0015 - target_food_loss: 5.2863e-04 - target_healthcare_loss: 0.0034 - target_housing_loss: 9.9158e-04 - target_othernecessities_loss: 6.5896e-04 - target_taxes_loss: 3.2997e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0103 - val_target_childcare_loss: 0.0015 - val_target_food_loss: 4.5971e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7423e-04 - val_target_taxes_loss: 3.2434e-04 - val_target_transportation_loss: 0.0031
# Epoch 50/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0101 - target_childcare_loss: 0.0015 - target_food_loss: 5.2055e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.8659e-04 - target_othernecessities_loss: 6.5471e-04 - target_taxes_loss: 3.1839e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.5206e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9683e-04 - val_target_taxes_loss: 3.2335e-04 - val_target_transportation_loss: 0.0031
# Epoch 51/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.8908e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 0.0010 - target_othernecessities_loss: 6.6184e-04 - target_taxes_loss: 3.0154e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0106 - val_target_childcare_loss: 0.0016 - val_target_food_loss: 4.4440e-04 - val_target_healthcare_loss: 0.0034 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9444e-04 - val_target_taxes_loss: 3.2307e-04 - val_target_transportation_loss: 0.0031
# Epoch 52/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0015 - target_food_loss: 5.1777e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7145e-04 - target_othernecessities_loss: 6.4715e-04 - target_taxes_loss: 3.1498e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3444e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.7814e-04 - val_target_taxes_loss: 3.1279e-04 - val_target_transportation_loss: 0.0031
# Epoch 53/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.9188e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.7723e-04 - target_othernecessities_loss: 6.4868e-04 - target_taxes_loss: 3.0941e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0103 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3816e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9384e-04 - val_target_taxes_loss: 3.1740e-04 - val_target_transportation_loss: 0.0030
# Epoch 54/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 4.9802e-04 - target_healthcare_loss: 0.0033 - target_housing_loss: 9.6319e-04 - target_othernecessities_loss: 6.3328e-04 - target_taxes_loss: 3.0852e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3427e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9231e-04 - val_target_taxes_loss: 3.2488e-04 - val_target_transportation_loss: 0.0031
# Epoch 55/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0100 - target_childcare_loss: 0.0015 - target_food_loss: 5.0390e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7066e-04 - target_othernecessities_loss: 6.3831e-04 - target_taxes_loss: 3.0972e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3376e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.6673e-04 - val_target_taxes_loss: 3.2461e-04 - val_target_transportation_loss: 0.0031
# Epoch 56/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0101 - target_childcare_loss: 0.0014 - target_food_loss: 4.8743e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.9263e-04 - target_othernecessities_loss: 6.5576e-04 - target_taxes_loss: 3.0511e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2773e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.8120e-04 - val_target_othernecessities_loss: 6.5219e-04 - val_target_taxes_loss: 3.0426e-04 - val_target_transportation_loss: 0.0030
# Epoch 57/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 5.1045e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7172e-04 - target_othernecessities_loss: 6.3519e-04 - target_taxes_loss: 2.9897e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4204e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 0.0010 - val_target_othernecessities_loss: 6.9506e-04 - val_target_taxes_loss: 3.0464e-04 - val_target_transportation_loss: 0.0031
# Epoch 58/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0099 - target_childcare_loss: 0.0014 - target_food_loss: 4.6720e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.5274e-04 - target_othernecessities_loss: 6.2796e-04 - target_taxes_loss: 2.9698e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0100 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3131e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.9006e-04 - val_target_othernecessities_loss: 6.5054e-04 - val_target_taxes_loss: 3.0857e-04 - val_target_transportation_loss: 0.0031
# Epoch 59/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8286e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.4669e-04 - target_othernecessities_loss: 6.0620e-04 - target_taxes_loss: 2.8807e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.4200e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 0.0011 - val_target_othernecessities_loss: 7.0599e-04 - val_target_taxes_loss: 3.1654e-04 - val_target_transportation_loss: 0.0031
# Epoch 60/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0100 - target_childcare_loss: 0.0014 - target_food_loss: 5.3029e-04 - target_healthcare_loss: 0.0032 - target_housing_loss: 9.7415e-04 - target_othernecessities_loss: 6.3323e-04 - target_taxes_loss: 3.0079e-04 - target_transportation_loss: 0.0030 - val_loss: 0.0101 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3610e-04 - val_target_healthcare_loss: 0.0033 - val_target_housing_loss: 9.8294e-04 - val_target_othernecessities_loss: 6.4985e-04 - val_target_taxes_loss: 3.1698e-04 - val_target_transportation_loss: 0.0030
# Epoch 61/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8220e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4082e-04 - target_othernecessities_loss: 6.1694e-04 - target_taxes_loss: 2.9936e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2777e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.6228e-04 - val_target_othernecessities_loss: 6.3004e-04 - val_target_taxes_loss: 3.0795e-04 - val_target_transportation_loss: 0.0031
# Epoch 62/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.7404e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3610e-04 - target_othernecessities_loss: 6.0110e-04 - target_taxes_loss: 2.8700e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.3669e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.7959e-04 - val_target_othernecessities_loss: 6.3989e-04 - val_target_taxes_loss: 3.0605e-04 - val_target_transportation_loss: 0.0030
# Epoch 63/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0098 - target_childcare_loss: 0.0014 - target_food_loss: 4.8801e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4883e-04 - target_othernecessities_loss: 6.1384e-04 - target_taxes_loss: 2.8837e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.1954e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.4873e-04 - val_target_othernecessities_loss: 6.3270e-04 - val_target_taxes_loss: 3.0944e-04 - val_target_transportation_loss: 0.0030
# Epoch 64/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.8951e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3586e-04 - target_othernecessities_loss: 6.0221e-04 - target_taxes_loss: 2.9586e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1170e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.4377e-04 - val_target_othernecessities_loss: 6.1619e-04 - val_target_taxes_loss: 3.0392e-04 - val_target_transportation_loss: 0.0030
# Epoch 65/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.7488e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.2607e-04 - target_othernecessities_loss: 5.8929e-04 - target_taxes_loss: 2.9580e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0098 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.6152e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.7422e-04 - val_target_othernecessities_loss: 6.4269e-04 - val_target_taxes_loss: 3.0129e-04 - val_target_transportation_loss: 0.0031
# Epoch 66/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.9688e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.3773e-04 - target_othernecessities_loss: 5.9443e-04 - target_taxes_loss: 2.9282e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2543e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.4908e-04 - val_target_othernecessities_loss: 6.2175e-04 - val_target_taxes_loss: 3.0238e-04 - val_target_transportation_loss: 0.0030
# Epoch 67/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.8559e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3451e-04 - target_othernecessities_loss: 6.0126e-04 - target_taxes_loss: 2.9670e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0098 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2674e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.8088e-04 - val_target_othernecessities_loss: 6.5603e-04 - val_target_taxes_loss: 3.0986e-04 - val_target_transportation_loss: 0.0030
# Epoch 68/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0097 - target_childcare_loss: 0.0014 - target_food_loss: 4.7915e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.6369e-04 - target_othernecessities_loss: 6.0975e-04 - target_taxes_loss: 2.9268e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2503e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.2800e-04 - val_target_othernecessities_loss: 6.0391e-04 - val_target_taxes_loss: 3.3546e-04 - val_target_transportation_loss: 0.0030
# Epoch 69/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.7430e-04 - target_healthcare_loss: 0.0031 - target_housing_loss: 9.4925e-04 - target_othernecessities_loss: 6.1166e-04 - target_taxes_loss: 2.8990e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0097 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.3437e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3872e-04 - val_target_othernecessities_loss: 6.1970e-04 - val_target_taxes_loss: 3.1191e-04 - val_target_transportation_loss: 0.0031
# Epoch 70/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0095 - target_childcare_loss: 0.0014 - target_food_loss: 4.7348e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.2578e-04 - target_othernecessities_loss: 5.8630e-04 - target_taxes_loss: 2.7993e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.1374e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.3313e-04 - val_target_othernecessities_loss: 5.9591e-04 - val_target_taxes_loss: 2.9334e-04 - val_target_transportation_loss: 0.0030
# Epoch 71/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.7084e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3078e-04 - target_othernecessities_loss: 5.8412e-04 - target_taxes_loss: 2.8407e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1883e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.2874e-04 - val_target_othernecessities_loss: 6.0201e-04 - val_target_taxes_loss: 3.0933e-04 - val_target_transportation_loss: 0.0030
# Epoch 72/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.6050e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0661e-04 - target_othernecessities_loss: 5.7449e-04 - target_taxes_loss: 2.8793e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1263e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0128e-04 - val_target_othernecessities_loss: 5.8115e-04 - val_target_taxes_loss: 3.2061e-04 - val_target_transportation_loss: 0.0030
# Epoch 73/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0095 - target_childcare_loss: 0.0013 - target_food_loss: 4.6032e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0278e-04 - target_othernecessities_loss: 5.6819e-04 - target_taxes_loss: 2.7614e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2929e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0641e-04 - val_target_othernecessities_loss: 5.9093e-04 - val_target_taxes_loss: 2.9900e-04 - val_target_transportation_loss: 0.0030
# Epoch 74/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.6363e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1400e-04 - target_othernecessities_loss: 5.7470e-04 - target_taxes_loss: 2.8205e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1831e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.8780e-04 - val_target_othernecessities_loss: 5.8015e-04 - val_target_taxes_loss: 2.9222e-04 - val_target_transportation_loss: 0.0030
# Epoch 75/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0096 - target_childcare_loss: 0.0014 - target_food_loss: 4.9431e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.3695e-04 - target_othernecessities_loss: 5.9416e-04 - target_taxes_loss: 2.8816e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1863e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0121e-04 - val_target_othernecessities_loss: 5.9615e-04 - val_target_taxes_loss: 2.9883e-04 - val_target_transportation_loss: 0.0030
# Epoch 76/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.6598e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9474e-04 - target_othernecessities_loss: 5.8013e-04 - target_taxes_loss: 2.8304e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0096 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2069e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.0732e-04 - val_target_othernecessities_loss: 5.9591e-04 - val_target_taxes_loss: 2.9785e-04 - val_target_transportation_loss: 0.0031
# Epoch 77/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0093 - target_childcare_loss: 0.0014 - target_food_loss: 4.8476e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0467e-04 - target_othernecessities_loss: 5.7551e-04 - target_taxes_loss: 2.8140e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.2677e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 9.0377e-04 - val_target_othernecessities_loss: 5.9855e-04 - val_target_taxes_loss: 2.9984e-04 - val_target_transportation_loss: 0.0030
# Epoch 78/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.6221e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.0556e-04 - target_othernecessities_loss: 5.6767e-04 - target_taxes_loss: 2.7855e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.1561e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.9169e-04 - val_target_othernecessities_loss: 5.8697e-04 - val_target_taxes_loss: 2.8247e-04 - val_target_transportation_loss: 0.0030
# Epoch 79/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0094 - target_childcare_loss: 0.0013 - target_food_loss: 4.8315e-04 - target_healthcare_loss: 0.0030 - target_housing_loss: 9.1336e-04 - target_othernecessities_loss: 5.7932e-04 - target_taxes_loss: 2.7831e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 4.2733e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 9.0725e-04 - val_target_othernecessities_loss: 5.9999e-04 - val_target_taxes_loss: 2.8802e-04 - val_target_transportation_loss: 0.0031
# Epoch 80/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7092e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0874e-04 - target_othernecessities_loss: 5.6382e-04 - target_taxes_loss: 2.7744e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 4.1417e-04 - val_target_healthcare_loss: 0.0027 - val_target_housing_loss: 8.6679e-04 - val_target_othernecessities_loss: 5.6311e-04 - val_target_taxes_loss: 2.9964e-04 - val_target_transportation_loss: 0.0031
# Epoch 81/200
# ...
# Epoch 99/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.8836e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.1376e-04 - target_othernecessities_loss: 5.9006e-04 - target_taxes_loss: 2.9097e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.4881e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.9181e-04 - val_target_othernecessities_loss: 5.7078e-04 - val_target_taxes_loss: 3.1275e-04 - val_target_transportation_loss: 0.0027
# Epoch 100/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7640e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0536e-04 - target_othernecessities_loss: 5.8220e-04 - target_taxes_loss: 2.8470e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.5600e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.5532e-04 - val_target_othernecessities_loss: 5.5060e-04 - val_target_taxes_loss: 3.1996e-04 - val_target_transportation_loss: 0.0027
# Epoch 101/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.5771e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.5098e-04 - target_othernecessities_loss: 5.4836e-04 - target_taxes_loss: 2.8192e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0094 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5865e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.8869e-04 - val_target_othernecessities_loss: 5.5456e-04 - val_target_taxes_loss: 2.9432e-04 - val_target_transportation_loss: 0.0027
# Epoch 102/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0093 - target_childcare_loss: 0.0014 - target_food_loss: 4.6425e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7987e-04 - target_othernecessities_loss: 5.6598e-04 - target_taxes_loss: 2.8139e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0091 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6666e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.5115e-04 - val_target_othernecessities_loss: 5.5043e-04 - val_target_taxes_loss: 3.0095e-04 - val_target_transportation_loss: 0.0027
# Epoch 103/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.7916e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7967e-04 - target_othernecessities_loss: 5.6191e-04 - target_taxes_loss: 2.8764e-04 - target_transportation_loss: 0.0027 - val_loss: 0.0091 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.8673e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6182e-04 - val_target_othernecessities_loss: 5.6281e-04 - val_target_taxes_loss: 2.9925e-04 - val_target_transportation_loss: 0.0027
# Epoch 104/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.7331e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9320e-04 - target_othernecessities_loss: 5.7634e-04 - target_taxes_loss: 2.8495e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.7039e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 8.7950e-04 - val_target_othernecessities_loss: 5.7477e-04 - val_target_taxes_loss: 2.9906e-04 - val_target_transportation_loss: 0.0027
# Epoch 105/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.9084e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8014e-04 - target_othernecessities_loss: 5.6905e-04 - target_taxes_loss: 2.8317e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0091 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.5141e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6541e-04 - val_target_othernecessities_loss: 5.5569e-04 - val_target_taxes_loss: 2.9952e-04 - val_target_transportation_loss: 0.0027
# Epoch 106/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6874e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8375e-04 - target_othernecessities_loss: 5.7274e-04 - target_taxes_loss: 2.8046e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5656e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 9.1663e-04 - val_target_othernecessities_loss: 5.7044e-04 - val_target_taxes_loss: 2.8974e-04 - val_target_transportation_loss: 0.0027
# Epoch 107/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0090 - target_childcare_loss: 0.0013 - target_food_loss: 4.6551e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.4121e-04 - target_othernecessities_loss: 5.4602e-04 - target_taxes_loss: 2.8072e-04 - target_transportation_loss: 0.0027 - val_loss: 0.0094 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 6.6077e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.5528e-04 - val_target_othernecessities_loss: 5.4870e-04 - val_target_taxes_loss: 2.8448e-04 - val_target_transportation_loss: 0.0027
# Epoch 108/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.7389e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7035e-04 - target_othernecessities_loss: 5.6134e-04 - target_taxes_loss: 2.7894e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6282e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.8937e-04 - val_target_othernecessities_loss: 5.6585e-04 - val_target_taxes_loss: 2.9118e-04 - val_target_transportation_loss: 0.0027
# Epoch 109/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.6453e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8316e-04 - target_othernecessities_loss: 5.7324e-04 - target_taxes_loss: 2.7741e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0091 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.4969e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.7223e-04 - val_target_othernecessities_loss: 5.5100e-04 - val_target_taxes_loss: 2.8516e-04 - val_target_transportation_loss: 0.0027
# Epoch 110/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.8707e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9113e-04 - target_othernecessities_loss: 5.7288e-04 - target_taxes_loss: 2.7395e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5057e-04 - val_target_healthcare_loss: 0.0032 - val_target_housing_loss: 8.6774e-04 - val_target_othernecessities_loss: 5.5519e-04 - val_target_taxes_loss: 3.0153e-04 - val_target_transportation_loss: 0.0028
# Epoch 111/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.4864e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.9129e-04 - target_othernecessities_loss: 5.5792e-04 - target_taxes_loss: 2.8062e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6224e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6903e-04 - val_target_othernecessities_loss: 5.5057e-04 - val_target_taxes_loss: 2.8416e-04 - val_target_transportation_loss: 0.0027
# Epoch 112/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6476e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7506e-04 - target_othernecessities_loss: 5.6560e-04 - target_taxes_loss: 2.7319e-04 - target_transportation_loss: 0.0029 - val_loss: 0.0095 - val_target_childcare_loss: 0.0014 - val_target_food_loss: 6.0084e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 8.5386e-04 - val_target_othernecessities_loss: 5.4398e-04 - val_target_taxes_loss: 2.8526e-04 - val_target_transportation_loss: 0.0027
# Epoch 113/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.7392e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7916e-04 - target_othernecessities_loss: 5.6257e-04 - target_taxes_loss: 2.7740e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0089 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.4810e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.4593e-04 - val_target_othernecessities_loss: 5.3815e-04 - val_target_taxes_loss: 2.8228e-04 - val_target_transportation_loss: 0.0027
# Epoch 114/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.9374e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.9395e-04 - target_othernecessities_loss: 5.6453e-04 - target_taxes_loss: 2.7306e-04 - target_transportation_loss: 0.0027 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5131e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.4850e-04 - val_target_othernecessities_loss: 5.3421e-04 - val_target_taxes_loss: 2.9801e-04 - val_target_transportation_loss: 0.0027
# Epoch 115/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0089 - target_childcare_loss: 0.0013 - target_food_loss: 4.6341e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.5791e-04 - target_othernecessities_loss: 5.6176e-04 - target_taxes_loss: 2.7184e-04 - target_transportation_loss: 0.0027 - val_loss: 0.0095 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.8335e-04 - val_target_healthcare_loss: 0.0031 - val_target_housing_loss: 9.0434e-04 - val_target_othernecessities_loss: 5.6286e-04 - val_target_taxes_loss: 2.8439e-04 - val_target_transportation_loss: 0.0027
# Epoch 116/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.5803e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.8832e-04 - target_othernecessities_loss: 5.7237e-04 - target_taxes_loss: 2.7157e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.5253e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.6595e-04 - val_target_othernecessities_loss: 5.5571e-04 - val_target_taxes_loss: 2.8381e-04 - val_target_transportation_loss: 0.0027
# Epoch 117/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.4951e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7289e-04 - target_othernecessities_loss: 5.6339e-04 - target_taxes_loss: 2.7146e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 6.0347e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.5849e-04 - val_target_othernecessities_loss: 5.6250e-04 - val_target_taxes_loss: 2.8283e-04 - val_target_transportation_loss: 0.0027
# Epoch 118/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0092 - target_childcare_loss: 0.0013 - target_food_loss: 4.6416e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 9.0179e-04 - target_othernecessities_loss: 5.7891e-04 - target_taxes_loss: 2.7147e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.4826e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.6087e-04 - val_target_othernecessities_loss: 5.4542e-04 - val_target_taxes_loss: 2.8010e-04 - val_target_transportation_loss: 0.0026
# Epoch 119/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0093 - target_childcare_loss: 0.0013 - target_food_loss: 4.6161e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 9.0433e-04 - target_othernecessities_loss: 5.7819e-04 - target_taxes_loss: 2.7596e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.4623e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.5900e-04 - val_target_othernecessities_loss: 5.5767e-04 - val_target_taxes_loss: 3.0154e-04 - val_target_transportation_loss: 0.0026
# Epoch 120/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.7265e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.8770e-04 - target_othernecessities_loss: 5.7654e-04 - target_taxes_loss: 2.6687e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0092 - val_target_childcare_loss: 0.0013 - val_target_food_loss: 5.5062e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.6321e-04 - val_target_othernecessities_loss: 5.4825e-04 - val_target_taxes_loss: 2.7973e-04 - val_target_transportation_loss: 0.0027
# Epoch 121/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.5204e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7753e-04 - target_othernecessities_loss: 5.6932e-04 - target_taxes_loss: 2.7088e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0090 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.4944e-04 - val_target_healthcare_loss: 0.0028 - val_target_housing_loss: 8.5997e-04 - val_target_othernecessities_loss: 5.5059e-04 - val_target_taxes_loss: 2.7169e-04 - val_target_transportation_loss: 0.0027
# Epoch 122/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.4592e-04 - target_healthcare_loss: 0.0029 - target_housing_loss: 8.7747e-04 - target_othernecessities_loss: 5.5578e-04 - target_taxes_loss: 2.7115e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0091 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.7420e-04 - val_target_healthcare_loss: 0.0029 - val_target_housing_loss: 8.7603e-04 - val_target_othernecessities_loss: 5.7202e-04 - val_target_taxes_loss: 2.8702e-04 - val_target_transportation_loss: 0.0027
# Epoch 123/200
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0091 - target_childcare_loss: 0.0013 - target_food_loss: 4.7185e-04 - target_healthcare_loss: 0.0028 - target_housing_loss: 8.7839e-04 - target_othernecessities_loss: 5.6755e-04 - target_taxes_loss: 2.6726e-04 - target_transportation_loss: 0.0028 - val_loss: 0.0093 - val_target_childcare_loss: 0.0012 - val_target_food_loss: 5.6543e-04 - val_target_healthcare_loss: 0.0030 - val_target_housing_loss: 9.1220e-04 - val_target_othernecessities_loss: 5.8312e-04 - val_target_taxes_loss: 2.8255e-04 - val_target_transportation_loss: 0.0026
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Training XGBoost...
# Results for Housing:
#   Train R^2: 0.9442
#   Validation R^2: 0.9274
#   Test R^2: 0.9329
#
# Results for Food:
#   Train R^2: 0.9795
#   Validation R^2: 0.9696
#   Test R^2: 0.9752
#
# Results for Transportation:
#   Train R^2: 0.8215
#   Validation R^2: 0.7968
#   Test R^2: 0.8038
#
# Results for Healthcare:
#   Train R^2: 0.9433
#   Validation R^2: 0.9385
#   Test R^2: 0.9361
#
# Results for Othernecessities:
#   Train R^2: 0.9759
#   Validation R^2: 0.9710
#   Test R^2: 0.9718
#
# Results for Childcare:
#   Train R^2: 0.9691
#   Validation R^2: 0.9623
#   Test R^2: 0.9640
#
# Results for Taxes:
#   Train R^2: 0.9899
#   Validation R^2: 0.9869
#   Test R^2: 0.9899

# %%
# Cross-Validation with Evaluation for XGBoost
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_boost_rounds=4000):
    fold = 1
    childcarelist = []
    childcarelist_pred = []
    for train_index, val_index in kf.split(X_scaled):
        models = []
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # Split validation and test data
        X_test, X_val, y_test, y_val = train_test_split(
            X_test_val, y_test_val, test_size=0.5, random_state=100
        )  # 50/50 split of remaining 20%

        # Train XGBoost model for each target variable
        # Store predictions for all targets in this fold
        all_y_train_pred = []
        all_y_val_pred = []
        all_y_test_pred = []

        for i in range(y_train.shape[1]):
            dtrain = xgb.DMatrix(X_train, label=y_train[:, i])
            dval = xgb.DMatrix(X_val, label=y_val[:, i])
            dtest = xgb.DMatrix(X_test)

            params = {
                'objective': 'reg:squarederror',
                'eval_metric': 'rmse',
                'learning_rate': 0.01,
                'max_depth': 6,
                'n_estimators': num_boost_rounds
            }

            evals = [(dtrain, 'train'), (dval, 'eval')]
            model = xgb.train(
                params, dtrain, num_boost_rounds, evals, early_stopping_rounds=50, verbose_eval=50
            )
            models.append(model) #Not required here

            # Predictions
            y_train_pred = model.predict(dtrain)
            y_val_pred = model.predict(dval)
            y_test_pred = model.predict(dtest)

            # Append predictions for current target to the list
            all_y_train_pred.append(y_train_pred)
            all_y_val_pred.append(y_val_pred)
            all_y_test_pred.append(y_test_pred)

        # Stack predictions for all targets to get the original shape
        y_train_pred = np.column_stack(all_y_train_pred)
        y_val_pred = np.column_stack(all_y_val_pred)
        y_test_pred = np.column_stack(all_y_test_pred)

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred) #Now y_train_pred has 7 columns matching scaler_y
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)  #Now y_val_pred has 7 columns matching scaler_y
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred) #Now y_test_pred has 7 columns matching scaler_y
        y_test_original = scaler_y.inverse_transform(y_test)


        # Enforce the rule after predictions for childcare expense
        y_train_pred_original[:, childcare_exp_col] = np.where(
            X_train[:, num_children_col] == 0, 0, y_train_pred_original[:, childcare_exp_col])

        y_val_pred_original[:, childcare_exp_col] = np.where(
            X_val[:, num_children_col] == 0, 0, y_val_pred_original[:, childcare_exp_col])

        y_test_pred_original[:, childcare_exp_col] = np.where(
            X_test[:, num_children_col] == 0, 0, y_test_pred_original[:, childcare_exp_col])

        # Metrics for each target
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()}:')
            print('Train Data:', regr_report(y_train_original[:, i], y_train_pred_original[:, i]))
            print('Validation Data:', regr_report(y_val_original[:, i], y_val_pred_original[:, i]))
            print('Test Data:', regr_report(y_test_original[:, i], y_test_pred_original[:, i])) #Print metrics for test set
            print()

        fold += 1
    return models

# Cross-Validation Execution
xgb_models = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
# Out:
# Fold 1/5
# [0]	train-rmse:0.09576	eval-rmse:0.09357
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:43:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.06498	eval-rmse:0.06382
# [100]	train-rmse:0.04792	eval-rmse:0.04759
# [150]	train-rmse:0.03894	eval-rmse:0.03937
# [200]	train-rmse:0.03424	eval-rmse:0.03522
# [250]	train-rmse:0.03154	eval-rmse:0.03279
# [300]	train-rmse:0.02986	eval-rmse:0.03120
# [350]	train-rmse:0.02847	eval-rmse:0.02993
# [400]	train-rmse:0.02729	eval-rmse:0.02883
# [450]	train-rmse:0.02634	eval-rmse:0.02797
# [500]	train-rmse:0.02578	eval-rmse:0.02749
# [550]	train-rmse:0.02528	eval-rmse:0.02708
# [600]	train-rmse:0.02482	eval-rmse:0.02670
# [650]	train-rmse:0.02448	eval-rmse:0.02645
# [700]	train-rmse:0.02410	eval-rmse:0.02616
# [750]	train-rmse:0.02364	eval-rmse:0.02578
# [800]	train-rmse:0.02330	eval-rmse:0.02550
# [850]	train-rmse:0.02298	eval-rmse:0.02523
# [900]	train-rmse:0.02266	eval-rmse:0.02493
# [950]	train-rmse:0.02233	eval-rmse:0.02463
# [1000]	train-rmse:0.02201	eval-rmse:0.02431
# [1050]	train-rmse:0.02180	eval-rmse:0.02412
# [1100]	train-rmse:0.02156	eval-rmse:0.02391
# [1150]	train-rmse:0.02134	eval-rmse:0.02374
# [1200]	train-rmse:0.02116	eval-rmse:0.02362
# [1250]	train-rmse:0.02098	eval-rmse:0.02348
# [1300]	train-rmse:0.02082	eval-rmse:0.02334
# [1350]	train-rmse:0.02064	eval-rmse:0.02318
# [1400]	train-rmse:0.02050	eval-rmse:0.02308
# [1450]	train-rmse:0.02034	eval-rmse:0.02297
# [1500]	train-rmse:0.02022	eval-rmse:0.02289
# [1550]	train-rmse:0.02009	eval-rmse:0.02281
# [1600]	train-rmse:0.01995	eval-rmse:0.02271
# [1650]	train-rmse:0.01981	eval-rmse:0.02262
# [1700]	train-rmse:0.01964	eval-rmse:0.02251
# [1750]	train-rmse:0.01953	eval-rmse:0.02245
# [1800]	train-rmse:0.01943	eval-rmse:0.02241
# [1850]	train-rmse:0.01932	eval-rmse:0.02236
# [1900]	train-rmse:0.01922	eval-rmse:0.02229
# [1950]	train-rmse:0.01912	eval-rmse:0.02223
# [2000]	train-rmse:0.01903	eval-rmse:0.02219
# [2050]	train-rmse:0.01894	eval-rmse:0.02215
# [2100]	train-rmse:0.01882	eval-rmse:0.02207
# [2150]	train-rmse:0.01872	eval-rmse:0.02201
# [2200]	train-rmse:0.01862	eval-rmse:0.02196
# [2250]	train-rmse:0.01851	eval-rmse:0.02189
# [2300]	train-rmse:0.01842	eval-rmse:0.02185
# [2350]	train-rmse:0.01834	eval-rmse:0.02181
# [2400]	train-rmse:0.01826	eval-rmse:0.02177
# [2450]	train-rmse:0.01818	eval-rmse:0.02172
# [2500]	train-rmse:0.01809	eval-rmse:0.02167
# [2550]	train-rmse:0.01799	eval-rmse:0.02162
# [2600]	train-rmse:0.01791	eval-rmse:0.02159
# [2650]	train-rmse:0.01782	eval-rmse:0.02155
# [2700]	train-rmse:0.01773	eval-rmse:0.02150
# [2750]	train-rmse:0.01764	eval-rmse:0.02145
# [2800]	train-rmse:0.01757	eval-rmse:0.02143
# [2850]	train-rmse:0.01751	eval-rmse:0.02141
# [2900]	train-rmse:0.01743	eval-rmse:0.02136
# [2950]	train-rmse:0.01734	eval-rmse:0.02131
# [3000]	train-rmse:0.01725	eval-rmse:0.02125
# [3050]	train-rmse:0.01718	eval-rmse:0.02121
# [3100]	train-rmse:0.01711	eval-rmse:0.02118
# [3150]	train-rmse:0.01703	eval-rmse:0.02114
# [3200]	train-rmse:0.01695	eval-rmse:0.02109
# [3250]	train-rmse:0.01686	eval-rmse:0.02103
# [3300]	train-rmse:0.01678	eval-rmse:0.02099
# [3350]	train-rmse:0.01670	eval-rmse:0.02094
# [3400]	train-rmse:0.01663	eval-rmse:0.02090
# [3450]	train-rmse:0.01656	eval-rmse:0.02086
# [3500]	train-rmse:0.01651	eval-rmse:0.02084
# [3550]	train-rmse:0.01646	eval-rmse:0.02082
# [3600]	train-rmse:0.01642	eval-rmse:0.02081
# [3650]	train-rmse:0.01635	eval-rmse:0.02077
# [3700]	train-rmse:0.01630	eval-rmse:0.02076
# [3750]	train-rmse:0.01624	eval-rmse:0.02075
# [3800]	train-rmse:0.01618	eval-rmse:0.02073
# [3850]	train-rmse:0.01610	eval-rmse:0.02069
# [3900]	train-rmse:0.01606	eval-rmse:0.02068
# [3950]	train-rmse:0.01599	eval-rmse:0.02065
# [3999]	train-rmse:0.01593	eval-rmse:0.02063
# [0]	train-rmse:0.11587	eval-rmse:0.11470
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:44:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07255	eval-rmse:0.07138
# [100]	train-rmse:0.04744	eval-rmse:0.04623
# [150]	train-rmse:0.03361	eval-rmse:0.03239
# [200]	train-rmse:0.02653	eval-rmse:0.02541
# [250]	train-rmse:0.02301	eval-rmse:0.02213
# [300]	train-rmse:0.02126	eval-rmse:0.02061
# [350]	train-rmse:0.02031	eval-rmse:0.01991
# [400]	train-rmse:0.01966	eval-rmse:0.01947
# [450]	train-rmse:0.01921	eval-rmse:0.01918
# [500]	train-rmse:0.01879	eval-rmse:0.01891
# [550]	train-rmse:0.01844	eval-rmse:0.01869
# [600]	train-rmse:0.01817	eval-rmse:0.01853
# [650]	train-rmse:0.01786	eval-rmse:0.01831
# [700]	train-rmse:0.01754	eval-rmse:0.01812
# [750]	train-rmse:0.01726	eval-rmse:0.01797
# [800]	train-rmse:0.01705	eval-rmse:0.01786
# [850]	train-rmse:0.01683	eval-rmse:0.01773
# [900]	train-rmse:0.01661	eval-rmse:0.01763
# [950]	train-rmse:0.01643	eval-rmse:0.01754
# [1000]	train-rmse:0.01623	eval-rmse:0.01744
# [1050]	train-rmse:0.01606	eval-rmse:0.01735
# [1100]	train-rmse:0.01590	eval-rmse:0.01728
# [1150]	train-rmse:0.01575	eval-rmse:0.01723
# [1200]	train-rmse:0.01562	eval-rmse:0.01717
# [1250]	train-rmse:0.01549	eval-rmse:0.01711
# [1300]	train-rmse:0.01536	eval-rmse:0.01706
# [1350]	train-rmse:0.01525	eval-rmse:0.01701
# [1400]	train-rmse:0.01514	eval-rmse:0.01696
# [1450]	train-rmse:0.01502	eval-rmse:0.01692
# [1500]	train-rmse:0.01489	eval-rmse:0.01687
# [1550]	train-rmse:0.01480	eval-rmse:0.01684
# [1600]	train-rmse:0.01470	eval-rmse:0.01681
# [1650]	train-rmse:0.01462	eval-rmse:0.01676
# [1700]	train-rmse:0.01452	eval-rmse:0.01671
# [1750]	train-rmse:0.01444	eval-rmse:0.01667
# [1800]	train-rmse:0.01435	eval-rmse:0.01663
# [1850]	train-rmse:0.01428	eval-rmse:0.01661
# [1900]	train-rmse:0.01420	eval-rmse:0.01658
# [1950]	train-rmse:0.01409	eval-rmse:0.01652
# [2000]	train-rmse:0.01397	eval-rmse:0.01644
# [2050]	train-rmse:0.01390	eval-rmse:0.01643
# [2100]	train-rmse:0.01383	eval-rmse:0.01641
# [2150]	train-rmse:0.01376	eval-rmse:0.01638
# [2200]	train-rmse:0.01367	eval-rmse:0.01634
# [2250]	train-rmse:0.01360	eval-rmse:0.01630
# [2300]	train-rmse:0.01352	eval-rmse:0.01627
# [2350]	train-rmse:0.01345	eval-rmse:0.01623
# [2400]	train-rmse:0.01338	eval-rmse:0.01621
# [2450]	train-rmse:0.01331	eval-rmse:0.01618
# [2500]	train-rmse:0.01325	eval-rmse:0.01615
# [2550]	train-rmse:0.01320	eval-rmse:0.01614
# [2600]	train-rmse:0.01314	eval-rmse:0.01613
# [2650]	train-rmse:0.01307	eval-rmse:0.01610
# [2700]	train-rmse:0.01302	eval-rmse:0.01609
# [2750]	train-rmse:0.01296	eval-rmse:0.01608
# [2800]	train-rmse:0.01291	eval-rmse:0.01606
# [2850]	train-rmse:0.01285	eval-rmse:0.01603
# [2900]	train-rmse:0.01278	eval-rmse:0.01600
# [2950]	train-rmse:0.01273	eval-rmse:0.01598
# [3000]	train-rmse:0.01266	eval-rmse:0.01594
# [3050]	train-rmse:0.01260	eval-rmse:0.01591
# [3100]	train-rmse:0.01254	eval-rmse:0.01588
# [3150]	train-rmse:0.01248	eval-rmse:0.01587
# [3200]	train-rmse:0.01242	eval-rmse:0.01585
# [3250]	train-rmse:0.01236	eval-rmse:0.01583
# [3300]	train-rmse:0.01232	eval-rmse:0.01582
# [3350]	train-rmse:0.01227	eval-rmse:0.01581
# [3400]	train-rmse:0.01223	eval-rmse:0.01581
# [3450]	train-rmse:0.01219	eval-rmse:0.01581
# [3500]	train-rmse:0.01215	eval-rmse:0.01580
# [3550]	train-rmse:0.01211	eval-rmse:0.01578
# [3600]	train-rmse:0.01205	eval-rmse:0.01574
# [3650]	train-rmse:0.01200	eval-rmse:0.01573
# [3700]	train-rmse:0.01194	eval-rmse:0.01570
# [3750]	train-rmse:0.01190	eval-rmse:0.01569
# [3800]	train-rmse:0.01187	eval-rmse:0.01569
# [3850]	train-rmse:0.01183	eval-rmse:0.01567
# [3900]	train-rmse:0.01178	eval-rmse:0.01566
# [3950]	train-rmse:0.01174	eval-rmse:0.01564
# [3999]	train-rmse:0.01169	eval-rmse:0.01562
# [0]	train-rmse:0.09852	eval-rmse:0.09932
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:44:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07425	eval-rmse:0.07564
# [100]	train-rmse:0.06247	eval-rmse:0.06458
# [150]	train-rmse:0.05688	eval-rmse:0.05955
# [200]	train-rmse:0.05397	eval-rmse:0.05694
# [250]	train-rmse:0.05206	eval-rmse:0.05511
# [300]	train-rmse:0.05054	eval-rmse:0.05370
# [350]	train-rmse:0.04926	eval-rmse:0.05258
# [400]	train-rmse:0.04831	eval-rmse:0.05177
# [450]	train-rmse:0.04736	eval-rmse:0.05089
# [500]	train-rmse:0.04649	eval-rmse:0.05012
# [550]	train-rmse:0.04557	eval-rmse:0.04930
# [600]	train-rmse:0.04489	eval-rmse:0.04867
# [650]	train-rmse:0.04405	eval-rmse:0.04792
# [700]	train-rmse:0.04343	eval-rmse:0.04736
# [750]	train-rmse:0.04295	eval-rmse:0.04692
# [800]	train-rmse:0.04241	eval-rmse:0.04645
# [850]	train-rmse:0.04200	eval-rmse:0.04610
# [900]	train-rmse:0.04162	eval-rmse:0.04577
# [950]	train-rmse:0.04125	eval-rmse:0.04545
# [1000]	train-rmse:0.04086	eval-rmse:0.04512
# [1050]	train-rmse:0.04053	eval-rmse:0.04483
# [1100]	train-rmse:0.04020	eval-rmse:0.04458
# [1150]	train-rmse:0.03991	eval-rmse:0.04436
# [1200]	train-rmse:0.03966	eval-rmse:0.04417
# [1250]	train-rmse:0.03930	eval-rmse:0.04387
# [1300]	train-rmse:0.03904	eval-rmse:0.04368
# [1350]	train-rmse:0.03871	eval-rmse:0.04343
# [1400]	train-rmse:0.03843	eval-rmse:0.04321
# [1450]	train-rmse:0.03811	eval-rmse:0.04294
# [1500]	train-rmse:0.03787	eval-rmse:0.04276
# [1550]	train-rmse:0.03753	eval-rmse:0.04249
# [1600]	train-rmse:0.03722	eval-rmse:0.04228
# [1650]	train-rmse:0.03692	eval-rmse:0.04204
# [1700]	train-rmse:0.03670	eval-rmse:0.04192
# [1750]	train-rmse:0.03645	eval-rmse:0.04174
# [1800]	train-rmse:0.03618	eval-rmse:0.04154
# [1850]	train-rmse:0.03596	eval-rmse:0.04140
# [1900]	train-rmse:0.03571	eval-rmse:0.04122
# [1950]	train-rmse:0.03547	eval-rmse:0.04108
# [2000]	train-rmse:0.03527	eval-rmse:0.04094
# [2050]	train-rmse:0.03509	eval-rmse:0.04084
# [2100]	train-rmse:0.03491	eval-rmse:0.04073
# [2150]	train-rmse:0.03476	eval-rmse:0.04065
# [2200]	train-rmse:0.03461	eval-rmse:0.04058
# [2250]	train-rmse:0.03447	eval-rmse:0.04053
# [2300]	train-rmse:0.03429	eval-rmse:0.04045
# [2350]	train-rmse:0.03410	eval-rmse:0.04034
# [2400]	train-rmse:0.03394	eval-rmse:0.04027
# [2450]	train-rmse:0.03376	eval-rmse:0.04019
# [2500]	train-rmse:0.03362	eval-rmse:0.04012
# [2550]	train-rmse:0.03348	eval-rmse:0.04005
# [2600]	train-rmse:0.03332	eval-rmse:0.03995
# [2650]	train-rmse:0.03316	eval-rmse:0.03987
# [2700]	train-rmse:0.03303	eval-rmse:0.03980
# [2750]	train-rmse:0.03288	eval-rmse:0.03971
# [2800]	train-rmse:0.03276	eval-rmse:0.03964
# [2850]	train-rmse:0.03263	eval-rmse:0.03957
# [2900]	train-rmse:0.03248	eval-rmse:0.03946
# [2950]	train-rmse:0.03236	eval-rmse:0.03941
# [3000]	train-rmse:0.03219	eval-rmse:0.03931
# [3050]	train-rmse:0.03196	eval-rmse:0.03917
# [3100]	train-rmse:0.03179	eval-rmse:0.03911
# [3150]	train-rmse:0.03168	eval-rmse:0.03906
# [3200]	train-rmse:0.03154	eval-rmse:0.03898
# [3250]	train-rmse:0.03140	eval-rmse:0.03889
# [3300]	train-rmse:0.03124	eval-rmse:0.03879
# [3350]	train-rmse:0.03112	eval-rmse:0.03873
# [3400]	train-rmse:0.03100	eval-rmse:0.03868
# [3450]	train-rmse:0.03089	eval-rmse:0.03863
# [3500]	train-rmse:0.03077	eval-rmse:0.03858
# [3550]	train-rmse:0.03065	eval-rmse:0.03852
# [3600]	train-rmse:0.03054	eval-rmse:0.03846
# [3650]	train-rmse:0.03036	eval-rmse:0.03834
# [3700]	train-rmse:0.03021	eval-rmse:0.03825
# [3750]	train-rmse:0.03007	eval-rmse:0.03817
# [3800]	train-rmse:0.02996	eval-rmse:0.03813
# [3850]	train-rmse:0.02985	eval-rmse:0.03808
# [3900]	train-rmse:0.02974	eval-rmse:0.03804
# [3950]	train-rmse:0.02966	eval-rmse:0.03802
# [3999]	train-rmse:0.02958	eval-rmse:0.03800
# [0]	train-rmse:0.15675	eval-rmse:0.15624
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:45:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.10823	eval-rmse:0.10734
# [100]	train-rmse:0.08253	eval-rmse:0.08148
# [150]	train-rmse:0.06934	eval-rmse:0.06845
# [200]	train-rmse:0.06187	eval-rmse:0.06123
# [250]	train-rmse:0.05592	eval-rmse:0.05552
# [300]	train-rmse:0.05132	eval-rmse:0.05104
# [350]	train-rmse:0.04789	eval-rmse:0.04796
# [400]	train-rmse:0.04496	eval-rmse:0.04538
# [450]	train-rmse:0.04283	eval-rmse:0.04343
# [500]	train-rmse:0.04133	eval-rmse:0.04207
# [550]	train-rmse:0.04003	eval-rmse:0.04094
# [600]	train-rmse:0.03885	eval-rmse:0.03989
# [650]	train-rmse:0.03785	eval-rmse:0.03904
# [700]	train-rmse:0.03712	eval-rmse:0.03846
# [750]	train-rmse:0.03642	eval-rmse:0.03791
# [800]	train-rmse:0.03588	eval-rmse:0.03748
# [850]	train-rmse:0.03539	eval-rmse:0.03709
# [900]	train-rmse:0.03490	eval-rmse:0.03671
# [950]	train-rmse:0.03449	eval-rmse:0.03643
# [1000]	train-rmse:0.03414	eval-rmse:0.03618
# [1050]	train-rmse:0.03381	eval-rmse:0.03593
# [1100]	train-rmse:0.03352	eval-rmse:0.03573
# [1150]	train-rmse:0.03327	eval-rmse:0.03557
# [1200]	train-rmse:0.03301	eval-rmse:0.03542
# [1250]	train-rmse:0.03274	eval-rmse:0.03524
# [1300]	train-rmse:0.03248	eval-rmse:0.03509
# [1350]	train-rmse:0.03226	eval-rmse:0.03496
# [1400]	train-rmse:0.03207	eval-rmse:0.03483
# [1450]	train-rmse:0.03187	eval-rmse:0.03466
# [1500]	train-rmse:0.03164	eval-rmse:0.03450
# [1550]	train-rmse:0.03144	eval-rmse:0.03436
# [1600]	train-rmse:0.03125	eval-rmse:0.03424
# [1650]	train-rmse:0.03107	eval-rmse:0.03412
# [1700]	train-rmse:0.03091	eval-rmse:0.03401
# [1750]	train-rmse:0.03074	eval-rmse:0.03389
# [1800]	train-rmse:0.03055	eval-rmse:0.03377
# [1850]	train-rmse:0.03039	eval-rmse:0.03368
# [1900]	train-rmse:0.03024	eval-rmse:0.03361
# [1950]	train-rmse:0.03009	eval-rmse:0.03351
# [2000]	train-rmse:0.02991	eval-rmse:0.03342
# [2050]	train-rmse:0.02971	eval-rmse:0.03331
# [2100]	train-rmse:0.02953	eval-rmse:0.03320
# [2150]	train-rmse:0.02932	eval-rmse:0.03306
# [2200]	train-rmse:0.02913	eval-rmse:0.03295
# [2250]	train-rmse:0.02892	eval-rmse:0.03283
# [2300]	train-rmse:0.02875	eval-rmse:0.03277
# [2350]	train-rmse:0.02862	eval-rmse:0.03272
# [2400]	train-rmse:0.02846	eval-rmse:0.03263
# [2450]	train-rmse:0.02834	eval-rmse:0.03255
# [2500]	train-rmse:0.02818	eval-rmse:0.03246
# [2550]	train-rmse:0.02802	eval-rmse:0.03236
# [2600]	train-rmse:0.02786	eval-rmse:0.03227
# [2650]	train-rmse:0.02766	eval-rmse:0.03214
# [2700]	train-rmse:0.02748	eval-rmse:0.03201
# [2750]	train-rmse:0.02732	eval-rmse:0.03191
# [2800]	train-rmse:0.02712	eval-rmse:0.03178
# [2850]	train-rmse:0.02698	eval-rmse:0.03171
# [2900]	train-rmse:0.02689	eval-rmse:0.03164
# [2950]	train-rmse:0.02674	eval-rmse:0.03155
# [3000]	train-rmse:0.02658	eval-rmse:0.03145
# [3050]	train-rmse:0.02642	eval-rmse:0.03136
# [3100]	train-rmse:0.02628	eval-rmse:0.03127
# [3150]	train-rmse:0.02615	eval-rmse:0.03119
# [3200]	train-rmse:0.02604	eval-rmse:0.03115
# [3250]	train-rmse:0.02594	eval-rmse:0.03111
# [3300]	train-rmse:0.02582	eval-rmse:0.03108
# [3350]	train-rmse:0.02572	eval-rmse:0.03106
# [3400]	train-rmse:0.02561	eval-rmse:0.03103
# [3450]	train-rmse:0.02549	eval-rmse:0.03100
# [3500]	train-rmse:0.02540	eval-rmse:0.03097
# [3550]	train-rmse:0.02529	eval-rmse:0.03093
# [3600]	train-rmse:0.02516	eval-rmse:0.03090
# [3650]	train-rmse:0.02504	eval-rmse:0.03085
# [3700]	train-rmse:0.02492	eval-rmse:0.03081
# [3750]	train-rmse:0.02481	eval-rmse:0.03077
# [3800]	train-rmse:0.02470	eval-rmse:0.03071
# [3850]	train-rmse:0.02460	eval-rmse:0.03066
# [3900]	train-rmse:0.02450	eval-rmse:0.03061
# [3950]	train-rmse:0.02442	eval-rmse:0.03056
# [3999]	train-rmse:0.02434	eval-rmse:0.03054
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:45:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.11543	eval-rmse:0.11390
# [50]	train-rmse:0.07384	eval-rmse:0.07269
# [100]	train-rmse:0.04999	eval-rmse:0.04938
# [150]	train-rmse:0.03695	eval-rmse:0.03680
# [200]	train-rmse:0.03013	eval-rmse:0.03030
# [250]	train-rmse:0.02660	eval-rmse:0.02701
# [300]	train-rmse:0.02462	eval-rmse:0.02521
# [350]	train-rmse:0.02327	eval-rmse:0.02406
# [400]	train-rmse:0.02227	eval-rmse:0.02316
# [450]	train-rmse:0.02155	eval-rmse:0.02252
# [500]	train-rmse:0.02089	eval-rmse:0.02193
# [550]	train-rmse:0.02031	eval-rmse:0.02145
# [600]	train-rmse:0.01974	eval-rmse:0.02092
# [650]	train-rmse:0.01928	eval-rmse:0.02049
# [700]	train-rmse:0.01887	eval-rmse:0.02011
# [750]	train-rmse:0.01855	eval-rmse:0.01984
# [800]	train-rmse:0.01827	eval-rmse:0.01963
# [850]	train-rmse:0.01806	eval-rmse:0.01948
# [900]	train-rmse:0.01787	eval-rmse:0.01934
# [950]	train-rmse:0.01772	eval-rmse:0.01925
# [1000]	train-rmse:0.01758	eval-rmse:0.01917
# [1050]	train-rmse:0.01743	eval-rmse:0.01909
# [1100]	train-rmse:0.01729	eval-rmse:0.01901
# [1150]	train-rmse:0.01716	eval-rmse:0.01895
# [1200]	train-rmse:0.01701	eval-rmse:0.01886
# [1250]	train-rmse:0.01686	eval-rmse:0.01877
# [1300]	train-rmse:0.01672	eval-rmse:0.01869
# [1350]	train-rmse:0.01659	eval-rmse:0.01863
# [1400]	train-rmse:0.01647	eval-rmse:0.01862
# [1450]	train-rmse:0.01636	eval-rmse:0.01858
# [1500]	train-rmse:0.01624	eval-rmse:0.01851
# [1550]	train-rmse:0.01611	eval-rmse:0.01844
# [1600]	train-rmse:0.01599	eval-rmse:0.01835
# [1650]	train-rmse:0.01589	eval-rmse:0.01828
# [1700]	train-rmse:0.01581	eval-rmse:0.01824
# [1750]	train-rmse:0.01570	eval-rmse:0.01818
# [1800]	train-rmse:0.01562	eval-rmse:0.01816
# [1850]	train-rmse:0.01554	eval-rmse:0.01813
# [1900]	train-rmse:0.01545	eval-rmse:0.01808
# [1950]	train-rmse:0.01536	eval-rmse:0.01803
# [2000]	train-rmse:0.01528	eval-rmse:0.01799
# [2050]	train-rmse:0.01519	eval-rmse:0.01794
# [2100]	train-rmse:0.01511	eval-rmse:0.01790
# [2150]	train-rmse:0.01502	eval-rmse:0.01786
# [2200]	train-rmse:0.01494	eval-rmse:0.01780
# [2250]	train-rmse:0.01486	eval-rmse:0.01776
# [2300]	train-rmse:0.01478	eval-rmse:0.01772
# [2350]	train-rmse:0.01472	eval-rmse:0.01769
# [2400]	train-rmse:0.01467	eval-rmse:0.01767
# [2450]	train-rmse:0.01461	eval-rmse:0.01765
# [2500]	train-rmse:0.01456	eval-rmse:0.01763
# [2550]	train-rmse:0.01449	eval-rmse:0.01761
# [2600]	train-rmse:0.01441	eval-rmse:0.01757
# [2650]	train-rmse:0.01435	eval-rmse:0.01754
# [2700]	train-rmse:0.01428	eval-rmse:0.01750
# [2750]	train-rmse:0.01421	eval-rmse:0.01746
# [2800]	train-rmse:0.01416	eval-rmse:0.01744
# [2850]	train-rmse:0.01410	eval-rmse:0.01742
# [2900]	train-rmse:0.01404	eval-rmse:0.01739
# [2950]	train-rmse:0.01398	eval-rmse:0.01736
# [3000]	train-rmse:0.01391	eval-rmse:0.01733
# [3050]	train-rmse:0.01384	eval-rmse:0.01729
# [3100]	train-rmse:0.01379	eval-rmse:0.01726
# [3150]	train-rmse:0.01374	eval-rmse:0.01724
# [3200]	train-rmse:0.01365	eval-rmse:0.01719
# [3250]	train-rmse:0.01358	eval-rmse:0.01715
# [3300]	train-rmse:0.01354	eval-rmse:0.01713
# [3350]	train-rmse:0.01348	eval-rmse:0.01711
# [3400]	train-rmse:0.01343	eval-rmse:0.01708
# [3450]	train-rmse:0.01338	eval-rmse:0.01705
# [3500]	train-rmse:0.01333	eval-rmse:0.01702
# [3550]	train-rmse:0.01327	eval-rmse:0.01699
# [3600]	train-rmse:0.01321	eval-rmse:0.01695
# [3650]	train-rmse:0.01315	eval-rmse:0.01693
# [3700]	train-rmse:0.01310	eval-rmse:0.01690
# [3750]	train-rmse:0.01306	eval-rmse:0.01688
# [3800]	train-rmse:0.01300	eval-rmse:0.01685
# [3850]	train-rmse:0.01294	eval-rmse:0.01682
# [3900]	train-rmse:0.01288	eval-rmse:0.01680
# [3950]	train-rmse:0.01284	eval-rmse:0.01679
# [3999]	train-rmse:0.01276	eval-rmse:0.01674
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:46:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.15315	eval-rmse:0.15413
# [50]	train-rmse:0.09915	eval-rmse:0.09992
# [100]	train-rmse:0.06850	eval-rmse:0.06916
# [150]	train-rmse:0.05179	eval-rmse:0.05247
# [200]	train-rmse:0.04274	eval-rmse:0.04347
# [250]	train-rmse:0.03783	eval-rmse:0.03859
# [300]	train-rmse:0.03470	eval-rmse:0.03550
# [350]	train-rmse:0.03275	eval-rmse:0.03358
# [400]	train-rmse:0.03138	eval-rmse:0.03230
# [450]	train-rmse:0.03049	eval-rmse:0.03148
# [500]	train-rmse:0.02982	eval-rmse:0.03088
# [550]	train-rmse:0.02919	eval-rmse:0.03040
# [600]	train-rmse:0.02876	eval-rmse:0.03012
# [650]	train-rmse:0.02829	eval-rmse:0.02978
# [700]	train-rmse:0.02774	eval-rmse:0.02939
# [750]	train-rmse:0.02731	eval-rmse:0.02910
# [800]	train-rmse:0.02690	eval-rmse:0.02879
# [850]	train-rmse:0.02658	eval-rmse:0.02855
# [900]	train-rmse:0.02629	eval-rmse:0.02836
# [950]	train-rmse:0.02606	eval-rmse:0.02824
# [1000]	train-rmse:0.02585	eval-rmse:0.02811
# [1050]	train-rmse:0.02565	eval-rmse:0.02800
# [1100]	train-rmse:0.02549	eval-rmse:0.02791
# [1150]	train-rmse:0.02533	eval-rmse:0.02783
# [1200]	train-rmse:0.02514	eval-rmse:0.02771
# [1250]	train-rmse:0.02498	eval-rmse:0.02761
# [1300]	train-rmse:0.02476	eval-rmse:0.02747
# [1350]	train-rmse:0.02454	eval-rmse:0.02732
# [1400]	train-rmse:0.02435	eval-rmse:0.02721
# [1450]	train-rmse:0.02418	eval-rmse:0.02711
# [1500]	train-rmse:0.02402	eval-rmse:0.02701
# [1550]	train-rmse:0.02385	eval-rmse:0.02691
# [1600]	train-rmse:0.02370	eval-rmse:0.02682
# [1650]	train-rmse:0.02356	eval-rmse:0.02674
# [1700]	train-rmse:0.02339	eval-rmse:0.02665
# [1750]	train-rmse:0.02323	eval-rmse:0.02658
# [1800]	train-rmse:0.02307	eval-rmse:0.02649
# [1850]	train-rmse:0.02295	eval-rmse:0.02644
# [1900]	train-rmse:0.02283	eval-rmse:0.02639
# [1950]	train-rmse:0.02270	eval-rmse:0.02632
# [2000]	train-rmse:0.02257	eval-rmse:0.02627
# [2050]	train-rmse:0.02245	eval-rmse:0.02621
# [2100]	train-rmse:0.02231	eval-rmse:0.02614
# [2150]	train-rmse:0.02218	eval-rmse:0.02607
# [2200]	train-rmse:0.02207	eval-rmse:0.02600
# [2250]	train-rmse:0.02199	eval-rmse:0.02597
# [2300]	train-rmse:0.02188	eval-rmse:0.02593
# [2350]	train-rmse:0.02174	eval-rmse:0.02586
# [2400]	train-rmse:0.02163	eval-rmse:0.02581
# [2450]	train-rmse:0.02152	eval-rmse:0.02575
# [2500]	train-rmse:0.02139	eval-rmse:0.02567
# [2550]	train-rmse:0.02129	eval-rmse:0.02561
# [2600]	train-rmse:0.02120	eval-rmse:0.02555
# [2650]	train-rmse:0.02111	eval-rmse:0.02551
# [2700]	train-rmse:0.02103	eval-rmse:0.02547
# [2750]	train-rmse:0.02094	eval-rmse:0.02543
# [2800]	train-rmse:0.02084	eval-rmse:0.02537
# [2850]	train-rmse:0.02074	eval-rmse:0.02533
# [2900]	train-rmse:0.02063	eval-rmse:0.02528
# [2950]	train-rmse:0.02053	eval-rmse:0.02523
# [3000]	train-rmse:0.02046	eval-rmse:0.02520
# [3050]	train-rmse:0.02038	eval-rmse:0.02517
# [3100]	train-rmse:0.02028	eval-rmse:0.02511
# [3150]	train-rmse:0.02018	eval-rmse:0.02503
# [3200]	train-rmse:0.02009	eval-rmse:0.02499
# [3250]	train-rmse:0.01998	eval-rmse:0.02493
# [3300]	train-rmse:0.01989	eval-rmse:0.02489
# [3350]	train-rmse:0.01982	eval-rmse:0.02486
# [3400]	train-rmse:0.01975	eval-rmse:0.02482
# [3450]	train-rmse:0.01967	eval-rmse:0.02480
# [3500]	train-rmse:0.01960	eval-rmse:0.02477
# [3550]	train-rmse:0.01954	eval-rmse:0.02474
# [3600]	train-rmse:0.01946	eval-rmse:0.02471
# [3650]	train-rmse:0.01939	eval-rmse:0.02468
# [3700]	train-rmse:0.01930	eval-rmse:0.02464
# [3750]	train-rmse:0.01924	eval-rmse:0.02462
# [3800]	train-rmse:0.01918	eval-rmse:0.02461
# [3850]	train-rmse:0.01908	eval-rmse:0.02457
# [3900]	train-rmse:0.01898	eval-rmse:0.02451
# [3950]	train-rmse:0.01887	eval-rmse:0.02445
# [3999]	train-rmse:0.01878	eval-rmse:0.02440
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:46:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.09365	eval-rmse:0.09279
# [50]	train-rmse:0.05961	eval-rmse:0.05918
# [100]	train-rmse:0.03966	eval-rmse:0.03967
# [150]	train-rmse:0.02828	eval-rmse:0.02865
# [200]	train-rmse:0.02176	eval-rmse:0.02241
# [250]	train-rmse:0.01798	eval-rmse:0.01878
# [300]	train-rmse:0.01562	eval-rmse:0.01642
# [350]	train-rmse:0.01404	eval-rmse:0.01486
# [400]	train-rmse:0.01275	eval-rmse:0.01355
# [450]	train-rmse:0.01152	eval-rmse:0.01232
# [500]	train-rmse:0.01052	eval-rmse:0.01135
# [550]	train-rmse:0.00975	eval-rmse:0.01060
# [600]	train-rmse:0.00919	eval-rmse:0.01003
# [650]	train-rmse:0.00871	eval-rmse:0.00956
# [700]	train-rmse:0.00827	eval-rmse:0.00914
# [750]	train-rmse:0.00783	eval-rmse:0.00873
# [800]	train-rmse:0.00752	eval-rmse:0.00843
# [850]	train-rmse:0.00733	eval-rmse:0.00823
# [900]	train-rmse:0.00716	eval-rmse:0.00806
# [950]	train-rmse:0.00699	eval-rmse:0.00790
# [1000]	train-rmse:0.00683	eval-rmse:0.00774
# [1050]	train-rmse:0.00671	eval-rmse:0.00762
# [1100]	train-rmse:0.00660	eval-rmse:0.00750
# [1150]	train-rmse:0.00652	eval-rmse:0.00743
# [1200]	train-rmse:0.00643	eval-rmse:0.00734
# [1250]	train-rmse:0.00636	eval-rmse:0.00728
# [1300]	train-rmse:0.00630	eval-rmse:0.00723
# [1350]	train-rmse:0.00623	eval-rmse:0.00715
# [1400]	train-rmse:0.00616	eval-rmse:0.00710
# [1450]	train-rmse:0.00610	eval-rmse:0.00704
# [1500]	train-rmse:0.00603	eval-rmse:0.00698
# [1550]	train-rmse:0.00592	eval-rmse:0.00686
# [1600]	train-rmse:0.00584	eval-rmse:0.00678
# [1650]	train-rmse:0.00577	eval-rmse:0.00672
# [1700]	train-rmse:0.00571	eval-rmse:0.00666
# [1750]	train-rmse:0.00564	eval-rmse:0.00661
# [1800]	train-rmse:0.00558	eval-rmse:0.00657
# [1850]	train-rmse:0.00553	eval-rmse:0.00652
# [1900]	train-rmse:0.00547	eval-rmse:0.00647
# [1950]	train-rmse:0.00540	eval-rmse:0.00642
# [2000]	train-rmse:0.00533	eval-rmse:0.00636
# [2050]	train-rmse:0.00527	eval-rmse:0.00632
# [2100]	train-rmse:0.00522	eval-rmse:0.00628
# [2150]	train-rmse:0.00517	eval-rmse:0.00625
# [2200]	train-rmse:0.00512	eval-rmse:0.00621
# [2250]	train-rmse:0.00508	eval-rmse:0.00618
# [2300]	train-rmse:0.00504	eval-rmse:0.00615
# [2350]	train-rmse:0.00499	eval-rmse:0.00612
# [2400]	train-rmse:0.00495	eval-rmse:0.00609
# [2450]	train-rmse:0.00490	eval-rmse:0.00604
# [2500]	train-rmse:0.00486	eval-rmse:0.00601
# [2550]	train-rmse:0.00480	eval-rmse:0.00597
# [2600]	train-rmse:0.00476	eval-rmse:0.00594
# [2650]	train-rmse:0.00471	eval-rmse:0.00591
# [2700]	train-rmse:0.00466	eval-rmse:0.00589
# [2750]	train-rmse:0.00462	eval-rmse:0.00587
# [2800]	train-rmse:0.00458	eval-rmse:0.00584
# [2850]	train-rmse:0.00453	eval-rmse:0.00581
# [2900]	train-rmse:0.00450	eval-rmse:0.00579
# [2950]	train-rmse:0.00447	eval-rmse:0.00577
# [3000]	train-rmse:0.00444	eval-rmse:0.00576
# [3050]	train-rmse:0.00441	eval-rmse:0.00573
# [3100]	train-rmse:0.00437	eval-rmse:0.00571
# [3150]	train-rmse:0.00435	eval-rmse:0.00569
# [3200]	train-rmse:0.00432	eval-rmse:0.00567
# [3250]	train-rmse:0.00430	eval-rmse:0.00566
# [3300]	train-rmse:0.00427	eval-rmse:0.00565
# [3350]	train-rmse:0.00424	eval-rmse:0.00563
# [3400]	train-rmse:0.00422	eval-rmse:0.00562
# [3450]	train-rmse:0.00419	eval-rmse:0.00560
# [3500]	train-rmse:0.00417	eval-rmse:0.00559
# [3550]	train-rmse:0.00414	eval-rmse:0.00557
# [3600]	train-rmse:0.00411	eval-rmse:0.00555
# [3650]	train-rmse:0.00409	eval-rmse:0.00554
# [3700]	train-rmse:0.00406	eval-rmse:0.00552
# [3750]	train-rmse:0.00405	eval-rmse:0.00551
# [3800]	train-rmse:0.00402	eval-rmse:0.00549
# [3850]	train-rmse:0.00400	eval-rmse:0.00547
# [3900]	train-rmse:0.00397	eval-rmse:0.00546
# [3950]	train-rmse:0.00395	eval-rmse:0.00544
# [3999]	train-rmse:0.00392	eval-rmse:0.00542
# Model Results for Housing:
# Train Data: MAE: 46.4297, R-Squared: 0.9728, RMSE: 63.7052, MSE: 4058.3462 ,smape: 4.536752273916304
# Validation Data: MAE: 58.5377, R-Squared: 0.9522, RMSE: 82.497, MSE: 6805.7549 ,smape: 5.582822430748464
# Test Data: MAE: 58.9512, R-Squared: 0.9533, RMSE: 83.0619, MSE: 6899.2848 ,smape: 5.526899428694649
#
# Model Results for Food:
# Train Data: MAE: 24.2792, R-Squared: 0.99, RMSE: 34.1269, MSE: 1164.6432 ,smape: 2.863793018695313
# Validation Data: MAE: 30.7575, R-Squared: 0.9818, RMSE: 45.5929, MSE: 2078.7115 ,smape: 3.534376697878943
# Test Data: MAE: 31.3883, R-Squared: 0.9774, RMSE: 51.497, MSE: 2651.9411 ,smape: 3.5234882461906336
#
# Model Results for Transportation:
# Train Data: MAE: 53.2176, R-Squared: 0.9111, RMSE: 70.7278, MSE: 5002.4256 ,smape: 3.491034036385527
# Validation Data: MAE: 67.7706, R-Squared: 0.8555, RMSE: 90.8668, MSE: 8256.7671 ,smape: 4.470302865870075
# Test Data: MAE: 66.4276, R-Squared: 0.8595, RMSE: 90.2438, MSE: 8143.9346 ,smape: 4.324094949112544
#
# Model Results for Healthcare:
# Train Data: MAE: 51.9968, R-Squared: 0.9763, RMSE: 75.635, MSE: 5720.6472 ,smape: 4.3640540867670286
# Validation Data: MAE: 63.3473, R-Squared: 0.9624, RMSE: 94.9225, MSE: 9010.2734 ,smape: 5.234836305173403
# Test Data: MAE: 65.0275, R-Squared: 0.9625, RMSE: 96.2831, MSE: 9270.4306 ,smape: 5.250842053915591
#
# Model Results for Othernecessities:
# Train Data: MAE: 18.4733, R-Squared: 0.988, RMSE: 25.0826, MSE: 629.1357 ,smape: 2.8312901733403457
# Validation Data: MAE: 23.2169, R-Squared: 0.9788, RMSE: 32.9084, MSE: 1082.9607 ,smape: 3.4765118449795933
# Test Data: MAE: 23.4626, R-Squared: 0.9781, RMSE: 33.5923, MSE: 1128.4428 ,smape: 3.4172594963473
#
# Model Results for Childcare:
# Train Data: MAE: 48.1492, R-Squared: 0.9854, RMSE: 75.7549, MSE: 5738.7996 ,smape: 4.512239509036532
# Validation Data: MAE: 61.2416, R-Squared: 0.9756, RMSE: 98.4638, MSE: 9695.1216 ,smape: 5.578351743210767
# Test Data: MAE: 63.3074, R-Squared: 0.974, RMSE: 100.4064, MSE: 10081.4534 ,smape: 5.738224130236837
#
# Model Results for Taxes:
# Train Data: MAE: 8.6286, R-Squared: 0.9983, RMSE: 16.9659, MSE: 287.8425 ,smape: 0.9785212634726485
# Validation Data: MAE: 11.619, R-Squared: 0.9967, RMSE: 23.463, MSE: 550.512 ,smape: 1.270998218949291
# Test Data: MAE: 11.5518, R-Squared: 0.9965, RMSE: 24.0941, MSE: 580.5277 ,smape: 1.234436927418765
#
# Fold 2/5
# [0]	train-rmse:0.09410	eval-rmse:0.10077
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:723: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:47:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.06394	eval-rmse:0.06942
# [100]	train-rmse:0.04722	eval-rmse:0.05186
# [150]	train-rmse:0.03835	eval-rmse:0.04252
# [200]	train-rmse:0.03365	eval-rmse:0.03765
# [250]	train-rmse:0.03094	eval-rmse:0.03488
# [300]	train-rmse:0.02919	eval-rmse:0.03314
# [350]	train-rmse:0.02788	eval-rmse:0.03172
# [400]	train-rmse:0.02678	eval-rmse:0.03058
# [450]	train-rmse:0.02592	eval-rmse:0.02966
# [500]	train-rmse:0.02528	eval-rmse:0.02896
# [550]	train-rmse:0.02485	eval-rmse:0.02851
# [600]	train-rmse:0.02438	eval-rmse:0.02801
# [650]	train-rmse:0.02396	eval-rmse:0.02757
# [700]	train-rmse:0.02357	eval-rmse:0.02716
# [750]	train-rmse:0.02321	eval-rmse:0.02682
# [800]	train-rmse:0.02288	eval-rmse:0.02649
# [850]	train-rmse:0.02257	eval-rmse:0.02616
# [900]	train-rmse:0.02225	eval-rmse:0.02584
# [950]	train-rmse:0.02199	eval-rmse:0.02557
# [1000]	train-rmse:0.02171	eval-rmse:0.02530
# [1050]	train-rmse:0.02148	eval-rmse:0.02507
# [1100]	train-rmse:0.02127	eval-rmse:0.02486
# [1150]	train-rmse:0.02109	eval-rmse:0.02470
# [1200]	train-rmse:0.02090	eval-rmse:0.02453
# [1250]	train-rmse:0.02075	eval-rmse:0.02440
# [1300]	train-rmse:0.02060	eval-rmse:0.02426
# [1350]	train-rmse:0.02043	eval-rmse:0.02410
# [1400]	train-rmse:0.02029	eval-rmse:0.02397
# [1450]	train-rmse:0.02018	eval-rmse:0.02388
# [1500]	train-rmse:0.02007	eval-rmse:0.02379
# [1550]	train-rmse:0.01996	eval-rmse:0.02371
# [1600]	train-rmse:0.01984	eval-rmse:0.02362
# [1650]	train-rmse:0.01975	eval-rmse:0.02356
# [1700]	train-rmse:0.01964	eval-rmse:0.02348
# [1750]	train-rmse:0.01953	eval-rmse:0.02339
# [1800]	train-rmse:0.01941	eval-rmse:0.02330
# [1850]	train-rmse:0.01931	eval-rmse:0.02325
# [1900]	train-rmse:0.01921	eval-rmse:0.02317
# [1950]	train-rmse:0.01908	eval-rmse:0.02308
# [2000]	train-rmse:0.01896	eval-rmse:0.02300
# [2050]	train-rmse:0.01887	eval-rmse:0.02293
# [2100]	train-rmse:0.01878	eval-rmse:0.02287
# [2150]	train-rmse:0.01869	eval-rmse:0.02280
# [2200]	train-rmse:0.01861	eval-rmse:0.02274
# [2250]	train-rmse:0.01850	eval-rmse:0.02267
# [2300]	train-rmse:0.01842	eval-rmse:0.02262
# [2350]	train-rmse:0.01833	eval-rmse:0.02257
# [2400]	train-rmse:0.01826	eval-rmse:0.02252
# [2450]	train-rmse:0.01818	eval-rmse:0.02247
# [2500]	train-rmse:0.01808	eval-rmse:0.02241
# [2550]	train-rmse:0.01799	eval-rmse:0.02235
# [2600]	train-rmse:0.01792	eval-rmse:0.02231
# [2650]	train-rmse:0.01784	eval-rmse:0.02227
# [2700]	train-rmse:0.01778	eval-rmse:0.02224
# [2750]	train-rmse:0.01771	eval-rmse:0.02221
# [2800]	train-rmse:0.01764	eval-rmse:0.02218
# [2850]	train-rmse:0.01757	eval-rmse:0.02213
# [2900]	train-rmse:0.01751	eval-rmse:0.02209
# [2950]	train-rmse:0.01742	eval-rmse:0.02204
# [3000]	train-rmse:0.01736	eval-rmse:0.02201
# [3050]	train-rmse:0.01729	eval-rmse:0.02196
# [3100]	train-rmse:0.01723	eval-rmse:0.02193
# [3150]	train-rmse:0.01715	eval-rmse:0.02188
# [3200]	train-rmse:0.01708	eval-rmse:0.02183
# [3250]	train-rmse:0.01701	eval-rmse:0.02180
# [3300]	train-rmse:0.01695	eval-rmse:0.02177
# [3350]	train-rmse:0.01686	eval-rmse:0.02172
# [3400]	train-rmse:0.01680	eval-rmse:0.02168
# [3450]	train-rmse:0.01671	eval-rmse:0.02162
# [3500]	train-rmse:0.01662	eval-rmse:0.02157
# [3550]	train-rmse:0.01655	eval-rmse:0.02152
# [3600]	train-rmse:0.01649	eval-rmse:0.02149
# [3650]	train-rmse:0.01642	eval-rmse:0.02146
# [3700]	train-rmse:0.01635	eval-rmse:0.02141
# [3750]	train-rmse:0.01630	eval-rmse:0.02138
# [3800]	train-rmse:0.01623	eval-rmse:0.02134
# [3850]	train-rmse:0.01615	eval-rmse:0.02131
# [3900]	train-rmse:0.01609	eval-rmse:0.02129
# [3950]	train-rmse:0.01603	eval-rmse:0.02125
# [3999]	train-rmse:0.01596	eval-rmse:0.02120
# [0]	train-rmse:0.11548	eval-rmse:0.11830
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:47:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07233	eval-rmse:0.07385
# [100]	train-rmse:0.04733	eval-rmse:0.04808
# [150]	train-rmse:0.03359	eval-rmse:0.03391
# [200]	train-rmse:0.02656	eval-rmse:0.02670
# [250]	train-rmse:0.02310	eval-rmse:0.02325
# [300]	train-rmse:0.02139	eval-rmse:0.02161
# [350]	train-rmse:0.02039	eval-rmse:0.02075
# [400]	train-rmse:0.01977	eval-rmse:0.02023
# [450]	train-rmse:0.01929	eval-rmse:0.01982
# [500]	train-rmse:0.01888	eval-rmse:0.01953
# [550]	train-rmse:0.01847	eval-rmse:0.01923
# [600]	train-rmse:0.01810	eval-rmse:0.01898
# [650]	train-rmse:0.01779	eval-rmse:0.01876
# [700]	train-rmse:0.01749	eval-rmse:0.01856
# [750]	train-rmse:0.01720	eval-rmse:0.01838
# [800]	train-rmse:0.01693	eval-rmse:0.01821
# [850]	train-rmse:0.01670	eval-rmse:0.01807
# [900]	train-rmse:0.01646	eval-rmse:0.01794
# [950]	train-rmse:0.01626	eval-rmse:0.01783
# [1000]	train-rmse:0.01607	eval-rmse:0.01771
# [1050]	train-rmse:0.01591	eval-rmse:0.01762
# [1100]	train-rmse:0.01577	eval-rmse:0.01753
# [1150]	train-rmse:0.01563	eval-rmse:0.01744
# [1200]	train-rmse:0.01550	eval-rmse:0.01736
# [1250]	train-rmse:0.01536	eval-rmse:0.01729
# [1300]	train-rmse:0.01523	eval-rmse:0.01722
# [1350]	train-rmse:0.01511	eval-rmse:0.01717
# [1400]	train-rmse:0.01500	eval-rmse:0.01712
# [1450]	train-rmse:0.01489	eval-rmse:0.01708
# [1500]	train-rmse:0.01481	eval-rmse:0.01704
# [1550]	train-rmse:0.01470	eval-rmse:0.01699
# [1600]	train-rmse:0.01460	eval-rmse:0.01694
# [1650]	train-rmse:0.01450	eval-rmse:0.01691
# [1700]	train-rmse:0.01441	eval-rmse:0.01686
# [1750]	train-rmse:0.01432	eval-rmse:0.01683
# [1800]	train-rmse:0.01422	eval-rmse:0.01679
# [1850]	train-rmse:0.01415	eval-rmse:0.01677
# [1900]	train-rmse:0.01407	eval-rmse:0.01675
# [1950]	train-rmse:0.01398	eval-rmse:0.01672
# [2000]	train-rmse:0.01390	eval-rmse:0.01668
# [2050]	train-rmse:0.01382	eval-rmse:0.01665
# [2100]	train-rmse:0.01376	eval-rmse:0.01663
# [2150]	train-rmse:0.01370	eval-rmse:0.01661
# [2200]	train-rmse:0.01363	eval-rmse:0.01659
# [2250]	train-rmse:0.01356	eval-rmse:0.01656
# [2300]	train-rmse:0.01349	eval-rmse:0.01653
# [2350]	train-rmse:0.01343	eval-rmse:0.01650
# [2400]	train-rmse:0.01338	eval-rmse:0.01649
# [2450]	train-rmse:0.01332	eval-rmse:0.01647
# [2500]	train-rmse:0.01325	eval-rmse:0.01645
# [2550]	train-rmse:0.01318	eval-rmse:0.01642
# [2600]	train-rmse:0.01313	eval-rmse:0.01640
# [2650]	train-rmse:0.01308	eval-rmse:0.01639
# [2700]	train-rmse:0.01300	eval-rmse:0.01637
# [2750]	train-rmse:0.01294	eval-rmse:0.01634
# [2800]	train-rmse:0.01289	eval-rmse:0.01632
# [2850]	train-rmse:0.01283	eval-rmse:0.01631
# [2900]	train-rmse:0.01277	eval-rmse:0.01629
# [2950]	train-rmse:0.01272	eval-rmse:0.01628
# [3000]	train-rmse:0.01266	eval-rmse:0.01626
# [3050]	train-rmse:0.01261	eval-rmse:0.01625
# [3100]	train-rmse:0.01256	eval-rmse:0.01624
# [3150]	train-rmse:0.01250	eval-rmse:0.01623
# [3200]	train-rmse:0.01246	eval-rmse:0.01621
# [3250]	train-rmse:0.01240	eval-rmse:0.01619
# [3300]	train-rmse:0.01235	eval-rmse:0.01617
# [3350]	train-rmse:0.01230	eval-rmse:0.01615
# [3400]	train-rmse:0.01226	eval-rmse:0.01613
# [3450]	train-rmse:0.01221	eval-rmse:0.01612
# [3500]	train-rmse:0.01217	eval-rmse:0.01610
# [3550]	train-rmse:0.01212	eval-rmse:0.01609
# [3600]	train-rmse:0.01208	eval-rmse:0.01608
# [3635]	train-rmse:0.01205	eval-rmse:0.01609
# [0]	train-rmse:0.09863	eval-rmse:0.10046
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:48:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.07433	eval-rmse:0.07648
# [100]	train-rmse:0.06261	eval-rmse:0.06521
# [150]	train-rmse:0.05713	eval-rmse:0.06017
# [200]	train-rmse:0.05420	eval-rmse:0.05760
# [250]	train-rmse:0.05233	eval-rmse:0.05581
# [300]	train-rmse:0.05057	eval-rmse:0.05397
# [350]	train-rmse:0.04912	eval-rmse:0.05253
# [400]	train-rmse:0.04798	eval-rmse:0.05146
# [450]	train-rmse:0.04717	eval-rmse:0.05073
# [500]	train-rmse:0.04634	eval-rmse:0.04991
# [550]	train-rmse:0.04555	eval-rmse:0.04914
# [600]	train-rmse:0.04479	eval-rmse:0.04836
# [650]	train-rmse:0.04411	eval-rmse:0.04765
# [700]	train-rmse:0.04353	eval-rmse:0.04706
# [750]	train-rmse:0.04297	eval-rmse:0.04655
# [800]	train-rmse:0.04239	eval-rmse:0.04602
# [850]	train-rmse:0.04183	eval-rmse:0.04546
# [900]	train-rmse:0.04135	eval-rmse:0.04503
# [950]	train-rmse:0.04091	eval-rmse:0.04467
# [1000]	train-rmse:0.04047	eval-rmse:0.04430
# [1050]	train-rmse:0.04011	eval-rmse:0.04401
# [1100]	train-rmse:0.03976	eval-rmse:0.04376
# [1150]	train-rmse:0.03944	eval-rmse:0.04353
# [1200]	train-rmse:0.03915	eval-rmse:0.04326
# [1250]	train-rmse:0.03885	eval-rmse:0.04302
# [1300]	train-rmse:0.03858	eval-rmse:0.04280
# [1350]	train-rmse:0.03830	eval-rmse:0.04258
# [1400]	train-rmse:0.03805	eval-rmse:0.04238
# [1450]	train-rmse:0.03776	eval-rmse:0.04215
# [1500]	train-rmse:0.03748	eval-rmse:0.04191
# [1550]	train-rmse:0.03721	eval-rmse:0.04166
# [1600]	train-rmse:0.03697	eval-rmse:0.04146
# [1650]	train-rmse:0.03677	eval-rmse:0.04131
# [1700]	train-rmse:0.03657	eval-rmse:0.04117
# [1750]	train-rmse:0.03642	eval-rmse:0.04109
# [1800]	train-rmse:0.03628	eval-rmse:0.04101
# [1850]	train-rmse:0.03614	eval-rmse:0.04092
# [1900]	train-rmse:0.03598	eval-rmse:0.04083
# [1950]	train-rmse:0.03579	eval-rmse:0.04069
# [2000]	train-rmse:0.03560	eval-rmse:0.04056
# [2050]	train-rmse:0.03541	eval-rmse:0.04044
# [2100]	train-rmse:0.03525	eval-rmse:0.04034
# [2150]	train-rmse:0.03506	eval-rmse:0.04020
# [2200]	train-rmse:0.03487	eval-rmse:0.04010
# [2250]	train-rmse:0.03467	eval-rmse:0.03997
# [2300]	train-rmse:0.03447	eval-rmse:0.03985
# [2350]	train-rmse:0.03429	eval-rmse:0.03973
# [2400]	train-rmse:0.03415	eval-rmse:0.03964
# [2450]	train-rmse:0.03398	eval-rmse:0.03952
# [2500]	train-rmse:0.03379	eval-rmse:0.03941
# [2550]	train-rmse:0.03365	eval-rmse:0.03934
# [2600]	train-rmse:0.03351	eval-rmse:0.03924
# [2650]	train-rmse:0.03336	eval-rmse:0.03915
# [2700]	train-rmse:0.03313	eval-rmse:0.03900
# [2750]	train-rmse:0.03293	eval-rmse:0.03885
# [2800]	train-rmse:0.03278	eval-rmse:0.03873
# [2850]	train-rmse:0.03269	eval-rmse:0.03869
# [2900]	train-rmse:0.03256	eval-rmse:0.03862
# [2950]	train-rmse:0.03245	eval-rmse:0.03854
# [3000]	train-rmse:0.03237	eval-rmse:0.03851
# [3050]	train-rmse:0.03227	eval-rmse:0.03845
# [3100]	train-rmse:0.03214	eval-rmse:0.03838
# [3150]	train-rmse:0.03205	eval-rmse:0.03834
# [3200]	train-rmse:0.03194	eval-rmse:0.03828
# [3250]	train-rmse:0.03182	eval-rmse:0.03819
# [3300]	train-rmse:0.03170	eval-rmse:0.03814
# [3350]	train-rmse:0.03155	eval-rmse:0.03804
# [3400]	train-rmse:0.03145	eval-rmse:0.03800
# [3450]	train-rmse:0.03133	eval-rmse:0.03794
# [3500]	train-rmse:0.03127	eval-rmse:0.03793
# [3550]	train-rmse:0.03114	eval-rmse:0.03787
# [3600]	train-rmse:0.03101	eval-rmse:0.03782
# [3650]	train-rmse:0.03093	eval-rmse:0.03780
# [3700]	train-rmse:0.03086	eval-rmse:0.03778
# [3750]	train-rmse:0.03076	eval-rmse:0.03775
# [3800]	train-rmse:0.03061	eval-rmse:0.03768
# [3850]	train-rmse:0.03050	eval-rmse:0.03763
# [3900]	train-rmse:0.03035	eval-rmse:0.03756
# [3950]	train-rmse:0.03022	eval-rmse:0.03750
# [3999]	train-rmse:0.03013	eval-rmse:0.03748
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:48:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.15664	eval-rmse:0.15831
# [50]	train-rmse:0.10801	eval-rmse:0.10934
# [100]	train-rmse:0.08206	eval-rmse:0.08347
# [150]	train-rmse:0.06901	eval-rmse:0.07080
# [200]	train-rmse:0.06101	eval-rmse:0.06323
# [250]	train-rmse:0.05544	eval-rmse:0.05816
# [300]	train-rmse:0.05106	eval-rmse:0.05398
# [350]	train-rmse:0.04769	eval-rmse:0.05055
# [400]	train-rmse:0.04488	eval-rmse:0.04767
# [450]	train-rmse:0.04272	eval-rmse:0.04551
# [500]	train-rmse:0.04091	eval-rmse:0.04366
# [550]	train-rmse:0.03934	eval-rmse:0.04209
# [600]	train-rmse:0.03810	eval-rmse:0.04095
# [650]	train-rmse:0.03717	eval-rmse:0.04011
# [700]	train-rmse:0.03642	eval-rmse:0.03943
# [750]	train-rmse:0.03573	eval-rmse:0.03879
# [800]	train-rmse:0.03521	eval-rmse:0.03834
# [850]	train-rmse:0.03477	eval-rmse:0.03798
# [900]	train-rmse:0.03433	eval-rmse:0.03763
# [950]	train-rmse:0.03397	eval-rmse:0.03737
# [1000]	train-rmse:0.03364	eval-rmse:0.03712
# [1050]	train-rmse:0.03337	eval-rmse:0.03693
# [1100]	train-rmse:0.03310	eval-rmse:0.03674
# [1150]	train-rmse:0.03287	eval-rmse:0.03658
# [1200]	train-rmse:0.03265	eval-rmse:0.03643
# [1250]	train-rmse:0.03241	eval-rmse:0.03627
# [1300]	train-rmse:0.03215	eval-rmse:0.03611
# [1350]	train-rmse:0.03191	eval-rmse:0.03596
# [1400]	train-rmse:0.03164	eval-rmse:0.03579
# [1450]	train-rmse:0.03140	eval-rmse:0.03563
# [1500]	train-rmse:0.03117	eval-rmse:0.03550
# [1550]	train-rmse:0.03097	eval-rmse:0.03538
# [1600]	train-rmse:0.03079	eval-rmse:0.03526
# [1650]	train-rmse:0.03058	eval-rmse:0.03512
# [1700]	train-rmse:0.03038	eval-rmse:0.03498
# [1750]	train-rmse:0.03020	eval-rmse:0.03486
# [1800]	train-rmse:0.03005	eval-rmse:0.03476
# [1850]	train-rmse:0.02988	eval-rmse:0.03467
# [1900]	train-rmse:0.02973	eval-rmse:0.03458
# [1950]	train-rmse:0.02957	eval-rmse:0.03448
# [2000]	train-rmse:0.02941	eval-rmse:0.03437
# [2050]	train-rmse:0.02927	eval-rmse:0.03429
# [2100]	train-rmse:0.02914	eval-rmse:0.03423
# [2150]	train-rmse:0.02898	eval-rmse:0.03414
# [2200]	train-rmse:0.02882	eval-rmse:0.03406
# [2250]	train-rmse:0.02865	eval-rmse:0.03399
# [2300]	train-rmse:0.02843	eval-rmse:0.03391
# [2350]	train-rmse:0.02821	eval-rmse:0.03381
# [2400]	train-rmse:0.02801	eval-rmse:0.03371
# [2450]	train-rmse:0.02785	eval-rmse:0.03361
# [2500]	train-rmse:0.02768	eval-rmse:0.03351
# [2550]	train-rmse:0.02752	eval-rmse:0.03342
# [2600]	train-rmse:0.02736	eval-rmse:0.03333
# [2650]	train-rmse:0.02721	eval-rmse:0.03325
# [2700]	train-rmse:0.02707	eval-rmse:0.03316
# [2750]	train-rmse:0.02695	eval-rmse:0.03311
# [2800]	train-rmse:0.02680	eval-rmse:0.03302
# [2850]	train-rmse:0.02664	eval-rmse:0.03296
# [2900]	train-rmse:0.02653	eval-rmse:0.03293
# [2950]	train-rmse:0.02640	eval-rmse:0.03288
# [3000]	train-rmse:0.02629	eval-rmse:0.03286
# [3050]	train-rmse:0.02620	eval-rmse:0.03283
# [3100]	train-rmse:0.02610	eval-rmse:0.03280
# [3150]	train-rmse:0.02597	eval-rmse:0.03274
# [3200]	train-rmse:0.02588	eval-rmse:0.03271
# [3250]	train-rmse:0.02578	eval-rmse:0.03265
# [3300]	train-rmse:0.02568	eval-rmse:0.03260
# [3350]	train-rmse:0.02557	eval-rmse:0.03255
# [3400]	train-rmse:0.02547	eval-rmse:0.03252
# [3450]	train-rmse:0.02536	eval-rmse:0.03248
# [3500]	train-rmse:0.02527	eval-rmse:0.03243
# [3550]	train-rmse:0.02518	eval-rmse:0.03239
# [3600]	train-rmse:0.02507	eval-rmse:0.03235
# [3650]	train-rmse:0.02495	eval-rmse:0.03231
# [3700]	train-rmse:0.02485	eval-rmse:0.03228
# [3750]	train-rmse:0.02470	eval-rmse:0.03219
# [3800]	train-rmse:0.02451	eval-rmse:0.03207
# [3850]	train-rmse:0.02441	eval-rmse:0.03203
# [3900]	train-rmse:0.02431	eval-rmse:0.03198
# [3950]	train-rmse:0.02420	eval-rmse:0.03192
# [3999]	train-rmse:0.02410	eval-rmse:0.03187
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:49:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.11405	eval-rmse:0.12063
# [50]	train-rmse:0.07292	eval-rmse:0.07786
# [100]	train-rmse:0.04934	eval-rmse:0.05352
# [150]	train-rmse:0.03639	eval-rmse:0.04009
# [200]	train-rmse:0.02960	eval-rmse:0.03307
# [250]	train-rmse:0.02605	eval-rmse:0.02939
# [300]	train-rmse:0.02414	eval-rmse:0.02740
# [350]	train-rmse:0.02294	eval-rmse:0.02615
# [400]	train-rmse:0.02198	eval-rmse:0.02515
# [450]	train-rmse:0.02128	eval-rmse:0.02441
# [500]	train-rmse:0.02065	eval-rmse:0.02376
# [550]	train-rmse:0.02014	eval-rmse:0.02319
# [600]	train-rmse:0.01963	eval-rmse:0.02258
# [650]	train-rmse:0.01925	eval-rmse:0.02217
# [700]	train-rmse:0.01889	eval-rmse:0.02180
# [750]	train-rmse:0.01865	eval-rmse:0.02153
# [800]	train-rmse:0.01838	eval-rmse:0.02124
# [850]	train-rmse:0.01814	eval-rmse:0.02099
# [900]	train-rmse:0.01797	eval-rmse:0.02084
# [950]	train-rmse:0.01777	eval-rmse:0.02064
# [1000]	train-rmse:0.01757	eval-rmse:0.02044
# [1050]	train-rmse:0.01741	eval-rmse:0.02026
# [1100]	train-rmse:0.01725	eval-rmse:0.02010
# [1150]	train-rmse:0.01711	eval-rmse:0.01998
# [1200]	train-rmse:0.01695	eval-rmse:0.01985
# [1250]	train-rmse:0.01677	eval-rmse:0.01970
# [1300]	train-rmse:0.01663	eval-rmse:0.01958
# [1350]	train-rmse:0.01649	eval-rmse:0.01947
# [1400]	train-rmse:0.01636	eval-rmse:0.01936
# [1450]	train-rmse:0.01624	eval-rmse:0.01927
# [1500]	train-rmse:0.01614	eval-rmse:0.01920
# [1550]	train-rmse:0.01604	eval-rmse:0.01913
# [1600]	train-rmse:0.01595	eval-rmse:0.01907
# [1650]	train-rmse:0.01585	eval-rmse:0.01899
# [1700]	train-rmse:0.01575	eval-rmse:0.01892
# [1750]	train-rmse:0.01564	eval-rmse:0.01885
# [1800]	train-rmse:0.01551	eval-rmse:0.01875
# [1850]	train-rmse:0.01541	eval-rmse:0.01870
# [1900]	train-rmse:0.01530	eval-rmse:0.01862
# [1950]	train-rmse:0.01521	eval-rmse:0.01856
# [2000]	train-rmse:0.01513	eval-rmse:0.01850
# [2050]	train-rmse:0.01505	eval-rmse:0.01845
# [2100]	train-rmse:0.01498	eval-rmse:0.01842
# [2150]	train-rmse:0.01488	eval-rmse:0.01835
# [2200]	train-rmse:0.01478	eval-rmse:0.01828
# [2250]	train-rmse:0.01468	eval-rmse:0.01820
# [2300]	train-rmse:0.01458	eval-rmse:0.01814
# [2350]	train-rmse:0.01450	eval-rmse:0.01809
# [2400]	train-rmse:0.01440	eval-rmse:0.01803
# [2450]	train-rmse:0.01432	eval-rmse:0.01798
# [2500]	train-rmse:0.01425	eval-rmse:0.01793
# [2550]	train-rmse:0.01417	eval-rmse:0.01788
# [2600]	train-rmse:0.01409	eval-rmse:0.01782
# [2650]	train-rmse:0.01402	eval-rmse:0.01779
# [2700]	train-rmse:0.01393	eval-rmse:0.01774
# [2750]	train-rmse:0.01389	eval-rmse:0.01772
# [2800]	train-rmse:0.01383	eval-rmse:0.01769
# [2850]	train-rmse:0.01375	eval-rmse:0.01763
# [2900]	train-rmse:0.01368	eval-rmse:0.01760
# [2950]	train-rmse:0.01362	eval-rmse:0.01756
# [3000]	train-rmse:0.01356	eval-rmse:0.01753
# [3050]	train-rmse:0.01351	eval-rmse:0.01750
# [3100]	train-rmse:0.01344	eval-rmse:0.01747
# [3150]	train-rmse:0.01335	eval-rmse:0.01741
# [3200]	train-rmse:0.01327	eval-rmse:0.01737
# [3250]	train-rmse:0.01320	eval-rmse:0.01733
# [3300]	train-rmse:0.01314	eval-rmse:0.01731
# [3350]	train-rmse:0.01309	eval-rmse:0.01729
# [3400]	train-rmse:0.01303	eval-rmse:0.01726
# [3450]	train-rmse:0.01299	eval-rmse:0.01724
# [3500]	train-rmse:0.01295	eval-rmse:0.01722
# [3550]	train-rmse:0.01292	eval-rmse:0.01721
# [3600]	train-rmse:0.01288	eval-rmse:0.01720
# [3650]	train-rmse:0.01285	eval-rmse:0.01719
# [3700]	train-rmse:0.01281	eval-rmse:0.01717
# [3750]	train-rmse:0.01274	eval-rmse:0.01714
# [3800]	train-rmse:0.01268	eval-rmse:0.01712
# [3850]	train-rmse:0.01264	eval-rmse:0.01710
# [3900]	train-rmse:0.01260	eval-rmse:0.01708
# [3950]	train-rmse:0.01257	eval-rmse:0.01707
# [3999]	train-rmse:0.01253	eval-rmse:0.01705
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:49:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.15263	eval-rmse:0.15654
# [50]	train-rmse:0.09877	eval-rmse:0.10111
# [100]	train-rmse:0.06821	eval-rmse:0.06960
# [150]	train-rmse:0.05161	eval-rmse:0.05273
# [200]	train-rmse:0.04263	eval-rmse:0.04377
# [250]	train-rmse:0.03771	eval-rmse:0.03886
# [300]	train-rmse:0.03459	eval-rmse:0.03573
# [350]	train-rmse:0.03253	eval-rmse:0.03375
# [400]	train-rmse:0.03120	eval-rmse:0.03250
# [450]	train-rmse:0.03025	eval-rmse:0.03164
# [500]	train-rmse:0.02951	eval-rmse:0.03100
# ...
# [1350]	train-rmse:0.03216	eval-rmse:0.03543
# [1400]	train-rmse:0.03192	eval-rmse:0.03526
# [1450]	train-rmse:0.03164	eval-rmse:0.03509
# [1500]	train-rmse:0.03134	eval-rmse:0.03492
# [1550]	train-rmse:0.03108	eval-rmse:0.03476
# [1600]	train-rmse:0.03083	eval-rmse:0.03458
# [1650]	train-rmse:0.03062	eval-rmse:0.03445
# [1700]	train-rmse:0.03042	eval-rmse:0.03433
# [1750]	train-rmse:0.03017	eval-rmse:0.03418
# [1800]	train-rmse:0.02999	eval-rmse:0.03407
# [1850]	train-rmse:0.02982	eval-rmse:0.03396
# [1900]	train-rmse:0.02966	eval-rmse:0.03386
# [1950]	train-rmse:0.02951	eval-rmse:0.03377
# [2000]	train-rmse:0.02936	eval-rmse:0.03368
# [2050]	train-rmse:0.02920	eval-rmse:0.03358
# [2100]	train-rmse:0.02905	eval-rmse:0.03347
# [2150]	train-rmse:0.02887	eval-rmse:0.03335
# [2200]	train-rmse:0.02874	eval-rmse:0.03327
# [2250]	train-rmse:0.02859	eval-rmse:0.03319
# [2300]	train-rmse:0.02846	eval-rmse:0.03313
# [2350]	train-rmse:0.02833	eval-rmse:0.03307
# [2400]	train-rmse:0.02819	eval-rmse:0.03303
# [2450]	train-rmse:0.02806	eval-rmse:0.03296
# [2500]	train-rmse:0.02794	eval-rmse:0.03291
# [2550]	train-rmse:0.02776	eval-rmse:0.03280
# [2600]	train-rmse:0.02765	eval-rmse:0.03275
# [2650]	train-rmse:0.02752	eval-rmse:0.03269
# [2700]	train-rmse:0.02736	eval-rmse:0.03262
# [2750]	train-rmse:0.02719	eval-rmse:0.03254
# [2800]	train-rmse:0.02703	eval-rmse:0.03249
# [2850]	train-rmse:0.02692	eval-rmse:0.03243
# [2900]	train-rmse:0.02680	eval-rmse:0.03237
# [2950]	train-rmse:0.02668	eval-rmse:0.03231
# [3000]	train-rmse:0.02657	eval-rmse:0.03226
# [3050]	train-rmse:0.02641	eval-rmse:0.03219
# [3100]	train-rmse:0.02625	eval-rmse:0.03212
# [3150]	train-rmse:0.02614	eval-rmse:0.03208
# [3200]	train-rmse:0.02596	eval-rmse:0.03197
# [3250]	train-rmse:0.02582	eval-rmse:0.03190
# [3300]	train-rmse:0.02573	eval-rmse:0.03188
# [3350]	train-rmse:0.02563	eval-rmse:0.03188
# [3400]	train-rmse:0.02553	eval-rmse:0.03185
# [3450]	train-rmse:0.02540	eval-rmse:0.03180
# [3500]	train-rmse:0.02530	eval-rmse:0.03177
# [3550]	train-rmse:0.02515	eval-rmse:0.03171
# [3600]	train-rmse:0.02505	eval-rmse:0.03166
# [3650]	train-rmse:0.02492	eval-rmse:0.03162
# [3700]	train-rmse:0.02480	eval-rmse:0.03155
# [3750]	train-rmse:0.02470	eval-rmse:0.03151
# [3800]	train-rmse:0.02458	eval-rmse:0.03148
# [3850]	train-rmse:0.02451	eval-rmse:0.03147
# [3900]	train-rmse:0.02440	eval-rmse:0.03142
# [3950]	train-rmse:0.02432	eval-rmse:0.03137
# [3999]	train-rmse:0.02423	eval-rmse:0.03134
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:59:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.11557	eval-rmse:0.11126
# [50]	train-rmse:0.07390	eval-rmse:0.07119
# [100]	train-rmse:0.05002	eval-rmse:0.04832
# [150]	train-rmse:0.03700	eval-rmse:0.03606
# [200]	train-rmse:0.03015	eval-rmse:0.02980
# [250]	train-rmse:0.02652	eval-rmse:0.02660
# [300]	train-rmse:0.02451	eval-rmse:0.02487
# [350]	train-rmse:0.02312	eval-rmse:0.02360
# [400]	train-rmse:0.02214	eval-rmse:0.02274
# [450]	train-rmse:0.02140	eval-rmse:0.02212
# [500]	train-rmse:0.02071	eval-rmse:0.02154
# [550]	train-rmse:0.01994	eval-rmse:0.02087
# [600]	train-rmse:0.01943	eval-rmse:0.02043
# [650]	train-rmse:0.01902	eval-rmse:0.02009
# [700]	train-rmse:0.01870	eval-rmse:0.01982
# [750]	train-rmse:0.01843	eval-rmse:0.01960
# [800]	train-rmse:0.01818	eval-rmse:0.01941
# [850]	train-rmse:0.01799	eval-rmse:0.01927
# [900]	train-rmse:0.01777	eval-rmse:0.01911
# [950]	train-rmse:0.01754	eval-rmse:0.01895
# [1000]	train-rmse:0.01735	eval-rmse:0.01882
# [1050]	train-rmse:0.01720	eval-rmse:0.01872
# [1100]	train-rmse:0.01703	eval-rmse:0.01861
# [1150]	train-rmse:0.01685	eval-rmse:0.01850
# [1200]	train-rmse:0.01668	eval-rmse:0.01837
# [1250]	train-rmse:0.01651	eval-rmse:0.01825
# [1300]	train-rmse:0.01636	eval-rmse:0.01816
# [1350]	train-rmse:0.01624	eval-rmse:0.01809
# [1400]	train-rmse:0.01611	eval-rmse:0.01802
# [1450]	train-rmse:0.01599	eval-rmse:0.01796
# [1500]	train-rmse:0.01588	eval-rmse:0.01790
# [1550]	train-rmse:0.01579	eval-rmse:0.01786
# [1600]	train-rmse:0.01571	eval-rmse:0.01783
# [1650]	train-rmse:0.01561	eval-rmse:0.01778
# [1700]	train-rmse:0.01553	eval-rmse:0.01772
# [1750]	train-rmse:0.01543	eval-rmse:0.01766
# [1800]	train-rmse:0.01534	eval-rmse:0.01760
# [1850]	train-rmse:0.01526	eval-rmse:0.01757
# [1900]	train-rmse:0.01519	eval-rmse:0.01753
# [1950]	train-rmse:0.01511	eval-rmse:0.01748
# [2000]	train-rmse:0.01503	eval-rmse:0.01743
# [2050]	train-rmse:0.01495	eval-rmse:0.01737
# [2100]	train-rmse:0.01487	eval-rmse:0.01734
# [2150]	train-rmse:0.01480	eval-rmse:0.01731
# [2200]	train-rmse:0.01474	eval-rmse:0.01728
# [2250]	train-rmse:0.01466	eval-rmse:0.01725
# [2300]	train-rmse:0.01458	eval-rmse:0.01721
# [2350]	train-rmse:0.01450	eval-rmse:0.01716
# [2400]	train-rmse:0.01442	eval-rmse:0.01712
# [2450]	train-rmse:0.01435	eval-rmse:0.01708
# [2500]	train-rmse:0.01428	eval-rmse:0.01705
# [2550]	train-rmse:0.01422	eval-rmse:0.01703
# [2600]	train-rmse:0.01417	eval-rmse:0.01701
# [2650]	train-rmse:0.01411	eval-rmse:0.01699
# [2700]	train-rmse:0.01403	eval-rmse:0.01695
# [2750]	train-rmse:0.01395	eval-rmse:0.01691
# [2800]	train-rmse:0.01388	eval-rmse:0.01688
# [2850]	train-rmse:0.01381	eval-rmse:0.01684
# [2900]	train-rmse:0.01376	eval-rmse:0.01682
# [2950]	train-rmse:0.01370	eval-rmse:0.01679
# [3000]	train-rmse:0.01366	eval-rmse:0.01677
# [3050]	train-rmse:0.01358	eval-rmse:0.01674
# [3100]	train-rmse:0.01352	eval-rmse:0.01671
# [3150]	train-rmse:0.01347	eval-rmse:0.01668
# [3200]	train-rmse:0.01342	eval-rmse:0.01666
# [3250]	train-rmse:0.01337	eval-rmse:0.01664
# [3300]	train-rmse:0.01332	eval-rmse:0.01662
# [3350]	train-rmse:0.01327	eval-rmse:0.01660
# [3400]	train-rmse:0.01321	eval-rmse:0.01658
# [3450]	train-rmse:0.01315	eval-rmse:0.01656
# [3500]	train-rmse:0.01309	eval-rmse:0.01652
# [3550]	train-rmse:0.01303	eval-rmse:0.01649
# [3600]	train-rmse:0.01298	eval-rmse:0.01647
# [3650]	train-rmse:0.01293	eval-rmse:0.01645
# [3700]	train-rmse:0.01287	eval-rmse:0.01642
# [3750]	train-rmse:0.01277	eval-rmse:0.01636
# [3800]	train-rmse:0.01269	eval-rmse:0.01633
# [3850]	train-rmse:0.01264	eval-rmse:0.01631
# [3900]	train-rmse:0.01257	eval-rmse:0.01628
# [3950]	train-rmse:0.01253	eval-rmse:0.01626
# [3999]	train-rmse:0.01249	eval-rmse:0.01625
# [0]	train-rmse:0.15394	eval-rmse:0.14753
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [20:59:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [50]	train-rmse:0.09960	eval-rmse:0.09560
# [100]	train-rmse:0.06871	eval-rmse:0.06631
# [150]	train-rmse:0.05199	eval-rmse:0.05081
# [200]	train-rmse:0.04292	eval-rmse:0.04256
# [250]	train-rmse:0.03791	eval-rmse:0.03808
# [300]	train-rmse:0.03486	eval-rmse:0.03535
# [350]	train-rmse:0.03277	eval-rmse:0.03356
# [400]	train-rmse:0.03141	eval-rmse:0.03243
# [450]	train-rmse:0.03053	eval-rmse:0.03168
# [500]	train-rmse:0.02982	eval-rmse:0.03106
# [550]	train-rmse:0.02907	eval-rmse:0.03044
# [600]	train-rmse:0.02864	eval-rmse:0.03007
# [650]	train-rmse:0.02821	eval-rmse:0.02971
# [700]	train-rmse:0.02777	eval-rmse:0.02935
# [750]	train-rmse:0.02737	eval-rmse:0.02905
# [800]	train-rmse:0.02702	eval-rmse:0.02879
# [850]	train-rmse:0.02672	eval-rmse:0.02855
# [900]	train-rmse:0.02645	eval-rmse:0.02835
# [950]	train-rmse:0.02624	eval-rmse:0.02820
# [1000]	train-rmse:0.02604	eval-rmse:0.02808
# [1050]	train-rmse:0.02579	eval-rmse:0.02791
# [1100]	train-rmse:0.02555	eval-rmse:0.02776
# [1150]	train-rmse:0.02534	eval-rmse:0.02765
# [1200]	train-rmse:0.02514	eval-rmse:0.02753
# [1250]	train-rmse:0.02493	eval-rmse:0.02741
# [1300]	train-rmse:0.02473	eval-rmse:0.02728
# [1350]	train-rmse:0.02456	eval-rmse:0.02717
# [1400]	train-rmse:0.02440	eval-rmse:0.02707
# [1450]	train-rmse:0.02425	eval-rmse:0.02699
# [1500]	train-rmse:0.02410	eval-rmse:0.02690
# [1550]	train-rmse:0.02396	eval-rmse:0.02683
# [1600]	train-rmse:0.02381	eval-rmse:0.02675
# [1650]	train-rmse:0.02365	eval-rmse:0.02665
# [1700]	train-rmse:0.02343	eval-rmse:0.02652
# [1750]	train-rmse:0.02328	eval-rmse:0.02642
# [1800]	train-rmse:0.02314	eval-rmse:0.02634
# [1850]	train-rmse:0.02304	eval-rmse:0.02629
# [1900]	train-rmse:0.02293	eval-rmse:0.02624
# [1950]	train-rmse:0.02282	eval-rmse:0.02620
# [2000]	train-rmse:0.02270	eval-rmse:0.02614
# [2050]	train-rmse:0.02257	eval-rmse:0.02607
# [2100]	train-rmse:0.02244	eval-rmse:0.02598
# [2150]	train-rmse:0.02233	eval-rmse:0.02593
# [2200]	train-rmse:0.02223	eval-rmse:0.02589
# [2250]	train-rmse:0.02213	eval-rmse:0.02584
# [2300]	train-rmse:0.02204	eval-rmse:0.02579
# [2350]	train-rmse:0.02193	eval-rmse:0.02573
# [2400]	train-rmse:0.02181	eval-rmse:0.02568
# [2450]	train-rmse:0.02170	eval-rmse:0.02562
# [2500]	train-rmse:0.02162	eval-rmse:0.02559
# [2550]	train-rmse:0.02151	eval-rmse:0.02555
# [2600]	train-rmse:0.02142	eval-rmse:0.02552
# [2650]	train-rmse:0.02132	eval-rmse:0.02550
# [2700]	train-rmse:0.02123	eval-rmse:0.02546
# [2750]	train-rmse:0.02114	eval-rmse:0.02542
# [2800]	train-rmse:0.02107	eval-rmse:0.02539
# [2850]	train-rmse:0.02101	eval-rmse:0.02538
# [2900]	train-rmse:0.02088	eval-rmse:0.02531
# [2950]	train-rmse:0.02077	eval-rmse:0.02525
# [3000]	train-rmse:0.02067	eval-rmse:0.02521
# [3050]	train-rmse:0.02058	eval-rmse:0.02517
# [3100]	train-rmse:0.02051	eval-rmse:0.02513
# [3150]	train-rmse:0.02041	eval-rmse:0.02507
# [3200]	train-rmse:0.02030	eval-rmse:0.02502
# [3250]	train-rmse:0.02019	eval-rmse:0.02496
# [3300]	train-rmse:0.02008	eval-rmse:0.02490
# [3350]	train-rmse:0.02001	eval-rmse:0.02485
# [3400]	train-rmse:0.01993	eval-rmse:0.02482
# [3450]	train-rmse:0.01989	eval-rmse:0.02480
# [3500]	train-rmse:0.01982	eval-rmse:0.02478
# [3550]	train-rmse:0.01974	eval-rmse:0.02475
# [3600]	train-rmse:0.01965	eval-rmse:0.02470
# [3650]	train-rmse:0.01956	eval-rmse:0.02464
# [3700]	train-rmse:0.01948	eval-rmse:0.02460
# [3750]	train-rmse:0.01937	eval-rmse:0.02454
# [3800]	train-rmse:0.01928	eval-rmse:0.02450
# [3850]	train-rmse:0.01923	eval-rmse:0.02448
# [3900]	train-rmse:0.01916	eval-rmse:0.02446
# [3950]	train-rmse:0.01909	eval-rmse:0.02443
# [3999]	train-rmse:0.01902	eval-rmse:0.02440
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:00:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-rmse:0.09399	eval-rmse:0.08839
# [50]	train-rmse:0.05980	eval-rmse:0.05650
# [100]	train-rmse:0.03976	eval-rmse:0.03803
# [150]	train-rmse:0.02828	eval-rmse:0.02761
# [200]	train-rmse:0.02175	eval-rmse:0.02173
# [250]	train-rmse:0.01796	eval-rmse:0.01829
# [300]	train-rmse:0.01562	eval-rmse:0.01617
# [350]	train-rmse:0.01393	eval-rmse:0.01454
# [400]	train-rmse:0.01271	eval-rmse:0.01339
# [450]	train-rmse:0.01165	eval-rmse:0.01230
# [500]	train-rmse:0.01075	eval-rmse:0.01138
# [550]	train-rmse:0.00992	eval-rmse:0.01050
# [600]	train-rmse:0.00925	eval-rmse:0.00979
# [650]	train-rmse:0.00871	eval-rmse:0.00923
# [700]	train-rmse:0.00816	eval-rmse:0.00863
# [750]	train-rmse:0.00782	eval-rmse:0.00826
# [800]	train-rmse:0.00752	eval-rmse:0.00795
# [850]	train-rmse:0.00731	eval-rmse:0.00772
# [900]	train-rmse:0.00710	eval-rmse:0.00751
# [950]	train-rmse:0.00693	eval-rmse:0.00734
# [1000]	train-rmse:0.00680	eval-rmse:0.00721
# [1050]	train-rmse:0.00670	eval-rmse:0.00712
# [1100]	train-rmse:0.00659	eval-rmse:0.00702
# [1150]	train-rmse:0.00650	eval-rmse:0.00694
# [1200]	train-rmse:0.00642	eval-rmse:0.00686
# [1250]	train-rmse:0.00635	eval-rmse:0.00680
# [1300]	train-rmse:0.00628	eval-rmse:0.00674
# [1350]	train-rmse:0.00621	eval-rmse:0.00668
# [1400]	train-rmse:0.00616	eval-rmse:0.00663
# [1450]	train-rmse:0.00610	eval-rmse:0.00659
# [1500]	train-rmse:0.00605	eval-rmse:0.00655
# [1550]	train-rmse:0.00600	eval-rmse:0.00651
# [1600]	train-rmse:0.00595	eval-rmse:0.00648
# [1650]	train-rmse:0.00589	eval-rmse:0.00644
# [1700]	train-rmse:0.00584	eval-rmse:0.00640
# [1750]	train-rmse:0.00576	eval-rmse:0.00635
# [1800]	train-rmse:0.00567	eval-rmse:0.00629
# [1850]	train-rmse:0.00560	eval-rmse:0.00624
# [1900]	train-rmse:0.00554	eval-rmse:0.00620
# [1950]	train-rmse:0.00550	eval-rmse:0.00617
# [2000]	train-rmse:0.00547	eval-rmse:0.00615
# [2050]	train-rmse:0.00542	eval-rmse:0.00612
# [2100]	train-rmse:0.00536	eval-rmse:0.00608
# [2150]	train-rmse:0.00532	eval-rmse:0.00607
# [2200]	train-rmse:0.00528	eval-rmse:0.00604
# [2250]	train-rmse:0.00525	eval-rmse:0.00602
# [2300]	train-rmse:0.00521	eval-rmse:0.00600
# [2350]	train-rmse:0.00516	eval-rmse:0.00597
# [2400]	train-rmse:0.00513	eval-rmse:0.00595
# [2450]	train-rmse:0.00509	eval-rmse:0.00592
# [2500]	train-rmse:0.00504	eval-rmse:0.00589
# [2550]	train-rmse:0.00498	eval-rmse:0.00585
# [2600]	train-rmse:0.00492	eval-rmse:0.00583
# [2650]	train-rmse:0.00488	eval-rmse:0.00581
# [2700]	train-rmse:0.00484	eval-rmse:0.00577
# [2750]	train-rmse:0.00478	eval-rmse:0.00572
# [2800]	train-rmse:0.00474	eval-rmse:0.00569
# [2850]	train-rmse:0.00470	eval-rmse:0.00567
# [2900]	train-rmse:0.00465	eval-rmse:0.00563
# [2950]	train-rmse:0.00460	eval-rmse:0.00560
# [3000]	train-rmse:0.00455	eval-rmse:0.00558
# [3050]	train-rmse:0.00450	eval-rmse:0.00555
# [3100]	train-rmse:0.00447	eval-rmse:0.00553
# [3150]	train-rmse:0.00443	eval-rmse:0.00551
# [3200]	train-rmse:0.00440	eval-rmse:0.00550
# [3250]	train-rmse:0.00437	eval-rmse:0.00548
# [3300]	train-rmse:0.00435	eval-rmse:0.00546
# [3350]	train-rmse:0.00432	eval-rmse:0.00545
# [3400]	train-rmse:0.00429	eval-rmse:0.00543
# [3450]	train-rmse:0.00426	eval-rmse:0.00542
# [3500]	train-rmse:0.00424	eval-rmse:0.00540
# [3550]	train-rmse:0.00421	eval-rmse:0.00538
# [3600]	train-rmse:0.00417	eval-rmse:0.00535
# [3650]	train-rmse:0.00414	eval-rmse:0.00534
# [3700]	train-rmse:0.00411	eval-rmse:0.00531
# [3750]	train-rmse:0.00408	eval-rmse:0.00530
# [3800]	train-rmse:0.00406	eval-rmse:0.00529
# [3850]	train-rmse:0.00403	eval-rmse:0.00527
# [3900]	train-rmse:0.00401	eval-rmse:0.00526
# [3950]	train-rmse:0.00398	eval-rmse:0.00524
# [3999]	train-rmse:0.00395	eval-rmse:0.00523
# Model Results for Housing:
# Train Data: MAE: 45.8717, R-Squared: 0.9733, RMSE: 63.2877, MSE: 4005.3357 ,smape: 4.495234172561228
# Validation Data: MAE: 58.6756, R-Squared: 0.9478, RMSE: 83.0992, MSE: 6905.4706 ,smape: 5.5143644666908544
# Test Data: MAE: 58.7247, R-Squared: 0.9522, RMSE: 85.0971, MSE: 7241.5234 ,smape: 5.507176998039062
#
# Model Results for Food:
# Train Data: MAE: 24.1082, R-Squared: 0.9902, RMSE: 33.8471, MSE: 1145.6242 ,smape: 2.8662187281937612
# Validation Data: MAE: 32.2275, R-Squared: 0.979, RMSE: 49.4855, MSE: 2448.8108 ,smape: 3.6405629740450105
# Test Data: MAE: 30.9908, R-Squared: 0.9806, RMSE: 47.3519, MSE: 2242.1999 ,smape: 3.524005217290762
#
# Model Results for Transportation:
# Train Data: MAE: 53.1869, R-Squared: 0.9118, RMSE: 70.6759, MSE: 4995.0778 ,smape: 3.4847124788612307
# Validation Data: MAE: 65.4898, R-Squared: 0.8536, RMSE: 89.396, MSE: 7991.6523 ,smape: 4.287196582407244
# Test Data: MAE: 64.5065, R-Squared: 0.8591, RMSE: 89.945, MSE: 8090.1071 ,smape: 4.251581186316233
#
# Model Results for Healthcare:
# Train Data: MAE: 51.8773, R-Squared: 0.9765, RMSE: 75.3205, MSE: 5673.174 ,smape: 4.348962951657064
# Validation Data: MAE: 67.3171, R-Squared: 0.9619, RMSE: 97.4027, MSE: 9487.2802 ,smape: 5.454105967666189
# Test Data: MAE: 63.1996, R-Squared: 0.9628, RMSE: 93.0793, MSE: 8663.758 ,smape: 5.191692503127953
#
# Model Results for Othernecessities:
# Train Data: MAE: 18.1536, R-Squared: 0.9885, RMSE: 24.5477, MSE: 602.591 ,smape: 2.781982864376989
# Validation Data: MAE: 22.836, R-Squared: 0.9791, RMSE: 31.9405, MSE: 1020.1957 ,smape: 3.3689233958976885
# Test Data: MAE: 22.6559, R-Squared: 0.9796, RMSE: 32.8339, MSE: 1078.0647 ,smape: 3.3459533439954154
#
# Model Results for Childcare:
# Train Data: MAE: 48.7099, R-Squared: 0.9851, RMSE: 76.7097, MSE: 5884.3857 ,smape: 4.56073619812923
# Validation Data: MAE: 61.6258, R-Squared: 0.9734, RMSE: 98.3683, MSE: 9676.3214 ,smape: 5.624669911986226
# Test Data: MAE: 61.2251, R-Squared: 0.9747, RMSE: 99.0389, MSE: 9808.7007 ,smape: 5.511102770178022
#
# Model Results for Taxes:
# Train Data: MAE: 8.6985, R-Squared: 0.9983, RMSE: 17.1239, MSE: 293.2271 ,smape: 0.9868476669326729
# Validation Data: MAE: 11.193, R-Squared: 0.9966, RMSE: 22.6514, MSE: 513.0874 ,smape: 1.1994220633479462
# Test Data: MAE: 10.7261, R-Squared: 0.9972, RMSE: 21.8282, MSE: 476.4721 ,smape: 1.1412139578816145

# %%
import pandas as pd
import numpy as np
import joblib

# Load the scalers
scaler_X = joblib.load('scaler_X.pkl')
scaler_y = joblib.load('scaler_y.pkl')

def get_prediction(model_combine, input_data, scaler_X, scaler_y, num_children_col, childcare_exp_col):
    """
    Generates predictions for expenses using the combined model.

    Args:
        model_combine: The trained Keras model.
        input_data: Pandas DataFrame of new input data.
        scaler_X: Fitted MinMaxScaler for features.
        scaler_y: Fitted MinMaxScaler for target variables.
        num_children_col: Integer column index for number of children.
        childcare_exp_col: Integer column index for the 'childcare' target.

    Returns:
         Numpy Array: Predicted expense values.
    """

    # Step 1: Create new features
    input_data_with_features = createFeatures(input_data.copy())

    # Step 2: Select relevant features
    X = input_data_with_features[['total', 'median_family_income', 'num_counties_in_st', 'n_children',
                                  'n_parents', 'n_members', 'per_member_cost', 'child_expense_cost',
                                  'parent_expense_cost', 'other_expense_cost','zero_childcare_cost']].values

    # Step 3: Scale the input data using the fitted scaler_X
    input_data_scaled = scaler_X.transform(X)

    # Step 4: Reshape for the CNN layer (add the extra dimension)
    input_data_scaled = input_data_scaled[..., np.newaxis]  # This line is crucial to match the training data shape

    # Step 5: Make predictions using the trained model
    # We need to unpack the predictions from the model output
    # Then, we can stack those into a single output array.
    input_data_pred = model_combine.predict(input_data_scaled)
    input_data_pred = np.column_stack(input_data_pred)

    # Step 6: Inverse transform the predictions to return them to the original scale
    input_data_pred_original = scaler_y.inverse_transform(input_data_pred)

    # Step 7: Enforce the rule that if there are no children, childcare cost is 0
    input_data_pred_original[:, childcare_exp_col] = np.where(
        input_data_with_features['n_children'].values == 0, 0, input_data_pred_original[:, childcare_exp_col]
    )

    return input_data_pred_original

def createFeatures(input_data):
    """
    Creates additional features needed for the model prediction.

    Args:
        input_data: The input pandas DataFrame with the original data.

    Returns:
        input_data: The input data with additional features.
    """
    # Step 1: Create additional features
    input_data["per_member_cost"] = input_data["total"] / input_data["n_members"]
    input_data["child_expense_cost"] = input_data["per_member_cost"] * input_data["n_children"]
    input_data["parent_expense_cost"] = input_data["per_member_cost"] * input_data["n_parents"]
    input_data["other_expense_cost"] = input_data["total"] - (input_data["child_expense_cost"] + input_data["parent_expense_cost"])

    # Step 2: Create binary column for whether there are children (0 if no children, 1 if there are children)
    input_data["zero_childcare_cost"] = input_data['n_children'].map(lambda x: 0 if x < 1 else 1)

    return input_data

# Example of input data to test predictions
input_data = pd.DataFrame(
    [[4541, 8790.0, 67, 0, 2, 2]],
    columns=['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']
)

# Assuming `model_combine` is your trained model
input_data_pred_original = get_prediction(model_combine, input_data, scaler_X, scaler_y, num_children_col=3, childcare_exp_col=5)

# Print predictions
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']
for i, prediction in enumerate(input_data_pred_original[0]):
    print(f"{target_col_list[i]}: {prediction:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# housing: 677.50
# food: 605.33
# transportation: 1355.80
# healthcare: 854.20
# othernecessities: 450.93
# childcare: 0.00
# taxes: 614.43
