# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_IDP_2024-2025/blob/main/XGBOOST_CNN_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
df = df.fillna(0)
# Out:
# Mounted at /content/drive

# %%
# Data Preprocessing
df.columns = [col.lower().replace(' ', '').replace('.', '') for col in df.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
df1 = df[cols_to_keep].copy()

df1['median_family_income'] = df1['median_family_income'].replace(',', '', regex=True).astype(float)

# %%
# Feature Engineering
df1['n_parents'] = df1['family'].str.slice(0, 1).astype(int)
df1['n_children'] = df1['family'].str.slice(2, 3).astype(int)
df1['n_members'] = df1['n_parents'] + df1['n_children']
df1['financial_stability'] = df1['median_family_income'] / df1['total']
df1["per_member_cost"] = df1["total"] / df1["n_members"]
df1["child_expense_cost"] = df1["per_member_cost"]*df1["n_children"]
df1["parent_expense_cost"] = df1["per_member_cost"]*df1["n_parents"]
df1["other_expense_cost"] = df1["total"] - (df1["child_expense_cost"]+df1["parent_expense_cost"])

# %%
# Splitting the data
X = df1[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost']].values
y_expenses = df1[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = StandardScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = StandardScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)



# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse}'

# %%
from tensorflow.keras.layers import Input, Conv1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# L2 regularization strength (you can tune this value)
l2_strength = 0.01

# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
'''import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Cross-Validation with Evaluation and Training/Validation Loss Curve
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=400):
    fold = 1

    # To store metrics across all folds
    metrics_summary = {target: {'train': [], 'val': [], 'test': []} for target in target_col_list}

    # To store loss values for each fold
    all_train_loss = []
    all_val_loss = []

    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # 50/50 split of remaining 20% for test and validation sets
        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        # Early stopping to prevent overfitting
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=10,
            verbose=1,
            mode='min',
            restore_best_weights=True
        )

        # Create and compile the model
        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        # Training
        history = model.fit(
            X_train, [y_train[:, i] for i in range(y_train.shape[1])],
            validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
            epochs=num_epochs,
            batch_size=128,
            verbose=1,
            callbacks=[early_stopping]
        )

        # Store loss values for the current fold
        all_train_loss.append(history.history['loss'])
        all_val_loss.append(history.history['val_loss'])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test))  # Prediction on test set

        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)  # Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test)  # Inverse transform for test set

        # Metrics for each target and accumulate results
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()} (Fold {fold}):')
            train_metrics = regr_report(y_train_original[:, i], y_train_pred_original[:, i])
            val_metrics = regr_report(y_val_original[:, i], y_val_pred_original[:, i])
            test_metrics = regr_report(y_test_original[:, i], y_test_pred_original[:, i])

            # Store metrics for this fold
            metrics_summary[target]['train'].append(train_metrics)
            metrics_summary[target]['val'].append(val_metrics)
            metrics_summary[target]['test'].append(test_metrics)

            print('Train Data:', train_metrics)
            print('Validation Data:', val_metrics)
            print('Test Data:', test_metrics)
            print()

        fold += 1

    # Compute and display final average metrics across all folds
    print("Final Average Metrics After 5 Folds:")
    for target in target_col_list:
        print(f"Results for {target.capitalize()}:")

        # Modified to calculate average metrics from numerical values
        train_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['train']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_train_metrics = train_metrics_df.mean().to_dict()

        val_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['val']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_val_metrics = val_metrics_df.mean().to_dict()

        test_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['test']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_test_metrics = test_metrics_df.mean().to_dict()

        print("Average Train Metrics:", avg_train_metrics)
        print("Average Validation Metrics:", avg_val_metrics)
        print("Average Test Metrics:", avg_test_metrics)
        print()

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 6))
    for i, (train_loss, val_loss) in enumerate(zip(all_train_loss, all_val_loss)):
        plt.plot(val_loss, label=f'Fold {i + 1} Validation Loss')
        plt.plot(train_loss, label=f'Fold {i + 1} Train Loss')


    plt.title("Training and Validation Loss Across Folds")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# Cross-Validation Execution
model = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
model.save_weights("model_expenses.weights.h5")'''
# Out:
# 'import matplotlib.pyplot as plt\nimport numpy as np\nimport pandas as pd\nfrom sklearn.model_selection import train_test_split\nfrom tensorflow.keras.callbacks import EarlyStopping\nfrom tensorflow.keras.optimizers import Adam\n\n# Cross-Validation with Evaluation and Training/Validation Loss Curve\ndef cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=400):\n    fold = 1\n\n    # To store metrics across all folds\n    metrics_summary = {target: {\'train\': [], \'val\': [], \'test\': []} for target in target_col_list}\n\n    # To store loss values for each fold\n    all_train_loss = []\n    all_val_loss = []\n\n    for train_index, val_index in kf.split(X_scaled):\n        print(f"Fold {fold}/{kf.get_n_splits()}")\n        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]\n        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]\n\n        # 50/50 split of remaining 20% for test and validation sets\n        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)\n\n        # Reshaping data for CNN\n        X_train = X_train[..., np.newaxis]\n        X_val = X_val[..., np.newaxis]\n        X_test = X_test[..., np.newaxis]\n\n        # Early stopping to prevent overfitting\n        early_stopping = EarlyStopping(\n            monitor=\'val_loss\',\n            patience=10,\n            verbose=1,\n            mode=\'min\',\n            restore_best_weights=True\n        )\n\n        # Create and compile the model\n        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])\n        model.compile(optimizer=Adam(learning_rate=0.001), loss=\'mean_squared_error\')\n\n        # Training\n        history = model.fit(\n            X_train, [y_train[:, i] for i in range(y_train.shape[1])],\n            validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),\n            epochs=num_epochs,\n            batch_size=128,\n            verbose=1,\n            callbacks=[early_stopping]\n        )\n\n        # Store loss values for the current fold\n        all_train_loss.append(history.history[\'loss\'])\n        all_val_loss.append(history.history[\'val_loss\'])\n\n        # Predictions\n        y_train_pred = np.column_stack(model.predict(X_train))\n        y_val_pred = np.column_stack(model.predict(X_val))\n        y_test_pred = np.column_stack(model.predict(X_test))  # Prediction on test set\n\n        # Inverse scaling\n        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)\n        y_train_original = scaler_y.inverse_transform(y_train)\n        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)\n        y_val_original = scaler_y.inverse_transform(y_val)\n        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)  # Inverse transform for test set\n        y_test_original = scaler_y.inverse_transform(y_test)  # Inverse transform for test set\n\n        # Metrics for each target and accumulate results\n        for i, target in enumerate(target_col_list):\n            print(f\'Model Results for {target.capitalize()} (Fold {fold}):\')\n            train_metrics = regr_report(y_train_original[:, i], y_train_pred_original[:, i])\n            val_metrics = regr_report(y_val_original[:, i], y_val_pred_original[:, i])\n            test_metrics = regr_report(y_test_original[:, i], y_test_pred_original[:, i])\n\n            # Store metrics for this fold\n            metrics_summary[target][\'train\'].append(train_metrics)\n            metrics_summary[target][\'val\'].append(val_metrics)\n            metrics_summary[target][\'test\'].append(test_metrics)\n\n            print(\'Train Data:\', train_metrics)\n            print(\'Validation Data:\', val_metrics)\n            print(\'Test Data:\', test_metrics)\n            print()\n\n        fold += 1\n\n    # Compute and display final average metrics across all folds\n    print("Final Average Metrics After 5 Folds:")\n    for ta ...

# %%
import xgboost as xgb
def create_xgboost_model(X_train, y_train):
    # Reshape X_train to 2D for XGBoost
    X_train_2d = X_train.reshape(X_train.shape[0], -1)  # Reshape to 2D
    xg_reg = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.1)
    xg_reg.fit(X_train_2d, y_train) # Use reshaped data for fitting
    return xg_reg

# %%
import matplotlib.pyplot as plt

# Cross-Validation with Evaluation and Training/Validation Loss Curve
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=400):
    fold = 1

    # To store metrics across all folds
    metrics_summary = {target: {'train': [], 'val': [], 'test': []} for target in target_col_list}

    # To store loss values for each fold
    all_train_loss = []
    all_val_loss = []

    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # 50/50 split of remaining 20% for test and validation sets
        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        # Early stopping to prevent overfitting
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=10,
            verbose=1,
            mode='min',
            restore_best_weights=True
        )

        # Create and compile the model
        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        # Training
        history = model.fit(
            X_train, [y_train[:, i] for i in range(y_train.shape[1])],
            validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
            epochs=num_epochs,
            batch_size=128,
            verbose=1,
            callbacks=[early_stopping]
        )

        # Store loss values for the current fold
        all_train_loss.append(history.history['loss'])
        all_val_loss.append(history.history['val_loss'])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test))  # Prediction on test set

        #Create XGBoost regressor
        xgboost_models = []
        for i in range(y_train.shape[1]):
            xg_model = create_xgboost_model(X_train, y_train[:, i])
            xgboost_models.append(xg_model)

        # Predictions from each XGBoost model
        y_train_xgb_pred = np.column_stack([model.predict(X_train.reshape(X_train.shape[0], -1)) for model in xgboost_models])
        y_val_xgb_pred = np.column_stack([model.predict(X_val.reshape(X_val.shape[0], -1)) for model in xgboost_models])
        y_test_xgb_pred = np.column_stack([model.predict(X_test.reshape(X_test.shape[0], -1)) for model in xgboost_models])


        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)  # Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test)  # Inverse transform for test set

        # Metrics for each target and accumulate results
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()} (Fold {fold}):')
            train_metrics = regr_report(y_train_original[:, i], y_train_pred_original[:, i])
            val_metrics = regr_report(y_val_original[:, i], y_val_pred_original[:, i])
            test_metrics = regr_report(y_test_original[:, i], y_test_pred_original[:, i])

            # Store metrics for this fold
            metrics_summary[target]['train'].append(train_metrics)
            metrics_summary[target]['val'].append(val_metrics)
            metrics_summary[target]['test'].append(test_metrics)

            print('Train Data:', train_metrics)
            print('Validation Data:', val_metrics)
            print('Test Data:', test_metrics)
            print()

        fold += 1

    # Compute and display final average metrics across all folds
    print("Final Average Metrics After 5 Folds:")
    for target in target_col_list:
        print(f"Results for {target.capitalize()}:")

        # Modified to calculate average metrics from numerical values
        train_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['train']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_train_metrics = train_metrics_df.mean().to_dict()

        val_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['val']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_val_metrics = val_metrics_df.mean().to_dict()

        test_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['test']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_test_metrics = test_metrics_df.mean().to_dict()

        print("Average Train Metrics:", avg_train_metrics)
        print("Average Validation Metrics:", avg_val_metrics)
        print("Average Test Metrics:", avg_test_metrics)
        print()

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 6))
    for i, (train_loss, val_loss) in enumerate(zip(all_train_loss, all_val_loss)):
        plt.plot(val_loss, label=f'Fold {i + 1} Validation Loss')
        plt.plot(train_loss, label=f'Fold {i + 1} Train Loss')


    plt.title("Training and Validation Loss Across Folds")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# Cross-Validation Execution
model = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
model.save_weights("model_expenses.weights.h5")
# Out:
# Fold 1/5
# Epoch 1/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss:
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7366 - target_childcare_loss: 0.0667 - target_food_loss: 0.0369 - target_healthcare_loss: 0.1488 - target_housing_loss: 0.1072 - target_othernecessities_loss: 0.0486 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.2938 - val_loss: 0.7726 - val_target_childcare_loss: 0.0647 - val_target_food_loss: 0.0334 - val_target_healthcare_loss: 0.1428 - val_target_housing_loss: 0.1120 - val_target_othernecessities_loss: 0.0521 - val_target_taxes_loss: 0.0391 - val_target_transportation_loss: 0.3269
# Epoch 20/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7610 - target_childcare_loss: 0.0665 - target_food_loss: 0.0376 - target_healthcare_loss: 0.1503 - target_housing_loss: 0.1119 - target_othernecessities_loss: 0.0509 - target_taxes_loss: 0.0366 - target_transportation_loss: 0.3073 - val_loss: 0.7688 - val_target_childcare_loss: 0.0634 - val_target_food_loss: 0.0327 - val_target_healthcare_loss: 0.1430 - val_target_housing_loss: 0.1145 - val_target_othernecessities_loss: 0.0522 - val_target_taxes_loss: 0.0367 - val_target_transportation_loss: 0.3242
# Epoch 21/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.7459 - target_childcare_loss: 0.0651 - target_food_loss: 0.0368 - target_healthcare_loss: 0.1504 - target_housing_loss: 0.1097 - target_othernecessities_loss: 0.0504 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.2990 - val_loss: 0.7590 - val_target_childcare_loss: 0.0637 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1391 - val_target_housing_loss: 0.1115 - val_target_othernecessities_loss: 0.0506 - val_target_taxes_loss: 0.0374 - val_target_transportation_loss: 0.3221
# Epoch 22/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.7413 - target_childcare_loss: 0.0654 - target_food_loss: 0.0366 - target_healthcare_loss: 0.1484 - target_housing_loss: 0.1097 - target_othernecessities_loss: 0.0497 - target_taxes_loss: 0.0349 - target_transportation_loss: 0.2965 - val_loss: 0.7661 - val_target_childcare_loss: 0.0692 - val_target_food_loss: 0.0342 - val_target_healthcare_loss: 0.1423 - val_target_housing_loss: 0.1112 - val_target_othernecessities_loss: 0.0510 - val_target_taxes_loss: 0.0370 - val_target_transportation_loss: 0.3198
# Epoch 23/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7265 - target_childcare_loss: 0.0630 - target_food_loss: 0.0375 - target_healthcare_loss: 0.1449 - target_housing_loss: 0.1077 - target_othernecessities_loss: 0.0488 - target_taxes_loss: 0.0344 - target_transportation_loss: 0.2901 - val_loss: 0.7563 - val_target_childcare_loss: 0.0639 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1436 - val_target_housing_loss: 0.1091 - val_target_othernecessities_loss: 0.0500 - val_target_taxes_loss: 0.0370 - val_target_transportation_loss: 0.3196
# Epoch 24/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7501 - target_childcare_loss: 0.0653 - target_food_loss: 0.0387 - target_healthcare_loss: 0.1466 - target_housing_loss: 0.1114 - target_othernecessities_loss: 0.0508 - target_taxes_loss: 0.0354 - target_transportation_loss: 0.3019 - val_loss: 0.7637 - val_target_childcare_loss: 0.0630 - val_target_food_loss: 0.0320 - val_target_healthcare_loss: 0.1398 - val_target_housing_loss: 0.1125 - val_target_othernecessities_loss: 0.0510 - val_target_taxes_loss: 0.0403 - val_target_transportation_loss: 0.3247
# Epoch 25/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7396 - target_childcare_loss: 0.0644 - target_food_loss: 0.0374 - target_healthcare_loss: 0.1446 - target_housing_loss: 0.1092 - target_othernecessities_loss: 0.0498 - target_taxes_loss: 0.0347 - target_transportation_loss: 0.2994 - val_loss: 0.7524 - val_target_childcare_loss: 0.0649 - val_target_food_loss: 0.0335 - val_target_healthcare_loss: 0.1367 - val_target_housing_loss: 0.1091 - val_target_othernecessities_loss: 0.0498 - val_target_taxes_loss: 0.0364 - val_target_transportation_loss: 0.3201
# Epoch 26/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7360 - target_childcare_loss: 0.0655 - target_food_loss: 0.0363 - target_healthcare_loss: 0.1450 - target_housing_loss: 0.1076 - target_othernecessities_loss: 0.0494 - target_taxes_loss: 0.0342 - target_transportation_loss: 0.2978 - val_loss: 0.7515 - val_target_childcare_loss: 0.0611 - val_target_food_loss: 0.0329 - val_target_healthcare_loss: 0.1349 - val_target_housing_loss: 0.1112 - val_target_othernecessities_loss: 0.0512 - val_target_taxes_loss: 0.0370 - val_target_transportation_loss: 0.3216
# Epoch 27/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7273 - target_childcare_loss: 0.0648 - target_food_loss: 0.0380 - target_healthcare_loss: 0.1421 - target_housing_loss: 0.1071 - target_othernecessities_loss: 0.0488 - target_taxes_loss: 0.0339 - target_transportation_loss: 0.2926 - val_loss: 0.7463 - val_target_childcare_loss: 0.0612 - val_target_food_loss: 0.0322 - val_target_healthcare_loss: 0.1355 - val_target_housing_loss: 0.1097 - val_target_othernecessities_loss: 0.0500 - val_target_taxes_loss: 0.0369 - val_target_transportation_loss: 0.3190
# Epoch 28/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7263 - target_childcare_loss: 0.0620 - target_food_loss: 0.0382 - target_healthcare_loss: 0.1446 - target_housing_loss: 0.1077 - target_othernecessities_loss: 0.0484 - target_taxes_loss: 0.0333 - target_transportation_loss: 0.2922 - val_loss: 0.7494 - val_target_childcare_loss: 0.0642 - val_target_food_loss: 0.0326 - val_target_healthcare_loss: 0.1361 - val_target_housing_loss: 0.1117 - val_target_othernecessities_loss: 0.0503 - val_target_taxes_loss: 0.0361 - val_target_transportation_loss: 0.3167
# Epoch 29/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.7303 - target_childcare_loss: 0.0646 - target_food_loss: 0.0363 - target_healthcare_loss: 0.1437 - target_housing_loss: 0.1074 - target_othernecessities_loss: 0.0493 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.2946 - val_loss: 0.7498 - val_target_childcare_loss: 0.0623 - val_target_food_loss: 0.0319 - val_target_healthcare_loss: 0.1349 - val_target_housing_loss: 0.1138 - val_target_othernecessities_loss: 0.0519 - val_target_taxes_loss: 0.0370 - val_target_transportation_loss: 0.3168
# Epoch 30/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.7330 - target_childcare_loss: 0.0647 - target_food_loss: 0.0353 - target_healthcare_loss: 0.1441 - target_housing_loss: 0.1079 - target_othernecessities_loss: 0.0499 - target_taxes_loss: 0.0348 - target_transportation_loss: 0.2962 - val_loss: 0.7495 - val_target_childcare_loss: 0.0621 - val_target_food_loss: 0.0320 - val_target_healthcare_loss: 0.1353 - val_target_housing_loss: 0.1117 - val_target_othernecessities_loss: 0.0502 - val_target_taxes_loss: 0.0364 - val_target_transportation_loss: 0.3198
# Epoch 31/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7248 - target_childcare_loss: 0.0621 - target_food_loss: 0.0376 - target_healthcare_loss: 0.1446 - target_housing_loss: 0.1060 - target_othernecessities_loss: 0.0488 - target_taxes_loss: 0.0332 - target_transportation_loss: 0.2926 - val_loss: 0.7364 - val_target_childcare_loss: 0.0598 - val_target_food_loss: 0.0323 - val_target_healthcare_loss: 0.1329 - val_target_housing_loss: 0.1100 - val_target_othernecessities_loss: 0.0503 - val_target_taxes_loss: 0.0365 - val_target_transportation_loss: 0.3128
# Epoch 38/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7014 - target_childcare_loss: 0.0612 - target_food_loss: 0.0364 - target_healthcare_loss: 0.1381 - target_housing_loss: 0.1014 - target_othernecessities_loss: 0.0463 - target_taxes_loss: 0.0326 - target_transportation_loss: 0.2853 - val_loss: 0.7317 - val_target_childcare_loss: 0.0590 - val_target_food_loss: 0.0336 - val_target_healthcare_loss: 0.1326 - val_target_housing_loss: 0.1087 - val_target_othernecessities_loss: 0.0494 - val_target_taxes_loss: 0.0353 - val_target_transportation_loss: 0.3119
# Epoch 39/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7277 - target_childcare_loss: 0.0620 - target_food_loss: 0.0373 - target_healthcare_loss: 0.1425 - target_housing_loss: 0.1085 - target_othernecessities_loss: 0.0485 - target_taxes_loss: 0.0338 - target_transportation_loss: 0.2951 - val_loss: 0.7328 - val_target_childcare_loss: 0.0598 - val_target_food_loss: 0.0326 - val_target_healthcare_loss: 0.1356 - val_target_housing_loss: 0.1085 - val_target_othernecessities_loss: 0.0492 - val_target_taxes_loss: 0.0352 - val_target_transportation_loss: 0.3104
# Epoch 40/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7282 - target_childcare_loss: 0.0608 - target_food_loss: 0.0372 - target_healthcare_loss: 0.1437 - target_housing_loss: 0.1096 - target_othernecessities_loss: 0.0503 - target_taxes_loss: 0.0337 - target_transportation_loss: 0.2929 - val_loss: 0.7401 - val_target_childcare_loss: 0.0598 - val_target_food_loss: 0.0314 - val_target_healthcare_loss: 0.1385 - val_target_housing_loss: 0.1118 - val_target_othernecessities_loss: 0.0493 - val_target_taxes_loss: 0.0357 - val_target_transportation_loss: 0.3122
# Epoch 41/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.7215 - target_childcare_loss: 0.0605 - target_food_loss: 0.0363 - target_healthcare_loss: 0.1424 - target_housing_loss: 0.1101 - target_othernecessities_loss: 0.0494 - target_taxes_loss: 0.0334 - target_transportation_loss: 0.2894 - val_loss: 0.7358 - val_target_childcare_loss: 0.0591 - val_target_food_loss: 0.0323 - val_target_healthcare_loss: 0.1336 - val_target_housing_loss: 0.1105 - val_target_othernecessities_loss: 0.0498 - val_target_taxes_loss: 0.0347 - val_target_transportation_loss: 0.3141
# Epoch 42/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7139 - target_childcare_loss: 0.0610 - target_food_loss: 0.0358 - target_healthcare_loss: 0.1384 - target_housing_loss: 0.1098 - target_othernecessities_loss: 0.0489 - target_taxes_loss: 0.0324 - target_transportation_loss: 0.2875 - val_loss: 0.7344 - val_target_childcare_loss: 0.0592 - val_target_food_loss: 0.0325 - val_target_healthcare_loss: 0.1370 - val_target_housing_loss: 0.1084 - val_target_othernecessities_loss: 0.0490 - val_target_taxes_loss: 0.0352 - val_target_transportation_loss: 0.3123
# Epoch 43/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7074 - target_childcare_loss: 0.0595 - target_food_loss: 0.0355 - target_healthcare_loss: 0.1353 - target_housing_loss: 0.1033 - target_othernecessities_loss: 0.0482 - target_taxes_loss: 0.0322 - target_transportation_loss: 0.2934 - val_loss: 0.7215 - val_target_childcare_loss: 0.0584 - val_target_food_loss: 0.0318 - val_target_healthcare_loss: 0.1299 - val_target_housing_loss: 0.1083 - val_target_othernecessities_loss: 0.0485 - val_target_taxes_loss: 0.0339 - val_target_transportation_loss: 0.3100
# Epoch 50/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6917 - target_childcare_loss: 0.0587 - target_food_loss: 0.0355 - target_healthcare_loss: 0.1344 - target_housing_loss: 0.1036 - target_othernecessities_loss: 0.0466 - target_taxes_loss: 0.0320 - target_transportation_loss: 0.2810 - val_loss: 0.7195 - val_target_childcare_loss: 0.0609 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1305 - val_target_housing_loss: 0.1062 - val_target_othernecessities_loss: 0.0487 - val_target_taxes_loss: 0.0347 - val_target_transportation_loss: 0.3047
# Epoch 51/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6993 - target_childcare_loss: 0.0606 - target_food_loss: 0.0348 - target_healthcare_loss: 0.1336 - target_housing_loss: 0.1059 - target_othernecessities_loss: 0.0481 - target_taxes_loss: 0.0323 - target_transportation_loss: 0.2841 - val_loss: 0.7312 - val_target_childcare_loss: 0.0618 - val_target_food_loss: 0.0318 - val_target_healthcare_loss: 0.1397 - val_target_housing_loss: 0.1086 - val_target_othernecessities_loss: 0.0481 - val_target_taxes_loss: 0.0336 - val_target_transportation_loss: 0.3066
# Epoch 52/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6987 - target_childcare_loss: 0.0588 - target_food_loss: 0.0369 - target_healthcare_loss: 0.1358 - target_housing_loss: 0.1023 - target_othernecessities_loss: 0.0465 - target_taxes_loss: 0.0320 - target_transportation_loss: 0.2864 - val_loss: 0.7119 - val_target_childcare_loss: 0.0573 - val_target_food_loss: 0.0316 - val_target_healthcare_loss: 0.1290 - val_target_housing_loss: 0.1078 - val_target_othernecessities_loss: 0.0483 - val_target_taxes_loss: 0.0334 - val_target_transportation_loss: 0.3041
# Epoch 53/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6994 - target_childcare_loss: 0.0599 - target_food_loss: 0.0346 - target_healthcare_loss: 0.1360 - target_housing_loss: 0.1065 - target_othernecessities_loss: 0.0477 - target_taxes_loss: 0.0326 - target_transportation_loss: 0.2820 - val_loss: 0.7145 - val_target_childcare_loss: 0.0587 - val_target_food_loss: 0.0319 - val_target_healthcare_loss: 0.1275 - val_target_housing_loss: 0.1061 - val_target_othernecessities_loss: 0.0484 - val_target_taxes_loss: 0.0336 - val_target_transportation_loss: 0.3082
# Epoch 54/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7100 - target_childcare_loss: 0.0604 - target_food_loss: 0.0355 - target_healthcare_loss: 0.1357 - target_housing_loss: 0.1083 - target_othernecessities_loss: 0.0484 - target_taxes_loss: 0.0318 - target_transportation_loss: 0.2900 - val_loss: 0.7143 - val_target_childcare_loss: 0.0585 - val_target_food_loss: 0.0317 - val_target_healthcare_loss: 0.1319 - val_target_housing_loss: 0.1059 - val_target_othernecessities_loss: 0.0480 - val_target_taxes_loss: 0.0340 - val_target_transportation_loss: 0.3038
# Epoch 55/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6849 - target_childcare_loss: 0.0572 - target_food_loss: 0.0364 - target_healthcare_loss: 0.1331 - target_housing_loss: 0.1016 - target_othernecessities_loss: 0.0462 - target_taxes_loss: 0.0308 - target_transportation_loss: 0.2796 - val_loss: 0.7140 - val_target_childcare_loss: 0.0596 - val_target_food_loss: 0.0331 - val_target_healthcare_loss: 0.1282 - val_target_housing_loss: 0.1066 - val_target_othernecessities_loss: 0.0473 - val_target_taxes_loss: 0.0330 - val_target_transportation_loss: 0.3051
# Epoch 68/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6773 - target_childcare_loss: 0.0572 - target_food_loss: 0.0356 - target_healthcare_loss: 0.1277 - target_housing_loss: 0.1012 - target_othernecessities_loss: 0.0464 - target_taxes_loss: 0.0301 - target_transportation_loss: 0.2790 - val_loss: 0.7065 - val_target_childcare_loss: 0.0568 - val_target_food_loss: 0.0310 - val_target_healthcare_loss: 0.1273 - val_target_housing_loss: 0.1072 - val_target_othernecessities_loss: 0.0483 - val_target_taxes_loss: 0.0335 - val_target_transportation_loss: 0.3017
# Epoch 69/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6860 - target_childcare_loss: 0.0563 - target_food_loss: 0.0356 - target_healthcare_loss: 0.1300 - target_housing_loss: 0.1024 - target_othernecessities_loss: 0.0461 - target_taxes_loss: 0.0301 - target_transportation_loss: 0.2855 - val_loss: 0.6962 - val_target_childcare_loss: 0.0561 - val_target_food_loss: 0.0318 - val_target_healthcare_loss: 0.1246 - val_target_housing_loss: 0.1049 - val_target_othernecessities_loss: 0.0471 - val_target_taxes_loss: 0.0323 - val_target_transportation_loss: 0.3000
# Epoch 70/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6787 - target_childcare_loss: 0.0562 - target_food_loss: 0.0368 - target_healthcare_loss: 0.1273 - target_housing_loss: 0.1009 - target_othernecessities_loss: 0.0456 - target_taxes_loss: 0.0301 - target_transportation_loss: 0.2819 - val_loss: 0.7052 - val_target_childcare_loss: 0.0579 - val_target_food_loss: 0.0311 - val_target_healthcare_loss: 0.1257 - val_target_housing_loss: 0.1081 - val_target_othernecessities_loss: 0.0483 - val_target_taxes_loss: 0.0330 - val_target_transportation_loss: 0.3008
# Epoch 71/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.6811 - target_childcare_loss: 0.0579 - target_food_loss: 0.0358 - target_healthcare_loss: 0.1277 - target_housing_loss: 0.1024 - target_othernecessities_loss: 0.0461 - target_taxes_loss: 0.0313 - target_transportation_loss: 0.2799 - val_loss: 0.7022 - val_target_childcare_loss: 0.0587 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1237 - val_target_housing_loss: 0.1054 - val_target_othernecessities_loss: 0.0474 - val_target_taxes_loss: 0.0330 - val_target_transportation_loss: 0.3019
# Epoch 72/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6692 - target_childcare_loss: 0.0569 - target_food_loss: 0.0341 - target_healthcare_loss: 0.1270 - target_housing_loss: 0.1010 - target_othernecessities_loss: 0.0455 - target_taxes_loss: 0.0306 - target_transportation_loss: 0.2743 - val_loss: 0.6933 - val_target_childcare_loss: 0.0569 - val_target_food_loss: 0.0311 - val_target_healthcare_loss: 0.1247 - val_target_housing_loss: 0.1040 - val_target_othernecessities_loss: 0.0463 - val_target_taxes_loss: 0.0330 - val_target_transportation_loss: 0.2971
# Epoch 73/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6646 - target_childcare_loss: 0.0574 - target_food_loss: 0.0338 - target_healthcare_loss: 0.1278 - target_housing_loss: 0.0974 - target_othernecessities_loss: 0.0445 - target_taxes_loss: 0.0306 - target_transportation_loss: 0.2730 - val_loss: 0.6987 - val_target_childcare_loss: 0.0596 - val_target_food_loss: 0.0322 - val_target_healthcare_loss: 0.1279 - val_target_housing_loss: 0.1027 - val_target_othernecessities_loss: 0.0466 - val_target_taxes_loss: 0.0328 - val_target_transportation_loss: 0.2976
# Epoch 74/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6896 - target_childcare_loss: 0.0595 - target_food_loss: 0.0357 - target_healthcare_loss: 0.1300 - target_housing_loss: 0.0998 - target_othernecessities_loss: 0.0457 - target_taxes_loss: 0.0307 - target_transportation_loss: 0.2881 - val_loss: 0.6946 - val_target_childcare_loss: 0.0564 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1257 - val_target_housing_loss: 0.1033 - val_target_othernecessities_loss: 0.0467 - val_target_taxes_loss: 0.0328 - val_target_transportation_loss: 0.2979
# Epoch 75/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6654 - target_childcare_loss: 0.0570 - target_food_loss: 0.0329 - target_healthcare_loss: 0.1274 - target_housing_loss: 0.0992 - target_othernecessities_loss: 0.0449 - target_taxes_loss: 0.0300 - target_transportation_loss: 0.2740 - val_loss: 0.6976 - val_target_childcare_loss: 0.0575 - val_target_food_loss: 0.0320 - val_target_healthcare_loss: 0.1252 - val_target_housing_loss: 0.1038 - val_target_othernecessities_loss: 0.0461 - val_target_taxes_loss: 0.0317 - val_target_transportation_loss: 0.3023
# Epoch 76/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6736 - target_childcare_loss: 0.0570 - target_food_loss: 0.0342 - target_healthcare_loss: 0.1273 - target_housing_loss: 0.1017 - target_othernecessities_loss: 0.0466 - target_taxes_loss: 0.0310 - target_transportation_loss: 0.2758 - val_loss: 0.6930 - val_target_childcare_loss: 0.0558 - val_target_food_loss: 0.0312 - val_target_healthcare_loss: 0.1241 - val_target_housing_loss: 0.1031 - val_target_othernecessities_loss: 0.0464 - val_target_taxes_loss: 0.0324 - val_target_transportation_loss: 0.3011
# Epoch 77/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6801 - target_childcare_loss: 0.0569 - target_food_loss: 0.0356 - target_healthcare_loss: 0.1286 - target_housing_loss: 0.0995 - target_othernecessities_loss: 0.0456 - target_taxes_loss: 0.0311 - target_transportation_loss: 0.2828 - val_loss: 0.6927 - val_target_childcare_loss: 0.0559 - val_target_food_loss: 0.0314 - val_target_healthcare_loss: 0.1252 - val_target_housing_loss: 0.1028 - val_target_othernecessities_loss: 0.0456 - val_target_taxes_loss: 0.0318 - val_target_transportation_loss: 0.3002
# Epoch 78/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6595 - target_childcare_loss: 0.0557 - target_food_loss: 0.0370 - target_healthcare_loss: 0.1236 - target_housing_loss: 0.0992 - target_othernecessities_loss: 0.0443 - target_taxes_loss: 0.0304 - target_transportation_loss: 0.2694 - val_loss: 0.6961 - val_target_childcare_loss: 0.0573 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1241 - val_target_housing_loss: 0.1032 - val_target_othernecessities_loss: 0.0469 - val_target_taxes_loss: 0.0329 - val_target_transportation_loss: 0.2992
# Epoch 79/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6272 - target_childcare_loss: 0.0546 - target_food_loss: 0.0322 - target_healthcare_loss: 0.1121 - target_housing_loss: 0.0915 - target_othernecessities_loss: 0.0399 - target_taxes_loss: 0.0300 - target_transportation_loss: 0.2669 - val_loss: 0.6409 - val_target_childcare_loss: 0.0543 - val_target_food_loss: 0.0404 - val_target_healthcare_loss: 0.1188 - val_target_housing_loss: 0.0911 - val_target_othernecessities_loss: 0.0395 - val_target_taxes_loss: 0.0336 - val_target_transportation_loss: 0.2632
# Epoch 101/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6273 - target_childcare_loss: 0.0543 - target_food_loss: 0.0337 - target_healthcare_loss: 0.1106 - target_housing_loss: 0.0895 - target_othernecessities_loss: 0.0385 - target_taxes_loss: 0.0296 - target_transportation_loss: 0.2711 - val_loss: 0.6569 - val_target_childcare_loss: 0.0557 - val_target_food_loss: 0.0407 - val_target_healthcare_loss: 0.1271 - val_target_housing_loss: 0.0933 - val_target_othernecessities_loss: 0.0400 - val_target_taxes_loss: 0.0320 - val_target_transportation_loss: 0.2681
# Epoch 102/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6269 - target_childcare_loss: 0.0533 - target_food_loss: 0.0324 - target_healthcare_loss: 0.1112 - target_housing_loss: 0.0886 - target_othernecessities_loss: 0.0393 - target_taxes_loss: 0.0298 - target_transportation_loss: 0.2723 - val_loss: 0.6476 - val_target_childcare_loss: 0.0556 - val_target_food_loss: 0.0407 - val_target_healthcare_loss: 0.1175 - val_target_housing_loss: 0.0924 - val_target_othernecessities_loss: 0.0405 - val_target_taxes_loss: 0.0322 - val_target_transportation_loss: 0.2684
# Epoch 103/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6135 - target_childcare_loss: 0.0544 - target_food_loss: 0.0315 - target_healthcare_loss: 0.1094 - target_housing_loss: 0.0871 - target_othernecessities_loss: 0.0380 - target_taxes_loss: 0.0295 - target_transportation_loss: 0.2637 - val_loss: 0.6502 - val_target_childcare_loss: 0.0553 - val_target_food_loss: 0.0407 - val_target_healthcare_loss: 0.1190 - val_target_housing_loss: 0.0920 - val_target_othernecessities_loss: 0.0397 - val_target_taxes_loss: 0.0324 - val_target_transportation_loss: 0.2703
# Epoch 104/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6290 - target_childcare_loss: 0.0553 - target_food_loss: 0.0326 - target_healthcare_loss: 0.1120 - target_housing_loss: 0.0903 - target_othernecessities_loss: 0.0388 - target_taxes_loss: 0.0293 - target_transportation_loss: 0.2707 - val_loss: 0.6456 - val_target_childcare_loss: 0.0528 - val_target_food_loss: 0.0408 - val_target_healthcare_loss: 0.1173 - val_target_housing_loss: 0.0934 - val_target_othernecessities_loss: 0.0408 - val_target_taxes_loss: 0.0326 - val_target_transportation_loss: 0.2685
# Epoch 105/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.6189 - target_childcare_loss: 0.0541 - target_food_loss: 0.0304 - target_healthcare_loss: 0.1091 - target_housing_loss: 0.0880 - target_othernecessities_loss: 0.0391 - target_taxes_loss: 0.0300 - target_transportation_loss: 0.2681 - val_loss: 0.6387 - val_target_childcare_loss: 0.0531 - val_target_food_loss: 0.0399 - val_target_healthcare_loss: 0.1154 - val_target_housing_loss: 0.0934 - val_target_othernecessities_loss: 0.0402 - val_target_taxes_loss: 0.0329 - val_target_transportation_loss: 0.2641
# Epoch 106/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6254 - target_childcare_loss: 0.0553 - target_food_loss: 0.0318 - target_healthcare_loss: 0.1107 - target_housing_loss: 0.0878 - target_othernecessities_loss: 0.0383 - target_taxes_loss: 0.0290 - target_transportation_loss: 0.2725 - val_loss: 0.6414 - val_target_childcare_loss: 0.0527 - val_target_food_loss: 0.0408 - val_target_healthcare_loss: 0.1180 - val_target_housing_loss: 0.0929 - val_target_othernecessities_loss: 0.0406 - val_target_taxes_loss: 0.0332 - val_target_transportation_loss: 0.2635
# Epoch 113/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6133 - target_childcare_loss: 0.0531 - target_food_loss: 0.0304 - target_healthcare_loss: 0.1081 - target_housing_loss: 0.0862 - target_othernecessities_loss: 0.0373 - target_taxes_loss: 0.0289 - target_transportation_loss: 0.2693 - val_loss: 0.6439 - val_target_childcare_loss: 0.0536 - val_target_food_loss: 0.0399 - val_target_healthcare_loss: 0.1166 - val_target_housing_loss: 0.0943 - val_target_othernecessities_loss: 0.0412 - val_target_taxes_loss: 0.0322 - val_target_transportation_loss: 0.2666
# Epoch 114/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6224 - target_childcare_loss: 0.0546 - target_food_loss: 0.0326 - target_healthcare_loss: 0.1093 - target_housing_loss: 0.0898 - target_othernecessities_loss: 0.0395 - target_taxes_loss: 0.0294 - target_transportation_loss: 0.2671 - val_loss: 0.6448 - val_target_childcare_loss: 0.0575 - val_target_food_loss: 0.0409 - val_target_healthcare_loss: 0.1197 - val_target_housing_loss: 0.0912 - val_target_othernecessities_loss: 0.0398 - val_target_taxes_loss: 0.0319 - val_target_transportation_loss: 0.2636
# Epoch 115/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6129 - target_childcare_loss: 0.0553 - target_food_loss: 0.0327 - target_healthcare_loss: 0.1082 - target_housing_loss: 0.0875 - target_othernecessities_loss: 0.0386 - target_taxes_loss: 0.0286 - target_transportation_loss: 0.2620 - val_loss: 0.6444 - val_target_childcare_loss: 0.0526 - val_target_food_loss: 0.0411 - val_target_healthcare_loss: 0.1200 - val_target_housing_loss: 0.0931 - val_target_othernecessities_loss: 0.0398 - val_target_taxes_loss: 0.0346 - val_target_transportation_loss: 0.2643
# Epoch 116/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6078 - target_childcare_loss: 0.0532 - target_food_loss: 0.0330 - target_healthcare_loss: 0.1074 - target_housing_loss: 0.0850 - target_othernecessities_loss: 0.0370 - target_taxes_loss: 0.0284 - target_transportation_loss: 0.2638 - val_loss: 0.6458 - val_target_childcare_loss: 0.0545 - val_target_food_loss: 0.0407 - val_target_healthcare_loss: 0.1181 - val_target_housing_loss: 0.0934 - val_target_othernecessities_loss: 0.0402 - val_target_taxes_loss: 0.0329 - val_target_transportation_loss: 0.2661
# Epoch 117/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6055 - target_childcare_loss: 0.0528 - target_food_loss: 0.0322 - target_healthcare_loss: 0.1078 - target_housing_loss: 0.0844 - target_othernecessities_loss: 0.0370 - target_taxes_loss: 0.0284 - target_transportation_loss: 0.2629 - val_loss: 0.6446 - val_target_childcare_loss: 0.0545 - val_target_food_loss: 0.0402 - val_target_healthcare_loss: 0.1145 - val_target_housing_loss: 0.0927 - val_target_othernecessities_loss: 0.0395 - val_target_taxes_loss: 0.0326 - val_target_transportation_loss: 0.2711
# Epoch 118/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5964 - target_childcare_loss: 0.0527 - target_food_loss: 0.0311 - target_healthcare_loss: 0.1085 - target_housing_loss: 0.0846 - target_othernecessities_loss: 0.0366 - target_taxes_loss: 0.0299 - target_transportation_loss: 0.2529 - val_loss: 0.6420 - val_target_childcare_loss: 0.0530 - val_target_food_loss: 0.0401 - val_target_healthcare_loss: 0.1165 - val_target_housing_loss: 0.0911 - val_target_othernecessities_loss: 0.0395 - val_target_taxes_loss: 0.0320 - val_target_transportation_loss: 0.2696
# Epoch 118: early stopping
# Restoring model weights from the end of the best epoch: 108.
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model Results for Housing (Fold 5):
# Train Data: MAE: 77.966, R-Squared: 0.9153, RMSE: 112.6672, MSE: 12693.8985
# Validation Data: MAE: 80.4856, R-Squared: 0.8986, RMSE: 115.8288, MSE: 13416.3168
# Test Data: MAE: 81.2624, R-Squared: 0.9073, RMSE: 118.4733, MSE: 14035.9272
#
# Model Results for Food (Fold 5):
# Train Data: MAE: 41.7795, R-Squared: 0.968, RMSE: 61.0595, MSE: 3728.2621
# Validation Data: MAE: 44.6322, R-Squared: 0.9602, RMSE: 68.0471, MSE: 4630.4054
# Test Data: MAE: 42.7355, R-Squared: 0.9666, RMSE: 62.2488, MSE: 3874.9112
#
# Model Results for Transportation (Fold 5):
# Train Data: MAE: 91.9195, R-Squared: 0.7334, RMSE: 122.8861, MSE: 15101.0037
# Validation Data: MAE: 92.7243, R-Squared: 0.7229, RMSE: 122.9862, MSE: 15125.6062
# Test Data: MAE: 93.646, R-Squared: 0.7208, RMSE: 126.6253, MSE: 16033.9734
#
# Model Results for Healthcare (Fold 5):
# Train Data: MAE: 112.5638, R-Squared: 0.8922, RMSE: 161.4764, MSE: 26074.6241
# Validation Data: MAE: 117.3516, R-Squared: 0.8891, RMSE: 166.2394, MSE: 27635.5491
# Test Data: MAE: 114.7834, R-Squared: 0.8836, RMSE: 164.6313, MSE: 27103.4751
#
# Model Results for Othernecessities (Fold 5):
# Train Data: MAE: 31.3067, R-Squared: 0.9628, RMSE: 44.2191, MSE: 1955.3263
# Validation Data: MAE: 32.4231, R-Squared: 0.9577, RMSE: 45.4126, MSE: 2062.3018
# Test Data: MAE: 32.2685, R-Squared: 0.959, RMSE: 46.5265, MSE: 2164.7194
#
# Model Results for Childcare (Fold 5):
# Train Data: MAE: 95.3527, R-Squared: 0.9474, RMSE: 144.2917, MSE: 20820.0919
# Validation Data: MAE: 96.3912, R-Squared: 0.9428, RMSE: 144.2355, MSE: 20803.8734
# Test Data: MAE: 94.782, R-Squared: 0.9441, RMSE: 147.368, MSE: 21717.3336
#
# Model Results for Taxes (Fold 5):
# Train Data: MAE: 45.3088, R-Squared: 0.9716, RMSE: 69.2773, MSE: 4799.3493
# Validation Data: MAE: 47.5531, R-Squared: 0.9639, RMSE: 73.4311, MSE: 5392.123
# Test Data: MAE: 44.5068, R-Squared: 0.9724, RMSE: 68.5728, MSE: 4702.2221
#
# Final Average Metrics After 5 Folds:
# Results for Housing:
# Average Train Metrics: {'MAE': 78.15816000000001, 'R-Squared': 0.9139199999999998, 'RMSE': 112.97567999999998, 'MSE': 12768.783720000001}
# Average Validation Metrics: {'MAE': 81.08394000000001, 'R-Squared': 0.9029399999999999, 'RMSE': 117.77914000000001, 'MSE': 13874.907000000001}
# Average Test Metrics: {'MAE': 82.70444, 'R-Squared': 0.9039400000000001, 'RMSE': 121.06226000000001, 'MSE': 14663.011180000001}
#
# Results for Food:
# Average Train Metrics: {'MAE': 41.549980000000005, 'R-Squared': 0.9678000000000001, 'RMSE': 61.22850000000001, 'MSE': 3749.51314}
# Average Validation Metrics: {'MAE': 42.73298, 'R-Squared': 0.9659000000000001, 'RMSE': 63.11523999999999, 'MSE': 3998.28638}
# Average Test Metrics: {'MAE': 42.63808, 'R-Squared': 0.9650599999999999, 'RMSE': 63.522040000000004, 'MSE': 4040.47758}
#
# Results for Transportation:
# Average Train Metrics: {'MAE': 90.6867, 'R-Squared': 0.73736, 'RMSE': 121.81794, 'MSE': 14845.179999999998}
# Average Validation Metrics: {'MAE': 93.77646, 'R-Squared': 0.71694, 'RMSE': 126.60968, 'MSE': 16036.5433}
# Average Test Metrics: {'MAE': 94.89504000000001, 'R-Squared': 0.70896, 'RMSE': 128.05130000000003, 'MSE': 16399.24798}
#
# Results for Healthcare:
# Average Train Metrics: {'MAE': 111.08206, 'R-Squared': 0.8936999999999999, 'RMSE': 160.24888, 'MSE': 25697.67808}
# Average Validation Metrics: {'MAE': 115.351, 'R-Squared': 0.8850999999999999, 'RMSE': 167.66406, 'MSE': 28134.448320000003}
# Average Test Metrics: {'MAE': 116.44386000000002, 'R-Squared': 0.88072, 'RMSE': 168.53446000000002, 'MSE': 28425.756800000003}
#
# Results for Othernecessities:
# Average Train Metrics: {'MAE': 31.269980000000004, 'R-Squared': 0.96236, 'RMSE': 44.323840000000004, 'MSE': 1965.5164}
# Average Validation Metrics: {'MAE': 32.80722, 'R-Squared': 0.9575400000000001, 'RMSE': 46.85762, 'MSE': 2196.8421000000003}
# Average Test Metrics: {'MAE': 32.823620000000005, 'R-Squared': 0.9578199999999999, 'RMSE': 47.07876, 'MSE': 2216.82274}
#
# Results for Childcare:
# Average Train Metrics: {'MAE': 94.36962000000001, 'R-Squared': 0.9480999999999998, 'RMSE': 142.6367, 'MSE': 20353.58982}
# Average Validation Metrics: {'MAE': 97.74154000000001, 'R-Squared': 0.9430200000000001, 'RMSE': 148.63986, 'MSE': 22120.13324}
# Average Test Metrics: {'MAE': 97.983, 'R-Squared': 0.9439, 'RMSE': 148.84382, 'MSE': 22164.05248}
#
# Results for Taxes:
# Average Train Metrics: {'MAE': 44.12424, 'R-Squared': 0.9727599999999998, 'RMSE': 67.42284, 'MSE': 4549.59584}
# Average Validation Metrics: {'MAE': 46.2019, 'R-Squared': 0.96906, 'RMSE': 70.98184, 'MSE': 5041.383019999999}
# Average Test Metrics: {'MAE': 44.510419999999996, 'R-Squared': 0.9724400000000001, 'RMSE': 68.40648000000002, 'MSE': 4681.7405}
