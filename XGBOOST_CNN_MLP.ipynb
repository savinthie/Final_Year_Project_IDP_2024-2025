# %% [markdown]
# <a href="https://colab.research.google.com/github/savinthie/Final_Year_Project_IDP_2024-2025/blob/main/XGBOOST_CNN_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Flatten, Dense, ReLU, Concatenate, MaxPooling1D,Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/FYP 2024 25/USDataset.csv', header=1)
df = df.fillna(0)
# Out:
# Mounted at /content/drive

# %%
# Data Preprocessing
df.columns = [col.lower().replace(' ', '').replace('.', '') for col in df.columns]
cols_to_keep = ['stateabv', 'county', 'family', 'housing', 'food', 'transportation',
                'healthcare', 'othernecessities', 'childcare', 'taxes', 'total',
                'median_family_income', 'num_counties_in_st']
df1 = df[cols_to_keep].copy()

df1['median_family_income'] = df1['median_family_income'].replace(',', '', regex=True).astype(float)

# %%
# Feature Engineering
df1['n_parents'] = df1['family'].str.slice(0, 1).astype(int)
df1['n_children'] = df1['family'].str.slice(2, 3).astype(int)
df1['n_members'] = df1['n_parents'] + df1['n_children']
df1['financial_stability'] = df1['median_family_income'] / df1['total']
df1["per_member_cost"] = df1["total"] / df1["n_members"]
df1["child_expense_cost"] = df1["per_member_cost"]*df1["n_children"]
df1["parent_expense_cost"] = df1["per_member_cost"]*df1["n_parents"]
df1["other_expense_cost"] = df1["total"] - (df1["child_expense_cost"]+df1["parent_expense_cost"])

# %%
# Splitting the data
X = df1[['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']+['per_member_cost','child_expense_cost','parent_expense_cost','other_expense_cost']].values
y_expenses = df1[['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']].values

target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']

# Scaling
scaler_X = StandardScaler()

# Load the X scaler
# scaler_X = joblib.load('scaler_X.pkl')

X_scaled = scaler_X.fit_transform(X)

scaler_y = StandardScaler()

# Load the y scaler
# scaler_y = joblib.load('scaler_y.pkl')
y_exp_scaled = scaler_y.fit_transform(y_expenses)



# Save the X scaler
joblib.dump(scaler_X, 'scaler_X.pkl')

# Save the y scaler
joblib.dump(scaler_y, 'scaler_y.pkl')
# Out:
# ['scaler_y.pkl']

# %%
# Cross-Validation Setup
kf = KFold(n_splits=5, shuffle=True, random_state=100)

# Metrics
def print_metrics(y_true, y_pred, task_name):
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{task_name} - MSE: {mse:.4f}, R2: {r2:.4f}")

def regr_report(x, y):
    mae = round(mean_absolute_error(x, y), 4)
    r2 = round(r2_score(x, y), 4)
    mse = round(mean_squared_error(x, y), 4)
    rmse = round(np.sqrt(mean_squared_error(x, y)), 4)
    return f'MAE: {mae}, R-Squared: {r2}, RMSE: {rmse}, MSE: {mse}'

# %%
from tensorflow.keras.layers import Input, Conv1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

# L2 regularization strength (you can tune this value)
l2_strength = 0.01

# Hybrid Model Definition
def create_hybrid_model(input_shape, output_shape):
    input_layer = Input(shape=input_shape)
    # CNN part
    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu')(input_layer)
    x = Flatten()(x)
    # MLP part
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    # Multiple regression outputs
    output_layers = [Dense(1, activation='linear', name=f'target_{col}')(x) for col in target_col_list]

    model = Model(inputs=input_layer, outputs=output_layers)
    return model

# %%
import xgboost as xgb
def create_xgboost_model(X_train, y_train):
    # Reshape X_train to 2D for XGBoost
    X_train_2d = X_train.reshape(X_train.shape[0], -1)  # Reshape to 2D
    xg_reg = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1000, learning_rate=0.1)
    xg_reg.fit(X_train_2d, y_train) # Use reshaped data for fitting
    return xg_reg

# %%
import matplotlib.pyplot as plt

# Cross-Validation with Evaluation and Training/Validation Loss Curve
def cross_val_with_evaluation(X_scaled, y_exp_scaled, kf, num_epochs=400):
    fold = 1

    # To store metrics across all folds
    metrics_summary = {target: {'train': [], 'val': [], 'test': []} for target in target_col_list}

    # To store loss values for each fold
    all_train_loss = []
    all_val_loss = []

    for train_index, val_index in kf.split(X_scaled):
        print(f"Fold {fold}/{kf.get_n_splits()}")
        X_train, X_test_val = X_scaled[train_index], X_scaled[val_index]
        y_train, y_test_val = y_exp_scaled[train_index], y_exp_scaled[val_index]

        # 50/50 split of remaining 20% for test and validation sets
        X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5, random_state=100)

        # Reshaping data for CNN
        X_train = X_train[..., np.newaxis]
        X_val = X_val[..., np.newaxis]
        X_test = X_test[..., np.newaxis]

        # Early stopping to prevent overfitting
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=10,
            verbose=1,
            mode='min',
            restore_best_weights=True
        )

        # Create and compile the model
        model = create_hybrid_model((X_train.shape[1], 1), y_train.shape[1])
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

        # Training
        history = model.fit(
            X_train, [y_train[:, i] for i in range(y_train.shape[1])],
            validation_data=(X_val, [y_val[:, i] for i in range(y_val.shape[1])]),
            epochs=num_epochs,
            batch_size=128,
            verbose=1,
            callbacks=[early_stopping]
        )

        # Store loss values for the current fold
        all_train_loss.append(history.history['loss'])
        all_val_loss.append(history.history['val_loss'])

        # Predictions
        y_train_pred = np.column_stack(model.predict(X_train))
        y_val_pred = np.column_stack(model.predict(X_val))
        y_test_pred = np.column_stack(model.predict(X_test))  # Prediction on test set

        #Create XGBoost regressor
        xgboost_models = []
        for i in range(y_train.shape[1]):
            xg_model = create_xgboost_model(X_train, y_train[:, i])
            xgboost_models.append(xg_model)

        # Predictions from each XGBoost model
        y_train_xgb_pred = np.column_stack([model.predict(X_train.reshape(X_train.shape[0], -1)) for model in xgboost_models])
        y_val_xgb_pred = np.column_stack([model.predict(X_val.reshape(X_val.shape[0], -1)) for model in xgboost_models])
        y_test_xgb_pred = np.column_stack([model.predict(X_test.reshape(X_test.shape[0], -1)) for model in xgboost_models])


        # Inverse scaling
        y_train_pred_original = scaler_y.inverse_transform(y_train_pred)
        y_train_original = scaler_y.inverse_transform(y_train)
        y_val_pred_original = scaler_y.inverse_transform(y_val_pred)
        y_val_original = scaler_y.inverse_transform(y_val)
        y_test_pred_original = scaler_y.inverse_transform(y_test_pred)  # Inverse transform for test set
        y_test_original = scaler_y.inverse_transform(y_test)  # Inverse transform for test set

        # Metrics for each target and accumulate results
        for i, target in enumerate(target_col_list):
            print(f'Model Results for {target.capitalize()} (Fold {fold}):')
            train_metrics = regr_report(y_train_original[:, i], y_train_pred_original[:, i])
            val_metrics = regr_report(y_val_original[:, i], y_val_pred_original[:, i])
            test_metrics = regr_report(y_test_original[:, i], y_test_pred_original[:, i])

            # Store metrics for this fold
            metrics_summary[target]['train'].append(train_metrics)
            metrics_summary[target]['val'].append(val_metrics)
            metrics_summary[target]['test'].append(test_metrics)

            print('Train Data:', train_metrics)
            print('Validation Data:', val_metrics)
            print('Test Data:', test_metrics)
            print()

        fold += 1

    # Compute and display final average metrics across all folds
    print("Final Average Metrics After 5 Folds:")
    for target in target_col_list:
        print(f"Results for {target.capitalize()}:")

        # Modified to calculate average metrics from numerical values
        train_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['train']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_train_metrics = train_metrics_df.mean().to_dict()

        val_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['val']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_val_metrics = val_metrics_df.mean().to_dict()

        test_metrics_df = pd.DataFrame([eval(x.replace('MAE: ', '').replace('R-Squared: ', '').replace('RMSE: ', '').replace('MSE: ', '').replace(', ', ',')) for x in metrics_summary[target]['test']], columns=['MAE', 'R-Squared', 'RMSE', 'MSE'])
        avg_test_metrics = test_metrics_df.mean().to_dict()

        print("Average Train Metrics:", avg_train_metrics)
        print("Average Validation Metrics:", avg_val_metrics)
        print("Average Test Metrics:", avg_test_metrics)
        print()

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 6))
    for i, (train_loss, val_loss) in enumerate(zip(all_train_loss, all_val_loss)):
        plt.plot(val_loss, label=f'Fold {i + 1} Validation Loss')
        plt.plot(train_loss, label=f'Fold {i + 1} Train Loss')


    plt.title("Training and Validation Loss Across Folds")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# Cross-Validation Execution
model = cross_val_with_evaluation(X_scaled, y_exp_scaled, kf)
model.save_weights("model_expenses.weights.h5")
# Out:
# Fold 1/5
# Epoch 1/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 2.4308 - target_childcare_loss: 0.2806 - target_food_loss: 0.2716 - target_healthcare_loss: 0.3520 - target_housing_loss: 0.4322 - target_othernecessities_loss: 0.2688 - target_taxes_loss: 0.3259 - target_transportation_loss: 0.4998 - val_loss: 0.8829 - val_target_childcare_loss: 0.0824 - val_target_food_loss: 0.0357 - val_target_healthcare_loss: 0.1747 - val_target_housing_loss: 0.1346 - val_target_othernecessities_loss: 0.0591 - val_target_taxes_loss: 0.0458 - val_target_transportation_loss: 0.3490
# Epoch 2/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8758 - target_childcare_loss: 0.0849 - target_food_loss: 0.0424 - target_healthcare_loss: 0.1841 - target_housing_loss: 0.1377 - target_othernecessities_loss: 0.0591 - target_taxes_loss: 0.0439 - target_transportation_loss: 0.3237 - val_loss: 0.8591 - val_target_childcare_loss: 0.0802 - val_target_food_loss: 0.0345 - val_target_healthcare_loss: 0.1724 - val_target_housing_loss: 0.1261 - val_target_othernecessities_loss: 0.0561 - val_target_taxes_loss: 0.0430 - val_target_transportation_loss: 0.3451
# Epoch 3/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.
- target_food_loss: 0.0377 - target_healthcare_loss: 0.1674 - target_housing_loss: 0.1148 - target_othernecessities_loss: 0.0520 - target_taxes_loss: 0.0365 - target_transportation_loss: 0.3087 - val_loss: 0.8246 - val_target_childcare_loss: 0.0753 - val_target_food_loss: 0.0338 - val_target_healthcare_loss: 0.1609 - val_target_housing_loss: 0.1205 - val_target_othernecessities_loss: 0.0530 - val_target_taxes_loss: 0.0396 - val_target_transportation_loss: 0.3389
# Epoch 10/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7880 - target_childcare_loss: 0.0755 - target_food_loss: 0.0375 - target_healthcare_loss: 0.1648 - target_housing_loss: 0.1157 - target_othernecessities_loss: 0.0522 - target_taxes_loss: 0.0372 - target_transportation_loss: 0.3051 - val_loss: 0.8091 - val_target_childcare_loss: 0.0732 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1574 - val_target_housing_loss: 0.1153 - val_target_othernecessities_loss: 0.0519 - val_target_taxes_loss: 0.0389 - val_target_transportation_loss: 0.3378
# Epoch 11/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7903 - target_childcare_loss: 0.0747 - target_food_loss: 0.0371 - target_healthcare_loss: 0.1648 - target_housing_loss: 0.1149 - target_othernecessities_loss: 0.0518 - target_taxes_loss: 0.0366 - target_transportation_loss: 0.3104 - val_loss: 0.8119 - val_target_childcare_loss: 0.0734 - val_target_food_loss: 0.0352 - val_target_healthcare_loss: 0.1545 - val_target_housing_loss: 0.1172 - val_target_othernecessities_loss: 0.0550 - val_target_taxes_loss: 0.0382 - val_target_transportation_loss: 0.3370
# Epoch 12/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7837 - target_childcare_loss: 0.0749 - target_food_loss: 0.0377 - target_healthcare_loss: 0.1614 - target_housing_loss: 0.1153 - target_othernecessities_loss: 0.0513 - target_taxes_loss: 0.0367 - target_transportation_loss: 0.3063 - val_loss: 0.7990 - val_target_childcare_loss: 0.0715 - val_target_food_loss: 0.0326 - val_target_healthcare_loss: 0.1539 - val_target_housing_loss: 0.1157 - val_target_othernecessities_loss: 0.0529 - val_target_taxes_loss: 0.0388 - val_target_transportation_loss: 0.3320
# Epoch 13/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7705 - target_childcare_loss: 0.0732 - target_food_loss: 0.0359 - target_healthcare_loss: 0.1603 - target_housing_loss: 0.1112 - target_othernecessities_loss: 0.0503 - target_taxes_loss: 0.0366 - target_transportation_loss: 0.3030 - val_loss: 0.8040 - val_target_childcare_loss: 0.0706 - val_target_food_loss: 0.0326 - val_target_healthcare_loss: 0.1514 - val_target_housing_loss: 0.1182 - val_target_othernecessities_loss: 0.0537 - val_target_taxes_loss: 0.0398 - val_target_transportation_loss: 0.3356
# Epoch 14/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7757 - target_childcare_loss: 0.0731 - target_food_loss: 0.0380 - target_healthcare_loss: 0.1629 - target_housing_loss: 0.1109 - target_othernecessities_loss: 0.0502 - target_taxes_loss: 0.0365 - target_transportation_loss: 0.3040 - val_loss: 0.7938 - val_target_childcare_loss: 0.0693 - val_target_food_loss: 0.0329 - val_target_healthcare_loss: 0.1488 - val_target_housing_loss: 0.1156 - val_target_othernecessities_loss: 0.0532 - val_target_taxes_loss: 0.0380 - val_target_transportation_loss: 0.3338
# Epoch 15/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7606 - target_childcare_loss: 0.0718 - target_food_loss: 0.0360 - target_healthcare_loss: 0.1576 - target_housing_loss: 0.1084 - target_othernecessities_loss: 0.0494 - target_taxes_loss: 0.0356 - target_transportation_loss: 0.3017 - val_loss: 0.7845 - val_target_childcare_loss: 0.0701 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1473 - val_target_housing_loss: 0.1136 - val_target_othernecessities_loss: 0.0521 - val_target_taxes_loss: 0.0377 - val_target_transportation_loss: 0.3296
# Epoch 16/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.
- val_target_food_loss: 0.0322 - val_target_healthcare_loss: 0.1409 - val_target_housing_loss: 0.1137 - val_target_othernecessities_loss: 0.0511 - val_target_taxes_loss: 0.0373 - val_target_transportation_loss: 0.3237
# Epoch 23/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7535 - target_childcare_loss: 0.0699 - target_food_loss: 0.0375 - target_healthcare_loss: 0.1509 - target_housing_loss: 0.1101 - target_othernecessities_loss: 0.0502 - target_taxes_loss: 0.0360 - target_transportation_loss: 0.2988 - val_loss: 0.7678 - val_target_childcare_loss: 0.0647 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1412 - val_target_housing_loss: 0.1144 - val_target_othernecessities_loss: 0.0517 - val_target_taxes_loss: 0.0378 - val_target_transportation_loss: 0.3243
# Epoch 24/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7362 - target_childcare_loss: 0.0667 - target_food_loss: 0.0394 - target_healthcare_loss: 0.1484 - target_housing_loss: 0.1053 - target_othernecessities_loss: 0.0476 - target_taxes_loss: 0.0352 - target_transportation_loss: 0.2936 - val_loss: 0.7583 - val_target_childcare_loss: 0.0644 - val_target_food_loss: 0.0326 - val_target_healthcare_loss: 0.1379 - val_target_housing_loss: 0.1108 - val_target_othernecessities_loss: 0.0505 - val_target_taxes_loss: 0.0376 - val_target_transportation_loss: 0.3230
# Epoch 25/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7318 - target_childcare_loss: 0.0666 - target_food_loss: 0.0357 - target_healthcare_loss: 0.1484 - target_housing_loss: 0.1075 - target_othernecessities_loss: 0.0491 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.2899 - val_loss: 0.7598 - val_target_childcare_loss: 0.0649 - val_target_food_loss: 0.0327 - val_target_healthcare_loss: 0.1409 - val_target_housing_loss: 0.1119 - val_target_othernecessities_loss: 0.0510 - val_target_taxes_loss: 0.0369 - val_target_transportation_loss: 0.3201
# Epoch 26/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7457 - target_childcare_loss: 0.0670 - target_food_loss: 0.0379 - target_healthcare_loss: 0.1474 - target_housing_loss: 0.1087 - target_othernecessities_loss: 0.0488 - target_taxes_loss: 0.0346 - target_transportation_loss: 0.3014 - val_loss: 0.7567 - val_target_childcare_loss: 0.0646 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1413 - val_target_housing_loss: 0.1107 - val_target_othernecessities_loss: 0.0507 - val_target_taxes_loss: 0.0363 - val_target_transportation_loss: 0.3191
# Epoch 27/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7380 - target_childcare_loss: 0.0653 - target_food_loss: 0.0368 - target_healthcare_loss: 0.1472 - target_housing_loss: 0.1085 - target_othernecessities_loss: 0.0491 - target_taxes_loss: 0.0351 - target_transportation_loss: 0.2960 - val_loss: 0.7505 - val_target_childcare_loss: 0.0648 - val_target_food_loss: 0.0319 - val_target_healthcare_loss: 0.1364 - val_target_housing_loss: 0.1092 - val_target_othernecessities_loss: 0.0500 - val_target_taxes_loss: 0.0364 - val_target_transportation_loss: 0.3199
# Epoch 28/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7427 - target_childcare_loss: 0.0660 - target_food_loss: 0.0373 - target_healthcare_loss: 0.1493 - target_housing_loss: 0.1093 - target_othernecessities_loss: 0.0498 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.2965 - val_loss: 0.7581 - val_target_childcare_loss: 0.0647 - val_target_food_loss: 0.0317 - val_target_healthcare_loss: 0.1401 - val_target_housing_loss: 0.1120 - val_target_othernecessities_loss: 0.0507 - val_target_taxes_loss: 0.0364 - val_target_transportation_loss: 0.3206
# Epoch 29/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7380 - target_childcare_loss: 0.0647 - target_food_loss: 0.0369 - target_healthcare_loss: 0.1468 - target_housing_loss: 0.1069 - target_othernecessities_loss: 0.0482 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.3000 - val_loss: 0.7483 - val_target_childcare_loss: 0.0633 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1377 - val_target_housing_loss: 0.1107 - val_target_othernecessities_loss: 0.0499 - val_target_taxes_loss: 0.0371 - val_target_transportation_loss: 0.3158
# Epoch 30/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7216 - target_childcare_loss: 0.0649 - target_food_loss: 0.0344 - target_healthcare_loss: 0.1417 - target_housing_loss: 0.1067 - target_othernecessities_loss: 0.0479 - target_taxes_loss: 0.0342 - target_transportation_loss: 0.2918 - val_loss: 0.7459 - val_target_childcare_loss: 0.0639 - val_target_food_loss: 0.0323 - val_target_healthcare_loss: 0.1338 - val_target_housing_loss: 0.1098 - val_target_othernecessities_loss: 0.0501 - val_target_taxes_loss: 0.0380 - val_target_transportation_loss: 0.3164
# Epoch 31/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.7299 - target_childcare_loss: 0.0654 - target_food_loss: 0.0364 - target_healthcare_loss: 0.1430 - target_housing_loss: 0.1082 - target_othernecessities_loss: 0.0491 - target_taxes_loss: 0.0347 - target_transportation_loss: 0.2931 - val_loss: 0.7473 - val_target_childcare_loss: 0.0634 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1369 - val_target_housing_loss: 0.1109 - val_target_othernecessities_loss: 0.0505 - val_target_taxes_loss: 0.0361 - val_target_transportation_loss: 0.3157
# Epoch 32/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7342 - target_childcare_loss: 0.0640 - target_food_loss: 0.0363 - target_healthcare_loss: 0.1447 - target_housing_loss: 0.1057 - target_othernecessities_loss: 0.0492 - target_taxes_loss: 0.0331 - target_transportation_loss: 0.3011 - val_loss: 0.7352 - val_target_childcare_loss: 0.0619 - val_target_food_loss: 0.0315 - val_target_healthcare_loss: 0.1329 - val_target_housing_loss: 0.1086 - val_target_othernecessities_loss: 0.0497 - val_target_taxes_loss: 0.0358 - val_target_transportation_loss: 0.3135
# Epoch 33/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7379 - target_childcare_loss: 0.0644 - target_food_loss: 0.0396 - target_healthcare_loss: 0.1452 - target_housing_loss: 0.1090 - target_othernecessities_loss: 0.0497 - target_taxes_loss: 0.0340 - target_transportation_loss: 0.2960 - val_loss: 0.7444 - val_target_childcare_loss: 0.0670 - val_target_food_loss: 0.0318 - val_target_healthcare_loss: 0.1379 - val_target_housing_loss: 0.1069 - val_target_othernecessities_loss: 0.0487 - val_target_taxes_loss: 0.0365 - val_target_transportation_loss: 0.3139
# Epoch 34/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7198 - target_childcare_loss: 0.0632 - target_food_loss: 0.0364 - target_healthcare_loss: 0.1406 - target_housing_loss: 0.1046 - target_othernecessities_loss: 0.0473 - target_taxes_loss: 0.0338 - target_transportation_loss: 0.2939 - val_loss: 0.7444 - val_target_childcare_loss: 0.0620 - val_target_food_loss: 0.0320 - val_target_healthcare_loss: 0.1342 - val_target_housing_loss: 0.1101 - val_target_othernecessities_loss: 0.0503 - val_target_taxes_loss: 0.0362 - val_target_transportation_loss: 0.3183
# Epoch 35/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7211 - target_childcare_loss: 0.0625 - target_food_loss: 0.0355 - target_healthcare_loss: 0.1420 - target_housing_loss: 0.1055 - target_othernecessities_loss: 0.0486 - target_taxes_loss: 0.0342 - target_transportation_loss: 0.2928 - val_loss: 0.7356 - val_target_childcare_loss: 0.0620 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1322 - val_target_housing_loss: 0.1096 - val_target_othernecessities_loss: 0.0494 - val_target_taxes_loss: 0.0349 - val_target_transportation_loss: 0.3138
# Epoch 36/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7284 - target_childcare_loss: 0.0651 - target_food_loss: 0.0373 - target_healthcare_loss: 0.1409 - target_housing_loss: 0.1065 - target_othernecessities_loss: 0.0491 - target_taxes_loss: 0.0345 - target_transportation_loss: 0.2951 - val_loss: 0.7412 - val_target_childcare_loss: 0.0627 - val_target_food_loss: 0.0323 - val_target_healthcare_loss: 0.1314 - val_target_housing_loss: 0.1092 - val_target_othernecessities_loss: 0.0499 - val_target_taxes_loss: 0.0348 - val_target_transportation_loss: 0.3194
# Epoch 37/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7051 - target_childcare_loss: 0.0628 - target_food_loss: 0.0346 - target_healthcare_loss: 0.1371 - target_housing_loss: 0.1046 - target_othernecessities_loss: 0.0475 - target_taxes_loss: 0.0331 - target_transportation_loss: 0.2854 - val_loss: 0.7320 - val_target_childcare_loss: 0.0615 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1306 - val_target_housing_loss: 0.1073 - val_target_othernecessities_loss: 0.0488 - val_target_taxes_loss: 0.0345 - val_target_transportation_loss: 0.3154
# Epoch 38/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7116 - target_childcare_loss: 0.0614 - target_food_loss: 0.0361 - target_healthcare_loss: 0.1373 - target_housing_loss: 0.1039 - target_othernecessities_loss: 0.0471 - target_taxes_loss: 0.0325 - target_transportation_loss: 0.2933 - val_loss: 0.7486 - val_target_childcare_loss: 0.0663 - val_target_food_loss: 0.0320 - val_target_healthcare_loss: 0.1378 - val_target_housing_loss: 0.1101 - val_target_othernecessities_loss: 0.0504 - val_target_taxes_loss: 0.0347 - val_target_transportation_loss: 0.3159
# Epoch 39/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7166 - target_childcare_loss: 0.0621 - target_food_loss: 0.0353 - target_healthcare_loss: 0.1393 - target_housing_loss: 0.1039 - target_othernecessities_loss: 0.0476 - target_taxes_loss: 0.0331 - target_transportation_loss: 0.2952 - val_loss: 0.7341 - val_target_childcare_loss: 0.0612 - val_target_food_loss: 0.0327 - val_target_healthcare_loss: 0.1320 - val_target_housing_loss: 0.1081 - val_target_othernecessities_loss: 0.0492 - val_target_taxes_loss: 0.0351 - val_target_transportation_loss: 0.3144
# Epoch 40/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.7226 - target_childcare_loss: 0.0626 - target_food_loss: 0.0381 - target_healthcare_loss: 0.1376 - target_housing_loss: 0.1043 - target_othernecessities_loss: 0.0470 - target_taxes_loss: 0.0332 - target_transportation_loss: 0.2997 - val_loss: 0.7275 - val_target_childcare_loss: 0.0604 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1306 - val_target_housing_loss: 0.1075 - val_target_othernecessities_loss: 0.0493 - val_target_taxes_loss: 0.0345 - val_target_transportation_loss: 0.3119
# Epoch 41/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7100 - target_childcare_loss: 0.0604 - target_food_loss: 0.0372 - target_healthcare_loss: 0.1362 - target_housing_loss: 0.1037 - target_othernecessities_loss: 0.0471 - target_taxes_loss: 0.0329 - target_transportation_loss: 0.2924 - val_loss: 0.7282 - val_target_childcare_loss: 0.0607 - val_target_food_loss: 0.0318 - val_target_healthcare_loss: 0.1328 - val_target_housing_loss: 0.1067 - val_target_othernecessities_loss: 0.0483 - val_target_taxes_loss: 0.0347 - val_target_transportation_loss: 0.3116
# Epoch 42/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.7169 - target_childcare_loss: 0.0618 - target_food_loss: 0.0378 - target_healthcare_loss: 0.1366 - target_housing_loss: 0.1071 - target_othernecessities_loss: 0.0482 - target_taxes_loss: 0.0321 - target_transportation_loss: 0.2935 - val_loss: 0.7228 - val_target_childcare_loss: 0.0605 - val_target_food_loss: 0.0324 - val_target_healthcare_loss: 0.1300 - val_target_housing_loss: 0.1068 - val_target_othernecessities_loss: 0.0484 - val_target_taxes_loss: 0.0342 - val_target_transportation_loss: 0.3096
# Epoch 43/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.7156 - target_childcare_loss: 0.0629 - target_food_loss: 0.0364 - target_healthcare_loss: 0.1371 - target_housing_loss: 0.1080 - target_othernecessities_loss: 0.0487 - target_taxes_loss: 0.0325 - target_transportation_loss: 0.2901 - val_loss: 0.7240 - val_target_childcare_loss: 0.0592 - val_target_food_loss: 0.0328 - val_target_healthcare_loss: 0.1312 - val_target_housing_loss: 0.1064 - val_target_othernecessities_loss: 0.0483 - val_target_taxes_loss: 0.0341 - val_target_transportation_loss: 0.3106
# Epoch 44/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7131 - target_childcare_loss: 0.0617 - target_food_loss: 0.0354 - target_healthcare_loss: 0.1337 - target_housing_loss: 0.1043 - target_othernecessities_loss: 0.0470 - target_taxes_loss: 0.0327 - target_transportation_loss: 0.2984 - val_loss: 0.7306 - val_target_childcare_loss: 0.0620 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1285 - val_target_housing_loss: 0.1085 - val_target_othernecessities_loss: 0.0490 - val_target_taxes_loss: 0.0341 - val_target_transportation_loss: 0.3148
# Epoch 45/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7173 - target_childcare_loss: 0.0624 - target_food_loss: 0.0373 - target_healthcare_loss: 0.1339 - target_housing_loss: 0.1038 - target_othernecessities_loss: 0.0470 - target_taxes_loss: 0.0321 - target_transportation_loss: 0.3008 - val_loss: 0.7193 - val_target_childcare_loss: 0.0624 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1278 - val_target_housing_loss: 0.1060 - val_target_othernecessities_loss: 0.0477 - val_target_taxes_loss: 0.0335 - val_target_transportation_loss: 0.3085
# Epoch 46/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7059 - target_childcare_loss: 0.0619 - target_food_loss: 0.0378 - target_healthcare_loss: 0.1339 - target_housing_loss: 0.1039 - target_othernecessities_loss: 0.0467 - target_taxes_loss: 0.0311 - target_transportation_loss: 0.2906 - val_loss: 0.7179 - val_target_childcare_loss: 0.0599 - val_target_food_loss: 0.0321 - val_target_healthcare_loss: 0.1280 - val_target_housing_loss: 0.1067 - val_target_othernecessities_loss: 0.0488 - val_target_taxes_loss: 0.0333 - val_target_transportation_loss: 0.3082
# Epoch 47/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6987 - target_childcare_loss: 0.0589 - target_food_loss: 0.0355 - target_healthcare_loss: 0.1341 - target_housing_loss: 0.1014 - target_othernecessities_loss: 0.0457 - target_taxes_loss: 0.0323 - target_transportation_loss: 0.2908 - val_loss: 0.7178 - val_target_childcare_loss: 0.0604 - val_target_food_loss: 0.0318 - val_target_healthcare_loss: 0.1271 - val_target_housing_loss: 0.1059 - val_target_othernecessities_loss: 0.0485 - val_target_taxes_loss: 0.0340 - val_target_transportation_loss: 0.3091
# Epoch 48/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6994 - target_childcare_loss: 0.0611 - target_food_loss: 0.0353 - target_healthcare_loss: 0.1338 - target_housing_loss: 0.1025 - target_othernecessities_loss: 0.0469 - target_taxes_loss: 0.0319 - target_transportation_loss: 0.2879 - val_loss: 0.7187 - val_target_childcare_loss: 0.0599 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1264 - val_target_housing_loss: 0.1058 - val_target_othernecessities_loss: 0.0480 - val_target_taxes_loss: 0.0338 - val_target_transportation_loss: 0.3116
# Epoch 49/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7053 - target_childcare_loss: 0.0609 - target_food_loss: 0.0352 - target_healthcare_loss: 0.1328 - target_housing_loss: 0.1035 - target_othernecessities_loss: 0.0478 - target_taxes_loss: 0.0331 - target_transportation_loss: 0.2920 - val_loss: 0.7155 - val_target_childcare_loss: 0.0605 - val_target_food_loss: 0.0319 - val_target_healthcare_loss: 0.1240 - val_target_housing_loss: 0.1061 - val_target_othernecessities_loss: 0.0476 - val_target_taxes_loss: 0.0335 - val_target_transportation_loss: 0.3114
# Epoch 50/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6892 - target_childcare_loss: 0.0594 - target_food_loss: 0.0354 - target_healthcare_loss: 0.1305 - target_housing_loss: 0.1007 - target_othernecessities_loss: 0.0464 - target_taxes_loss: 0.0317 - target_transportation_loss: 0.2851 - val_loss: 0.7176 - val_target_childcare_loss: 0.0606 - val_target_food_loss: 0.0320 - val_target_healthcare_loss: 0.1253 - val_target_housing_loss: 0.1068 - val_target_othernecessities_loss: 0.0478 - val_target_taxes_loss: 0.0337 - val_target_transportation_loss: 0.3115
# Epoch 51/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.7018 - target_childcare_loss: 0.0611 - target_food_loss: 0.0344 - target_healthcare_loss: 0.1305 - target_housing_loss: 0.1032 - target_othernecessities_loss: 0.0470 - target_taxes_loss: 0.0313 - target_transportation_loss: 0.2944 - val_loss: 0.7143 - val_target_childcare_loss: 0.0602 - val_target_food_loss: 0.0316 - val_target_healthcare_loss: 0.1251 - val_target_housing_loss: 0.1063 - val_target_othernecessities_loss: 0.0476 - val_target_taxes_loss: 0.0335 - val_target_transportation_loss: 0.3090
# Epoch 52/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6963 - target_childcare_loss: 0.0599 - target_food_loss: 0.0369 - target_healthcare_loss: 0.1258 - target_housing_loss: 0.1023 - target_othernecessities_loss: 0.0463 - target_taxes_loss: 0.0317 - target_transportation_loss: 0.2934 - val_loss: 0.7154 - val_target_childcare_loss: 0.0596 - val_target_food_loss: 0.0317 - val_target_healthcare_loss: 0.1261 - val_target_housing_loss: 0.1065 - val_target_othernecessities_loss: 0.0473 - val_target_taxes_loss: 0.0327 - val_target_transportation_loss: 0.3111
# Epoch 53/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6855 - target_childcare_loss: 0.0600 - target_food_loss: 0.0364 - target_healthcare_loss: 0.1298 - target_housing_loss: 0.1001 - target_othernecessities_loss: 0.0457 - target_taxes_loss: 0.0306 - target_transportation_loss: 0.2828 - val_loss: 0.7221 - val_target_childcare_loss: 0.0648 - val_target_food_loss: 0.0326 - val_target_healthcare_loss: 0.1268 - val_target_housing_loss: 0.1065 - val_target_othernecessities_loss: 0.0495 - val_target_taxes_loss: 0.0342 - val_target_transportation_loss: 0.3066
# Epoch 54/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6841 - target_childcare_loss: 0.0606 - target_food_loss: 0.0347 - target_healthcare_loss: 0.1279 - target_housing_loss: 0.0998 - target_othernecessities_loss: 0.0453 - target_taxes_loss: 0.0305 - target_transportation_loss: 0.2854 - val_loss: 0.7125 - val_target_childcare_loss: 0.0616 - val_target_food_loss: 0.0330 - val_target_healthcare_loss: 0.1242 - val_target_housing_loss: 0.1025 - val_target_othernecessities_loss: 0.0467 - val_target_taxes_loss: 0.0339 - val_target_transportation_loss: 0.3095
# Epoch 55/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6871 - target_childcare_loss: 0.0589 - target_food_loss: 0.0353 - target_healthcare_loss: 0.1277 - target_housing_loss: 0.1011 - target_othernecessities_loss: 0.0454 - target_taxes_loss: 0.0316 - target_transportation_loss: 0.2872 - val_loss: 0.7089 - val_target_childcare_loss: 0.0611 - val_target_food_loss: 0.0315 - val_target_healthcare_loss: 0.1233 - val_target_housing_loss: 0.1050 - val_target_othernecessities_loss: 0.0471 - val_target_taxes_loss: 0.0321 - val_target_transportation_loss: 0.3088
# Epoch 56/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6795 - target_childcare_loss: 0.0587 - target_food_loss: 0.0350 - target_healthcare_loss: 0.1282 - target_housing_loss: 0.0994 - target_othernecessities_loss: 0.0456 - target_taxes_loss: 0.0314 - target_transportation_loss: 0.2813 - val_loss: 0.7098 - val_target_childcare_loss: 0.0620 - val_target_food_loss: 0.0323 - val_target_healthcare_loss: 0.1251 - val_target_housing_loss: 0.1033 - val_target_othernecessities_loss: 0.0473 - val_target_taxes_loss: 0.0329 - val_target_transportation_loss: 0.3064
# Epoch 57/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6718 - target_childcare_loss: 0.0604 - target_food_loss: 0.0360 - target_healthcare_loss: 0.1297 - target_housing_loss: 0.0962 - target_othernecessities_loss: 0.0440 - target_taxes_loss: 0.0313 - target_transportation_loss: 0.2743 - val_loss: 0.7048 - val_target_childcare_loss: 0.0596 - val_target_food_loss: 0.0317 - val_target_healthcare_loss: 0.1225 - val_target_housing_loss: 0.1024 - val_target_othernecessities_loss: 0.0468 - val_target_taxes_loss: 0.0329 - val_target_transportation_loss: 0.3081
# Epoch 58/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6762 - target_childcare_loss: 0.0577 - target_food_loss: 0.0337 - target_healthcare_loss: 0.1264 - target_housing_loss: 0.0973 - target_othernecessities_loss: 0.0440 - target_taxes_loss: 0.0308 - target_transportation_loss: 0.2864 - val_loss: 0.7023 - val_target_childcare_loss: 0.0596 - val_target_food_loss: 0.0313 - val_target_healthcare_loss: 0.1213 - val_target_housing_loss: 0.1018 - val_target_othernecessities_loss: 0.0465 - val_target_taxes_loss: 0.0331 - val_target_transportation_loss: 0.3077
# Epoch 59/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6770 - target_childcare_loss: 0.0592 - target_food_loss: 0.0358 - target_healthcare_loss: 0.1268 - target_housing_loss: 0.0993 - target_othernecessities_loss: 0.0452 - target_taxes_loss: 0.0312 - target_transportation_loss: 0.2795 - val_loss: 0.7085 - val_target_childcare_loss: 0.0597 - val_target_food_loss: 0.0317 - val_target_healthcare_loss: 0.1234 - val_target_housing_loss: 0.1024 - val_target_othernecessities_loss: 0.0465 - val_target_taxes_loss: 0.0327 - val_target_transportation_loss: 0.3121
# Epoch 60/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6838 - target_childcare_loss: 0.0586 - target_food_loss: 0.0356 - target_healthcare_loss: 0.1273 - target_housing_loss: 0.0997 - target_othernecessities_loss: 0.0451 - target_taxes_loss: 0.0311 - target_transportation_loss: 0.2863 - val_loss: 0.7056 - val_target_childcare_loss: 0.0586 - val_target_food_loss: 0.0311 - val_target_healthcare_loss: 0.1198 - val_target_housing_loss: 0.1051 - val_target_othernecessities_loss: 0.0480 - val_target_taxes_loss: 0.0320 - val_target_transportation_loss: 0.3109
# Epoch 61/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6803 - target_childcare_loss: 0.0583 - target_food_loss: 0.0341 - target_healthcare_loss: 0.1261 - target_housing_loss: 0.1002 - target_othernecessities_loss: 0.0451 - target_taxes_loss: 0.0310 - target_transportation_loss: 0.2854 - val_loss: 0.7009 - val_target_childcare_loss: 0.0585 - val_target_food_loss: 0.0310 - val_target_healthcare_loss: 0.1220 - val_target_housing_loss: 0.1031 - val_target_othernecessities_loss: 0.0461 - val_target_taxes_loss: 0.0333 - val_target_transportation_loss: 0.3072
# Epoch 62/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6740 - target_childcare_loss: 0.0594 - target_food_loss: 0.0348 - target_healthcare_loss: 0.1226 - target_housing_loss: 0.0993 - target_othernecessities_loss: 0.0447 - target_taxes_loss: 0.0313 - target_transportation_loss: 0.2818 - val_loss: 0.6901 - val_target_childcare_loss: 0.0588 - val_target_food_loss: 0.0310 - val_target_healthcare_loss: 0.1186 - val_target_housing_loss: 0.1005 - val_target_othernecessities_loss: 0.0454 - val_target_taxes_loss: 0.0318 - val_target_transportation_loss: 0.3043
# Epoch 63/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6762 - target_childcare_loss: 0.0581 - target_food_loss: 0.0360 - target_healthcare_loss: 0.1231 - target_housing_loss: 0.0990 - target_othernecessities_loss: 0.0442 - target_taxes_loss: 0.0308 - target_transportation_loss: 0.2849 - val_loss: 0.7023 - val_target_childcare_loss: 0.0600 - val_target_food_loss: 0.0316 - val_target_healthcare_loss: 0.1225 - val_target_housing_loss: 0.1019 - val_target_othernecessities_loss: 0.0456 - val_target_taxes_loss: 0.0329 - val_target_transportation_loss: 0.3073
# Epoch 64/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6788 - target_childcare_loss: 0.0579 - target_food_loss: 0.0345 - target_healthcare_loss: 0.1253 - target_housing_loss: 0.0992 - target_othernecessities_loss: 0.0443 - target_taxes_loss: 0.0305 - target_transportation_loss: 0.2872 - val_loss: 0.6882 - val_target_childcare_loss: 0.0582 - val_target_food_loss: 0.0314 - val_target_healthcare_loss: 0.1181 - val_target_housing_loss: 0.0998 - val_target_othernecessities_loss: 0.0453 - val_target_taxes_loss: 0.0315 - val_target_transportation_loss: 0.3045
# Epoch 65/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6825 - target_childcare_loss: 0.0573 - target_food_loss: 0.0353 - target_healthcare_loss: 0.1234 - target_housing_loss: 0.0992 - target_othernecessities_loss: 0.0443 - target_taxes_loss: 0.0315 - target_transportation_loss: 0.2914 - val_loss: 0.6854 - val_target_childcare_loss: 0.0578 - val_target_food_loss: 0.0319 - val_target_healthcare_loss: 0.1158 - val_target_housing_loss: 0.0991 - val_target_othernecessities_loss: 0.0450 - val_target_taxes_loss: 0.0315 - val_target_transportation_loss: 0.3043
# Epoch 66/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6799 - target_childcare_loss: 0.0606 - target_food_loss: 0.0355 - target_healthcare_loss: 0.1243 - target_housing_loss: 0.0990 - target_othernecessities_loss: 0.0440 - target_taxes_loss: 0.0302 - target_transportation_loss: 0.2862 - val_loss: 0.6974 - val_target_childcare_loss: 0.0604 - val_target_food_loss: 0.0309 - val_target_healthcare_loss: 0.1210 - val_target_housing_loss: 0.1017 - val_target_othernecessities_loss: 0.0460 - val_target_taxes_loss: 0.0310 - val_target_transportation_loss: 0.3067
# Epoch 67/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6692 - target_childcare_loss: 0.0589 - target_food_loss: 0.0345 - target_healthcare_loss: 0.1226 - target_housing_loss: 0.0956 - target_othernecessities_loss: 0.0435 - target_taxes_loss: 0.0301 - target_transportation_loss: 0.2841 - val_loss: 0.6956 - val_target_childcare_loss: 0.0616 - val_target_food_loss: 0.0322 - val_target_healthcare_loss: 0.
- val_target_food_loss: 0.0312 - val_target_healthcare_loss: 0.1141 - val_target_housing_loss: 0.0976 - val_target_othernecessities_loss: 0.0438 - val_target_taxes_loss: 0.0313 - val_target_transportation_loss: 0.2992
# Epoch 75/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6471 - target_childcare_loss: 0.0573 - target_food_loss: 0.0338 - target_healthcare_loss: 0.1159 - target_housing_loss: 0.0954 - target_othernecessities_loss: 0.0418 - target_taxes_loss: 0.0291 - target_transportation_loss: 0.2738 - val_loss: 0.6787 - val_target_childcare_loss: 0.0584 - val_target_food_loss: 0.0316 - val_target_healthcare_loss: 0.1128 - val_target_housing_loss: 0.0968 - val_target_othernecessities_loss: 0.0440 - val_target_taxes_loss: 0.0313 - val_target_transportation_loss: 0.3037
# Epoch 76/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6489 - target_childcare_loss: 0.0572 - target_food_loss: 0.0337 - target_healthcare_loss: 0.1167 - target_housing_loss: 0.0940 - target_othernecessities_loss: 0.0421 - target_taxes_loss: 0.0287 - target_transportation_loss: 0.2766 - val_loss: 0.6761 - val_target_childcare_loss: 0.0586 - val_target_food_loss: 0.0314 - val_target_healthcare_loss: 0.1160 - val_target_housing_loss: 0.0975 - val_target_othernecessities_loss: 0.0442 - val_target_taxes_loss: 0.0319 - val_target_transportation_loss: 0.2964
# Epoch 77/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6543 - target_childcare_loss: 0.0583 - target_food_loss: 0.0348 - target_healthcare_loss: 0.1199 - target_housing_loss: 0.0950 - target_othernecessities_loss: 0.0423 - target_taxes_loss: 0.0303 - target_transportation_loss: 0.2736 - val_loss: 0.6690 - val_target_childcare_loss: 0.0579 - val_target_food_loss: 0.0312 - val_target_healthcare_loss: 0.1122 - val_target_housing_loss: 0.0975 - val_target_othernecessities_loss: 0.0431 - val_target_taxes_loss: 0.0325 - val_target_transportation_loss: 0.2949
# Epoch 78/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6476 - target_childcare_loss: 0.0574 - target_food_loss: 0.0362 - target_healthcare_loss: 0.1175 - target_housing_loss: 0.0939 - target_othernecessities_loss: 0.0418 - target_taxes_loss: 0.0288 - target_transportation_loss: 0.2719 - val_loss: 0.6693 - val_target_childcare_loss: 0.0575 - val_target_food_loss: 0.0311 - val_target_healthcare_loss: 0.1120 - val_target_housing_loss: 0.0960 - val_target_othernecessities_loss: 0.0429 - val_target_taxes_loss: 0.0314 - val_target_transportation_loss: 0.2987
# Epoch 79/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6587 - target_childcare_loss: 0.0564 - target_food_loss: 0.0350 - target_healthcare_loss: 0.1147 - target_housing_loss: 0.0986 - target_othernecessities_loss: 0.0437 - target_taxes_loss: 0.0294 - target_transportation_loss: 0.2809 - val_loss: 0.6807 - val_target_childcare_loss: 0.0588 - val_target_food_loss: 0.0322 - val_target_healthcare_loss: 0.1164 - val_target_housing_loss: 0.0975 - val_target_othernecessities_loss: 0.0435 - val_target_taxes_loss: 0.0306 - val_target_transportation_loss: 0.3025
# Epoch 80/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6472 - target_childcare_loss: 0.0580 - target_food_loss: 0.0354 - target_healthcare_loss: 0.1156 - target_housing_loss: 0.0925 - target_othernecessities_loss: 0.0407 - target_taxes_loss: 0.0286 - target_transportation_loss: 0.2764 - val_loss: 0.6729 - val_target_childcare_loss: 0.0579 - val_target_food_loss: 0.0311 - val_target_healthcare_loss: 0.1112 - val_target_housing_loss: 0.0962 - val_target_othernecessities_loss: 0.0434 - val_target_taxes_loss: 0.0308 - val_target_transportation_loss: 0.3027
# Epoch 81/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.
400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6241 - target_childcare_loss: 0.0551 - target_food_loss: 0.0324 - target_healthcare_loss: 0.1098 - target_housing_loss: 0.0908 - target_othernecessities_loss: 0.0394 - target_taxes_loss: 0.0280 - target_transportation_loss: 0.2686 - val_loss: 0.6411 - val_target_childcare_loss: 0.0542 - val_target_food_loss: 0.0412 - val_target_healthcare_loss: 0.1119 - val_target_housing_loss: 0.0919 - val_target_othernecessities_loss: 0.0396 - val_target_taxes_loss: 0.0300 - val_target_transportation_loss: 0.2723
# Epoch 138/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.6196 - target_childcare_loss: 0.0560 - target_food_loss: 0.0334 - target_healthcare_loss: 0.1064 - target_housing_loss: 0.0901 - target_othernecessities_loss: 0.0389 - target_taxes_loss: 0.0269 - target_transportation_loss: 0.2677 - val_loss: 0.6465 - val_target_childcare_loss: 0.0551 - val_target_food_loss: 0.0430 - val_target_healthcare_loss: 0.1140 - val_target_housing_loss: 0.0934 - val_target_othernecessities_loss: 0.0406 - val_target_taxes_loss: 0.0306 - val_target_transportation_loss: 0.2703
# Epoch 139/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6204 - target_childcare_loss: 0.0557 - target_food_loss: 0.0323 - target_healthcare_loss: 0.1082 - target_housing_loss: 0.0891 - target_othernecessities_loss: 0.0395 - target_taxes_loss: 0.0276 - target_transportation_loss: 0.2681 - val_loss: 0.6433 - val_target_childcare_loss: 0.0545 - val_target_food_loss: 0.0412 - val_target_healthcare_loss: 0.1133 - val_target_housing_loss: 0.0937 - val_target_othernecessities_loss: 0.0404 - val_target_taxes_loss: 0.0321 - val_target_transportation_loss: 0.2699
# Epoch 140/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.6139 - target_childcare_loss: 0.0544 - target_food_loss: 0.0314 - target_healthcare_loss: 0.1068 - target_housing_loss: 0.0897 - target_othernecessities_loss: 0.0388 - target_taxes_loss: 0.0273 - target_transportation_loss: 0.2656 - val_loss: 0.6470 - val_target_childcare_loss: 0.0542 - val_target_food_loss: 0.0412 - val_target_healthcare_loss: 0.1146 - val_target_housing_loss: 0.0942 - val_target_othernecessities_loss: 0.0405 - val_target_taxes_loss: 0.0318 - val_target_transportation_loss: 0.2719
# Epoch 141/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.6227 - target_childcare_loss: 0.0543 - target_food_loss: 0.0317 - target_healthcare_loss: 0.1105 - target_housing_loss: 0.0916 - target_othernecessities_loss: 0.0397 - target_taxes_loss: 0.0275 - target_transportation_loss: 0.2673 - val_loss: 0.6490 - val_target_childcare_loss: 0.0536 - val_target_food_loss: 0.0420 - val_target_healthcare_loss: 0.1140 - val_target_housing_loss: 0.0960 - val_target_othernecessities_loss: 0.0405 - val_target_taxes_loss: 0.0303 - val_target_transportation_loss: 0.2739
# Epoch 142/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6285 - target_childcare_loss: 0.0553 - target_food_loss: 0.0328 - target_healthcare_loss: 0.1085 - target_housing_loss: 0.0901 - target_othernecessities_loss: 0.0392 - target_taxes_loss: 0.0279 - target_transportation_loss: 0.2749 - val_loss: 0.6464 - val_target_childcare_loss: 0.0541 - val_target_food_loss: 0.0407 - val_target_healthcare_loss: 0.1192 - val_target_housing_loss: 0.0928 - val_target_othernecessities_loss: 0.0400 - val_target_taxes_loss: 0.0304 - val_target_transportation_loss: 0.2706
# Epoch 143/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6228 - target_childcare_loss: 0.0531 - target_food_loss: 0.0329 - target_healthcare_loss: 0.1052 - target_housing_loss: 0.0911 - target_othernecessities_loss: 0.0394 - target_taxes_loss: 0.0275 - target_transportation_loss: 0.2735 - val_loss: 0.6515 - val_target_childcare_loss: 0.0557 - val_target_food_loss: 0.0409 - val_target_healthcare_loss: 0.1166 - val_target_housing_loss: 0.0949 - val_target_othernecessities_loss: 0.0405 - val_target_taxes_loss: 0.0308 - val_target_transportation_loss: 0.2727
# Epoch 144/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6154 - target_childcare_loss: 0.0530 - target_food_loss: 0.0325 - target_healthcare_loss: 0.1057 - target_housing_loss: 0.0895 - target_othernecessities_loss: 0.0388 - target_taxes_loss: 0.0273 - target_transportation_loss: 0.2686 - val_loss: 0.6520 - val_target_childcare_loss: 0.0557 - val_target_food_loss: 0.0408 - val_target_healthcare_loss: 0.1194 - val_target_housing_loss: 0.0954 - val_target_othernecessities_loss: 0.0409 - val_target_taxes_loss: 0.0309 - val_target_transportation_loss: 0.2697
# Epoch 145/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.6131 - target_childcare_loss: 0.0541 - target_food_loss: 0.0324 - target_healthcare_loss: 0.1080 - target_housing_loss: 0.0872 - target_othernecessities_loss: 0.0377 - target_taxes_loss: 0.0273 - target_transportation_loss: 0.2664 - val_loss: 0.6443 - val_target_childcare_loss: 0.0533 - val_target_food_loss: 0.0405 - val_target_healthcare_loss: 0.1141 - val_target_housing_loss: 0.0945 - val_target_othernecessities_loss: 0.0407 - val_target_taxes_loss: 0.0292 - val_target_transportation_loss: 0.2722
# Epoch 146/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.6270 - target_childcare_loss: 0.0538 - target_food_loss: 0.0320 - target_healthcare_loss: 0.1076 - target_housing_loss: 0.0916 - target_othernecessities_loss: 0.0401 - target_taxes_loss: 0.0280 - target_transportation_loss: 0.2739 - val_loss: 0.6562 - val_target_childcare_loss: 0.0538 - val_target_food_loss: 0.0413 - val_target_healthcare_loss: 0.1183 - val_target_housing_loss: 0.0991 - val_target_othernecessities_loss: 0.0421 - val_target_taxes_loss: 0.0323 - val_target_transportation_loss: 0.2721
# Epoch 146: early stopping
# Restoring model weights from the end of the best epoch: 136.
# 786/786 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Model Results for Housing (Fold 5):
# Train Data: MAE: 78.7986, R-Squared: 0.9126, RMSE: 114.4435, MSE: 13097.3164
# Validation Data: MAE: 80.9853, R-Squared: 0.8953, RMSE: 117.6457, MSE: 13840.5025
# Test Data: MAE: 82.21, R-Squared: 0.9015, RMSE: 122.1633, MSE: 14923.8706
#
# Model Results for Food (Fold 5):
# Train Data: MAE: 40.56, R-Squared: 0.9684, RMSE: 60.6479, MSE: 3678.1627
# Validation Data: MAE: 43.9009, R-Squared: 0.9591, RMSE: 68.999, MSE: 4760.8577
# Test Data: MAE: 41.7216, R-Squared: 0.9662, RMSE: 62.6137, MSE: 3920.4771
#
# Model Results for Transportation (Fold 5):
# Train Data: MAE: 91.0862, R-Squared: 0.7365, RMSE: 122.181, MSE: 14928.2083
# Validation Data: MAE: 92.0797, R-Squared: 0.7228, RMSE: 123.0188, MSE: 15133.626
# Test Data: MAE: 93.0837, R-Squared: 0.7238, RMSE: 125.9425, MSE: 15861.5137
#
# Model Results for Healthcare (Fold 5):
# Train Data: MAE: 110.0009, R-Squared: 0.8955, RMSE: 158.9854, MSE: 25276.3552
# Validation Data: MAE: 115.179, R-Squared: 0.8911, RMSE: 164.7287, MSE: 27135.5414
# Test Data: MAE: 112.0395, R-Squared: 0.8841, RMSE: 164.2579, MSE: 26980.6721
#
# Model Results for Othernecessities (Fold 5):
# Train Data: MAE: 31.4385, R-Squared: 0.9618, RMSE: 44.807, MSE: 2007.6641
# Validation Data: MAE: 32.4672, R-Squared: 0.9564, RMSE: 46.0982, MSE: 2125.0414
# Test Data: MAE: 32.3892, R-Squared: 0.957, RMSE: 47.6281, MSE: 2268.4366
#
# Model Results for Childcare (Fold 5):
# Train Data: MAE: 98.3737, R-Squared: 0.9462, RMSE: 145.9895, MSE: 21312.9358
# Validation Data: MAE: 99.5094, R-Squared: 0.9414, RMSE: 146.0148, MSE: 21320.3301
# Test Data: MAE: 99.111, R-Squared: 0.9425, RMSE: 149.4054, MSE: 22321.9638
#
# Model Results for Taxes (Fold 5):
# Train Data: MAE: 43.88, R-Squared: 0.9735, RMSE: 66.924, MSE: 4478.8158
# Validation Data: MAE: 46.1318, R-Squared: 0.9654, RMSE: 71.9145, MSE: 5171.6986
# Test Data: MAE: 44.2576, R-Squared: 0.9722, RMSE: 68.7877, MSE: 4731.7439
#
# Final Average Metrics After 5 Folds:
# Results for Housing:
# Average Train Metrics: {'MAE': 78.00814, 'R-Squared': 0.91324, 'RMSE': 113.38381999999999, 'MSE': 12863.56892}
# Average Validation Metrics: {'MAE': 81.0102, 'R-Squared': 0.9022, 'RMSE': 118.23710000000001, 'MSE': 13982.2443}
# Average Test Metrics: {'MAE': 82.18824, 'R-Squared': 0.9039999999999999, 'RMSE': 121.06726, 'MSE': 14661.945919999998}
#
# Results for Food:
# Average Train Metrics: {'MAE': 42.173379999999995, 'R-Squared': 0.96738, 'RMSE': 61.609680000000004, 'MSE': 3797.0209999999997}
# Average Validation Metrics: {'MAE': 43.553399999999996, 'R-Squared': 0.9654399999999999, 'RMSE': 63.576620000000005, 'MSE': 4054.59936}
# Average Test Metrics: {'MAE': 43.02802, 'R-Squared': 0.9647, 'RMSE': 63.816359999999996, 'MSE': 4080.4515400000005}
#
# Results for Transportation:
# Average Train Metrics: {'MAE': 90.71950000000001, 'R-Squared': 0.73754, 'RMSE': 121.78262, 'MSE': 14833.95148}
# Average Validation Metrics: {'MAE': 93.94986, 'R-Squared': 0.7176600000000001, 'RMSE': 126.4444, 'MSE': 15997.355379999999}
# Average Test Metrics: {'MAE': 94.72788, 'R-Squared': 0.71038, 'RMSE': 127.75539999999998, 'MSE': 16324.995420000001}
#
# Results for Healthcare:
# Average Train Metrics: {'MAE': 110.80604000000001, 'R-Squared': 0.8936399999999999, 'RMSE': 160.29702000000003, 'MSE': 25706.729960000004}
# Average Validation Metrics: {'MAE': 114.43422000000001, 'R-Squared': 0.8864599999999999, 'RMSE': 166.73311999999999, 'MSE': 27805.59214}
# Average Test Metrics: {'MAE': 116.11558, 'R-Squared': 0.8810399999999999, 'RMSE': 168.41338000000002, 'MSE': 28375.164}
#
# Results for Othernecessities:
# Average Train Metrics: {'MAE': 31.396620000000002, 'R-Squared': 0.962, 'RMSE': 44.52554, 'MSE': 1983.79728}
# Average Validation Metrics: {'MAE': 32.72622, 'R-Squared': 0.9575800000000001, 'RMSE': 46.83588, 'MSE': 2194.00318}
# Average Test Metrics: {'MAE': 32.8943, 'R-Squared': 0.95802, 'RMSE': 46.98234, 'MSE': 2207.9171199999996}
#
# Results for Childcare:
# Average Train Metrics: {'MAE': 96.67564, 'R-Squared': 0.9469, 'RMSE': 144.23944, 'MSE': 20812.259360000004}
# Average Validation Metrics: {'MAE': 99.81161999999999, 'R-Squared': 0.9422200000000001, 'RMSE': 149.81866, 'MSE': 22458.05442}
# Average Test Metrics: {'MAE': 100.64218, 'R-Squared': 0.9423600000000001, 'RMSE': 150.8606, 'MSE': 22765.51308}
#
# Results for Taxes:
# Average Train Metrics: {'MAE': 45.123020000000004, 'R-Squared': 0.9722200000000001, 'RMSE': 68.1199, 'MSE': 4643.88728}
# Average Validation Metrics: {'MAE': 47.23896, 'R-Squared': 0.9686400000000001, 'RMSE': 71.61246000000001, 'MSE': 5132.90732}
# Average Test Metrics: {'MAE': 45.51208, 'R-Squared': 0.9717600000000001, 'RMSE': 69.26816000000001, 'MSE': 4800.986040000001}

# %%
def get_prediction(model, input_data):
    input_data_val = input_data.values
    input_data_val_scaled = scaler_X.fit_transform(input_data_val)
    input_data_val_scaled = input_data_val_scaled[..., np.newaxis]
    input_data_pred = np.column_stack(model.predict(input_data_val_scaled))
    input_data_pred_original = scaler_y.inverse_transform(input_data_pred)
    return input_data_pred_original

# %%
import pandas as pd
import numpy as np

input_data = pd.DataFrame(
    [[7000, 40000, 50, 2, 0, 1]],
    columns=['total', 'median_family_income', 'num_counties_in_st', 'n_children', 'n_parents', 'n_members']
)

input_data["per_member_cost"] = input_data["total"] / input_data["n_members"]
input_data["child_expense_cost"] = input_data["per_member_cost"] * input_data["n_children"]
input_data["parent_expense_cost"] = input_data["per_member_cost"] * input_data["n_parents"]
input_data["other_expense_cost"] = input_data["total"] - (input_data["child_expense_cost"] + input_data["parent_expense_cost"])

input_data_pred_original = get_prediction(model, input_data)


# Print predictions with labels
target_col_list = ['housing', 'food', 'transportation', 'healthcare', 'othernecessities', 'childcare', 'taxes']
for i, prediction in enumerate(input_data_pred_original[0]):
    print(f"{target_col_list[i]}: {prediction}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# housing: 1050.640380859375
# food: 872.3759765625
# transportation: 1549.3123779296875
# healthcare: 1333.8138427734375
# othernecessities: 682.7656860351562
# childcare: 1095.3363037109375
# taxes: 1030.017822265625
